# %% [markdown]
# **Scheduling Problem**

# %% [markdown]
# Random Space Time Network Instance_F

# %% [markdown]
# **Step 01 Generating a Space Time Network**

# %%
# Load required libraries
import json  # Used to read and parse JSON files
import matplotlib.pyplot as plt  # Used for plotting the space-time network
import re  # Used for natural sorting of station names like Station1, Station2, Station10
import time  # Used to measure computation time
import matplotlib.ticker as ticker  # (Optional) used for custom formatting of x-axis ticks

# Start the timer to measure total computation time
start_time = time.time()

# Open and load the JSON file containing the instance data for stations, trips, and empty runs
with open("Instance_F.json") as f:
    data = json.load(f)

# Define a helper function that creates a sorting key for natural sorting (e.g., Station2 before Station10)
def natural_key(s):
    return [int(text) if text.isdigit() else text for text in re.split('(\d+)', s)]

# Extract and sort all station names using natural sorting
stations = sorted([s["Name"] for s in data["StationList"]], key=natural_key)

# Create a dictionary mapping each station name to a corresponding y-axis index (0, 1, ..., 33)
station_to_y = {name: i for i, name in enumerate(stations)}

# Sort all trips based on their start times
trips = sorted(data["TripList"], key=lambda x: x["StartTime"])

# Extract the empty run data which contains light travel durations between station pairs
empty_runs = data["EmptyRunData"]

# Initialize lists to store different types of arcs (edges) and special nodes
train_arcs = []          # Arcs representing productive trips (trains with passengers)
light_arcs_arrival = []  # Arcs representing light vehicle travel after completing a trip
light_arcs_source = []   # Arcs representing vehicle repositioning from source to first trip
ground_arcs = []         # Arcs representing idle waiting time at a station
source_nodes = []        # Artificial source nodes (before each trip)
sink_nodes = []          # Artificial sink nodes (after each trip)
nodes_set = set()        # Set to store all unique (time, station index) pairs (i.e., nodes)

# Step 1: Create artificial source and sink nodes for each trip
for trip in trips:
    source_nodes.append((trip["StartTime"] - 1, station_to_y[trip["Origin"]]))  # source node before trip starts
    sink_nodes.append((trip["EndTime"] + 1, station_to_y[trip["Destination"]]))  # sink node after trip ends

# Step 2: Create productive train arcs
for trip in trips:
    u = (trip["StartTime"], station_to_y[trip["Origin"]])
    v = (trip["EndTime"], station_to_y[trip["Destination"]])
    train_arcs.append((u, v))
    nodes_set.update([u, v])  # store nodes

# Step 3: Create light arcs from trip end to future trip start
for trip_a in trips:
    for trip_b in trips:
        if trip_a["Id"] != trip_b["Id"] and trip_a["EndTime"] < trip_b["StartTime"]:
            key = f"{trip_a['Destination']},{trip_b['Origin']}"
            if trip_a["Destination"] != trip_b["Origin"] and key in empty_runs:
                transfer_time = empty_runs[key]["Duration"]
                if trip_a["EndTime"] + transfer_time <= trip_b["StartTime"]:
                    u = (trip_a["EndTime"], station_to_y[trip_a["Destination"]])
                    v = (trip_a["EndTime"] + transfer_time, station_to_y[trip_b["Origin"]])
                    light_arcs_arrival.append((u, v))
                    nodes_set.update([u, v])
                    break

# Step 4: Create light arcs from artificial source to feasible trip origin
for src in source_nodes:
    t0, y0 = src
    for trip in trips:
        key = f"{stations[y0]},{trip['Origin']}"
        if key in empty_runs and t0 < trip["StartTime"]:
            duration = empty_runs[key]["Duration"]
            if t0 + duration <= trip["StartTime"]:
                u = src
                v = (t0 + duration, station_to_y[trip["Origin"]])
                light_arcs_source.append((u, v))
                nodes_set.update([u, v])
                break

# Step 5: Create ground arcs between end of one trip and start of another at same station
for trip_a in trips:
    for trip_b in trips:
        if trip_a["Destination"] == trip_b["Origin"] and trip_b["StartTime"] > trip_a["EndTime"]:
            u = (trip_a["EndTime"], station_to_y[trip_a["Destination"]])
            v = (trip_b["StartTime"], station_to_y[trip_b["Origin"]])
            ground_arcs.append((u, v))
            nodes_set.update([u, v])
            break

# Start plotting the space-time network
plt.figure(figsize=(20, 12))

# Draw productive train arcs (blue)
for u, v in train_arcs:
    plt.plot([u[0], v[0]], [u[1], v[1]], color='blue', linewidth=0.9)

# Draw light arcs after trip end (dashed gray)
for u, v in light_arcs_arrival:
    plt.plot([u[0], v[0]], [u[1], v[1]], color='gray', linestyle='dashed', linewidth=0.8)

# Draw light arcs from source node (dotted dark gray)
for u, v in light_arcs_source:
    plt.plot([u[0], v[0]], [u[1], v[1]], color='darkgray', linestyle='dotted', linewidth=0.8)

# Draw ground arcs (green)
for u, v in ground_arcs:
    plt.plot([u[0], v[0]], [u[1], v[1]], color='green', linestyle='solid', linewidth=0.7)

# Scatter plot all nodes for clarity
for (u, v) in train_arcs + light_arcs_arrival + light_arcs_source + ground_arcs:
    plt.scatter([u[0], v[0]], [u[1], v[1]], s=6, color='black')

# Configure y-axis with station names in top-down order
plt.yticks(range(len(stations)), stations)

# Set labels and title
plt.xlabel("Time (seconds)")
plt.ylabel("Stations (top: Station0)")
plt.title("Space-Time Network - Instance_F")

# Add grid and tighten layout
plt.grid(True, linestyle='--', linewidth=0.3)
plt.tight_layout()

# Show the final plot
plt.show()

# Calculate total edges and computation time
total_edges = len(train_arcs) + len(light_arcs_arrival) + len(light_arcs_source) + len(ground_arcs)
end_time_calc = time.time()

# Print network statistics
print("Network Summary")
print(f"Number of nodes       : {len(nodes_set)}")
print(f"Number of edges       : {total_edges}")
print(f"Computation time (s)  : {round(end_time_calc - start_time, 3)}")
# Out:
# Network Summary
# Number of nodes       : 1528
# Number of edges       : 2511
# Computation time (s)  : 31.928

# %% [markdown]
# **Step 02 Costing Calculation and Vehicles Calculation Using Pulp**

# %% [markdown]
# Pulp Installation for Mixed Integer Program Optimization

# %%
# Install PuLP
# !pip install pulp

# Load libraries
import json, re
import pulp
import pandas as pd

# Load JSON file
with open("Instance_F.json") as f:
    data = json.load(f)

# Cost parameters
C_TU = 1000
C_Light = 0.10

# Parse stations and trips
stations = sorted(
    [s["Name"] for s in data["StationList"]],
    key=lambda s: [int(t) if t.isdigit() else t for t in re.split("(\d+)", s)]
)
station_index = {name: i for i, name in enumerate(stations)}

trips = sorted(data["TripList"], key=lambda x: x["StartTime"])
trip_ids = [trip["Id"] for trip in trips]
trip_map = {trip["Id"]: trip for trip in trips}
empty_runs = data["EmptyRunData"]

# Optimization model
model = pulp.LpProblem("RollingStockCirculationPlanning", pulp.LpMinimize)

x = {trip["Id"]: pulp.LpVariable(f"x_{trip['Id']}", cat="Binary") for trip in trips}
vehicles = {trip["Id"]: pulp.LpVariable(f"veh_{trip['Id']}", cat="Binary") for trip in trips}
z = {}

# Generate light travel arcs
for i, trip_a in enumerate(trips):
    for j, trip_b in enumerate(trips):
        if i != j and trip_a["EndTime"] < trip_b["StartTime"]:
            key = f"{trip_a['Destination']},{trip_b['Origin']}"
            if key in empty_runs:
                ttime = empty_runs[key]["Duration"]
                if trip_a["EndTime"] + ttime <= trip_b["StartTime"]:
                    arc = f"{trip_a['Id']}_{trip_b['Id']}"
                    z[arc] = pulp.LpVariable(f"z_{arc}", cat="Binary")

# Objective
model += (
    pulp.lpSum([vehicles[trip["Id"]] for trip in trips]) * C_TU +
    pulp.lpSum([
        z[arc] *
        empty_runs[f"{trip_map[int(arc.split('_')[0])]['Destination']},{trip_map[int(arc.split('_')[1])]['Origin']}"]["Distance"] *
        C_Light for arc in z
    ])
)

# Constraints
for trip in trips:
    model += x[trip["Id"]] == 1

for trip in trips:
    incoming = [z[arc] for arc in z if int(arc.split('_')[1]) == trip["Id"]]
    model += vehicles[trip["Id"]] + pulp.lpSum(incoming) >= x[trip["Id"]]

for trip in trips:
    outgoing = [z[arc] for arc in z if int(arc.split('_')[0]) == trip["Id"]]
    model += pulp.lpSum(outgoing) <= 1

# Solve
model.solve(pulp.PULP_CBC_CMD(msg=0))

# Result
num_vehicles = sum(v.varValue for v in vehicles.values())
light_cost = sum(
    z[arc].varValue *
    empty_runs[f"{trip_map[int(arc.split('_')[0])]['Destination']},{trip_map[int(arc.split('_')[1])]['Origin']}"]["Distance"] *
    C_Light for arc in z
)
traction_cost = num_vehicles * C_TU
total_cost = traction_cost + light_cost

# Display
results = {
    "Total Cost": round(total_cost, 2),
    "Traction Unit Cost": round(traction_cost, 2),
    "Light Travel Cost": round(light_cost, 2),
    "Deadheading Cost": 0.00,
    "Number of Vehicles Used": int(num_vehicles)
}
pd.DataFrame([results])
# Out:
# Collecting pulp
#   Downloading pulp-3.2.1-py3-none-any.whl.metadata (6.9 kB)
# Downloading pulp-3.2.1-py3-none-any.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 78.3 MB/s eta 0:00:00
# Installing collected packages: pulp
# Successfully installed pulp-3.2.1
#    Total Cost  Traction Unit Cost  Light Travel Cost  Deadheading Cost  \
# 0    13014.95             13000.0              14.95               0.0
#
#    Number of Vehicles Used
# 0                       13

# %% [markdown]
# **`Schedule Calculator`**

# %%
# STEP 1: Install pulp (for Google Colab; skip if already installed)
# !pip install pulp

# STEP 2: Import required libraries
import json           # For reading the JSON file
import re             # For sorting station names naturally
import pulp           # For defining and solving the optimization model
import pandas as pd   # For creating and displaying schedule tables
from pulp import LpStatus  # For checking the model solution status

# STEP 3: Load data from the JSON file
with open("Instance_F.json") as f:
    data = json.load(f)

# STEP 4: Define cost parameters
C_TU = 1000       # Cost for using a train unit
C_Light = 0.10    # Cost per km for light (empty) travel

# STEP 5: Prepare and sort stations
stations = sorted(
    [s["Name"] for s in data["StationList"]],
    key=lambda s: [int(t) if t.isdigit() else t for t in re.split("(\d+)", s)]
)
station_index = {name: i for i, name in enumerate(stations)}

# STEP 6: Extract trips and empty run data
trips = sorted(data["TripList"], key=lambda x: x["StartTime"])
trip_map = {trip["Id"]: trip for trip in trips}
empty_runs = data["EmptyRunData"]

# STEP 7: Define the optimization model
model = pulp.LpProblem("RollingStock", pulp.LpMinimize)

# Binary variable for each trip: 1 if performed
x = {trip["Id"]: pulp.LpVariable(f"x_{trip['Id']}", cat="Binary") for trip in trips}

# Binary variable for vehicle usage: 1 if a new train starts with this trip
vehicles = {trip["Id"]: pulp.LpVariable(f"veh_{trip['Id']}", cat="Binary") for trip in trips}

# Binary variables for light connections between trips
z = {}
for i, a in enumerate(trips):
    for j, b in enumerate(trips):
        if i != j and a["EndTime"] < b["StartTime"]:
            key = f"{a['Destination']},{b['Origin']}"
            if key in empty_runs:
                dt = empty_runs[key]["Duration"]
                if a["EndTime"] + dt <= b["StartTime"]:
                    arc = f"{a['Id']}_{b['Id']}"
                    z[arc] = pulp.LpVariable(f"z_{arc}", cat="Binary")

# STEP 8: Define objective function to minimize total cost
model += (
    pulp.lpSum([vehicles[tid] for tid in x]) * C_TU +
    pulp.lpSum([
        z[arc] * empty_runs[
            f"{trip_map[int(arc.split('_')[0])]['Destination']},{trip_map[int(arc.split('_')[1])]['Origin']}"
        ]["Distance"] * C_Light for arc in z
    ])
)

# STEP 9: Add constraints
# Ensure each trip is covered
for trip in trips:
    model += x[trip["Id"]] == 1

# A trip is covered either by a new vehicle or from a previous trip via light travel
for trip in trips:
    incoming = [z[arc] for arc in z if int(arc.split("_")[1]) == trip["Id"]]
    model += vehicles[trip["Id"]] + pulp.lpSum(incoming) >= x[trip["Id"]]

# A trip connects to at most one next trip
for trip in trips:
    outgoing = [z[arc] for arc in z if int(arc.split("_")[0]) == trip["Id"]]
    model += pulp.lpSum(outgoing) <= 1

# STEP 10: Solve the model
model.solve(pulp.PULP_CBC_CMD(msg=0))

# STEP 11: Check if solution is feasible
status = LpStatus[model.status]
print(f"\n🔍 Model Status: {status}")
if status != "Optimal":
    print(" No feasible or optimal solution found.")
else:
    print(" Feasible and optimal solution found.")

# STEP 12: Assign Train IDs
trip_to_train = {}
train_counter = 1
outgoing_map = {int(arc.split('_')[0]): int(arc.split('_')[1]) for arc in z if z[arc].varValue == 1}
visited = set()

for trip in trips:
    tid = trip["Id"]
    if tid not in visited:
        current_train = f"Train_{train_counter}"
        while tid in trip_map:
            visited.add(tid)
            trip_to_train[tid] = current_train
            tid = outgoing_map.get(tid, None)
            if tid is None or tid in visited:
                break
        train_counter += 1

# STEP 13: Build the full trip and light travel schedule
full_schedule = []

# Add train trips
for tid, var in x.items():
    if var.varValue == 1:
        trip = trip_map[tid]
        full_schedule.append({
            "Train": trip_to_train[tid],
            "Type": "Train Trip",
            "From": trip["Origin"],
            "To": trip["Destination"],
            "StartTime": trip["StartTime"],
            "EndTime": trip["EndTime"]
        })

# Add light travel trips
light_travel_cost = 0
for arc, var in z.items():
    if var.varValue == 1:
        from_id, to_id = map(int, arc.split("_"))
        trip_a = trip_map[from_id]
        trip_b = trip_map[to_id]
        key = f"{trip_a['Destination']},{trip_b['Origin']}"
        dur = empty_runs[key]["Duration"]
        dist = empty_runs[key]["Distance"]
        cost = dist * C_Light
        light_travel_cost += cost
        full_schedule.append({
            "Train": trip_to_train[from_id],
            "Type": "Light Travel",
            "From": trip_a["Destination"],
            "To": trip_b["Origin"],
            "StartTime": trip_a["EndTime"],
            "EndTime": trip_a["EndTime"] + dur
        })

# STEP 14: Display the final schedule
full_schedule = sorted(full_schedule, key=lambda x: x["StartTime"])
df_schedule = pd.DataFrame(full_schedule)
print("\n Complete Trip and Light Travel Schedule:")
print(df_schedule.to_string(index=False))

# STEP 15: Print cost breakdown
traction_units = sum([vehicles[tid].varValue for tid in vehicles])
traction_cost = traction_units * C_TU
total_cost = pulp.value(model.objective)

print("\n Cost Breakdown:")
print(f"Total Cost           : {total_cost:.2f}")
print(f"Traction Unit Cost   : {traction_cost:.2f}")
print(f"Light Travel Cost    : {light_travel_cost:.2f}")
print(f"Number of Vehicles   : {int(traction_units)}")
# Out:
# Requirement already satisfied: pulp in /usr/local/lib/python3.11/dist-packages (3.2.1)
#
# 🔍 Model Status: Optimal
#  Feasible and optimal solution found.
#
#  Complete Trip and Light Travel Schedule:
#    Train         Type      From        To  StartTime  EndTime
#  Train_1   Train Trip  Station0  Station1          0      780
#  Train_2   Train Trip  Station2  Station1          0      780
#  Train_3   Train Trip  Station3  Station4          0     1020
#  Train_4   Train Trip  Station5  Station1          0     2760
#  Train_5   Train Trip  Station6  Station1          0     2760
#  Train_6   Train Trip  Station7  Station4          0     4560
#  Train_1 Light Travel  Station1  Station1        780      780
#  Train_2 Light Travel  Station1  Station1        780      780
#  Train_3 Light Travel  Station4  Station4       1020     1020
#  Train_1   Train Trip  Station1  Station4       1320     2940
#  Train_2   Train Trip  Station1  Station4       1320     2940
#  Train_4 Light Travel  Station1  Station1       2760     2760
#  Train_5 Light Travel  Station1  Station1       2760     2760
#  Train_1 Light Travel  Station4  Station4       2940     2940
#  Train_2 Light Travel  Station4  Station4       2940     2940
#  Train_6 Light Travel  Station4  Station4       4560     4560
#  Train_7   Train Trip  Station8  Station9      12840    14220
#  Train_7 Light Travel  Station9  Station9      14220    14220
#  Train_3   Train Trip  Station4 Station10      16020    19140
#  Train_2   Train Trip  Station4 Station10      16020    19140
#  Train_8   Train Trip Station11  Station1      16080    16980
#  Train_4   Train Trip  Station1 Station11      16260    17160
#  Train_5   Train Trip  Station1 Station11      16260    17160
#  Train_9   Train Trip  Station4 Station12      16320    18120
# Train_10   Train Trip  Station4 Station12      16320    18120
# Train_11   Train Trip Station13 Station14      16380    25860
#  Train_1   Train Trip  Station4 Station11      16800    18960
#  Train_6   Train Trip  Station4 Station11      16800    18960
#  Train_8 Light Travel  Station1  Station1      16980    16980
#  Train_7   Train Trip  Station9 Station15      17160    20820
#  Train_4 Light Travel Station11 Station11      17160    17160
#  Train_5 Light Travel Station11 Station11      17160    17160
#  Train_5   Train Trip Station11 Station13      17880    26280
#  Train_4   Train Trip Station11 Station13      17880    26280
# Train_12   Train Trip  Station4 Station14      17940    22260
#  Train_8   Train Trip  Station1  Station4      18000    19560
#  Train_9 Light Travel Station12 Station12      18120    18120
# Train_10 Light Travel Station12 Station12      18120    18120
#  Train_1 Light Travel Station11 Station11      18960    18960
#  Train_6 Light Travel Station11 Station11      18960    18960
#  Train_3 Light Travel Station10 Station10      19140    19140
#  Train_2 Light Travel Station10 Station10      19140    19140
#  Train_8 Light Travel  Station4  Station4      19560    19560
#  Train_1   Train Trip Station11 Station13      19680    27900
#  Train_6   Train Trip Station11 Station13      19680    27900
# Train_13   Train Trip  Station4 Station16      19800    21900
#  Train_8   Train Trip  Station4 Station16      19800    21900
#  Train_3   Train Trip Station10 Station16      20580    25500
#  Train_2   Train Trip Station10 Station16      20580    25500
#  Train_7 Light Travel Station15 Station15      20820    20820
# Train_10   Train Trip Station12 Station17      21420    24720
#  Train_9   Train Trip Station12 Station17      21420    24720
# Train_13 Light Travel Station16 Station16      21900    21900
#  Train_8 Light Travel Station16 Station16      21900    21900
# Train_13   Train Trip Station16 Station10      22260    27540
#  Train_8   Train Trip Station16 Station10      22260    27540
# Train_12 Light Travel Station14 Station14      22260    22260
# Train_12   Train Trip Station14  Station1      24480    26640
# Train_10 Light Travel Station17 Station17      24720    24720
#  Train_9 Light Travel Station17 Station17      24720    24720
#  Train_9   Train Trip Station17 Station18      24900    25320
# Train_10   Train Trip Station17 Station18      24900    25320
#  Train_9 Light Travel Station18 Station18      25320    25320
# Train_10 Light Travel Station18 Station18      25320    25320
#  Train_3 Light Travel Station16 Station16      25500    25500
#  Train_2 Light Travel Station16 Station16      25500    25500
#  Train_3   Train Trip Station16 Station10      25860    31140
#  Train_2   Train Trip Station16 Station10      25860    31140
# Train_11 Light Travel Station14 Station14      25860    25860
#  Train_5 Light Travel Station13 Station13      26280    26280
#  Train_4 Light Travel Station13 Station13      26280    26280
# Train_12 Light Travel  Station1  Station1      26640    26640
# Train_12   Train Trip  Station1 Station14      27060    29460
# Train_13 Light Travel Station10 Station10      27540    27540
#  Train_8 Light Travel Station10 Station10      27540    27540
#  Train_1 Light Travel Station13 Station13      27900    27900
#  Train_6 Light Travel Station13 Station13      27900    27900
# Train_11   Train Trip Station14  Station1      28080    30360
#  Train_6   Train Trip Station13  Station1      28080    34980
#  Train_1   Train Trip Station13  Station1      28080    34980
# Train_13   Train Trip Station10 Station13      28140    37080
#  Train_8   Train Trip Station10 Station13      28140    37080
# Train_12 Light Travel Station14 Station14      29460    29460
#  Train_4   Train Trip Station13 Station10      29640    38340
#  Train_5   Train Trip Station13 Station10      29640    38340
# Train_11 Light Travel  Station1  Station1      30360    30360
#  Train_3 Light Travel Station10 Station10      31140    31140
#  Train_2 Light Travel Station10 Station10      31140    31140
# Train_12   Train Trip Station14 Station19      31680    32100
#  Train_2   Train Trip Station10 Station13      31740    40680
#  Train_3   Train Trip Station10 Station13      31740    40680
# Train_12 Light Travel Station19 Station19      32100    32100
#  Train_6 Light Travel  Station1  Station1      34980    34980
#  Train_1 Light Travel  Station1  Station1      34980    34980
# Train_13 Light Travel Station13 Station13      37080    37080
#  Train_8 Light Travel Station13 Station13      37080    37080
#  Train_4 Light Travel Station10 Station10      38340    38340
#  Train_5 Light Travel Station10 Station10      38340    38340
# Train_13   Train Trip Station13 Station11      38460    46800
#  Train_8   Train Trip Station13 Station11      38460    46800
#  Train_1   Train Trip  Station1 Station20      38640    45000
# Train_11   Train Trip  Station1 Station20      38640    45000
#  Train_5   Train Trip Station10 Station13      38940    47880
#  Train_4   Train Trip Station10 Station13      38940    47880
#  Train_2 Light Travel Station13 Station13      40680    40680
#  Train_3 Light Travel Station13 Station13      40680    40680
#  Train_3   Train Trip Station13 Station11      42060    50400
#  Train_2   Train Trip Station13 Station11      42060    50400
#  Train_1 Light Travel Station20 Station20      45000    45000
# Train_11 Light Travel Station20 Station20      45000    45000
# Train_13 Light Travel Station11 Station11      46800    46800
#  Train_8 Light Travel Station11 Station11      46800    46800
#  Train_5 Light Travel Station13 Station13      47880    47880
#  Train_4 Light Travel Station13 Station13      47880    47880
# Train_13   Train Trip Station11 Station20      48480    55800
#  Train_8   Train Trip Station11 Station20      48480    55800
#  Train_1   Train Trip Station20 Station10      48480    56340
# Train_11   Train Trip Station20 Station10      48480    56340
#  Train_4   Train Trip Station13 Station11      49260    57600
#  Train_5   Train Trip Station13 Station11      49260    57600
#  Train_3 Light Travel Station11 Station11      50400    50400
#  Train_2 Light Travel Station11 Station11      50400    50400
#  Train_2   Train Trip Station11 Station20      52080    59400
#  Train_3   Train Trip Station11 Station20      52080    59400
# Train_13 Light Travel Station20 Station20      55800    55800
#  Train_8 Light Travel Station20 Station20      55800    55800
#  Train_1 Light Travel Station10 Station10      56340    56340
# Train_11 Light Travel Station10 Station10      56340    56340
# Train_11   Train Trip Station10 Station13      56940    65880
#  Train_1   Train Trip Station10 Station13      56940    65880
#  Train_4 Light Travel Station11 Station11      57600    57600
#  Train_5 Light Travel Station11 Station11      57600    57600
# Train_12   Train Trip Station19 Station14      57660    58140
# Train_12 Light Travel Station14 Station14      58140    58140
#  Train_7   Train Trip Station15  Station9      58500    62040
# Train_13   Train Trip Station20 Station10      59280    67140
#  Train_8   Train Trip Station20 Station10      59280    67140
#  Train_5   Train Trip Station11 Station13      59280    67500
#  Train_4   Train Trip Station11 Station13      59280    67500
#  Train_2 Light Travel Station20 Station20      59400    59400
#  Train_3 Light Travel Station20 Station20      59400    59400
#  Train_6   Train Trip  Station1 Station14      59460    61980
# Train_12   Train Trip Station14  Station1      60480    62760
# Train_10   Train Trip Station18 Station21      61140    63780
#  Train_9   Train Trip Station18 Station21      61140    63780
#  Train_6 Light Travel Station14 Station14      61980    61980
#  Train_7 Light Travel  Station9  Station9      62040    62040
# Train_12 Light Travel  Station1  Station1      62760    62760
#  Train_2   Train Trip Station20 Station10      62880    70740
#  Train_3   Train Trip Station20 Station10      62880    70740
# Train_12   Train Trip  Station1 Station14      63060    65580
#  Train_7   Train Trip  Station9  Station8      63180    64620
# Train_10 Light Travel Station21  Station4      63780    63900
#  Train_9 Light Travel Station21  Station4      63780    63900
#  Train_6   Train Trip Station14  Station1      64080    66360
#  Train_7 Light Travel  Station8  Station8      64620    64620
# Train_12 Light Travel Station14 Station14      65580    65580
# Train_11 Light Travel Station13 Station13      65880    65880
#  Train_1 Light Travel Station13 Station13      65880    65880
#  Train_6 Light Travel  Station1  Station1      66360    66360
# Train_13 Light Travel Station10 Station10      67140    67140
#  Train_8 Light Travel Station10 Station10      67140    67140
#  Train_1   Train Trip Station13 Station11      67260    75600
# Train_11   Train Trip Station13 Station11      67260    75600
#  Train_5 Light Travel Station13 Station13      67500    67500
#  Train_4 Light Travel Station13 Station13      67500    67500
# Train_12   Train Trip Station14  Station1      67680    69960
#  Train_8   Train Trip Station10 Station13      67740    76680
# Train_13   Train Trip Station10 Station13      67740    76680
# Train_12 Light Travel  Station1  Station1      69960    69960
#  Train_6   Train Trip  Station1 Station21      70680    73200
#  Train_2 Light Travel Station10 Station10      70740    70740
#  Train_3 Light Travel Station10 Station10      70740    70740
#  Train_3   Train Trip Station10 Station13      71340    80280
#  Train_2   Train Trip Station10 Station13      71340    80280
#  Train_6 Light Travel Station21  Station4      73200    73320
#  Train_1 Light Travel Station11 Station11      75600    75600
# Train_11 Light Travel Station11 Station11      75600    75600
#  Train_8 Light Travel Station13 Station13      76680    76680
# Train_13 Light Travel Station13 Station13      76680    76680
# Train_11   Train Trip Station11 Station22      77280    82560
#  Train_1   Train Trip Station11 Station22      77280    82560
#  Train_8   Train Trip Station13  Station4      78060    83760
# Train_13   Train Trip Station13  Station4      78060    83760
#  Train_3 Light Travel Station13 Station13      80280    80280
#  Train_2 Light Travel Station13 Station13      80280    80280
# Train_11 Light Travel Station22 Station22      82560    82560
#  Train_1 Light Travel Station22 Station22      82560    82560
# Train_11   Train Trip Station22  Station1      82980    87180
#  Train_1   Train Trip Station22  Station1      82980    87180
#  Train_3   Train Trip Station13  Station1      83460    89160
#  Train_4   Train Trip Station13  Station1      83460    89160
#  Train_8 Light Travel  Station4  Station4      83760    83760
# Train_13 Light Travel  Station4  Station4      83760    83760
# Train_10   Train Trip  Station4 Station11      83940    86400
#  Train_2   Train Trip Station13  Station4      85380    90960
# Train_12   Train Trip  Station1  Station4      85800    87420
# Train_10 Light Travel Station11 Station11      86400    86400
# Train_11 Light Travel  Station1  Station1      87180    87180
#  Train_1 Light Travel  Station1  Station1      87180    87180
# Train_12 Light Travel  Station4  Station4      87420    87420
#  Train_1   Train Trip  Station1  Station4      87720    89340
# Train_11   Train Trip  Station1  Station4      87720    89340
#  Train_3 Light Travel  Station1  Station1      89160    89160
#  Train_4 Light Travel  Station1  Station1      89160    89160
#  Train_1 Light Travel  Station4  Station4      89340    89340
# Train_11 Light Travel  Station4  Station4      89340    89340
#  Train_2 Light Travel  Station4  Station4      90960    90960
#  Train_7   Train Trip  Station8  Station9      99240   100620
#  Train_7 Light Travel  Station9  Station9     100620   100620
# Train_13   Train Trip  Station4 Station10     102420   105540
#  Train_9   Train Trip  Station4 Station10     102420   105540
# Train_10   Train Trip Station11  Station1     102480   103380
#  Train_4   Train Trip  Station1 Station11     102660   103560
#  Train_3   Train Trip  Station1 Station11     102660   103560
# Train_12   Train Trip  Station4 Station12     102720   104520
#  Train_6   Train Trip  Station4 Station12     102720   104520
#  Train_5   Train Trip Station13 Station14     102780   112260
# Train_11   Train Trip  Station4 Station11     103200   105360
#  Train_2   Train Trip  Station4 Station11     103200   105360
# Train_10 Light Travel  Station1  Station1     103380   103380
#  Train_7   Train Trip  Station9 Station15     103560   107220
#  Train_4 Light Travel Station11 Station11     103560   103560
#  Train_3 Light Travel Station11 Station11     103560   103560
#  Train_3   Train Trip Station11 Station13     104280   112680
#  Train_4   Train Trip Station11 Station13     104280   112680
#  Train_8   Train Trip  Station4 Station14     104340   108660
# Train_10   Train Trip  Station1  Station4     104400   105960
# Train_12 Light Travel Station12 Station12     104520   104520
#  Train_6 Light Travel Station12 Station12     104520   104520
# Train_11 Light Travel Station11 Station11     105360   105360
#  Train_2 Light Travel Station11 Station11     105360   105360
# Train_13 Light Travel Station10 Station10     105540   105540
#  Train_9 Light Travel Station10 Station10     105540   105540
# Train_10 Light Travel  Station4  Station4     105960   105960
#  Train_2   Train Trip Station11 Station13     106080   114300
# Train_11   Train Trip Station11 Station13     106080   114300
#  Train_1   Train Trip  Station4 Station16     106200   108300
# Train_10   Train Trip  Station4 Station16     106200   108300
#  Train_9   Train Trip Station10 Station16     106980   111900
# Train_13   Train Trip Station10 Station16     106980   111900
#  Train_7 Light Travel Station15 Station15     107220   107220
# Train_12   Train Trip Station12 Station17     107820   111120
#  Train_6   Train Trip Station12 Station17     107820   111120
#  Train_1 Light Travel Station16 Station16     108300   108300
# Train_10 Light Travel Station16 Station16     108300   108300
#  Train_1   Train Trip Station16 Station10     108660   113940
# Train_10   Train Trip Station16 Station10     108660   113940
#  Train_8 Light Travel Station14 Station14     108660   108660
#  Train_8   Train Trip Station14  Station1     110880   113040
# Train_12 Light Travel Station17 Station17     111120   111120
#  Train_6 Light Travel Station17 Station17     111120   111120
#  Train_6   Train Trip Station17 Station18     111300   111720
# Train_12   Train Trip Station17 Station18     111300   111720
#  Train_6 Light Travel Station18 Station18     111720   111720
# Train_12 Light Travel Station18 Station18     111720   111720
#  Train_9 Light Travel Station16 Station16     111900   111900
# Train_13 Light Travel Station16 Station16     111900   111900
#  Train_9   Train Trip Station16 Station10     112260   117540
# Train_13   Train Trip Station16 Station10     112260   117540
#  Train_5 Light Travel Station14 Station14     112260   112260
#  Train_3 Light Travel Station13 Station13     112680   112680
#  Train_4 Light Travel Station13 Station13     112680   112680
#  Train_8 Light Travel  Station1  Station1     113040   113040
#  Train_8   Train Trip  Station1 Station14     113460   115860
#  Train_1 Light Travel Station10 Station10     113940   113940
# Train_10 Light Travel Station10 Station10     113940   113940
#  Train_2 Light Travel Station13 Station13     114300   114300
# Train_11 Light Travel Station13 Station13     114300   114300
#  Train_5   Train Trip Station14  Station1     114480   116760
# Train_11   Train Trip Station13  Station1     114480   121380
#  Train_2   Train Trip Station13  Station1     114480   121380
# Train_10   Train Trip Station10 Station13     114540   123480
#  Train_1   Train Trip Station10 Station13     114540   123480
#  Train_8 Light Travel Station14 Station14     115860   115860
#  Train_4   Train Trip Station13 Station10     116040   124740
#  Train_3   Train Trip Station13 Station10     116040   124740
#  Train_5 Light Travel  Station1  Station1     116760   116760
#  Train_9 Light Travel Station10 Station10     117540   117540
# Train_13 Light Travel Station10 Station10     117540   117540
#  Train_8   Train Trip Station14 Station19     118080   118500
# Train_13   Train Trip Station10 Station13     118140   127080
#  Train_9   Train Trip Station10 Station13     118140   127080
#  Train_8 Light Travel Station19 Station19     118500   118500
# Train_11 Light Travel  Station1  Station1     121380   121380
#  Train_2 Light Travel  Station1  Station1     121380   121380
# Train_10 Light Travel Station13 Station13     123480   123480
#  Train_1 Light Travel Station13 Station13     123480   123480
#  Train_4 Light Travel Station10 Station10     124740   124740
#  Train_3 Light Travel Station10 Station10     124740   124740
#  Train_1   Train Trip Station13 Station11     124860   133200
# Train_10   Train Trip Station13 Station11     124860   133200
#  Train_2   Train Trip  Station1 Station20     125040   131400
#  Train_5   Train Trip  Station1 Station20     125040   131400
#  Train_3   Train Trip Station10 Station13     125340   134280
#  Train_4   Train Trip Station10 Station13     125340   134280
# Train_13 Light Travel Station13 Station13     127080   127080
#  Train_9 Light Travel Station13 Station13     127080   127080
#  Train_9   Train Trip Station13 Station11     128460   136800
# Train_13   Train Trip Station13 Station11     128460   136800
#  Train_2 Light Travel Station20 Station20     131400   131400
#  Train_5 Light Travel Station20 Station20     131400   131400
#  Train_1 Light Travel Station11 Station11     133200   133200
# Train_10 Light Travel Station11 Station11     133200   133200
#  Train_3 Light Travel Station13 Station13     134280   134280
#  Train_4 Light Travel Station13 Station13     134280   134280
# Train_10   Train Trip Station11 Station20     134880   142200
#  Train_1   Train Trip Station11 Station20     134880   142200
#  Train_2   Train Trip Station20 Station10     134880   142740
#  Train_5   Train Trip Station20 Station10     134880   142740
#  Train_4   Train Trip Station13 Station11     135660   144000
#  Train_3   Train Trip Station13 Station11     135660   144000
#  Train_9 Light Travel Station11 Station11     136800   136800
# Train_13 Light Travel Station11 Station11     136800   136800
# Train_13   Train Trip Station11 Station20     138480   145800
#  Train_9   Train Trip Station11 Station20     138480   145800
# Train_10 Light Travel Station20 Station20     142200   142200
#  Train_1 Light Travel Station20 Station20     142200   142200
#  Train_2 Light Travel Station10 Station10     142740   142740
#  Train_5 Light Travel Station10 Station10     142740   142740
#  Train_5   Train Trip Station10 Station13     143340   152280
#  Train_2   Train Trip Station10 Station13     143340   152280
#  Train_4 Light Travel Station11 Station11     144000   144000
#  Train_3 Light Travel Station11 Station11     144000   144000
#  Train_8   Train Trip Station19 Station14     144060   144540
#  Train_8 Light Travel Station14 Station14     144540   144540
#  Train_7   Train Trip Station15  Station9     144900   148440
# Train_10   Train Trip Station20 Station10     145680   153540
#  Train_1   Train Trip Station20 Station10     145680   153540
#  Train_3   Train Trip Station11 Station13     145680   153900
#  Train_4   Train Trip Station11 Station13     145680   153900
# Train_13 Light Travel Station20 Station20     145800   145800
#  Train_9 Light Travel Station20 Station20     145800   145800
# Train_11   Train Trip  Station1 Station14     145860   148380
#  Train_8   Train Trip Station14  Station1     146880   149160
#  Train_6   Train Trip Station18 Station21     147540   150180
# Train_12   Train Trip Station18 Station21     147540   150180
# Train_11 Light Travel Station14 Station14     148380   148380
#  Train_7 Light Travel  Station9  Station9     148440   148440
#  Train_8 Light Travel  Station1  Station1     149160   149160
#  Train_9   Train Trip Station20 Station10     149280   157140
# Train_13   Train Trip Station20 Station10     149280   157140
#  Train_8   Train Trip  Station1 Station14     149460   151980
#  Train_7   Train Trip  Station9  Station8     149580   151020
#  Train_6 Light Travel Station21 Station23     150180   151500
# Train_12 Light Travel Station21  Station4     150180   150300
# Train_11   Train Trip Station14  Station1     150480   152760
#  Train_7 Light Travel  Station8  Station8     151020   151020
#  Train_8 Light Travel Station14 Station14     151980   151980
#  Train_5 Light Travel Station13 Station13     152280   152280
#  Train_2 Light Travel Station13 Station13     152280   152280
# Train_11 Light Travel  Station1  Station1     152760   152760
# Train_10 Light Travel Station10 Station10     153540   153540
#  Train_1 Light Travel Station10 Station10     153540   153540
#  Train_2   Train Trip Station13 Station11     153660   162000
#  Train_5   Train Trip Station13 Station11     153660   162000
#  Train_3 Light Travel Station13 Station13     153900   153900
#  Train_4 Light Travel Station13 Station13     153900   153900
#  Train_8   Train Trip Station14  Station1     154080   156360
#  Train_1   Train Trip Station10 Station13     154140   163080
# Train_10   Train Trip Station10 Station13     154140   163080
#  Train_8 Light Travel  Station1  Station1     156360   156360
#  Train_8   Train Trip  Station1 Station21     157080   159600
#  Train_9 Light Travel Station10 Station10     157140   157140
# Train_13 Light Travel Station10 Station10     157140   157140
# Train_13   Train Trip Station10 Station13     157740   166680
#  Train_9   Train Trip Station10 Station13     157740   166680
#  Train_8 Light Travel Station21  Station4     159600   159720
#  Train_2 Light Travel Station11 Station11     162000   162000
#  Train_5 Light Travel Station11 Station11     162000   162000
#  Train_1 Light Travel Station13 Station13     163080   163080
# Train_10 Light Travel Station13 Station13     163080   163080
#  Train_5   Train Trip Station11 Station22     163680   168960
#  Train_2   Train Trip Station11 Station22     163680   168960
# Train_10   Train Trip Station13  Station4     164460   170160
#  Train_1   Train Trip Station13  Station4     164460   170160
# Train_13 Light Travel Station13 Station13     166680   166680
#  Train_9 Light Travel Station13 Station13     166680   166680
#  Train_5 Light Travel Station22 Station22     168960   168960
#  Train_2 Light Travel Station22 Station22     168960   168960
#  Train_5   Train Trip Station22  Station1     169380   173580
#  Train_2   Train Trip Station22  Station1     169380   173580
#  Train_9   Train Trip Station13  Station1     169860   175560
#  Train_3   Train Trip Station13  Station1     169860   175560
# Train_10 Light Travel  Station4  Station4     170160   170160
#  Train_1 Light Travel  Station4  Station4     170160   170160
#  Train_8   Train Trip  Station4 Station11     170340   172800
# Train_13   Train Trip Station13  Station4     171780   177360
# Train_11   Train Trip  Station1  Station4     172200   173820
#  Train_8 Light Travel Station11 Station11     172800   172800
#  Train_5 Light Travel  Station1  Station1     173580   173580
#  Train_2 Light Travel  Station1  Station1     173580   173580
# Train_11 Light Travel  Station4  Station4     173820   173820
#  Train_2   Train Trip  Station1  Station4     174120   175740
#  Train_5   Train Trip  Station1  Station4     174120   175740
#  Train_9 Light Travel  Station1  Station1     175560   175560
#  Train_3 Light Travel  Station1  Station1     175560   175560
#  Train_2 Light Travel  Station4  Station4     175740   175740
#  Train_5 Light Travel  Station4 Station23     175740   176940
#  Train_3   Train Trip  Station1 Station23     176700   180180
#  Train_9   Train Trip  Station1 Station23     176700   180180
# Train_13 Light Travel  Station4  Station4     177360   177360
#  Train_6   Train Trip Station23  Station1     178980   182400
#  Train_5   Train Trip Station23  Station1     178980   182400
#  Train_3 Light Travel Station23  Station4     180180   181380
#  Train_9 Light Travel Station23  Station4     180180   181380
#  Train_6 Light Travel  Station1  Station1     182400   182400
#  Train_5 Light Travel  Station1  Station1     182400   182400
#  Train_7   Train Trip  Station8  Station9     185640   187020
#  Train_7 Light Travel  Station9  Station9     187020   187020
#  Train_3   Train Trip  Station4 Station10     188820   191940
# Train_10   Train Trip  Station4 Station10     188820   191940
#  Train_8   Train Trip Station11  Station1     188880   189780
#  Train_5   Train Trip  Station1 Station11     189060   189960
#  Train_6   Train Trip  Station1 Station11     189060   189960
# Train_13   Train Trip  Station4 Station12     189120   190920
# Train_11   Train Trip  Station4 Station12     189120   190920
#  Train_4   Train Trip Station13 Station14     189180   198660
#  Train_9   Train Trip  Station4 Station11     189600   191760
#  Train_1   Train Trip  Station4 Station11     189600   191760
#  Train_8 Light Travel  Station1  Station1     189780   189780
#  Train_7   Train Trip  Station9 Station15     189960   193620
#  Train_5 Light Travel Station11 Station11     189960   189960
#  Train_6 Light Travel Station11 Station11     189960   189960
#  Train_6   Train Trip Station11 Station13     190680   199080
#  Train_5   Train Trip Station11 Station13     190680   199080
# Train_12   Train Trip  Station4 Station14     190740   195060
#  Train_8   Train Trip  Station1  Station4     190800   192360
# Train_13 Light Travel Station12 Station12     190920   190920
# Train_11 Light Travel Station12 Station12     190920   190920
#  Train_9 Light Travel Station11 Station11     191760   191760
#  Train_1 Light Travel Station11 Station11     191760   191760
#  Train_3 Light Travel Station10 Station10     191940   191940
# Train_10 Light Travel Station10 Station10     191940   191940
#  Train_8 Light Travel  Station4  Station4     192360   192360
#  Train_1   Train Trip Station11 Station13     192480   200700
#  Train_9   Train Trip Station11 Station13     192480   200700
#  Train_8   Train Trip  Station4 Station16     192600   194700
#  Train_2   Train Trip  Station4 Station16     192600   194700
# Train_10   Train Trip Station10 Station16     193380   198300
#  Train_3   Train Trip Station10 Station16     193380   198300
#  Train_7 Light Travel Station15 Station15     193620   193620
# Train_13   Train Trip Station12 Station17     194220   197520
# Train_11   Train Trip Station12 Station17     194220   197520
#  Train_8 Light Travel Station16 Station16     194700   194700
#  Train_2 Light Travel Station16 Station16     194700   194700
#  Train_8   Train Trip Station16 Station10     195060   200340
#  Train_2   Train Trip Station16 Station10     195060   200340
# Train_12 Light Travel Station14 Station14     195060   195060
# Train_12   Train Trip Station14  Station1     197280   199440
# Train_13 Light Travel Station17 Station17     197520   197520
# Train_11 Light Travel Station17 Station17     197520   197520
# Train_13   Train Trip Station17 Station18     197700   198120
# Train_11   Train Trip Station17 Station18     197700   198120
# Train_13 Light Travel Station18 Station18     198120   198120
# Train_11 Light Travel Station18 Station18     198120   198120
# Train_10 Light Travel Station16 Station16     198300   198300
#  Train_3 Light Travel Station16 Station16     198300   198300
# Train_10   Train Trip Station16 Station10     198660   203940
#  Train_3   Train Trip Station16 Station10     198660   203940
#  Train_4 Light Travel Station14 Station14     198660   198660
#  Train_6 Light Travel Station13 Station13     199080   199080
#  Train_5 Light Travel Station13 Station13     199080   199080
# Train_12 Light Travel  Station1  Station1     199440   199440
# Train_12   Train Trip  Station1 Station14     199860   202260
#  Train_8 Light Travel Station10 Station10     200340   200340
#  Train_2 Light Travel Station10 Station10     200340   200340
#  Train_1 Light Travel Station13 Station13     200700   200700
#  Train_9 Light Travel Station13 Station13     200700   200700
#  Train_4   Train Trip Station14  Station1     200880   203160
#  Train_9   Train Trip Station13  Station1     200880   207780
#  Train_1   Train Trip Station13  Station1     200880   207780
#  Train_2   Train Trip Station10 Station13     200940   209880
#  Train_8   Train Trip Station10 Station13     200940   209880
# Train_12 Light Travel Station14 Station14     202260   202260
#  Train_5   Train Trip Station13 Station10     202440   211140
#  Train_6   Train Trip Station13 Station10     202440   211140
#  Train_4 Light Travel  Station1  Station1     203160   203160
# Train_10 Light Travel Station10 Station10     203940   203940
#  Train_3 Light Travel Station10 Station10     203940   203940
# Train_12   Train Trip Station14 Station19     204480   204900
#  Train_3   Train Trip Station10 Station13     204540   213480
# Train_10   Train Trip Station10 Station13     204540   213480
# Train_12 Light Travel Station19 Station19     204900   204900
#  Train_9 Light Travel  Station1  Station1     207780   207780
#  Train_1 Light Travel  Station1  Station1     207780   207780
#  Train_2 Light Travel Station13 Station13     209880   209880
#  Train_8 Light Travel Station13 Station13     209880   209880
#  Train_5 Light Travel Station10 Station10     211140   211140
#  Train_6 Light Travel Station10 Station10     211140   211140
#  Train_8   Train Trip Station13 Station11     211260   219600
#  Train_2   Train Trip Station13 Station11     211260   219600
#  Train_1   Train Trip  Station1 Station20     211440   217800
#  Train_4   Train Trip  Station1 Station20     211440   217800
#  Train_6   Train Trip Station10 Station13     211740   220680
#  Train_5   Train Trip Station10 Station13     211740   220680
#  Train_3 Light Travel Station13 Station13     213480   213480
# Train_10 Light Travel Station13 Station13     213480   213480
# Train_10   Train Trip Station13 Station11     214860   223200
#  Train_3   Train Trip Station13 Station11     214860   223200
#  Train_1 Light Travel Station20 Station20     217800   217800
#  Train_4 Light Travel Station20 Station20     217800   217800
#  Train_8 Light Travel Station11 Station11     219600   219600
#  Train_2 Light Travel Station11 Station11     219600   219600
#  Train_6 Light Travel Station13 Station13     220680   220680
#  Train_5 Light Travel Station13 Station13     220680   220680
#  Train_2   Train Trip Station11 Station20     221280   228600
#  Train_8   Train Trip Station11 Station20     221280   228600
#  Train_1   Train Trip Station20 Station10     221280   229140
#  Train_4   Train Trip Station20 Station10     221280   229140
#  Train_5   Train Trip Station13 Station11     222060   230400
#  Train_6   Train Trip Station13 Station11     222060   230400
# Train_10 Light Travel Station11 Station11     223200   223200
#  Train_3 Light Travel Station11 Station11     223200   223200
#  Train_3   Train Trip Station11 Station20     224880   232200
# Train_10   Train Trip Station11 Station20     224880   232200
#  Train_2 Light Travel Station20 Station20     228600   228600
#  Train_8 Light Travel Station20 Station20     228600   228600
#  Train_1 Light Travel Station10 Station10     229140   229140
#  Train_4 Light Travel Station10 Station10     229140   229140
#  Train_4   Train Trip Station10 Station13     229740   238680
#  Train_1   Train Trip Station10 Station13     229740   238680
#  Train_5 Light Travel Station11 Station11     230400   230400
#  Train_6 Light Travel Station11 Station11     230400   230400
# Train_12   Train Trip Station19 Station14     230460   230940
# Train_12 Light Travel Station14 Station14     230940   230940
#  Train_7   Train Trip Station15  Station9     231300   234840
#  Train_2   Train Trip Station20 Station10     232080   239940
#  Train_8   Train Trip Station20 Station10     232080   239940
#  Train_6   Train Trip Station11 Station13     232080   240300
#  Train_5   Train Trip Station11 Station13     232080   240300
#  Train_3 Light Travel Station20 Station20     232200   232200
# Train_10 Light Travel Station20 Station20     232200   232200
#  Train_9   Train Trip  Station1 Station14     232260   234780
# Train_12   Train Trip Station14  Station1     233280   235560
# Train_13   Train Trip Station18 Station21     233940   236580
# Train_11   Train Trip Station18 Station21     233940   236580
#  Train_9 Light Travel Station14 Station14     234780   234780
#  Train_7 Light Travel  Station9  Station9     234840   234840
# Train_12 Light Travel  Station1  Station1     235560   235560
#  Train_3   Train Trip Station20 Station10     235680   243540
# Train_10   Train Trip Station20 Station10     235680   243540
# Train_12   Train Trip  Station1 Station14     235860   238380
#  Train_7   Train Trip  Station9 Station21     235980   241560
# Train_13 Light Travel Station21  Station4     236580   236700
# Train_11 Light Travel Station21 Station23     236580   237900
#  Train_9   Train Trip Station14  Station1     236880   239160
# Train_12 Light Travel Station14 Station14     238380   238380
#  Train_4 Light Travel Station13 Station13     238680   238680
#  Train_1 Light Travel Station13 Station13     238680   238680
#  Train_9 Light Travel  Station1  Station1     239160   239160
#  Train_2 Light Travel Station10 Station10     239940   239940
#  Train_8 Light Travel Station10 Station10     239940   239940
#  Train_6 Light Travel Station13 Station13     240300   240300
#  Train_5 Light Travel Station13 Station13     240300   240300
# Train_12   Train Trip Station14  Station1     240480   242760
#  Train_8   Train Trip Station10  Station4     240540   243660
#  Train_2   Train Trip Station10  Station4     240540   243660
#  Train_7 Light Travel Station21  Station4     241560   241680
# Train_12 Light Travel  Station1  Station1     242760   242760
# Train_12   Train Trip  Station1 Station21     243480   246000
#  Train_3 Light Travel Station10 Station10     243540   243540
# Train_10 Light Travel Station10 Station10     243540   243540
#  Train_5   Train Trip Station13  Station1     243660   250980
#  Train_6   Train Trip Station13  Station1     243660   250980
#  Train_8 Light Travel  Station4  Station4     243660   243660
#  Train_2 Light Travel  Station4  Station4     243660   243660
#  Train_2   Train Trip  Station4 Station13     243720   249480
# Train_10   Train Trip Station10 Station13     244140   253080
#  Train_3   Train Trip Station10 Station13     244140   253080
# Train_12 Light Travel Station21  Station4     246000   246120
#  Train_2 Light Travel Station13 Station13     249480   249480
#  Train_4   Train Trip Station13 Station11     250860   259200
#  Train_2   Train Trip Station13 Station11     250860   259200
#  Train_5 Light Travel  Station1  Station1     250980   250980
#  Train_6 Light Travel  Station1  Station1     250980   250980
# Train_10 Light Travel Station13 Station13     253080   253080
#  Train_3 Light Travel Station13 Station13     253080   253080
#  Train_3   Train Trip Station13  Station1     254580   261780
#  Train_1   Train Trip Station13  Station1     254580   261780
#  Train_6   Train Trip  Station1 Station22     254640   258960
#  Train_5   Train Trip  Station1 Station22     254640   258960
#  Train_6 Light Travel Station22 Station22     258960   258960
#  Train_5 Light Travel Station22 Station22     258960   258960
#  Train_4 Light Travel Station11 Station11     259200   259200
#  Train_2 Light Travel Station11 Station11     259200   259200
#  Train_6   Train Trip Station22 Station24     259380   262260
#  Train_5   Train Trip Station22 Station24     259380   262260
#  Train_9   Train Trip  Station1  Station4     260040   261660
#  Train_9 Light Travel  Station4  Station4     261660   261660
#  Train_3 Light Travel  Station1  Station1     261780   261780
#  Train_1 Light Travel  Station1  Station1     261780   261780
#  Train_6 Light Travel Station24 Station24     262260   262260
#  Train_5 Light Travel Station24 Station24     262260   262260
#  Train_6   Train Trip Station24 Station23     262620   264780
#  Train_5   Train Trip Station24 Station23     262620   264780
#  Train_6 Light Travel Station23 Station23     264780   264780
#  Train_5 Light Travel Station23 Station23     264780   264780
#  Train_5   Train Trip Station23  Station1     265380   268800
# Train_11   Train Trip Station23 Station24     267180   269340
#  Train_6   Train Trip Station23 Station24     267180   269340
#  Train_5 Light Travel  Station1  Station1     268800   268800
# Train_11 Light Travel Station24 Station24     269340   269340
#  Train_6 Light Travel Station24 Station24     269340   269340
# Train_11   Train Trip Station24 Station23     269820   271980
#  Train_6   Train Trip Station24 Station23     269820   271980
#  Train_1   Train Trip  Station1 Station23     270300   273780
#  Train_3   Train Trip  Station1 Station23     270300   273780
# Train_11 Light Travel Station23 Station23     271980   271980
#  Train_6 Light Travel Station23 Station23     271980   271980
#  Train_6   Train Trip Station23  Station1     272580   276000
# Train_11   Train Trip Station23  Station1     272580   276000
#  Train_1 Light Travel Station23 Station23     273780   273780
#  Train_3 Light Travel Station23 Station23     273780   273780
#  Train_3   Train Trip Station23 Station24     274380   276540
#  Train_1   Train Trip Station23 Station24     274380   276540
#  Train_8   Train Trip  Station4 Station22     274740   277080
#  Train_6 Light Travel  Station1  Station1     276000   276000
# Train_11 Light Travel  Station1  Station1     276000   276000
#  Train_3 Light Travel Station24 Station24     276540   276540
#  Train_1 Light Travel Station24 Station24     276540   276540
#  Train_3   Train Trip Station24 Station21     276900   277920
#  Train_1   Train Trip Station24 Station21     276900   277920
#  Train_8 Light Travel Station22 Station22     277080   277080
#  Train_7   Train Trip  Station4 Station14     277140   281460
#  Train_3 Light Travel Station21  Station4     277920   278040
#  Train_1 Light Travel Station21  Station4     277920   278040
#  Train_6   Train Trip  Station1 Station13     278040   285480
# Train_11   Train Trip  Station1 Station13     278040   285480
#  Train_1   Train Trip  Station4 Station22     278520   281160
#  Train_8   Train Trip Station22  Station4     279420   281940
#  Train_9   Train Trip  Station4 Station17     280620   282120
# Train_12   Train Trip  Station4 Station17     280620   282120
#  Train_1 Light Travel Station22 Station22     281160   281160
#  Train_7 Light Travel Station14 Station14     281460   281460
#  Train_8 Light Travel  Station4  Station4     281940   281940
#  Train_9 Light Travel Station17 Station17     282120   282120
# Train_12 Light Travel Station17 Station17     282120   282120
#  Train_2   Train Trip Station11 Station22     282480   287760
#  Train_4   Train Trip Station11 Station22     282480   287760
#  Train_1   Train Trip Station22  Station4     283020   285540
#  Train_7   Train Trip Station14  Station1     283680   285840
#  Train_9   Train Trip Station17  Station1     283860   286980
# Train_12   Train Trip Station17  Station1     283860   286980
#  Train_6 Light Travel Station13 Station13     285480   285480
# Train_11 Light Travel Station13 Station13     285480   285480
#  Train_1 Light Travel  Station4  Station4     285540   285540
#  Train_7 Light Travel  Station1  Station1     285840   285840
#  Train_7   Train Trip  Station1 Station14     286260   288660
#  Train_9 Light Travel  Station1  Station1     286980   286980
# Train_12 Light Travel  Station1  Station1     286980   286980
# Train_11   Train Trip Station13 Station21     287640   292440
#  Train_6   Train Trip Station13 Station21     287640   292440
#  Train_2 Light Travel Station22 Station22     287760   287760
#  Train_4 Light Travel Station22 Station22     287760   287760
#  Train_2   Train Trip Station22  Station4     288360   290940
#  Train_4   Train Trip Station22  Station4     288360   290940
#  Train_7 Light Travel Station14 Station14     288660   288660
# Train_12   Train Trip  Station1 Station22     290640   294960
#  Train_5   Train Trip  Station1 Station22     290640   294960
#  Train_7   Train Trip Station14 Station19     290880   291300
#  Train_2 Light Travel  Station4  Station4     290940   290940
#  Train_4 Light Travel  Station4  Station4     290940   290940
#  Train_7 Light Travel Station19 Station19     291300   291300
# Train_11 Light Travel Station21  Station4     292440   292560
#  Train_6 Light Travel Station21  Station4     292440   292560
# Train_12 Light Travel Station22 Station22     294960   294960
#  Train_5 Light Travel Station22 Station22     294960   294960
# Train_12   Train Trip Station22 Station10     295380   301140
#  Train_5   Train Trip Station22 Station10     295380   301140
# Train_12 Light Travel Station10 Station10     301140   301140
#  Train_5 Light Travel Station10 Station10     301140   301140
#  Train_5   Train Trip Station10 Station13     301740   310680
# Train_12   Train Trip Station10 Station13     301740   310680
#  Train_5 Light Travel Station13 Station13     310680   310680
# Train_12 Light Travel Station13 Station13     310680   310680
# Train_12   Train Trip Station13  Station1     312060   319380
# Train_10   Train Trip Station13  Station1     312060   319380
#  Train_7   Train Trip Station19 Station14     316860   317340
#  Train_7 Light Travel Station14 Station14     317340   317340
# Train_12 Light Travel  Station1  Station1     319380   319380
# Train_10 Light Travel  Station1  Station1     319380   319380
#  Train_7   Train Trip Station14  Station1     319680   321960
#  Train_7 Light Travel  Station1  Station1     321960   321960
#  Train_7   Train Trip  Station1 Station14     322260   324780
#  Train_9   Train Trip  Station1 Station22     323040   327360
# Train_12   Train Trip  Station1 Station22     323040   327360
#  Train_7 Light Travel Station14 Station14     324780   324780
#  Train_7   Train Trip Station14  Station1     326880   329160
#  Train_9 Light Travel Station22 Station22     327360   327360
# Train_12 Light Travel Station22 Station22     327360   327360
# Train_12   Train Trip Station22 Station10     327780   333540
#  Train_9   Train Trip Station22 Station10     327780   333540
#  Train_7 Light Travel  Station1  Station1     329160   329160
# Train_12 Light Travel Station10 Station10     333540   333540
#  Train_9 Light Travel Station10 Station10     333540   333540
#  Train_9   Train Trip Station10 Station13     334140   343080
# Train_12   Train Trip Station10 Station13     334140   343080
#  Train_7   Train Trip  Station1 Station22     341040   345360
#  Train_9 Light Travel Station13 Station13     343080   343080
# Train_12 Light Travel Station13 Station13     343080   343080
# Train_12   Train Trip Station13  Station1     344580   351780
#  Train_9   Train Trip Station13  Station1     344580   351780
#  Train_7 Light Travel Station22 Station22     345360   345360
#  Train_7   Train Trip Station22 Station24     345780   348660
#  Train_7 Light Travel Station24 Station24     348660   348660
#  Train_7   Train Trip Station24 Station23     349020   351180
#  Train_7 Light Travel Station23 Station23     351180   351180
# Train_12 Light Travel  Station1  Station1     351780   351780
#  Train_9 Light Travel  Station1  Station1     351780   351780
#  Train_9   Train Trip  Station1 Station23     353100   356580
# Train_10   Train Trip  Station1 Station23     353100   356580
#  Train_6   Train Trip  Station4 Station24     355680   355860
#  Train_4   Train Trip  Station4 Station24     355680   355860
#  Train_6 Light Travel Station24 Station24     355860   355860
#  Train_4 Light Travel Station24 Station24     355860   355860
#  Train_6   Train Trip Station24 Station23     356220   358380
#  Train_4   Train Trip Station24 Station23     356220   358380
#  Train_9 Light Travel Station23  Station4     356580   357780
# Train_10 Light Travel Station23 Station23     356580   356580
# Train_12   Train Trip  Station1 Station23     356700   360180
# Train_10   Train Trip Station23 Station24     357180   359340
#  Train_7   Train Trip Station23 Station24     357180   359340
#  Train_6 Light Travel Station23 Station23     358380   358380
#  Train_4 Light Travel Station23 Station23     358380   358380
#  Train_4   Train Trip Station23  Station1     358980   362400
#  Train_6   Train Trip Station23  Station1     358980   362400
# Train_10 Light Travel Station24 Station24     359340   359340
#  Train_7 Light Travel Station24 Station24     359340   359340
# Train_10   Train Trip Station24 Station21     359700   360720
#  Train_7   Train Trip Station24 Station21     359700   360720
# Train_12 Light Travel Station23 Station23     360180   360180
#  Train_2   Train Trip  Station4 Station22     360720   363360
#  Train_1   Train Trip  Station4 Station22     360720   363360
# Train_10 Light Travel Station21  Station4     360720   360840
#  Train_7 Light Travel Station21  Station4     360720   360840
# Train_12   Train Trip Station23 Station24     360780   362940
#  Train_4 Light Travel  Station1  Station1     362400   362400
#  Train_6 Light Travel  Station1  Station1     362400   362400
# Train_12 Light Travel Station24 Station24     362940   362940
# Train_12   Train Trip Station24 Station21     363300   364320
#  Train_2 Light Travel Station22 Station22     363360   363360
#  Train_1 Light Travel Station22 Station22     363360   363360
#  Train_7   Train Trip  Station4 Station17     363420   364920
# Train_10   Train Trip  Station4 Station17     363420   364920
#  Train_9   Train Trip  Station4 Station14     363540   367860
#  Train_1   Train Trip Station22  Station4     363960   366540
#  Train_2   Train Trip Station22  Station4     363960   366540
# Train_12 Light Travel Station21  Station4     364320   364440
#  Train_6   Train Trip  Station1 Station13     364440   371880
#  Train_4   Train Trip  Station1 Station13     364440   371880
#  Train_7 Light Travel Station17 Station17     364920   364920
# Train_10 Light Travel Station17 Station17     364920   364920
# Train_11   Train Trip  Station4 Station17     366540   368040
#  Train_3   Train Trip  Station4 Station17     366540   368040
#  Train_1 Light Travel  Station4  Station4     366540   366540
#  Train_2 Light Travel  Station4  Station4     366540   366540
#  Train_7   Train Trip Station17  Station1     366660   369780
# Train_10   Train Trip Station17  Station1     366660   369780
#  Train_9 Light Travel Station14 Station14     367860   367860
# Train_11 Light Travel Station17 Station17     368040   368040
#  Train_3 Light Travel Station17 Station17     368040   368040
# Train_11   Train Trip Station17 Station10     368460   373140
#  Train_3   Train Trip Station17 Station10     368460   373140
#  Train_7 Light Travel  Station1  Station1     369780   369780
# Train_10 Light Travel  Station1  Station1     369780   369780
#  Train_9   Train Trip Station14  Station1     370080   372240
#  Train_2   Train Trip  Station4 Station17     370140   371640
#  Train_1   Train Trip  Station4 Station17     370140   371640
#  Train_2 Light Travel Station17 Station17     371640   371640
# ...
#  Train_1   Train Trip Station10 Station13     488940   497880
#  Train_8   Train Trip Station10 Station13     488940   497880
#  Train_6 Light Travel Station11 Station11     489600   489600
# Train_10 Light Travel Station11 Station11     489600   489600
#  Train_9   Train Trip Station19 Station14     489660   490140
#  Train_9 Light Travel Station14 Station14     490140   490140
#  Train_4   Train Trip Station15  Station9     490500   494040
#  Train_7   Train Trip Station20 Station10     491280   499140
#  Train_2   Train Trip Station20 Station10     491280   499140
# Train_10   Train Trip Station11 Station13     491280   499500
#  Train_6   Train Trip Station11 Station13     491280   499500
#  Train_3 Light Travel Station20 Station20     491400   491400
# Train_12 Light Travel Station20 Station20     491400   491400
# Train_11   Train Trip  Station1 Station14     491460   493980
#  Train_9   Train Trip Station14  Station1     492480   494760
#  Train_5   Train Trip Station18 Station21     493140   495780
# Train_13   Train Trip Station18 Station21     493140   495780
# Train_11 Light Travel Station14 Station14     493980   493980
#  Train_4 Light Travel  Station9  Station9     494040   494040
#  Train_9 Light Travel  Station1  Station1     494760   494760
# Train_12   Train Trip Station20 Station10     494880   502740
#  Train_3   Train Trip Station20 Station10     494880   502740
#  Train_9   Train Trip  Station1 Station14     495060   497580
#  Train_4   Train Trip  Station9  Station8     495180   496620
#  Train_5 Light Travel Station21  Station4     495780   495900
# Train_13 Light Travel Station21  Station4     495780   495900
# Train_11   Train Trip Station14  Station1     496080   498360
#  Train_4 Light Travel  Station8  Station8     496620   496620
#  Train_9 Light Travel Station14 Station14     497580   497580
#  Train_1 Light Travel Station13 Station13     497880   497880
#  Train_8 Light Travel Station13 Station13     497880   497880
# Train_11 Light Travel  Station1  Station1     498360   498360
#  Train_7 Light Travel Station10 Station10     499140   499140
#  Train_2 Light Travel Station10 Station10     499140   499140
#  Train_8   Train Trip Station13 Station11     499260   507600
#  Train_1   Train Trip Station13 Station11     499260   507600
# Train_10 Light Travel Station13 Station13     499500   499500
#  Train_6 Light Travel Station13 Station13     499500   499500
#  Train_9   Train Trip Station14  Station1     499680   501960
#  Train_2   Train Trip Station10 Station13     499740   508680
#  Train_7   Train Trip Station10 Station13     499740   508680
#  Train_9 Light Travel  Station1  Station1     501960   501960
#  Train_9   Train Trip  Station1 Station21     502680   505200
# Train_12 Light Travel Station10 Station10     502740   502740
#  Train_3 Light Travel Station10 Station10     502740   502740
#  Train_3   Train Trip Station10 Station13     503340   512280
# Train_12   Train Trip Station10 Station13     503340   512280
#  Train_9 Light Travel Station21  Station4     505200   505320
#  Train_8 Light Travel Station11 Station11     507600   507600
#  Train_1 Light Travel Station11 Station11     507600   507600
#  Train_2 Light Travel Station13 Station13     508680   508680
#  Train_7 Light Travel Station13 Station13     508680   508680
#  Train_1   Train Trip Station11 Station22     509280   514560
#  Train_8   Train Trip Station11 Station22     509280   514560
#  Train_2   Train Trip Station13  Station4     510060   515760
# Train_10   Train Trip Station13  Station4     510060   515760
#  Train_3 Light Travel Station13 Station13     512280   512280
# Train_12 Light Travel Station13 Station13     512280   512280
#  Train_1 Light Travel Station22 Station22     514560   514560
#  Train_8 Light Travel Station22 Station22     514560   514560
#  Train_8   Train Trip Station22  Station1     514980   519180
#  Train_1   Train Trip Station22  Station1     514980   519180
# Train_12   Train Trip Station13  Station1     515460   521160
#  Train_6   Train Trip Station13  Station1     515460   521160
#  Train_2 Light Travel  Station4  Station4     515760   515760
# Train_10 Light Travel  Station4  Station4     515760   515760
#  Train_9   Train Trip  Station4 Station11     515940   518400
#  Train_7   Train Trip Station13  Station4     517380   522960
# Train_11   Train Trip  Station1  Station4     517800   519420
#  Train_9 Light Travel Station11 Station11     518400   518400
#  Train_8 Light Travel  Station1  Station1     519180   519180
#  Train_1 Light Travel  Station1  Station1     519180   519180
# Train_11 Light Travel  Station4  Station4     519420   519420
#  Train_1   Train Trip  Station1  Station4     519720   521340
#  Train_8   Train Trip  Station1  Station4     519720   521340
# Train_12 Light Travel  Station1  Station1     521160   521160
#  Train_6 Light Travel  Station1  Station1     521160   521160
#  Train_1 Light Travel  Station4  Station4     521340   521340
#  Train_8 Light Travel  Station4  Station4     521340   521340
#  Train_7 Light Travel  Station4  Station4     522960   522960
#  Train_4   Train Trip  Station8  Station9     531240   532620
#  Train_4 Light Travel  Station9  Station9     532620   532620
#  Train_8   Train Trip  Station4 Station10     534420   537540
#  Train_5   Train Trip  Station4 Station10     534420   537540
#  Train_9   Train Trip Station11  Station1     534480   535380
#  Train_6   Train Trip  Station1 Station11     534660   535560
# Train_12   Train Trip  Station1 Station11     534660   535560
# Train_13   Train Trip  Station4 Station12     534720   536520
#  Train_1   Train Trip  Station4 Station12     534720   536520
#  Train_3   Train Trip Station13 Station14     534780   544260
#  Train_2   Train Trip  Station4 Station11     535200   537360
# Train_11   Train Trip  Station4 Station11     535200   537360
#  Train_9 Light Travel  Station1  Station1     535380   535380
#  Train_4   Train Trip  Station9 Station15     535560   539220
#  Train_6 Light Travel Station11 Station11     535560   535560
# Train_12 Light Travel Station11 Station11     535560   535560
# Train_12   Train Trip Station11 Station13     536280   544680
#  Train_6   Train Trip Station11 Station13     536280   544680
# Train_10   Train Trip  Station4 Station14     536340   540660
#  Train_9   Train Trip  Station1  Station4     536400   537960
# Train_13 Light Travel Station12 Station12     536520   536520
#  Train_1 Light Travel Station12 Station12     536520   536520
#  Train_2 Light Travel Station11 Station11     537360   537360
# Train_11 Light Travel Station11 Station11     537360   537360
#  Train_8 Light Travel Station10 Station10     537540   537540
#  Train_5 Light Travel Station10 Station10     537540   537540
#  Train_9 Light Travel  Station4  Station4     537960   537960
# Train_11   Train Trip Station11 Station13     538080   546300
#  Train_2   Train Trip Station11 Station13     538080   546300
#  Train_9   Train Trip  Station4 Station16     538200   540300
#  Train_7   Train Trip  Station4 Station16     538200   540300
#  Train_5   Train Trip Station10 Station16     538980   543900
#  Train_8   Train Trip Station10 Station16     538980   543900
#  Train_4 Light Travel Station15 Station15     539220   539220
# Train_13   Train Trip Station12 Station17     539820   543120
#  Train_1   Train Trip Station12 Station17     539820   543120
#  Train_9 Light Travel Station16 Station16     540300   540300
#  Train_7 Light Travel Station16 Station16     540300   540300
#  Train_9   Train Trip Station16 Station10     540660   545940
#  Train_7   Train Trip Station16 Station10     540660   545940
# Train_10 Light Travel Station14 Station14     540660   540660
# Train_10   Train Trip Station14  Station1     542880   545040
# Train_13 Light Travel Station17 Station17     543120   543120
#  Train_1 Light Travel Station17 Station17     543120   543120
# Train_13   Train Trip Station17 Station18     543300   543720
#  Train_1   Train Trip Station17 Station18     543300   543720
# Train_13 Light Travel Station18 Station18     543720   543720
#  Train_1 Light Travel Station18 Station18     543720   543720
#  Train_5 Light Travel Station16 Station16     543900   543900
#  Train_8 Light Travel Station16 Station16     543900   543900
#  Train_5   Train Trip Station16 Station10     544260   549540
#  Train_8   Train Trip Station16 Station10     544260   549540
#  Train_3 Light Travel Station14 Station14     544260   544260
# Train_12 Light Travel Station13 Station13     544680   544680
#  Train_6 Light Travel Station13 Station13     544680   544680
# Train_10 Light Travel  Station1  Station1     545040   545040
# Train_10   Train Trip  Station1 Station14     545460   547860
#  Train_9 Light Travel Station10 Station10     545940   545940
#  Train_7 Light Travel Station10 Station10     545940   545940
# Train_11 Light Travel Station13 Station13     546300   546300
#  Train_2 Light Travel Station13 Station13     546300   546300
#  Train_3   Train Trip Station14  Station1     546480   548760
# Train_11   Train Trip Station13  Station1     546480   553380
#  Train_2   Train Trip Station13  Station1     546480   553380
#  Train_7   Train Trip Station10 Station13     546540   555480
#  Train_9   Train Trip Station10 Station13     546540   555480
# Train_10 Light Travel Station14 Station14     547860   547860
# Train_12   Train Trip Station13 Station10     548040   556740
#  Train_6   Train Trip Station13 Station10     548040   556740
#  Train_3 Light Travel  Station1  Station1     548760   548760
#  Train_5 Light Travel Station10 Station10     549540   549540
#  Train_8 Light Travel Station10 Station10     549540   549540
# Train_10   Train Trip Station14 Station19     550080   550500
#  Train_8   Train Trip Station10 Station13     550140   559080
#  Train_5   Train Trip Station10 Station13     550140   559080
# Train_10 Light Travel Station19 Station19     550500   550500
# Train_11 Light Travel  Station1  Station1     553380   553380
#  Train_2 Light Travel  Station1  Station1     553380   553380
#  Train_7 Light Travel Station13 Station13     555480   555480
#  Train_9 Light Travel Station13 Station13     555480   555480
# Train_12 Light Travel Station10 Station10     556740   556740
#  Train_6 Light Travel Station10 Station10     556740   556740
#  Train_9   Train Trip Station13 Station11     556860   565200
#  Train_7   Train Trip Station13 Station11     556860   565200
#  Train_2   Train Trip  Station1 Station20     557040   563400
#  Train_3   Train Trip  Station1 Station20     557040   563400
#  Train_6   Train Trip Station10 Station13     557340   566280
# Train_12   Train Trip Station10 Station13     557340   566280
#  Train_8 Light Travel Station13 Station13     559080   559080
#  Train_5 Light Travel Station13 Station13     559080   559080
#  Train_5   Train Trip Station13 Station11     560460   568800
#  Train_8   Train Trip Station13 Station11     560460   568800
#  Train_2 Light Travel Station20 Station20     563400   563400
#  Train_3 Light Travel Station20 Station20     563400   563400
#  Train_9 Light Travel Station11 Station11     565200   565200
#  Train_7 Light Travel Station11 Station11     565200   565200
#  Train_6 Light Travel Station13 Station13     566280   566280
# Train_12 Light Travel Station13 Station13     566280   566280
#  Train_7   Train Trip Station11 Station20     566880   574200
#  Train_9   Train Trip Station11 Station20     566880   574200
#  Train_3   Train Trip Station20 Station10     566880   574740
#  Train_2   Train Trip Station20 Station10     566880   574740
# Train_12   Train Trip Station13 Station11     567660   576000
#  Train_6   Train Trip Station13 Station11     567660   576000
#  Train_5 Light Travel Station11 Station11     568800   568800
#  Train_8 Light Travel Station11 Station11     568800   568800
#  Train_8   Train Trip Station11 Station20     570480   577800
#  Train_5   Train Trip Station11 Station20     570480   577800
#  Train_7 Light Travel Station20 Station20     574200   574200
#  Train_9 Light Travel Station20 Station20     574200   574200
#  Train_3 Light Travel Station10 Station10     574740   574740
#  Train_2 Light Travel Station10 Station10     574740   574740
#  Train_2   Train Trip Station10 Station13     575340   584280
#  Train_3   Train Trip Station10 Station13     575340   584280
# Train_12 Light Travel Station11 Station11     576000   576000
#  Train_6 Light Travel Station11 Station11     576000   576000
# Train_10   Train Trip Station19 Station14     576060   576540
# Train_10 Light Travel Station14 Station14     576540   576540
#  Train_4   Train Trip Station15  Station9     576900   580440
#  Train_9   Train Trip Station20 Station10     577680   585540
#  Train_7   Train Trip Station20 Station10     577680   585540
#  Train_6   Train Trip Station11 Station13     577680   585900
# Train_12   Train Trip Station11 Station13     577680   585900
#  Train_8 Light Travel Station20 Station20     577800   577800
#  Train_5 Light Travel Station20 Station20     577800   577800
# Train_11   Train Trip  Station1 Station14     577860   580380
# Train_10   Train Trip Station14  Station1     578880   581160
# Train_13   Train Trip Station18 Station21     579540   582180
#  Train_1   Train Trip Station18 Station21     579540   582180
# Train_11 Light Travel Station14 Station14     580380   580380
#  Train_4 Light Travel  Station9  Station9     580440   580440
# Train_10 Light Travel  Station1  Station1     581160   581160
#  Train_5   Train Trip Station20 Station10     581280   589140
#  Train_8   Train Trip Station20 Station10     581280   589140
# Train_10   Train Trip  Station1 Station14     581460   583980
#  Train_4   Train Trip  Station9  Station8     581580   583020
# Train_11   Train Trip Station14  Station1     582480   584760
# Train_10 Light Travel Station14 Station14     583980   583980
#  Train_2 Light Travel Station13 Station13     584280   584280
#  Train_3 Light Travel Station13 Station13     584280   584280
# Train_11 Light Travel  Station1  Station1     584760   584760
#  Train_9 Light Travel Station10 Station10     585540   585540
#  Train_7 Light Travel Station10 Station10     585540   585540
#  Train_3   Train Trip Station13 Station11     585660   594000
#  Train_2   Train Trip Station13 Station11     585660   594000
#  Train_6 Light Travel Station13 Station13     585900   585900
# Train_12 Light Travel Station13 Station13     585900   585900
# Train_10   Train Trip Station14  Station1     586080   588360
#  Train_7   Train Trip Station10 Station13     586140   595080
#  Train_9   Train Trip Station10 Station13     586140   595080
# Train_10 Light Travel  Station1  Station1     588360   588360
# Train_11   Train Trip  Station1 Station21     589080   591600
#  Train_5 Light Travel Station10 Station10     589140   589140
#  Train_8 Light Travel Station10 Station10     589140   589140
#  Train_8   Train Trip Station10 Station13     589740   598680
#  Train_5   Train Trip Station10 Station13     589740   598680
#  Train_3 Light Travel Station11 Station11     594000   594000
#  Train_2 Light Travel Station11 Station11     594000   594000
#  Train_7 Light Travel Station13 Station13     595080   595080
#  Train_9 Light Travel Station13 Station13     595080   595080
#  Train_2   Train Trip Station11 Station22     595680   600960
#  Train_3   Train Trip Station11 Station22     595680   600960
#  Train_9   Train Trip Station13  Station4     596460   602160
#  Train_6   Train Trip Station13  Station4     596460   602160
#  Train_8 Light Travel Station13 Station13     598680   598680
#  Train_2 Light Travel Station22 Station22     600960   600960
#  Train_3 Light Travel Station22 Station22     600960   600960
#  Train_3   Train Trip Station22  Station0     601380   604800
#  Train_2   Train Trip Station22  Station2     601380   604800
#  Train_8   Train Trip Station13  Station5     601860   604800
#  Train_7   Train Trip Station13  Station6     601860   604800
#  Train_9 Light Travel  Station4  Station4     602160   602160
#  Train_9   Train Trip  Station4 Station11     602340   604800
# Train_12   Train Trip Station13  Station7     603780   604800
# Train_10   Train Trip  Station1  Station3     604200   604800
#
#  Cost Breakdown:
# Total Cost           : 13014.95
# Traction Unit Cost   : 13000.00
# Light Travel Cost    : 14.95
# Number of Vehicles   : 13

# %% [markdown]
# **Convert List_A to a CSV File**

# %%
import pandas as pd

# Convert full_schedule (a list of dicts) into a DataFrame
df_schedule = pd.DataFrame(full_schedule)

# Save to CSV
df_schedule.to_csv("full_schedule_Instance_F.csv", index=False)

# For Google Colab: provide download link
from google.colab import files
files.download("full_schedule_Instance_F.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.lines as mlines
import time

# Start timer
start_time = time.time()

# Load schedule
df_schedule = pd.read_csv("full_schedule_Instance_F.csv")

# Step 1: Map stations to Y-axis positions
stations = sorted(set(df_schedule["From"]).union(set(df_schedule["To"])))
station_to_y = {station: i for i, station in enumerate(stations)}

# Step 2: Predefine 16 train IDs
train_ids = [f"Train_{i}" for i in range(1, 14)]

# Step 3: Assign each train a unique color
cmap = cm.get_cmap('tab20', len(train_ids))
train_to_color = {train: cmap(i) for i, train in enumerate(train_ids)}

# Step 4: Initialize plot and track nodes/edges
plt.figure(figsize=(20, 12))
nodes = set()
edges = []

# Step 5: Plot edges and store nodes/edges
for _, row in df_schedule.iterrows():
    from_station = row["From"]
    to_station = row["To"]
    start_time_trip = row["StartTime"]
    end_time_trip = row["EndTime"]
    train = row["Train"]
    edge_type = row["Type"]

    u = (start_time_trip, station_to_y[from_station])
    v = (end_time_trip, station_to_y[to_station])

    nodes.update([u, v])
    edges.append((u, v))

    color = train_to_color.get(train, 'black')
    linestyle = '-' if edge_type == "Train Trip" else '--'
    plt.plot([u[0], v[0]], [u[1], v[1]], color=color, linestyle=linestyle, linewidth=1)

# Step 6: Plot nodes
for t, y in nodes:
    plt.scatter(t, y, color='black', s=10)
    plt.text(t, y + 0.1, f'{t}', fontsize=5, ha='center', color='darkred')

# Step 7: Axis formatting
plt.yticks(list(station_to_y.values()), list(station_to_y.keys()))
plt.xlabel("Time (seconds)")
plt.ylabel("Stations")
plt.title("Space-Time Network_Instance_F")
plt.grid(True, linestyle='--', linewidth=0.5)

# Step 8: Legend
legend_lines = [
    mlines.Line2D([], [], color=train_to_color[train], linewidth=2, label=train)
    for train in train_ids
]
plt.legend(handles=legend_lines, title="Trains", loc='upper center', bbox_to_anchor=(0.5, -0.08),
           ncol=6, fontsize=8, title_fontsize=10, frameon=True)

plt.tight_layout()
plt.show()

# End timer
end_time = time.time()

# Step 9: Print summary
print("\n===== Network Summary =====")
print(f"Total Nodes      : {len(nodes)}")
print(f"Total Edges      : {len(edges)}")
print(f"Execution Time   : {round(end_time - start_time, 3)} seconds")
# Out:
# /tmp/ipython-input-11-1737506909.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(train_ids))
# ===== Network Summary =====
# Total Nodes      : 792
# Total Edges      : 1253
# Execution Time   : 10.34 seconds

# %% [markdown]
# **Robustness Calculation**

# %%
# STEP 01: Identify tight connections
# Define threshold (e.g., 300 seconds = 5 minutes)
TIGHT_THRESHOLD = 300  # seconds

# Extract only productive train trips for each train
train_trips = df_schedule[df_schedule["Type"] == "Train Trip"].copy()
train_trips.sort_values(by=["Train", "StartTime"], inplace=True)

# Find consecutive trips by the same train
tight_connections = []
for train_id, group in train_trips.groupby("Train"):
    trips = group.sort_values("StartTime").reset_index(drop=True)
    for i in range(len(trips) - 1):
        current_end = trips.loc[i, "EndTime"]
        next_start = trips.loc[i + 1, "StartTime"]
        connection_time = next_start - current_end
        if connection_time <= TIGHT_THRESHOLD:
            tight_connections.append({
                "Train": train_id,
                "FromTripEnd": current_end,
                "ToTripStart": next_start,
                "ConnectionTime": connection_time,
                "FromStation": trips.loc[i, "To"],
                "ToStation": trips.loc[i + 1, "From"]
            })

# Display the tight connections
df_tight = pd.DataFrame(tight_connections)
print(f"\n Tight Connections (<= {TIGHT_THRESHOLD} seconds): {len(df_tight)} found")
if not df_tight.empty:
    print(df_tight.to_string(index=False))
else:
    print(" No tight connections found.")
# Out:
#  Tight Connections (<= 300 seconds): 33 found
#    Train  FromTripEnd  ToTripStart  ConnectionTime FromStation ToStation
#  Train_1        27900        28080             180   Station13 Station13
#  Train_1       200700       200880             180   Station13 Station13
#  Train_1       543120       543300             180   Station17 Station17
# Train_10        24720        24900             180   Station17 Station17
# Train_10       105960       106200             240    Station4  Station4
# Train_10       581160       581460             300    Station1  Station1
# Train_11       114300       114480             180   Station13 Station13
# Train_11       197520       197700             180   Station17 Station17
# Train_11       459900       460080             180   Station13 Station13
# Train_11       546300       546480             180   Station13 Station13
# Train_12        62760        63060             300    Station1  Station1
# Train_12       111120       111300             180   Station17 Station17
# Train_12       235560       235860             300    Station1  Station1
# Train_13       197520       197700             180   Station17 Station17
# Train_13       456720       456900             180   Station17 Station17
# Train_13       543120       543300             180   Station17 Station17
#  Train_2       114300       114480             180   Station13 Station13
#  Train_2       243660       243720              60    Station4  Station4
#  Train_2       546300       546480             180   Station13 Station13
#  Train_5       456720       456900             180   Station17 Station17
#  Train_6        27900        28080             180   Station13 Station13
#  Train_6       111120       111300             180   Station17 Station17
#  Train_7       321960       322260             300    Station1  Station1
#  Train_8        19560        19800             240    Station4  Station4
#  Train_8       149160       149460             300    Station1  Station1
#  Train_8       192360       192600             240    Station4  Station4
#  Train_8       459900       460080             180   Station13 Station13
#  Train_9        24720        24900             180   Station17 Station17
#  Train_9       200700       200880             180   Station13 Station13
#  Train_9       408360       408660             300    Station1  Station1
#  Train_9       494760       495060             300    Station1  Station1
#  Train_9       537960       538200             240    Station4  Station4
#  Train_9       602160       602340             180    Station4  Station4

# %%
import pandas as pd

# Step 2: Set threshold for tight connections
TIGHT_THRESHOLD = 300  # seconds
BUFFER_TIME = 600      # seconds

# Step 3: Detect tight connections
train_trips = df_schedule[df_schedule["Type"] == "Train Trip"].copy()
train_trips.sort_values(by=["Train", "StartTime"], inplace=True)

tight_connections = []
for train_id, group in train_trips.groupby("Train"):
    trips = group.sort_values("StartTime").reset_index(drop=True)
    for i in range(len(trips) - 1):
        current_end = trips.loc[i, "EndTime"]
        next_start = trips.loc[i + 1, "StartTime"]
        connection_time = next_start - current_end
        if connection_time <= TIGHT_THRESHOLD:
            tight_connections.append({
                "Train": train_id,
                "FromTripEnd": current_end,
                "ToTripStart": next_start,
                "ConnectionTime": connection_time,
                "FromStation": trips.loc[i, "To"],
                "ToStation": trips.loc[i + 1, "From"]
            })

df_tight = pd.DataFrame(tight_connections)

# Step 4: Apply buffer by shifting trips forward
df_buffered = df_schedule.copy()
df_buffered.sort_values(by=["Train", "StartTime"], inplace=True)

for _, row in df_tight.iterrows():
    train_id = row["Train"]
    to_start = row["ToTripStart"]
    affected = df_buffered[
        (df_buffered["Train"] == train_id) &
        (df_buffered["StartTime"] >= to_start)
    ].index
    df_buffered.loc[affected, "StartTime"] += BUFFER_TIME
    df_buffered.loc[affected, "EndTime"] += BUFFER_TIME

# Step 5: Recalculate cost
C_TU = 1000
C_Light = 0.10
traction_units = df_buffered["Train"].nunique()
traction_cost = traction_units * C_TU

light_travel_cost = 0
for _, row in df_buffered[df_buffered["Type"] == "Light Travel"].iterrows():
    key = f"{row['From']},{row['To']}"
    if key in empty_runs:
        dist = empty_runs[key]["Distance"]
        light_travel_cost += dist * C_Light

total_cost = traction_cost + light_travel_cost

# Step 6: Calculate nodes and edges
nodes = set()
edges = 0
for _, row in df_buffered.iterrows():
    u = (row["StartTime"], row["From"])
    v = (row["EndTime"], row["To"])
    nodes.update([u, v])
    edges += 1

# Step 7: Save result
buffered_schedule_path = "schedule_buffered_600s.csv"
df_buffered.to_csv(buffered_schedule_path, index=False)

# Step 8: Summary
print("\n===== ⏱️ Buffered Plan Summary (600s for tight links) =====")
print(f" Tight Connections Found   : {len(df_tight)}")
print(f" Buffer Applied per Link   : {BUFFER_TIME} seconds")
print(f" Trains (Vehicles) Used    : {traction_units}")
print(f" Light Travel Cost         : {round(light_travel_cost, 2)}")
print(f" Total Cost                : {round(total_cost, 2)}")
print(f" Total Edges               : {edges}")
print(f" Total Unique Nodes        : {len(nodes)}")
print(f" Saved to File             : {buffered_schedule_path}")
# Out:
# ===== ⏱️ Buffered Plan Summary (600s for tight links) =====
#  Tight Connections Found   : 33
#  Buffer Applied per Link   : 600 seconds
#  Trains (Vehicles) Used    : 13
#  Light Travel Cost         : 14.95
#  Total Cost                : 13014.95
#  Total Edges               : 1253
#  Total Unique Nodes        : 1143
#  Saved to File             : schedule_buffered_600s.csv

# %%
import pandas as pd

# Load the original schedule before buffering
df_schedule = pd.read_csv("full_schedule_Instance_F.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.lines as mlines
import json
import re

# Load JSON data
with open("Instance_F.json") as f:
    data = json.load(f)

# Extract empty runs
empty_runs = data["EmptyRunData"]

# === CONFIGURATION ===
TIGHT_THRESHOLD = 300  # seconds
BUFFER_TIME = 600      # buffer to add after tight connections
C_TU = 1000            # traction unit cost
C_Light = 0.10         # light travel cost per km

# === STEP 1: Detect Tight Connections ===
train_trips = df_schedule[df_schedule["Type"] == "Train Trip"].copy()
train_trips.sort_values(by=["Train", "StartTime"], inplace=True)

tight_connections = []
for train_id, group in train_trips.groupby("Train"):
    trips = group.sort_values("StartTime").reset_index(drop=True)
    for i in range(len(trips) - 1):
        current_end = trips.loc[i, "EndTime"]
        next_start = trips.loc[i + 1, "StartTime"]
        connection_time = next_start - current_end
        if connection_time <= TIGHT_THRESHOLD:
            tight_connections.append({
                "Train": train_id,
                "FromTripEnd": current_end,
                "ToTripStart": next_start,
                "ConnectionTime": connection_time,
                "FromStation": trips.loc[i, "To"],
                "ToStation": trips.loc[i + 1, "From"]
            })

df_tight = pd.DataFrame(tight_connections)

# === STEP 2: Apply Buffer ===
df_buffered = df_schedule.copy()
df_buffered.sort_values(by=["Train", "StartTime"], inplace=True)

for _, row in df_tight.iterrows():
    train_id = row["Train"]
    to_start = row["ToTripStart"]
    affected = df_buffered[
        (df_buffered["Train"] == train_id) &
        (df_buffered["StartTime"] >= to_start)
    ].index
    df_buffered.loc[affected, "StartTime"] += BUFFER_TIME
    df_buffered.loc[affected, "EndTime"] += BUFFER_TIME

# === STEP 3: Recalculate Cost ===
traction_units = df_buffered["Train"].nunique()
traction_cost = traction_units * C_TU

light_travel_cost = 0
for _, row in df_buffered[df_buffered["Type"] == "Light Travel"].iterrows():
    key = f"{row['From']},{row['To']}"
    if key in empty_runs:
        dist = empty_runs[key]["Distance"]
        light_travel_cost += dist * C_Light

total_cost = traction_cost + light_travel_cost

# === STEP 4: Plot with Buffer Annotations ===
stations = sorted(set(df_buffered["From"]).union(set(df_buffered["To"])))
station_to_y = {station: i for i, station in enumerate(stations)}

train_ids = sorted(df_buffered["Train"].unique())
cmap = cm.get_cmap('tab20', len(train_ids))
train_to_color = {train: cmap(i) for i, train in enumerate(train_ids)}

plt.figure(figsize=(20, 12))
nodes = set()

# Plot train arcs
for _, row in df_buffered.iterrows():
    from_station = row["From"]
    to_station = row["To"]
    start = row["StartTime"]
    end = row["EndTime"]
    train = row["Train"]
    typ = row["Type"]

    u = (start, station_to_y[from_station])
    v = (end, station_to_y[to_station])
    color = train_to_color[train]
    linestyle = '-' if typ == "Train Trip" else '--'

    plt.plot([u[0], v[0]], [u[1], v[1]], color=color, linestyle=linestyle, linewidth=1)
    nodes.update([u, v])

# Annotate buffer arcs in red
for _, row in df_tight.iterrows():
    train_id = row["Train"]
    station = row["ToStation"]
    y = station_to_y[station]
    from_time = row["ToTripStart"]
    to_time = from_time + BUFFER_TIME
    plt.plot([from_time, to_time], [y, y], color='red', linestyle=':', linewidth=1)
    plt.text(to_time + 10, y + 0.15, '+600s', fontsize=6, color='red')

# Plot nodes
for t, y in nodes:
    plt.scatter(t, y, color='black', s=10)

# Axis settings
plt.yticks(list(station_to_y.values()), list(station_to_y.keys()))
plt.xlabel("Time (seconds)")
plt.ylabel("Stations")
plt.title("Buffered Plan with 600s Delay Buffers on Tight Connections")
plt.grid(True, linestyle='--', linewidth=0.5)

# Legend
legend_lines = [
    mlines.Line2D([], [], color=train_to_color[train], linewidth=2, label=train)
    for train in train_ids[:12]
]
legend_lines.append(mlines.Line2D([], [], color='red', linestyle=':', linewidth=1, label='Buffer +600s'))
plt.legend(handles=legend_lines, title="Trains", loc='upper center', bbox_to_anchor=(0.5, -0.08),
           ncol=6, fontsize=8, title_fontsize=10, frameon=True)

plt.tight_layout()
plt.show()

# === STEP 5: Summary ===
print("\n===== ⏱️ Buffered Plan Summary (600s for tight links) =====")
print(f" Tight Connections Found   : {len(df_tight)}")
print(f" Buffer Applied per Link   : {BUFFER_TIME} seconds")
print(f" Trains (Vehicles) Used    : {traction_units}")
print(f" Light Travel Cost         : {round(light_travel_cost, 2)}")
print(f" Total Cost                : {round(total_cost, 2)}")
print(f" Total Edges               : {len(df_buffered)}")
print(f" Total Unique Nodes        : {len(nodes)}")
# Out:
# /tmp/ipython-input-9-516020638.py:76: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(train_ids))
# ===== ⏱️ Buffered Plan Summary (600s for tight links) =====
#  Tight Connections Found   : 33
#  Buffer Applied per Link   : 600 seconds
#  Trains (Vehicles) Used    : 13
#  Light Travel Cost         : 14.95
#  Total Cost                : 13014.95
#  Total Edges               : 1253
#  Total Unique Nodes        : 1143

# %%
from collections import defaultdict
import pandas as pd

# Configuration
TIGHT_THRESHOLD = 300  # seconds

# Initialize counter
tight_counts = defaultdict(int)
total_counts = defaultdict(int)

# Detect tight and total connections per station
train_trips = df_schedule[df_schedule["Type"] == "Train Trip"].copy()
train_trips.sort_values(by=["Train", "StartTime"], inplace=True)

for train_id, group in train_trips.groupby("Train"):
    trips = group.reset_index(drop=True)
    for i in range(len(trips) - 1):
        end_time = trips.loc[i, "EndTime"]
        next_start = trips.loc[i + 1, "StartTime"]
        conn_time = next_start - end_time
        station = trips.loc[i + 1, "From"]

        total_counts[station] += 1
        if conn_time <= TIGHT_THRESHOLD:
            tight_counts[station] += 1

# Create summary DataFrame
df_station_tightness = pd.DataFrame({
    "TotalConnections": pd.Series(total_counts),
    "TightConnections": pd.Series(tight_counts)
})
df_station_tightness["TightRatio"] = df_station_tightness["TightConnections"] / df_station_tightness["TotalConnections"]
df_station_tightness = df_station_tightness.fillna(0).sort_values(by="TightRatio", ascending=False)

# Show top 10 stations
print("\n===== 🔍 Stations with Highest Tight Connection Ratios =====")
print(df_station_tightness.head(10).round(2))
# Out:
# ===== 🔍 Stations with Highest Tight Connection Ratios =====
#            TotalConnections  TightConnections  TightRatio
# Station17                18              10.0        0.56
# Station4                 60               6.0        0.10
# Station13               108              10.0        0.09
# Station1                 86               7.0        0.08
# Station10                86               0.0        0.00
# Station11                71               0.0        0.00
# Station14                38               0.0        0.00
# Station15                 5               0.0        0.00
# Station16                20               0.0        0.00
# Station18                10               0.0        0.00
