# %% [markdown]
# **Scheduling Problem**

# %% [markdown]
# Random Space Time Network Instance_G

# %% [markdown]
# **Step 01 Generating a Space Time Network**

# %%
# Load required libraries
import json  # Used to read and parse JSON files
import matplotlib.pyplot as plt  # Used for plotting the space-time network
import re  # Used for natural sorting of station names like Station1, Station2, Station10
import time  # Used to measure computation time
import matplotlib.ticker as ticker  # (Optional) used for custom formatting of x-axis ticks

# Start the timer to measure total computation time
start_time = time.time()

# Open and load the JSON file containing the instance data for stations, trips, and empty runs
with open("Instance_G.json") as f:
    data = json.load(f)

# Define a helper function that creates a sorting key for natural sorting (e.g., Station2 before Station10)
def natural_key(s):
    return [int(text) if text.isdigit() else text for text in re.split('(\d+)', s)]

# Extract and sort all station names using natural sorting
stations = sorted([s["Name"] for s in data["StationList"]], key=natural_key)

# Create a dictionary mapping each station name to a corresponding y-axis index (0, 1, ..., 33)
station_to_y = {name: i for i, name in enumerate(stations)}

# Sort all trips based on their start times
trips = sorted(data["TripList"], key=lambda x: x["StartTime"])

# Extract the empty run data which contains light travel durations between station pairs
empty_runs = data["EmptyRunData"]

# Initialize lists to store different types of arcs (edges) and special nodes
train_arcs = []          # Arcs representing productive trips (trains with passengers)
light_arcs_arrival = []  # Arcs representing light vehicle travel after completing a trip
light_arcs_source = []   # Arcs representing vehicle repositioning from source to first trip
ground_arcs = []         # Arcs representing idle waiting time at a station
source_nodes = []        # Artificial source nodes (before each trip)
sink_nodes = []          # Artificial sink nodes (after each trip)
nodes_set = set()        # Set to store all unique (time, station index) pairs (i.e., nodes)

# Step 1: Create artificial source and sink nodes for each trip
for trip in trips:
    source_nodes.append((trip["StartTime"] - 1, station_to_y[trip["Origin"]]))  # source node before trip starts
    sink_nodes.append((trip["EndTime"] + 1, station_to_y[trip["Destination"]]))  # sink node after trip ends

# Step 2: Create productive train arcs
for trip in trips:
    u = (trip["StartTime"], station_to_y[trip["Origin"]])
    v = (trip["EndTime"], station_to_y[trip["Destination"]])
    train_arcs.append((u, v))
    nodes_set.update([u, v])  # store nodes

# Step 3: Create light arcs from trip end to future trip start
for trip_a in trips:
    for trip_b in trips:
        if trip_a["Id"] != trip_b["Id"] and trip_a["EndTime"] < trip_b["StartTime"]:
            key = f"{trip_a['Destination']},{trip_b['Origin']}"
            if trip_a["Destination"] != trip_b["Origin"] and key in empty_runs:
                transfer_time = empty_runs[key]["Duration"]
                if trip_a["EndTime"] + transfer_time <= trip_b["StartTime"]:
                    u = (trip_a["EndTime"], station_to_y[trip_a["Destination"]])
                    v = (trip_a["EndTime"] + transfer_time, station_to_y[trip_b["Origin"]])
                    light_arcs_arrival.append((u, v))
                    nodes_set.update([u, v])
                    break

# Step 4: Create light arcs from artificial source to feasible trip origin
for src in source_nodes:
    t0, y0 = src
    for trip in trips:
        key = f"{stations[y0]},{trip['Origin']}"
        if key in empty_runs and t0 < trip["StartTime"]:
            duration = empty_runs[key]["Duration"]
            if t0 + duration <= trip["StartTime"]:
                u = src
                v = (t0 + duration, station_to_y[trip["Origin"]])
                light_arcs_source.append((u, v))
                nodes_set.update([u, v])
                break

# Step 5: Create ground arcs between end of one trip and start of another at same station
for trip_a in trips:
    for trip_b in trips:
        if trip_a["Destination"] == trip_b["Origin"] and trip_b["StartTime"] > trip_a["EndTime"]:
            u = (trip_a["EndTime"], station_to_y[trip_a["Destination"]])
            v = (trip_b["StartTime"], station_to_y[trip_b["Origin"]])
            ground_arcs.append((u, v))
            nodes_set.update([u, v])
            break

# Start plotting the space-time network
plt.figure(figsize=(20, 12))

# Draw productive train arcs (blue)
for u, v in train_arcs:
    plt.plot([u[0], v[0]], [u[1], v[1]], color='blue', linewidth=0.9)

# Draw light arcs after trip end (dashed gray)
for u, v in light_arcs_arrival:
    plt.plot([u[0], v[0]], [u[1], v[1]], color='gray', linestyle='dashed', linewidth=0.8)

# Draw light arcs from source node (dotted dark gray)
for u, v in light_arcs_source:
    plt.plot([u[0], v[0]], [u[1], v[1]], color='darkgray', linestyle='dotted', linewidth=0.8)

# Draw ground arcs (green)
for u, v in ground_arcs:
    plt.plot([u[0], v[0]], [u[1], v[1]], color='green', linestyle='solid', linewidth=0.7)

# Scatter plot all nodes for clarity
for (u, v) in train_arcs + light_arcs_arrival + light_arcs_source + ground_arcs:
    plt.scatter([u[0], v[0]], [u[1], v[1]], s=6, color='black')

# Configure y-axis with station names in top-down order
plt.yticks(range(len(stations)), stations)

# Set labels and title
plt.xlabel("Time (seconds)")
plt.ylabel("Stations (top: Station0)")
plt.title("Space-Time Network - Instance_G")

# Add grid and tighten layout
plt.grid(True, linestyle='--', linewidth=0.3)
plt.tight_layout()

# Show the final plot
plt.show()

# Calculate total edges and computation time
total_edges = len(train_arcs) + len(light_arcs_arrival) + len(light_arcs_source) + len(ground_arcs)
end_time_calc = time.time()

# Print network statistics
print("Network Summary")
print(f"Number of nodes       : {len(nodes_set)}")
print(f"Number of edges       : {total_edges}")
print(f"Computation time (s)  : {round(end_time_calc - start_time, 3)}")
# Out:
# Network Summary
# Number of nodes       : 1636
# Number of edges       : 4248
# Computation time (s)  : 142.045

# %% [markdown]
# **Step 02 Costing Calculation and Vehicles Calculation Using Pulp**

# %% [markdown]
# Pulp Installation for Mixed Integer Program Optimization

# %%
# Install PuLP
# !pip install pulp

# Load libraries
import json, re
import pulp
import pandas as pd

# Load JSON file
with open("Instance_G.json") as f:
    data = json.load(f)

# Cost parameters
C_TU = 1000
C_Light = 0.10

# Parse stations and trips
stations = sorted(
    [s["Name"] for s in data["StationList"]],
    key=lambda s: [int(t) if t.isdigit() else t for t in re.split("(\d+)", s)]
)
station_index = {name: i for i, name in enumerate(stations)}

trips = sorted(data["TripList"], key=lambda x: x["StartTime"])
trip_ids = [trip["Id"] for trip in trips]
trip_map = {trip["Id"]: trip for trip in trips}
empty_runs = data["EmptyRunData"]

# Optimization model
model = pulp.LpProblem("RollingStockCirculationPlanning", pulp.LpMinimize)

x = {trip["Id"]: pulp.LpVariable(f"x_{trip['Id']}", cat="Binary") for trip in trips}
vehicles = {trip["Id"]: pulp.LpVariable(f"veh_{trip['Id']}", cat="Binary") for trip in trips}
z = {}

# Generate light travel arcs
for i, trip_a in enumerate(trips):
    for j, trip_b in enumerate(trips):
        if i != j and trip_a["EndTime"] < trip_b["StartTime"]:
            key = f"{trip_a['Destination']},{trip_b['Origin']}"
            if key in empty_runs:
                ttime = empty_runs[key]["Duration"]
                if trip_a["EndTime"] + ttime <= trip_b["StartTime"]:
                    arc = f"{trip_a['Id']}_{trip_b['Id']}"
                    z[arc] = pulp.LpVariable(f"z_{arc}", cat="Binary")

# Objective
model += (
    pulp.lpSum([vehicles[trip["Id"]] for trip in trips]) * C_TU +
    pulp.lpSum([
        z[arc] *
        empty_runs[f"{trip_map[int(arc.split('_')[0])]['Destination']},{trip_map[int(arc.split('_')[1])]['Origin']}"]["Distance"] *
        C_Light for arc in z
    ])
)

# Constraints
for trip in trips:
    model += x[trip["Id"]] == 1

for trip in trips:
    incoming = [z[arc] for arc in z if int(arc.split('_')[1]) == trip["Id"]]
    model += vehicles[trip["Id"]] + pulp.lpSum(incoming) >= x[trip["Id"]]

for trip in trips:
    outgoing = [z[arc] for arc in z if int(arc.split('_')[0]) == trip["Id"]]
    model += pulp.lpSum(outgoing) <= 1

# Solve
model.solve(pulp.PULP_CBC_CMD(msg=0))

# Result
num_vehicles = sum(v.varValue for v in vehicles.values())
light_cost = sum(
    z[arc].varValue *
    empty_runs[f"{trip_map[int(arc.split('_')[0])]['Destination']},{trip_map[int(arc.split('_')[1])]['Origin']}"]["Distance"] *
    C_Light for arc in z
)
traction_cost = num_vehicles * C_TU
total_cost = traction_cost + light_cost

# Display
results = {
    "Total Cost": round(total_cost, 2),
    "Traction Unit Cost": round(traction_cost, 2),
    "Light Travel Cost": round(light_cost, 2),
    "Deadheading Cost": 0.00,
    "Number of Vehicles Used": int(num_vehicles)
}
pd.DataFrame([results])
# Out:
# Collecting pulp
#   Downloading pulp-3.2.1-py3-none-any.whl.metadata (6.9 kB)
# Downloading pulp-3.2.1-py3-none-any.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 63.7 MB/s eta 0:00:00
# Installing collected packages: pulp
# Successfully installed pulp-3.2.1
#    Total Cost  Traction Unit Cost  Light Travel Cost  Deadheading Cost  \
# 0      4000.0              4000.0                0.0               0.0
#
#    Number of Vehicles Used
# 0                        4

# %% [markdown]
# **`Schedule Calculator`**

# %%
# STEP 1: Install pulp (for Google Colab; skip if already installed)
# !pip install pulp

# STEP 2: Import required libraries
import json           # For reading the JSON file
import re             # For sorting station names naturally
import pulp           # For defining and solving the optimization model
import pandas as pd   # For creating and displaying schedule tables
from pulp import LpStatus  # For checking the model solution status

# STEP 3: Load data from the JSON file
with open("Instance_G.json") as f:
    data = json.load(f)

# STEP 4: Define cost parameters
C_TU = 1000       # Cost for using a train unit
C_Light = 0.10    # Cost per km for light (empty) travel

# STEP 5: Prepare and sort stations
stations = sorted(
    [s["Name"] for s in data["StationList"]],
    key=lambda s: [int(t) if t.isdigit() else t for t in re.split("(\d+)", s)]
)
station_index = {name: i for i, name in enumerate(stations)}

# STEP 6: Extract trips and empty run data
trips = sorted(data["TripList"], key=lambda x: x["StartTime"])
trip_map = {trip["Id"]: trip for trip in trips}
empty_runs = data["EmptyRunData"]

# STEP 7: Define the optimization model
model = pulp.LpProblem("RollingStock", pulp.LpMinimize)

# Binary variable for each trip: 1 if performed
x = {trip["Id"]: pulp.LpVariable(f"x_{trip['Id']}", cat="Binary") for trip in trips}

# Binary variable for vehicle usage: 1 if a new train starts with this trip
vehicles = {trip["Id"]: pulp.LpVariable(f"veh_{trip['Id']}", cat="Binary") for trip in trips}

# Binary variables for light connections between trips
z = {}
for i, a in enumerate(trips):
    for j, b in enumerate(trips):
        if i != j and a["EndTime"] < b["StartTime"]:
            key = f"{a['Destination']},{b['Origin']}"
            if key in empty_runs:
                dt = empty_runs[key]["Duration"]
                if a["EndTime"] + dt <= b["StartTime"]:
                    arc = f"{a['Id']}_{b['Id']}"
                    z[arc] = pulp.LpVariable(f"z_{arc}", cat="Binary")

# STEP 8: Define objective function to minimize total cost
model += (
    pulp.lpSum([vehicles[tid] for tid in x]) * C_TU +
    pulp.lpSum([
        z[arc] * empty_runs[
            f"{trip_map[int(arc.split('_')[0])]['Destination']},{trip_map[int(arc.split('_')[1])]['Origin']}"
        ]["Distance"] * C_Light for arc in z
    ])
)

# STEP 9: Add constraints
# Ensure each trip is covered
for trip in trips:
    model += x[trip["Id"]] == 1

# A trip is covered either by a new vehicle or from a previous trip via light travel
for trip in trips:
    incoming = [z[arc] for arc in z if int(arc.split("_")[1]) == trip["Id"]]
    model += vehicles[trip["Id"]] + pulp.lpSum(incoming) >= x[trip["Id"]]

# A trip connects to at most one next trip
for trip in trips:
    outgoing = [z[arc] for arc in z if int(arc.split("_")[0]) == trip["Id"]]
    model += pulp.lpSum(outgoing) <= 1

# STEP 10: Solve the model
model.solve(pulp.PULP_CBC_CMD(msg=0))

# STEP 11: Check if solution is feasible
status = LpStatus[model.status]
print(f"\n🔍 Model Status: {status}")
if status != "Optimal":
    print(" No feasible or optimal solution found.")
else:
    print(" Feasible and optimal solution found.")

# STEP 12: Assign Train IDs
trip_to_train = {}
train_counter = 1
outgoing_map = {int(arc.split('_')[0]): int(arc.split('_')[1]) for arc in z if z[arc].varValue == 1}
visited = set()

for trip in trips:
    tid = trip["Id"]
    if tid not in visited:
        current_train = f"Train_{train_counter}"
        while tid in trip_map:
            visited.add(tid)
            trip_to_train[tid] = current_train
            tid = outgoing_map.get(tid, None)
            if tid is None or tid in visited:
                break
        train_counter += 1

# STEP 13: Build the full trip and light travel schedule
full_schedule = []

# Add train trips
for tid, var in x.items():
    if var.varValue == 1:
        trip = trip_map[tid]
        full_schedule.append({
            "Train": trip_to_train[tid],
            "Type": "Train Trip",
            "From": trip["Origin"],
            "To": trip["Destination"],
            "StartTime": trip["StartTime"],
            "EndTime": trip["EndTime"]
        })

# Add light travel trips
light_travel_cost = 0
for arc, var in z.items():
    if var.varValue == 1:
        from_id, to_id = map(int, arc.split("_"))
        trip_a = trip_map[from_id]
        trip_b = trip_map[to_id]
        key = f"{trip_a['Destination']},{trip_b['Origin']}"
        dur = empty_runs[key]["Duration"]
        dist = empty_runs[key]["Distance"]
        cost = dist * C_Light
        light_travel_cost += cost
        full_schedule.append({
            "Train": trip_to_train[from_id],
            "Type": "Light Travel",
            "From": trip_a["Destination"],
            "To": trip_b["Origin"],
            "StartTime": trip_a["EndTime"],
            "EndTime": trip_a["EndTime"] + dur
        })

# STEP 14: Display the final schedule
full_schedule = sorted(full_schedule, key=lambda x: x["StartTime"])
df_schedule = pd.DataFrame(full_schedule)
print("\n Complete Trip and Light Travel Schedule:")
print(df_schedule.to_string(index=False))

# STEP 15: Print cost breakdown
traction_units = sum([vehicles[tid].varValue for tid in vehicles])
traction_cost = traction_units * C_TU
total_cost = pulp.value(model.objective)

print("\n Cost Breakdown:")
print(f"Total Cost           : {total_cost:.2f}")
print(f"Traction Unit Cost   : {traction_cost:.2f}")
print(f"Light Travel Cost    : {light_travel_cost:.2f}")
print(f"Number of Vehicles   : {int(traction_units)}")
# Out:
# Requirement already satisfied: pulp in /usr/local/lib/python3.11/dist-packages (3.2.1)
#
# 🔍 Model Status: Optimal
#  Feasible and optimal solution found.
#
#  Complete Trip and Light Travel Schedule:
#   Train         Type     From       To  StartTime  EndTime
# Train_1   Train Trip Station0 Station1        480     1020
# Train_2   Train Trip Station0 Station1        480     1020
# Train_1 Light Travel Station1 Station1       1020     1020
# Train_2 Light Travel Station1 Station1       1020     1020
# Train_2   Train Trip Station1 Station0      18780    19500
# Train_3   Train Trip Station1 Station0      18780    19500
# Train_2 Light Travel Station0 Station0      19500    19500
# Train_3 Light Travel Station0 Station0      19500    19500
# Train_2   Train Trip Station0 Station2      20220    21180
# Train_3   Train Trip Station0 Station2      20220    21180
# Train_4   Train Trip Station1 Station0      20580    21300
# Train_1   Train Trip Station1 Station0      20580    21300
# Train_2 Light Travel Station2 Station2      21180    21180
# Train_3 Light Travel Station2 Station2      21180    21180
# Train_4 Light Travel Station0 Station0      21300    21300
# Train_1 Light Travel Station0 Station0      21300    21300
# Train_4   Train Trip Station0 Station2      22020    22980
# Train_1   Train Trip Station0 Station2      22020    22980
# Train_3   Train Trip Station2 Station0      22080    23040
# Train_2   Train Trip Station2 Station0      22080    23040
# Train_4 Light Travel Station2 Station2      22980    22980
# Train_1 Light Travel Station2 Station2      22980    22980
# Train_3 Light Travel Station0 Station0      23040    23040
# Train_2 Light Travel Station0 Station0      23040    23040
# Train_2   Train Trip Station0 Station2      23820    24780
# Train_3   Train Trip Station0 Station2      23820    24780
# Train_1   Train Trip Station2 Station0      23880    24840
# Train_4   Train Trip Station2 Station0      23880    24840
# Train_2 Light Travel Station2 Station2      24780    24780
# Train_3 Light Travel Station2 Station2      24780    24780
# Train_1 Light Travel Station0 Station0      24840    24840
# Train_4 Light Travel Station0 Station0      24840    24840
# Train_4   Train Trip Station0 Station2      25620    26580
# Train_1   Train Trip Station0 Station2      25620    26580
# Train_3   Train Trip Station2 Station0      25680    26640
# Train_2   Train Trip Station2 Station0      25680    26640
# Train_4 Light Travel Station2 Station2      26580    26580
# Train_1 Light Travel Station2 Station2      26580    26580
# Train_3 Light Travel Station0 Station0      26640    26640
# Train_2 Light Travel Station0 Station0      26640    26640
# Train_2   Train Trip Station0 Station2      27420    28380
# Train_3   Train Trip Station0 Station2      27420    28380
# Train_1   Train Trip Station2 Station0      27480    28440
# Train_4   Train Trip Station2 Station0      27480    28440
# Train_2 Light Travel Station2 Station2      28380    28380
# Train_3 Light Travel Station2 Station2      28380    28380
# Train_1 Light Travel Station0 Station0      28440    28440
# Train_4 Light Travel Station0 Station0      28440    28440
# Train_4   Train Trip Station0 Station2      29220    30180
# Train_1   Train Trip Station0 Station2      29220    30180
# Train_3   Train Trip Station2 Station0      29280    30240
# Train_2   Train Trip Station2 Station0      29280    30240
# Train_4 Light Travel Station2 Station2      30180    30180
# Train_1 Light Travel Station2 Station2      30180    30180
# Train_3 Light Travel Station0 Station0      30240    30240
# Train_2 Light Travel Station0 Station0      30240    30240
# Train_2   Train Trip Station0 Station2      31020    31980
# Train_3   Train Trip Station0 Station2      31020    31980
# Train_1   Train Trip Station2 Station0      31080    32040
# Train_4   Train Trip Station2 Station0      31080    32040
# Train_2 Light Travel Station2 Station2      31980    31980
# Train_3 Light Travel Station2 Station2      31980    31980
# Train_1 Light Travel Station0 Station0      32040    32040
# Train_4 Light Travel Station0 Station0      32040    32040
# Train_4   Train Trip Station0 Station2      32820    33780
# Train_1   Train Trip Station0 Station2      32820    33780
# Train_3   Train Trip Station2 Station0      32880    33840
# Train_2   Train Trip Station2 Station0      32880    33840
# Train_4 Light Travel Station2 Station2      33780    33780
# Train_1 Light Travel Station2 Station2      33780    33780
# Train_3 Light Travel Station0 Station0      33840    33840
# Train_2 Light Travel Station0 Station0      33840    33840
# Train_2   Train Trip Station0 Station2      34620    35580
# Train_3   Train Trip Station0 Station2      34620    35580
# Train_1   Train Trip Station2 Station0      34680    35640
# Train_4   Train Trip Station2 Station0      34680    35640
# Train_2 Light Travel Station2 Station2      35580    35580
# Train_3 Light Travel Station2 Station2      35580    35580
# Train_1 Light Travel Station0 Station0      35640    35640
# Train_4 Light Travel Station0 Station0      35640    35640
# Train_4   Train Trip Station0 Station2      36420    37380
# Train_1   Train Trip Station0 Station2      36420    37380
# Train_3   Train Trip Station2 Station0      36480    37440
# Train_2   Train Trip Station2 Station0      36480    37440
# Train_4 Light Travel Station2 Station2      37380    37380
# Train_1 Light Travel Station2 Station2      37380    37380
# Train_3 Light Travel Station0 Station0      37440    37440
# Train_2 Light Travel Station0 Station0      37440    37440
# Train_2   Train Trip Station0 Station2      38220    39180
# Train_3   Train Trip Station0 Station2      38220    39180
# Train_1   Train Trip Station2 Station0      38280    39240
# Train_4   Train Trip Station2 Station0      38280    39240
# Train_2 Light Travel Station2 Station2      39180    39180
# Train_3 Light Travel Station2 Station2      39180    39180
# Train_1 Light Travel Station0 Station0      39240    39240
# Train_4 Light Travel Station0 Station0      39240    39240
# Train_4   Train Trip Station0 Station2      40020    40980
# Train_1   Train Trip Station0 Station2      40020    40980
# Train_3   Train Trip Station2 Station0      40080    41040
# Train_2   Train Trip Station2 Station0      40080    41040
# Train_4 Light Travel Station2 Station2      40980    40980
# Train_1 Light Travel Station2 Station2      40980    40980
# Train_3 Light Travel Station0 Station0      41040    41040
# Train_2 Light Travel Station0 Station0      41040    41040
# Train_2   Train Trip Station0 Station2      41820    42780
# Train_3   Train Trip Station0 Station2      41820    42780
# Train_1   Train Trip Station2 Station0      41880    42840
# Train_4   Train Trip Station2 Station0      41880    42840
# Train_2 Light Travel Station2 Station2      42780    42780
# Train_3 Light Travel Station2 Station2      42780    42780
# Train_1 Light Travel Station0 Station0      42840    42840
# Train_4 Light Travel Station0 Station0      42840    42840
# Train_4   Train Trip Station0 Station2      43620    44580
# Train_1   Train Trip Station0 Station2      43620    44580
# Train_3   Train Trip Station2 Station0      43680    44640
# Train_2   Train Trip Station2 Station0      43680    44640
# Train_4 Light Travel Station2 Station2      44580    44580
# Train_1 Light Travel Station2 Station2      44580    44580
# Train_3 Light Travel Station0 Station0      44640    44640
# Train_2 Light Travel Station0 Station0      44640    44640
# Train_2   Train Trip Station0 Station2      45420    46380
# Train_3   Train Trip Station0 Station2      45420    46380
# Train_1   Train Trip Station2 Station0      45480    46440
# Train_4   Train Trip Station2 Station0      45480    46440
# Train_2 Light Travel Station2 Station2      46380    46380
# Train_3 Light Travel Station2 Station2      46380    46380
# Train_1 Light Travel Station0 Station0      46440    46440
# Train_4 Light Travel Station0 Station0      46440    46440
# Train_4   Train Trip Station0 Station2      47220    48180
# Train_1   Train Trip Station0 Station2      47220    48180
# Train_3   Train Trip Station2 Station0      47280    48240
# Train_2   Train Trip Station2 Station0      47280    48240
# Train_4 Light Travel Station2 Station2      48180    48180
# Train_1 Light Travel Station2 Station2      48180    48180
# Train_3 Light Travel Station0 Station0      48240    48240
# Train_2 Light Travel Station0 Station0      48240    48240
# Train_2   Train Trip Station0 Station2      49020    49980
# Train_3   Train Trip Station0 Station2      49020    49980
# Train_1   Train Trip Station2 Station0      49080    50040
# Train_4   Train Trip Station2 Station0      49080    50040
# Train_2 Light Travel Station2 Station2      49980    49980
# Train_3 Light Travel Station2 Station2      49980    49980
# Train_1 Light Travel Station0 Station0      50040    50040
# Train_4 Light Travel Station0 Station0      50040    50040
# Train_4   Train Trip Station0 Station2      50820    51780
# Train_1   Train Trip Station0 Station2      50820    51780
# Train_3   Train Trip Station2 Station0      50880    51840
# Train_2   Train Trip Station2 Station0      50880    51840
# Train_4 Light Travel Station2 Station2      51780    51780
# Train_1 Light Travel Station2 Station2      51780    51780
# Train_3 Light Travel Station0 Station0      51840    51840
# Train_2 Light Travel Station0 Station0      51840    51840
# Train_2   Train Trip Station0 Station2      52620    53580
# Train_3   Train Trip Station0 Station2      52620    53580
# Train_1   Train Trip Station2 Station0      52680    53640
# Train_4   Train Trip Station2 Station0      52680    53640
# Train_2 Light Travel Station2 Station2      53580    53580
# Train_3 Light Travel Station2 Station2      53580    53580
# Train_1 Light Travel Station0 Station0      53640    53640
# Train_4 Light Travel Station0 Station0      53640    53640
# Train_4   Train Trip Station0 Station2      54420    55380
# Train_1   Train Trip Station0 Station2      54420    55380
# Train_3   Train Trip Station2 Station0      54480    55440
# Train_2   Train Trip Station2 Station0      54480    55440
# Train_4 Light Travel Station2 Station2      55380    55380
# Train_1 Light Travel Station2 Station2      55380    55380
# Train_3 Light Travel Station0 Station0      55440    55440
# Train_2 Light Travel Station0 Station0      55440    55440
# Train_2   Train Trip Station0 Station2      56220    57180
# Train_3   Train Trip Station0 Station2      56220    57180
# Train_1   Train Trip Station2 Station0      56280    57240
# Train_4   Train Trip Station2 Station0      56280    57240
# Train_2 Light Travel Station2 Station2      57180    57180
# Train_3 Light Travel Station2 Station2      57180    57180
# Train_1 Light Travel Station0 Station0      57240    57240
# Train_4 Light Travel Station0 Station0      57240    57240
# Train_4   Train Trip Station0 Station2      58020    58980
# Train_1   Train Trip Station0 Station2      58020    58980
# Train_3   Train Trip Station2 Station0      58080    59040
# Train_2   Train Trip Station2 Station0      58080    59040
# Train_4 Light Travel Station2 Station2      58980    58980
# Train_1 Light Travel Station2 Station2      58980    58980
# Train_3 Light Travel Station0 Station0      59040    59040
# Train_2 Light Travel Station0 Station0      59040    59040
# Train_2   Train Trip Station0 Station2      59820    60780
# Train_3   Train Trip Station0 Station2      59820    60780
# Train_1   Train Trip Station2 Station0      59880    60840
# Train_4   Train Trip Station2 Station0      59880    60840
# Train_2 Light Travel Station2 Station2      60780    60780
# Train_3 Light Travel Station2 Station2      60780    60780
# Train_1 Light Travel Station0 Station0      60840    60840
# Train_4 Light Travel Station0 Station0      60840    60840
# Train_1   Train Trip Station0 Station2      61620    62580
# Train_4   Train Trip Station0 Station2      61620    62580
# Train_3   Train Trip Station2 Station0      61680    62640
# Train_2   Train Trip Station2 Station0      61680    62640
# Train_1 Light Travel Station2 Station2      62580    62580
# Train_4 Light Travel Station2 Station2      62580    62580
# Train_3 Light Travel Station0 Station0      62640    62640
# Train_2 Light Travel Station0 Station0      62640    62640
# Train_3   Train Trip Station0 Station2      63420    64380
# Train_2   Train Trip Station0 Station2      63420    64380
# Train_1   Train Trip Station2 Station0      63480    64440
# Train_4   Train Trip Station2 Station0      63480    64440
# Train_3 Light Travel Station2 Station2      64380    64380
# Train_2 Light Travel Station2 Station2      64380    64380
# Train_1 Light Travel Station0 Station0      64440    64440
# Train_4 Light Travel Station0 Station0      64440    64440
# Train_4   Train Trip Station0 Station2      65220    66180
# Train_1   Train Trip Station0 Station2      65220    66180
# Train_2   Train Trip Station2 Station0      65280    66240
# Train_3   Train Trip Station2 Station0      65280    66240
# Train_4 Light Travel Station2 Station2      66180    66180
# Train_1 Light Travel Station2 Station2      66180    66180
# Train_2 Light Travel Station0 Station0      66240    66240
# Train_3 Light Travel Station0 Station0      66240    66240
# Train_3   Train Trip Station0 Station2      67020    67980
# Train_2   Train Trip Station0 Station2      67020    67980
# Train_1   Train Trip Station2 Station0      67080    68040
# Train_4   Train Trip Station2 Station0      67080    68040
# Train_3 Light Travel Station2 Station2      67980    67980
# Train_2 Light Travel Station2 Station2      67980    67980
# Train_1 Light Travel Station0 Station0      68040    68040
# Train_4 Light Travel Station0 Station0      68040    68040
# Train_1   Train Trip Station0 Station2      68820    69780
# Train_4   Train Trip Station0 Station2      68820    69780
# Train_2   Train Trip Station2 Station0      68880    69840
# Train_3   Train Trip Station2 Station0      68880    69840
# Train_1 Light Travel Station2 Station2      69780    69780
# Train_4 Light Travel Station2 Station2      69780    69780
# Train_2 Light Travel Station0 Station0      69840    69840
# Train_3 Light Travel Station0 Station0      69840    69840
# Train_2   Train Trip Station0 Station2      70620    71580
# Train_3   Train Trip Station0 Station2      70620    71580
# Train_1   Train Trip Station2 Station0      70680    71640
# Train_4   Train Trip Station2 Station0      70680    71640
# Train_2 Light Travel Station2 Station2      71580    71580
# Train_3 Light Travel Station2 Station2      71580    71580
# Train_1 Light Travel Station0 Station0      71640    71640
# Train_4 Light Travel Station0 Station0      71640    71640
# Train_1   Train Trip Station0 Station2      72420    73380
# Train_4   Train Trip Station0 Station2      72420    73380
# Train_2   Train Trip Station2 Station0      72480    73440
# Train_3   Train Trip Station2 Station0      72480    73440
# Train_1 Light Travel Station2 Station2      73380    73380
# Train_4 Light Travel Station2 Station2      73380    73380
# Train_2 Light Travel Station0 Station0      73440    73440
# Train_3 Light Travel Station0 Station0      73440    73440
# Train_2   Train Trip Station0 Station2      74220    75180
# Train_3   Train Trip Station0 Station2      74220    75180
# Train_1   Train Trip Station2 Station0      74280    75240
# Train_4   Train Trip Station2 Station0      74280    75240
# Train_2 Light Travel Station2 Station2      75180    75180
# Train_3 Light Travel Station2 Station2      75180    75180
# Train_1 Light Travel Station0 Station0      75240    75240
# Train_4 Light Travel Station0 Station0      75240    75240
# Train_1   Train Trip Station0 Station2      76020    76980
# Train_4   Train Trip Station0 Station2      76020    76980
# Train_2   Train Trip Station2 Station0      76080    77040
# Train_3   Train Trip Station2 Station0      76080    77040
# Train_1 Light Travel Station2 Station2      76980    76980
# Train_4 Light Travel Station2 Station2      76980    76980
# Train_2 Light Travel Station0 Station0      77040    77040
# Train_3 Light Travel Station0 Station0      77040    77040
# Train_2   Train Trip Station0 Station2      77820    78780
# Train_3   Train Trip Station0 Station2      77820    78780
# Train_1   Train Trip Station2 Station0      77880    78840
# Train_4   Train Trip Station2 Station0      77880    78840
# Train_2 Light Travel Station2 Station2      78780    78780
# Train_3 Light Travel Station2 Station2      78780    78780
# Train_1 Light Travel Station0 Station0      78840    78840
# Train_4 Light Travel Station0 Station0      78840    78840
# Train_1   Train Trip Station0 Station2      79620    80580
# Train_4   Train Trip Station0 Station2      79620    80580
# Train_2   Train Trip Station2 Station0      79680    80640
# Train_3   Train Trip Station2 Station0      79680    80640
# Train_1 Light Travel Station2 Station2      80580    80580
# Train_4 Light Travel Station2 Station2      80580    80580
# Train_2 Light Travel Station0 Station0      80640    80640
# Train_3 Light Travel Station0 Station0      80640    80640
# Train_2   Train Trip Station0 Station2      81420    82380
# Train_3   Train Trip Station0 Station2      81420    82380
# Train_1   Train Trip Station2 Station0      81480    82440
# Train_4   Train Trip Station2 Station0      81480    82440
# Train_2 Light Travel Station2 Station2      82380    82380
# Train_3 Light Travel Station2 Station2      82380    82380
# Train_1 Light Travel Station0 Station0      82440    82440
# Train_4 Light Travel Station0 Station0      82440    82440
# Train_1   Train Trip Station0 Station2      83220    84180
# Train_4   Train Trip Station0 Station2      83220    84180
# Train_2   Train Trip Station2 Station0      83280    84240
# Train_3   Train Trip Station2 Station0      83280    84240
# Train_1 Light Travel Station2 Station2      84180    84180
# Train_4 Light Travel Station2 Station2      84180    84180
# Train_2 Light Travel Station0 Station0      84240    84240
# Train_3 Light Travel Station0 Station0      84240    84240
# Train_2   Train Trip Station0 Station1      85080    85620
# Train_3   Train Trip Station0 Station1      85080    85620
# Train_1   Train Trip Station2 Station0      85080    86040
# Train_4   Train Trip Station2 Station0      85080    86040
# Train_2 Light Travel Station1 Station1      85620    85620
# Train_3 Light Travel Station1 Station1      85620    85620
# Train_1 Light Travel Station0 Station0      86040    86040
# Train_4 Light Travel Station0 Station0      86040    86040
# Train_1   Train Trip Station0 Station1      86880    87420
# Train_4   Train Trip Station0 Station1      86880    87420
# Train_1 Light Travel Station1 Station1      87420    87420
# Train_4 Light Travel Station1 Station1      87420    87420
# Train_4   Train Trip Station1 Station0     105180   105900
# Train_3   Train Trip Station1 Station0     105180   105900
# Train_4 Light Travel Station0 Station0     105900   105900
# Train_3 Light Travel Station0 Station0     105900   105900
# Train_4   Train Trip Station0 Station2     106620   107580
# Train_3   Train Trip Station0 Station2     106620   107580
# Train_1   Train Trip Station1 Station0     106980   107700
# Train_2   Train Trip Station1 Station0     106980   107700
# Train_4 Light Travel Station2 Station2     107580   107580
# Train_3 Light Travel Station2 Station2     107580   107580
# Train_1 Light Travel Station0 Station0     107700   107700
# Train_2 Light Travel Station0 Station0     107700   107700
# Train_1   Train Trip Station0 Station2     108420   109380
# Train_2   Train Trip Station0 Station2     108420   109380
# Train_4   Train Trip Station2 Station0     108480   109440
# Train_3   Train Trip Station2 Station0     108480   109440
# Train_1 Light Travel Station2 Station2     109380   109380
# Train_2 Light Travel Station2 Station2     109380   109380
# Train_4 Light Travel Station0 Station0     109440   109440
# Train_3 Light Travel Station0 Station0     109440   109440
# Train_4   Train Trip Station0 Station2     110220   111180
# Train_3   Train Trip Station0 Station2     110220   111180
# Train_1   Train Trip Station2 Station0     110280   111240
# Train_2   Train Trip Station2 Station0     110280   111240
# Train_4 Light Travel Station2 Station2     111180   111180
# Train_3 Light Travel Station2 Station2     111180   111180
# Train_1 Light Travel Station0 Station0     111240   111240
# Train_2 Light Travel Station0 Station0     111240   111240
# Train_1   Train Trip Station0 Station2     112020   112980
# Train_2   Train Trip Station0 Station2     112020   112980
# Train_4   Train Trip Station2 Station0     112080   113040
# Train_3   Train Trip Station2 Station0     112080   113040
# Train_1 Light Travel Station2 Station2     112980   112980
# Train_2 Light Travel Station2 Station2     112980   112980
# Train_4 Light Travel Station0 Station0     113040   113040
# Train_3 Light Travel Station0 Station0     113040   113040
# Train_4   Train Trip Station0 Station2     113820   114780
# Train_3   Train Trip Station0 Station2     113820   114780
# Train_1   Train Trip Station2 Station0     113880   114840
# Train_2   Train Trip Station2 Station0     113880   114840
# Train_4 Light Travel Station2 Station2     114780   114780
# Train_3 Light Travel Station2 Station2     114780   114780
# Train_1 Light Travel Station0 Station0     114840   114840
# Train_2 Light Travel Station0 Station0     114840   114840
# Train_1   Train Trip Station0 Station2     115620   116580
# Train_2   Train Trip Station0 Station2     115620   116580
# Train_4   Train Trip Station2 Station0     115680   116640
# Train_3   Train Trip Station2 Station0     115680   116640
# Train_1 Light Travel Station2 Station2     116580   116580
# Train_2 Light Travel Station2 Station2     116580   116580
# Train_4 Light Travel Station0 Station0     116640   116640
# Train_3 Light Travel Station0 Station0     116640   116640
# Train_4   Train Trip Station0 Station2     117420   118380
# Train_3   Train Trip Station0 Station2     117420   118380
# Train_1   Train Trip Station2 Station0     117480   118440
# Train_2   Train Trip Station2 Station0     117480   118440
# Train_4 Light Travel Station2 Station2     118380   118380
# Train_3 Light Travel Station2 Station2     118380   118380
# Train_1 Light Travel Station0 Station0     118440   118440
# Train_2 Light Travel Station0 Station0     118440   118440
# Train_1   Train Trip Station0 Station2     119220   120180
# Train_2   Train Trip Station0 Station2     119220   120180
# Train_4   Train Trip Station2 Station0     119280   120240
# Train_3   Train Trip Station2 Station0     119280   120240
# Train_1 Light Travel Station2 Station2     120180   120180
# Train_2 Light Travel Station2 Station2     120180   120180
# Train_4 Light Travel Station0 Station0     120240   120240
# Train_3 Light Travel Station0 Station0     120240   120240
# Train_4   Train Trip Station0 Station2     121020   121980
# Train_3   Train Trip Station0 Station2     121020   121980
# Train_1   Train Trip Station2 Station0     121080   122040
# Train_2   Train Trip Station2 Station0     121080   122040
# Train_4 Light Travel Station2 Station2     121980   121980
# Train_3 Light Travel Station2 Station2     121980   121980
# Train_1 Light Travel Station0 Station0     122040   122040
# Train_2 Light Travel Station0 Station0     122040   122040
# Train_1   Train Trip Station0 Station2     122820   123780
# Train_2   Train Trip Station0 Station2     122820   123780
# Train_4   Train Trip Station2 Station0     122880   123840
# Train_3   Train Trip Station2 Station0     122880   123840
# Train_1 Light Travel Station2 Station2     123780   123780
# Train_2 Light Travel Station2 Station2     123780   123780
# Train_4 Light Travel Station0 Station0     123840   123840
# Train_3 Light Travel Station0 Station0     123840   123840
# Train_4   Train Trip Station0 Station2     124620   125580
# Train_3   Train Trip Station0 Station2     124620   125580
# Train_1   Train Trip Station2 Station0     124680   125640
# Train_2   Train Trip Station2 Station0     124680   125640
# Train_4 Light Travel Station2 Station2     125580   125580
# Train_3 Light Travel Station2 Station2     125580   125580
# Train_1 Light Travel Station0 Station0     125640   125640
# Train_2 Light Travel Station0 Station0     125640   125640
# Train_1   Train Trip Station0 Station2     126420   127380
# Train_2   Train Trip Station0 Station2     126420   127380
# Train_4   Train Trip Station2 Station0     126480   127440
# Train_3   Train Trip Station2 Station0     126480   127440
# Train_1 Light Travel Station2 Station2     127380   127380
# Train_2 Light Travel Station2 Station2     127380   127380
# Train_4 Light Travel Station0 Station0     127440   127440
# Train_3 Light Travel Station0 Station0     127440   127440
# Train_4   Train Trip Station0 Station2     128220   129180
# Train_3   Train Trip Station0 Station2     128220   129180
# Train_1   Train Trip Station2 Station0     128280   129240
# Train_2   Train Trip Station2 Station0     128280   129240
# Train_4 Light Travel Station2 Station2     129180   129180
# Train_3 Light Travel Station2 Station2     129180   129180
# Train_1 Light Travel Station0 Station0     129240   129240
# Train_2 Light Travel Station0 Station0     129240   129240
# Train_2   Train Trip Station0 Station2     130020   130980
# Train_1   Train Trip Station0 Station2     130020   130980
# Train_4   Train Trip Station2 Station0     130080   131040
# Train_3   Train Trip Station2 Station0     130080   131040
# Train_2 Light Travel Station2 Station2     130980   130980
# Train_1 Light Travel Station2 Station2     130980   130980
# Train_4 Light Travel Station0 Station0     131040   131040
# Train_3 Light Travel Station0 Station0     131040   131040
# Train_3   Train Trip Station0 Station2     131820   132780
# Train_4   Train Trip Station0 Station2     131820   132780
# Train_2   Train Trip Station2 Station0     131880   132840
# Train_1   Train Trip Station2 Station0     131880   132840
# Train_3 Light Travel Station2 Station2     132780   132780
# Train_4 Light Travel Station2 Station2     132780   132780
# Train_2 Light Travel Station0 Station0     132840   132840
# Train_1 Light Travel Station0 Station0     132840   132840
# Train_1   Train Trip Station0 Station2     133620   134580
# Train_2   Train Trip Station0 Station2     133620   134580
# Train_3   Train Trip Station2 Station0     133680   134640
# Train_4   Train Trip Station2 Station0     133680   134640
# Train_1 Light Travel Station2 Station2     134580   134580
# Train_2 Light Travel Station2 Station2     134580   134580
# Train_3 Light Travel Station0 Station0     134640   134640
# Train_4 Light Travel Station0 Station0     134640   134640
# Train_4   Train Trip Station0 Station2     135420   136380
# Train_3   Train Trip Station0 Station2     135420   136380
# Train_1   Train Trip Station2 Station0     135480   136440
# Train_2   Train Trip Station2 Station0     135480   136440
# Train_4 Light Travel Station2 Station2     136380   136380
# Train_3 Light Travel Station2 Station2     136380   136380
# Train_1 Light Travel Station0 Station0     136440   136440
# Train_2 Light Travel Station0 Station0     136440   136440
# Train_2   Train Trip Station0 Station2     137220   138180
# Train_1   Train Trip Station0 Station2     137220   138180
# Train_3   Train Trip Station2 Station0     137280   138240
# Train_4   Train Trip Station2 Station0     137280   138240
# Train_2 Light Travel Station2 Station2     138180   138180
# Train_1 Light Travel Station2 Station2     138180   138180
# Train_3 Light Travel Station0 Station0     138240   138240
# Train_4 Light Travel Station0 Station0     138240   138240
# Train_4   Train Trip Station0 Station2     139020   139980
# Train_3   Train Trip Station0 Station2     139020   139980
# Train_1   Train Trip Station2 Station0     139080   140040
# Train_2   Train Trip Station2 Station0     139080   140040
# Train_4 Light Travel Station2 Station2     139980   139980
# Train_3 Light Travel Station2 Station2     139980   139980
# Train_1 Light Travel Station0 Station0     140040   140040
# Train_2 Light Travel Station0 Station0     140040   140040
# Train_2   Train Trip Station0 Station2     140820   141780
# Train_1   Train Trip Station0 Station2     140820   141780
# Train_3   Train Trip Station2 Station0     140880   141840
# Train_4   Train Trip Station2 Station0     140880   141840
# Train_2 Light Travel Station2 Station2     141780   141780
# Train_1 Light Travel Station2 Station2     141780   141780
# Train_3 Light Travel Station0 Station0     141840   141840
# Train_4 Light Travel Station0 Station0     141840   141840
# Train_4   Train Trip Station0 Station2     142620   143580
# Train_3   Train Trip Station0 Station2     142620   143580
# Train_1   Train Trip Station2 Station0     142680   143640
# Train_2   Train Trip Station2 Station0     142680   143640
# Train_4 Light Travel Station2 Station2     143580   143580
# Train_3 Light Travel Station2 Station2     143580   143580
# Train_1 Light Travel Station0 Station0     143640   143640
# Train_2 Light Travel Station0 Station0     143640   143640
# Train_2   Train Trip Station0 Station2     144420   145380
# Train_1   Train Trip Station0 Station2     144420   145380
# Train_3   Train Trip Station2 Station0     144480   145440
# Train_4   Train Trip Station2 Station0     144480   145440
# Train_2 Light Travel Station2 Station2     145380   145380
# Train_1 Light Travel Station2 Station2     145380   145380
# Train_3 Light Travel Station0 Station0     145440   145440
# Train_4 Light Travel Station0 Station0     145440   145440
# Train_4   Train Trip Station0 Station2     146220   147180
# Train_3   Train Trip Station0 Station2     146220   147180
# Train_1   Train Trip Station2 Station0     146280   147240
# Train_2   Train Trip Station2 Station0     146280   147240
# Train_4 Light Travel Station2 Station2     147180   147180
# Train_3 Light Travel Station2 Station2     147180   147180
# Train_1 Light Travel Station0 Station0     147240   147240
# Train_2 Light Travel Station0 Station0     147240   147240
# Train_2   Train Trip Station0 Station2     148020   148980
# Train_1   Train Trip Station0 Station2     148020   148980
# Train_3   Train Trip Station2 Station0     148080   149040
# Train_4   Train Trip Station2 Station0     148080   149040
# Train_2 Light Travel Station2 Station2     148980   148980
# Train_1 Light Travel Station2 Station2     148980   148980
# Train_3 Light Travel Station0 Station0     149040   149040
# Train_4 Light Travel Station0 Station0     149040   149040
# Train_3   Train Trip Station0 Station2     149820   150780
# Train_4   Train Trip Station0 Station2     149820   150780
# Train_1   Train Trip Station2 Station0     149880   150840
# Train_2   Train Trip Station2 Station0     149880   150840
# Train_3 Light Travel Station2 Station2     150780   150780
# Train_4 Light Travel Station2 Station2     150780   150780
# Train_1 Light Travel Station0 Station0     150840   150840
# Train_2 Light Travel Station0 Station0     150840   150840
# Train_2   Train Trip Station0 Station2     151620   152580
# Train_1   Train Trip Station0 Station2     151620   152580
# Train_4   Train Trip Station2 Station0     151680   152640
# Train_3   Train Trip Station2 Station0     151680   152640
# Train_2 Light Travel Station2 Station2     152580   152580
# Train_1 Light Travel Station2 Station2     152580   152580
# Train_4 Light Travel Station0 Station0     152640   152640
# Train_3 Light Travel Station0 Station0     152640   152640
# Train_3   Train Trip Station0 Station2     153420   154380
# Train_4   Train Trip Station0 Station2     153420   154380
# Train_1   Train Trip Station2 Station0     153480   154440
# Train_2   Train Trip Station2 Station0     153480   154440
# Train_3 Light Travel Station2 Station2     154380   154380
# Train_4 Light Travel Station2 Station2     154380   154380
# Train_1 Light Travel Station0 Station0     154440   154440
# Train_2 Light Travel Station0 Station0     154440   154440
# Train_2   Train Trip Station0 Station2     155220   156180
# Train_1   Train Trip Station0 Station2     155220   156180
# Train_4   Train Trip Station2 Station0     155280   156240
# Train_3   Train Trip Station2 Station0     155280   156240
# Train_2 Light Travel Station2 Station2     156180   156180
# Train_1 Light Travel Station2 Station2     156180   156180
# Train_4 Light Travel Station0 Station0     156240   156240
# Train_3 Light Travel Station0 Station0     156240   156240
# Train_3   Train Trip Station0 Station2     157020   157980
# Train_4   Train Trip Station0 Station2     157020   157980
# Train_1   Train Trip Station2 Station0     157080   158040
# Train_2   Train Trip Station2 Station0     157080   158040
# Train_3 Light Travel Station2 Station2     157980   157980
# Train_4 Light Travel Station2 Station2     157980   157980
# Train_1 Light Travel Station0 Station0     158040   158040
# Train_2 Light Travel Station0 Station0     158040   158040
# Train_2   Train Trip Station0 Station2     158820   159780
# Train_1   Train Trip Station0 Station2     158820   159780
# Train_4   Train Trip Station2 Station0     158880   159840
# Train_3   Train Trip Station2 Station0     158880   159840
# Train_2 Light Travel Station2 Station2     159780   159780
# Train_1 Light Travel Station2 Station2     159780   159780
# Train_4 Light Travel Station0 Station0     159840   159840
# Train_3 Light Travel Station0 Station0     159840   159840
# Train_3   Train Trip Station0 Station2     160620   161580
# Train_4   Train Trip Station0 Station2     160620   161580
# Train_1   Train Trip Station2 Station0     160680   161640
# Train_2   Train Trip Station2 Station0     160680   161640
# Train_3 Light Travel Station2 Station2     161580   161580
# Train_4 Light Travel Station2 Station2     161580   161580
# Train_1 Light Travel Station0 Station0     161640   161640
# Train_2 Light Travel Station0 Station0     161640   161640
# Train_2   Train Trip Station0 Station2     162420   163380
# Train_1   Train Trip Station0 Station2     162420   163380
# Train_4   Train Trip Station2 Station0     162480   163440
# Train_3   Train Trip Station2 Station0     162480   163440
# Train_2 Light Travel Station2 Station2     163380   163380
# Train_1 Light Travel Station2 Station2     163380   163380
# Train_4 Light Travel Station0 Station0     163440   163440
# Train_3 Light Travel Station0 Station0     163440   163440
# Train_3   Train Trip Station0 Station2     164220   165180
# Train_4   Train Trip Station0 Station2     164220   165180
# Train_1   Train Trip Station2 Station0     164280   165240
# Train_2   Train Trip Station2 Station0     164280   165240
# Train_3 Light Travel Station2 Station2     165180   165180
# Train_4 Light Travel Station2 Station2     165180   165180
# Train_1 Light Travel Station0 Station0     165240   165240
# Train_2 Light Travel Station0 Station0     165240   165240
# Train_2   Train Trip Station0 Station2     166020   166980
# Train_1   Train Trip Station0 Station2     166020   166980
# Train_4   Train Trip Station2 Station0     166080   167040
# Train_3   Train Trip Station2 Station0     166080   167040
# Train_2 Light Travel Station2 Station2     166980   166980
# Train_1 Light Travel Station2 Station2     166980   166980
# Train_4 Light Travel Station0 Station0     167040   167040
# Train_3 Light Travel Station0 Station0     167040   167040
# Train_3   Train Trip Station0 Station2     167820   168780
# Train_4   Train Trip Station0 Station2     167820   168780
# Train_1   Train Trip Station2 Station0     167880   168840
# Train_2   Train Trip Station2 Station0     167880   168840
# Train_3 Light Travel Station2 Station2     168780   168780
# Train_4 Light Travel Station2 Station2     168780   168780
# Train_1 Light Travel Station0 Station0     168840   168840
# Train_2 Light Travel Station0 Station0     168840   168840
# Train_2   Train Trip Station0 Station2     169620   170580
# Train_1   Train Trip Station0 Station2     169620   170580
# Train_4   Train Trip Station2 Station0     169680   170640
# Train_3   Train Trip Station2 Station0     169680   170640
# Train_2 Light Travel Station2 Station2     170580   170580
# Train_1 Light Travel Station2 Station2     170580   170580
# Train_4 Light Travel Station0 Station0     170640   170640
# Train_3 Light Travel Station0 Station0     170640   170640
# Train_3   Train Trip Station0 Station1     171480   172020
# Train_4   Train Trip Station0 Station1     171480   172020
# Train_1   Train Trip Station2 Station0     171480   172440
# Train_2   Train Trip Station2 Station0     171480   172440
# Train_3 Light Travel Station1 Station1     172020   172020
# Train_4 Light Travel Station1 Station1     172020   172020
# Train_1 Light Travel Station0 Station0     172440   172440
# Train_2 Light Travel Station0 Station0     172440   172440
# Train_2   Train Trip Station0 Station1     173280   173820
# Train_1   Train Trip Station0 Station1     173280   173820
# Train_2 Light Travel Station1 Station1     173820   173820
# Train_1 Light Travel Station1 Station1     173820   173820
# Train_1   Train Trip Station1 Station0     191580   192300
# Train_2   Train Trip Station1 Station0     191580   192300
# Train_1 Light Travel Station0 Station0     192300   192300
# Train_2 Light Travel Station0 Station0     192300   192300
# Train_2   Train Trip Station0 Station2     193020   193980
# Train_1   Train Trip Station0 Station2     193020   193980
# Train_4   Train Trip Station1 Station0     193380   194100
# Train_3   Train Trip Station1 Station0     193380   194100
# Train_2 Light Travel Station2 Station2     193980   193980
# Train_1 Light Travel Station2 Station2     193980   193980
# Train_4 Light Travel Station0 Station0     194100   194100
# Train_3 Light Travel Station0 Station0     194100   194100
# Train_3   Train Trip Station0 Station2     194820   195780
# Train_4   Train Trip Station0 Station2     194820   195780
# Train_1   Train Trip Station2 Station0     194880   195840
# Train_2   Train Trip Station2 Station0     194880   195840
# Train_3 Light Travel Station2 Station2     195780   195780
# Train_4 Light Travel Station2 Station2     195780   195780
# Train_1 Light Travel Station0 Station0     195840   195840
# Train_2 Light Travel Station0 Station0     195840   195840
# Train_2   Train Trip Station0 Station2     196620   197580
# Train_1   Train Trip Station0 Station2     196620   197580
# Train_4   Train Trip Station2 Station0     196680   197640
# Train_3   Train Trip Station2 Station0     196680   197640
# Train_2 Light Travel Station2 Station2     197580   197580
# Train_1 Light Travel Station2 Station2     197580   197580
# Train_4 Light Travel Station0 Station0     197640   197640
# Train_3 Light Travel Station0 Station0     197640   197640
# Train_3   Train Trip Station0 Station2     198420   199380
# Train_4   Train Trip Station0 Station2     198420   199380
# Train_1   Train Trip Station2 Station0     198480   199440
# Train_2   Train Trip Station2 Station0     198480   199440
# Train_3 Light Travel Station2 Station2     199380   199380
# Train_4 Light Travel Station2 Station2     199380   199380
# Train_1 Light Travel Station0 Station0     199440   199440
# Train_2 Light Travel Station0 Station0     199440   199440
# Train_2   Train Trip Station0 Station2     200220   201180
# Train_1   Train Trip Station0 Station2     200220   201180
# Train_4   Train Trip Station2 Station0     200280   201240
# Train_3   Train Trip Station2 Station0     200280   201240
# Train_2 Light Travel Station2 Station2     201180   201180
# Train_1 Light Travel Station2 Station2     201180   201180
# Train_4 Light Travel Station0 Station0     201240   201240
# Train_3 Light Travel Station0 Station0     201240   201240
# Train_3   Train Trip Station0 Station2     202020   202980
# Train_4   Train Trip Station0 Station2     202020   202980
# Train_1   Train Trip Station2 Station0     202080   203040
# Train_2   Train Trip Station2 Station0     202080   203040
# Train_3 Light Travel Station2 Station2     202980   202980
# Train_4 Light Travel Station2 Station2     202980   202980
# Train_1 Light Travel Station0 Station0     203040   203040
# Train_2 Light Travel Station0 Station0     203040   203040
# Train_2   Train Trip Station0 Station2     203820   204780
# Train_1   Train Trip Station0 Station2     203820   204780
# Train_4   Train Trip Station2 Station0     203880   204840
# Train_3   Train Trip Station2 Station0     203880   204840
# Train_2 Light Travel Station2 Station2     204780   204780
# Train_1 Light Travel Station2 Station2     204780   204780
# Train_4 Light Travel Station0 Station0     204840   204840
# Train_3 Light Travel Station0 Station0     204840   204840
# Train_3   Train Trip Station0 Station2     205620   206580
# Train_4   Train Trip Station0 Station2     205620   206580
# Train_1   Train Trip Station2 Station0     205680   206640
# Train_2   Train Trip Station2 Station0     205680   206640
# Train_3 Light Travel Station2 Station2     206580   206580
# Train_4 Light Travel Station2 Station2     206580   206580
# Train_1 Light Travel Station0 Station0     206640   206640
# Train_2 Light Travel Station0 Station0     206640   206640
# Train_2   Train Trip Station0 Station2     207420   208380
# Train_1   Train Trip Station0 Station2     207420   208380
# Train_4   Train Trip Station2 Station0     207480   208440
# Train_3   Train Trip Station2 Station0     207480   208440
# Train_2 Light Travel Station2 Station2     208380   208380
# Train_1 Light Travel Station2 Station2     208380   208380
# Train_4 Light Travel Station0 Station0     208440   208440
# Train_3 Light Travel Station0 Station0     208440   208440
# Train_3   Train Trip Station0 Station2     209220   210180
# Train_4   Train Trip Station0 Station2     209220   210180
# Train_1   Train Trip Station2 Station0     209280   210240
# Train_2   Train Trip Station2 Station0     209280   210240
# Train_3 Light Travel Station2 Station2     210180   210180
# Train_4 Light Travel Station2 Station2     210180   210180
# Train_1 Light Travel Station0 Station0     210240   210240
# Train_2 Light Travel Station0 Station0     210240   210240
# Train_2   Train Trip Station0 Station2     211020   211980
# Train_1   Train Trip Station0 Station2     211020   211980
# Train_4   Train Trip Station2 Station0     211080   212040
# Train_3   Train Trip Station2 Station0     211080   212040
# Train_2 Light Travel Station2 Station2     211980   211980
# Train_1 Light Travel Station2 Station2     211980   211980
# Train_4 Light Travel Station0 Station0     212040   212040
# Train_3 Light Travel Station0 Station0     212040   212040
# Train_3   Train Trip Station0 Station2     212820   213780
# Train_4   Train Trip Station0 Station2     212820   213780
# Train_1   Train Trip Station2 Station0     212880   213840
# Train_2   Train Trip Station2 Station0     212880   213840
# Train_3 Light Travel Station2 Station2     213780   213780
# Train_4 Light Travel Station2 Station2     213780   213780
# Train_1 Light Travel Station0 Station0     213840   213840
# Train_2 Light Travel Station0 Station0     213840   213840
# Train_2   Train Trip Station0 Station2     214620   215580
# Train_1   Train Trip Station0 Station2     214620   215580
# Train_4   Train Trip Station2 Station0     214680   215640
# Train_3   Train Trip Station2 Station0     214680   215640
# Train_2 Light Travel Station2 Station2     215580   215580
# Train_1 Light Travel Station2 Station2     215580   215580
# Train_4 Light Travel Station0 Station0     215640   215640
# Train_3 Light Travel Station0 Station0     215640   215640
# Train_3   Train Trip Station0 Station2     216420   217380
# Train_4   Train Trip Station0 Station2     216420   217380
# Train_1   Train Trip Station2 Station0     216480   217440
# Train_2   Train Trip Station2 Station0     216480   217440
# Train_3 Light Travel Station2 Station2     217380   217380
# Train_4 Light Travel Station2 Station2     217380   217380
# Train_1 Light Travel Station0 Station0     217440   217440
# Train_2 Light Travel Station0 Station0     217440   217440
# Train_2   Train Trip Station0 Station2     218220   219180
# Train_1   Train Trip Station0 Station2     218220   219180
# Train_4   Train Trip Station2 Station0     218280   219240
# Train_3   Train Trip Station2 Station0     218280   219240
# Train_2 Light Travel Station2 Station2     219180   219180
# Train_1 Light Travel Station2 Station2     219180   219180
# Train_4 Light Travel Station0 Station0     219240   219240
# Train_3 Light Travel Station0 Station0     219240   219240
# Train_3   Train Trip Station0 Station2     220020   220980
# Train_4   Train Trip Station0 Station2     220020   220980
# Train_1   Train Trip Station2 Station0     220080   221040
# Train_2   Train Trip Station2 Station0     220080   221040
# Train_3 Light Travel Station2 Station2     220980   220980
# Train_4 Light Travel Station2 Station2     220980   220980
# Train_1 Light Travel Station0 Station0     221040   221040
# Train_2 Light Travel Station0 Station0     221040   221040
# Train_2   Train Trip Station0 Station2     221820   222780
# Train_1   Train Trip Station0 Station2     221820   222780
# Train_3   Train Trip Station2 Station0     221880   222840
# Train_4   Train Trip Station2 Station0     221880   222840
# Train_2 Light Travel Station2 Station2     222780   222780
# Train_1 Light Travel Station2 Station2     222780   222780
# Train_3 Light Travel Station0 Station0     222840   222840
# Train_4 Light Travel Station0 Station0     222840   222840
# Train_4   Train Trip Station0 Station2     223620   224580
# Train_3   Train Trip Station0 Station2     223620   224580
# Train_2   Train Trip Station2 Station0     223680   224640
# Train_1   Train Trip Station2 Station0     223680   224640
# Train_4 Light Travel Station2 Station2     224580   224580
# Train_3 Light Travel Station2 Station2     224580   224580
# Train_2 Light Travel Station0 Station0     224640   224640
# Train_1 Light Travel Station0 Station0     224640   224640
# Train_1   Train Trip Station0 Station2     225420   226380
# Train_2   Train Trip Station0 Station2     225420   226380
# Train_3   Train Trip Station2 Station0     225480   226440
# Train_4   Train Trip Station2 Station0     225480   226440
# Train_1 Light Travel Station2 Station2     226380   226380
# Train_2 Light Travel Station2 Station2     226380   226380
# Train_3 Light Travel Station0 Station0     226440   226440
# Train_4 Light Travel Station0 Station0     226440   226440
# Train_4   Train Trip Station0 Station2     227220   228180
# Train_3   Train Trip Station0 Station2     227220   228180
# Train_2   Train Trip Station2 Station0     227280   228240
# Train_1   Train Trip Station2 Station0     227280   228240
# Train_4 Light Travel Station2 Station2     228180   228180
# Train_3 Light Travel Station2 Station2     228180   228180
# Train_2 Light Travel Station0 Station0     228240   228240
# Train_1 Light Travel Station0 Station0     228240   228240
# Train_1   Train Trip Station0 Station2     229020   229980
# Train_2   Train Trip Station0 Station2     229020   229980
# Train_3   Train Trip Station2 Station0     229080   230040
# Train_4   Train Trip Station2 Station0     229080   230040
# Train_1 Light Travel Station2 Station2     229980   229980
# Train_2 Light Travel Station2 Station2     229980   229980
# Train_3 Light Travel Station0 Station0     230040   230040
# Train_4 Light Travel Station0 Station0     230040   230040
# Train_4   Train Trip Station0 Station2     230820   231780
# Train_3   Train Trip Station0 Station2     230820   231780
# Train_2   Train Trip Station2 Station0     230880   231840
# Train_1   Train Trip Station2 Station0     230880   231840
# Train_4 Light Travel Station2 Station2     231780   231780
# Train_3 Light Travel Station2 Station2     231780   231780
# Train_2 Light Travel Station0 Station0     231840   231840
# Train_1 Light Travel Station0 Station0     231840   231840
# Train_1   Train Trip Station0 Station2     232620   233580
# Train_2   Train Trip Station0 Station2     232620   233580
# Train_3   Train Trip Station2 Station0     232680   233640
# Train_4   Train Trip Station2 Station0     232680   233640
# Train_1 Light Travel Station2 Station2     233580   233580
# Train_2 Light Travel Station2 Station2     233580   233580
# Train_3 Light Travel Station0 Station0     233640   233640
# Train_4 Light Travel Station0 Station0     233640   233640
# Train_4   Train Trip Station0 Station2     234420   235380
# Train_3   Train Trip Station0 Station2     234420   235380
# Train_2   Train Trip Station2 Station0     234480   235440
# Train_1   Train Trip Station2 Station0     234480   235440
# Train_4 Light Travel Station2 Station2     235380   235380
# Train_3 Light Travel Station2 Station2     235380   235380
# Train_2 Light Travel Station0 Station0     235440   235440
# Train_1 Light Travel Station0 Station0     235440   235440
# Train_1   Train Trip Station0 Station2     236220   237180
# ...
# Train_4   Train Trip Station0 Station2     544020   544980
# Train_3   Train Trip Station0 Station2     544020   544980
# Train_1   Train Trip Station2 Station0     544080   545040
# Train_2   Train Trip Station2 Station0     544080   545040
# Train_4 Light Travel Station2 Station2     544980   544980
# Train_3 Light Travel Station2 Station2     544980   544980
# Train_1 Light Travel Station0 Station0     545040   545040
# Train_2 Light Travel Station0 Station0     545040   545040
# Train_2   Train Trip Station0 Station2     545820   546780
# Train_1   Train Trip Station0 Station2     545820   546780
# Train_3   Train Trip Station2 Station0     545880   546840
# Train_4   Train Trip Station2 Station0     545880   546840
# Train_2 Light Travel Station2 Station2     546780   546780
# Train_1 Light Travel Station2 Station2     546780   546780
# Train_3 Light Travel Station0 Station0     546840   546840
# Train_4 Light Travel Station0 Station0     546840   546840
# Train_4   Train Trip Station0 Station2     547620   548580
# Train_3   Train Trip Station0 Station2     547620   548580
# Train_1   Train Trip Station2 Station0     547680   548640
# Train_2   Train Trip Station2 Station0     547680   548640
# Train_4 Light Travel Station2 Station2     548580   548580
# Train_3 Light Travel Station2 Station2     548580   548580
# Train_1 Light Travel Station0 Station0     548640   548640
# Train_2 Light Travel Station0 Station0     548640   548640
# Train_2   Train Trip Station0 Station2     549420   550380
# Train_1   Train Trip Station0 Station2     549420   550380
# Train_3   Train Trip Station2 Station0     549480   550440
# Train_4   Train Trip Station2 Station0     549480   550440
# Train_2 Light Travel Station2 Station2     550380   550380
# Train_1 Light Travel Station2 Station2     550380   550380
# Train_3 Light Travel Station0 Station0     550440   550440
# Train_4 Light Travel Station0 Station0     550440   550440
# Train_4   Train Trip Station0 Station2     551220   552180
# Train_3   Train Trip Station0 Station2     551220   552180
# Train_1   Train Trip Station2 Station0     551280   552240
# Train_2   Train Trip Station2 Station0     551280   552240
# Train_4 Light Travel Station2 Station2     552180   552180
# Train_3 Light Travel Station2 Station2     552180   552180
# Train_1 Light Travel Station0 Station0     552240   552240
# Train_2 Light Travel Station0 Station0     552240   552240
# Train_2   Train Trip Station0 Station2     553020   553980
# Train_1   Train Trip Station0 Station2     553020   553980
# Train_3   Train Trip Station2 Station0     553080   554040
# Train_4   Train Trip Station2 Station0     553080   554040
# Train_2 Light Travel Station2 Station2     553980   553980
# Train_1 Light Travel Station2 Station2     553980   553980
# Train_3 Light Travel Station0 Station0     554040   554040
# Train_4 Light Travel Station0 Station0     554040   554040
# Train_3   Train Trip Station0 Station2     554820   555780
# Train_4   Train Trip Station0 Station2     554820   555780
# Train_1   Train Trip Station2 Station0     554880   555840
# Train_2   Train Trip Station2 Station0     554880   555840
# Train_3 Light Travel Station2 Station2     555780   555780
# Train_4 Light Travel Station2 Station2     555780   555780
# Train_1 Light Travel Station0 Station0     555840   555840
# Train_2 Light Travel Station0 Station0     555840   555840
# Train_2   Train Trip Station0 Station2     556620   557580
# Train_1   Train Trip Station0 Station2     556620   557580
# Train_4   Train Trip Station2 Station0     556680   557640
# Train_3   Train Trip Station2 Station0     556680   557640
# Train_2 Light Travel Station2 Station2     557580   557580
# Train_1 Light Travel Station2 Station2     557580   557580
# Train_4 Light Travel Station0 Station0     557640   557640
# Train_3 Light Travel Station0 Station0     557640   557640
# Train_4   Train Trip Station0 Station2     558420   559380
# Train_3   Train Trip Station0 Station2     558420   559380
# Train_1   Train Trip Station2 Station0     558480   559440
# Train_2   Train Trip Station2 Station0     558480   559440
# Train_4 Light Travel Station2 Station2     559380   559380
# Train_3 Light Travel Station2 Station2     559380   559380
# Train_1 Light Travel Station0 Station0     559440   559440
# Train_2 Light Travel Station0 Station0     559440   559440
# Train_1   Train Trip Station0 Station2     560220   561180
# Train_2   Train Trip Station0 Station2     560220   561180
# Train_3   Train Trip Station2 Station0     560280   561240
# Train_4   Train Trip Station2 Station0     560280   561240
# Train_1 Light Travel Station2 Station2     561180   561180
# Train_2 Light Travel Station2 Station2     561180   561180
# Train_3 Light Travel Station0 Station0     561240   561240
# Train_4 Light Travel Station0 Station0     561240   561240
# Train_4   Train Trip Station0 Station2     562020   562980
# Train_3   Train Trip Station0 Station2     562020   562980
# Train_2   Train Trip Station2 Station0     562080   563040
# Train_1   Train Trip Station2 Station0     562080   563040
# Train_4 Light Travel Station2 Station2     562980   562980
# Train_3 Light Travel Station2 Station2     562980   562980
# Train_2 Light Travel Station0 Station0     563040   563040
# Train_1 Light Travel Station0 Station0     563040   563040
# Train_1   Train Trip Station0 Station2     563820   564780
# Train_2   Train Trip Station0 Station2     563820   564780
# Train_3   Train Trip Station2 Station0     563880   564840
# Train_4   Train Trip Station2 Station0     563880   564840
# Train_1 Light Travel Station2 Station2     564780   564780
# Train_2 Light Travel Station2 Station2     564780   564780
# Train_3 Light Travel Station0 Station0     564840   564840
# Train_4 Light Travel Station0 Station0     564840   564840
# Train_4   Train Trip Station0 Station2     565620   566580
# Train_3   Train Trip Station0 Station2     565620   566580
# Train_2   Train Trip Station2 Station0     565680   566640
# Train_1   Train Trip Station2 Station0     565680   566640
# Train_4 Light Travel Station2 Station2     566580   566580
# Train_3 Light Travel Station2 Station2     566580   566580
# Train_2 Light Travel Station0 Station0     566640   566640
# Train_1 Light Travel Station0 Station0     566640   566640
# Train_1   Train Trip Station0 Station2     567420   568380
# Train_2   Train Trip Station0 Station2     567420   568380
# Train_4   Train Trip Station2 Station0     567480   568440
# Train_3   Train Trip Station2 Station0     567480   568440
# Train_1 Light Travel Station2 Station2     568380   568380
# Train_2 Light Travel Station2 Station2     568380   568380
# Train_4 Light Travel Station0 Station0     568440   568440
# Train_3 Light Travel Station0 Station0     568440   568440
# Train_3   Train Trip Station0 Station2     569220   570180
# Train_4   Train Trip Station0 Station2     569220   570180
# Train_1   Train Trip Station2 Station0     569280   570240
# Train_2   Train Trip Station2 Station0     569280   570240
# Train_3 Light Travel Station2 Station2     570180   570180
# Train_4 Light Travel Station2 Station2     570180   570180
# Train_1 Light Travel Station0 Station0     570240   570240
# Train_2 Light Travel Station0 Station0     570240   570240
# Train_2   Train Trip Station0 Station2     571020   571980
# Train_1   Train Trip Station0 Station2     571020   571980
# Train_3   Train Trip Station2 Station0     571080   572040
# Train_4   Train Trip Station2 Station0     571080   572040
# Train_2 Light Travel Station2 Station2     571980   571980
# Train_1 Light Travel Station2 Station2     571980   571980
# Train_3 Light Travel Station0 Station0     572040   572040
# Train_4 Light Travel Station0 Station0     572040   572040
# Train_4   Train Trip Station0 Station2     572820   573780
# Train_3   Train Trip Station0 Station2     572820   573780
# Train_1   Train Trip Station2 Station0     572880   573840
# Train_2   Train Trip Station2 Station0     572880   573840
# Train_4 Light Travel Station2 Station2     573780   573780
# Train_3 Light Travel Station2 Station2     573780   573780
# Train_1 Light Travel Station0 Station0     573840   573840
# Train_2 Light Travel Station0 Station0     573840   573840
# Train_2   Train Trip Station0 Station2     574620   575580
# Train_1   Train Trip Station0 Station2     574620   575580
# Train_4   Train Trip Station2 Station0     574680   575640
# Train_3   Train Trip Station2 Station0     574680   575640
# Train_2 Light Travel Station2 Station2     575580   575580
# Train_1 Light Travel Station2 Station2     575580   575580
# Train_4 Light Travel Station0 Station0     575640   575640
# Train_3 Light Travel Station0 Station0     575640   575640
# Train_3   Train Trip Station0 Station2     576420   577380
# Train_4   Train Trip Station0 Station2     576420   577380
# Train_1   Train Trip Station2 Station0     576480   577440
# Train_2   Train Trip Station2 Station0     576480   577440
# Train_3 Light Travel Station2 Station2     577380   577380
# Train_4 Light Travel Station2 Station2     577380   577380
# Train_1 Light Travel Station0 Station0     577440   577440
# Train_2 Light Travel Station0 Station0     577440   577440
# Train_2   Train Trip Station0 Station2     578220   579180
# Train_1   Train Trip Station0 Station2     578220   579180
# Train_4   Train Trip Station2 Station0     578280   579240
# Train_3   Train Trip Station2 Station0     578280   579240
# Train_2 Light Travel Station2 Station2     579180   579180
# Train_1 Light Travel Station2 Station2     579180   579180
# Train_4 Light Travel Station0 Station0     579240   579240
# Train_3 Light Travel Station0 Station0     579240   579240
# Train_3   Train Trip Station0 Station2     580020   580980
# Train_4   Train Trip Station0 Station2     580020   580980
# Train_1   Train Trip Station2 Station0     580080   581040
# Train_2   Train Trip Station2 Station0     580080   581040
# Train_3 Light Travel Station2 Station2     580980   580980
# Train_4 Light Travel Station2 Station2     580980   580980
# Train_1 Light Travel Station0 Station0     581040   581040
# Train_2 Light Travel Station0 Station0     581040   581040
# Train_2   Train Trip Station0 Station2     581820   582780
# Train_1   Train Trip Station0 Station2     581820   582780
# Train_3   Train Trip Station2 Station0     581880   582840
# Train_4   Train Trip Station2 Station0     581880   582840
# Train_2 Light Travel Station2 Station2     582780   582780
# Train_1 Light Travel Station2 Station2     582780   582780
# Train_3 Light Travel Station0 Station0     582840   582840
# Train_4 Light Travel Station0 Station0     582840   582840
# Train_3   Train Trip Station0 Station2     583620   584580
# Train_4   Train Trip Station0 Station2     583620   584580
# Train_1   Train Trip Station2 Station0     583680   584640
# Train_2   Train Trip Station2 Station0     583680   584640
# Train_3 Light Travel Station2 Station2     584580   584580
# Train_4 Light Travel Station2 Station2     584580   584580
# Train_1 Light Travel Station0 Station0     584640   584640
# Train_2 Light Travel Station0 Station0     584640   584640
# Train_2   Train Trip Station0 Station2     585420   586380
# Train_1   Train Trip Station0 Station2     585420   586380
# Train_4   Train Trip Station2 Station0     585480   586440
# Train_3   Train Trip Station2 Station0     585480   586440
# Train_2 Light Travel Station2 Station2     586380   586380
# Train_1 Light Travel Station2 Station2     586380   586380
# Train_4 Light Travel Station0 Station0     586440   586440
# Train_3 Light Travel Station0 Station0     586440   586440
# Train_4   Train Trip Station0 Station2     587220   588180
# Train_3   Train Trip Station0 Station2     587220   588180
# Train_1   Train Trip Station2 Station0     587280   588240
# Train_2   Train Trip Station2 Station0     587280   588240
# Train_4 Light Travel Station2 Station2     588180   588180
# Train_3 Light Travel Station2 Station2     588180   588180
# Train_1 Light Travel Station0 Station0     588240   588240
# Train_2 Light Travel Station0 Station0     588240   588240
# Train_1   Train Trip Station0 Station2     589020   589980
# Train_2   Train Trip Station0 Station2     589020   589980
# Train_3   Train Trip Station2 Station0     589080   590040
# Train_4   Train Trip Station2 Station0     589080   590040
# Train_1 Light Travel Station2 Station2     589980   589980
# Train_2 Light Travel Station2 Station2     589980   589980
# Train_3 Light Travel Station0 Station0     590040   590040
# Train_4 Light Travel Station0 Station0     590040   590040
# Train_4   Train Trip Station0 Station2     590820   591780
# Train_3   Train Trip Station0 Station2     590820   591780
# Train_1   Train Trip Station2 Station0     590880   591840
# Train_2   Train Trip Station2 Station0     590880   591840
# Train_4 Light Travel Station2 Station2     591780   591780
# Train_3 Light Travel Station2 Station2     591780   591780
# Train_1 Light Travel Station0 Station0     591840   591840
# Train_2 Light Travel Station0 Station0     591840   591840
# Train_2   Train Trip Station0 Station2     592620   593580
# Train_1   Train Trip Station0 Station2     592620   593580
# Train_4   Train Trip Station2 Station0     592680   593640
# Train_3   Train Trip Station2 Station0     592680   593640
# Train_2 Light Travel Station2 Station2     593580   593580
# Train_1 Light Travel Station2 Station2     593580   593580
# Train_4 Light Travel Station0 Station0     593640   593640
# Train_3 Light Travel Station0 Station0     593640   593640
# Train_4   Train Trip Station0 Station2     594420   595380
# Train_3   Train Trip Station0 Station2     594420   595380
# Train_1   Train Trip Station2 Station0     594480   595440
# Train_2   Train Trip Station2 Station0     594480   595440
# Train_4 Light Travel Station2 Station2     595380   595380
# Train_3 Light Travel Station2 Station2     595380   595380
# Train_1 Light Travel Station0 Station0     595440   595440
# Train_2 Light Travel Station0 Station0     595440   595440
# Train_2   Train Trip Station0 Station2     596220   597180
# Train_1   Train Trip Station0 Station2     596220   597180
# Train_3   Train Trip Station2 Station0     596280   597240
# Train_4   Train Trip Station2 Station0     596280   597240
# Train_2 Light Travel Station2 Station2     597180   597180
# Train_1 Light Travel Station2 Station2     597180   597180
# Train_3 Light Travel Station0 Station0     597240   597240
# Train_4 Light Travel Station0 Station0     597240   597240
# Train_4   Train Trip Station0 Station2     598020   598980
# Train_3   Train Trip Station0 Station2     598020   598980
# Train_1   Train Trip Station2 Station0     598080   599040
# Train_2   Train Trip Station2 Station0     598080   599040
# Train_4 Light Travel Station2 Station2     598980   598980
# Train_3 Light Travel Station2 Station2     598980   598980
# Train_1 Light Travel Station0 Station0     599040   599040
# Train_2 Light Travel Station0 Station0     599040   599040
# Train_1   Train Trip Station0 Station2     599820   600780
# Train_2   Train Trip Station0 Station2     599820   600780
# Train_4   Train Trip Station2 Station0     599880   600840
# Train_3   Train Trip Station2 Station0     599880   600840
# Train_1 Light Travel Station2 Station2     600780   600780
# Train_2 Light Travel Station2 Station2     600780   600780
# Train_4 Light Travel Station0 Station0     600840   600840
# Train_3 Light Travel Station0 Station0     600840   600840
# Train_4   Train Trip Station0 Station2     601620   602580
# Train_3   Train Trip Station0 Station2     601620   602580
# Train_1   Train Trip Station2 Station0     601680   602640
# Train_2   Train Trip Station2 Station0     601680   602640
# Train_4 Light Travel Station2 Station2     602580   602580
# Train_3 Light Travel Station2 Station2     602580   602580
# Train_1 Light Travel Station0 Station0     602640   602640
# Train_2 Light Travel Station0 Station0     602640   602640
# Train_1   Train Trip Station0 Station1     603480   604020
# Train_2   Train Trip Station0 Station1     603480   604020
# Train_3   Train Trip Station2 Station0     603480   604440
# Train_4   Train Trip Station2 Station0     603480   604440
#
#  Cost Breakdown:
# Total Cost           : 4000.00
# Traction Unit Cost   : 4000.00
# Light Travel Cost    : 0.00
# Number of Vehicles   : 4

# %% [markdown]
# **Convert List_A to a CSV File**

# %%
import pandas as pd

# Convert full_schedule (a list of dicts) into a DataFrame
df_schedule = pd.DataFrame(full_schedule)

# Save to CSV
df_schedule.to_csv("full_schedule_Instance_G.csv", index=False)

# For Google Colab: provide download link
from google.colab import files
files.download("full_schedule_Instance_G.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.lines as mlines
import time

# Start timer
start_time = time.time()

# Load schedule
df_schedule = pd.read_csv("full_schedule_Instance_G.csv")

# Step 1: Map stations to Y-axis positions
stations = sorted(set(df_schedule["From"]).union(set(df_schedule["To"])))
station_to_y = {station: i for i, station in enumerate(stations)}

# Step 2: Predefine train IDs
train_ids = [f"Train_{i}" for i in range(1, 5)]

# Step 3: Assign each train a unique color
cmap = cm.get_cmap('tab20', len(train_ids))
train_to_color = {train: cmap(i) for i, train in enumerate(train_ids)}

# Step 4: Initialize plot and track nodes/edges
plt.figure(figsize=(20, 12))
nodes = set()
edges = []

# Step 5: Plot edges and store nodes/edges
for _, row in df_schedule.iterrows():
    from_station = row["From"]
    to_station = row["To"]
    start_time_trip = row["StartTime"]
    end_time_trip = row["EndTime"]
    train = row["Train"]
    edge_type = row["Type"]

    u = (start_time_trip, station_to_y[from_station])
    v = (end_time_trip, station_to_y[to_station])

    nodes.update([u, v])
    edges.append((u, v))

    color = train_to_color.get(train, 'black')
    linestyle = '-' if edge_type == "Train Trip" else '--'
    plt.plot([u[0], v[0]], [u[1], v[1]], color=color, linestyle=linestyle, linewidth=1)

# Step 6: Plot nodes
for t, y in nodes:
    plt.scatter(t, y, color='black', s=10)
    plt.text(t, y + 0.1, f'{t}', fontsize=5, ha='center', color='darkred')

# Step 7: Axis formatting
plt.yticks(list(station_to_y.values()), list(station_to_y.keys()))
plt.xlabel("Time (seconds)")
plt.ylabel("Stations")
plt.title("Space-Time Network_Instance_G")
plt.grid(True, linestyle='--', linewidth=0.5)

# Step 8: Legend
legend_lines = [
    mlines.Line2D([], [], color=train_to_color[train], linewidth=2, label=train)
    for train in train_ids
]
plt.legend(handles=legend_lines, title="Trains", loc='upper center', bbox_to_anchor=(0.5, -0.08),
           ncol=6, fontsize=8, title_fontsize=10, frameon=True)

plt.tight_layout()
plt.show()

# End timer
end_time = time.time()

# Step 9: Print summary
print("\n===== Network Summary =====")
print(f"Total Nodes      : {len(nodes)}")
print(f"Total Edges      : {len(edges)}")
print(f"Execution Time   : {round(end_time - start_time, 3)} seconds")
# Out:
# ===== Network Summary =====
# Total Nodes      : 1064
# Total Edges      : 2124
# Execution Time   : 32.076 seconds
# /tmp/ipython-input-12-986865833.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(train_ids))

# %% [markdown]
# **Robustness Calculation**

# %%
# STEP 01: Identify tight connections
# Define threshold (e.g., 300 seconds = 5 minutes)
TIGHT_THRESHOLD = 300  # seconds

# Extract only productive train trips for each train
train_trips = df_schedule[df_schedule["Type"] == "Train Trip"].copy()
train_trips.sort_values(by=["Train", "StartTime"], inplace=True)

# Find consecutive trips by the same train
tight_connections = []
for train_id, group in train_trips.groupby("Train"):
    trips = group.sort_values("StartTime").reset_index(drop=True)
    for i in range(len(trips) - 1):
        current_end = trips.loc[i, "EndTime"]
        next_start = trips.loc[i + 1, "StartTime"]
        connection_time = next_start - current_end
        if connection_time <= TIGHT_THRESHOLD:
            tight_connections.append({
                "Train": train_id,
                "FromTripEnd": current_end,
                "ToTripStart": next_start,
                "ConnectionTime": connection_time,
                "FromStation": trips.loc[i, "To"],
                "ToStation": trips.loc[i + 1, "From"]
            })

# Display the tight connections
df_tight = pd.DataFrame(tight_connections)
print(f"\n Tight Connections (<= {TIGHT_THRESHOLD} seconds): {len(df_tight)} found")
if not df_tight.empty:
    print(df_tight.to_string(index=False))
else:
    print(" No tight connections found.")
# Out:
#  Tight Connections (<= 300 seconds): 0 found
#  No tight connections found.

# %%
import pandas as pd

# Step 2: Set threshold for tight connections
TIGHT_THRESHOLD = 300  # seconds
BUFFER_TIME = 600      # seconds

# Step 3: Detect tight connections
train_trips = df_schedule[df_schedule["Type"] == "Train Trip"].copy()
train_trips.sort_values(by=["Train", "StartTime"], inplace=True)

tight_connections = []
for train_id, group in train_trips.groupby("Train"):
    trips = group.sort_values("StartTime").reset_index(drop=True)
    for i in range(len(trips) - 1):
        current_end = trips.loc[i, "EndTime"]
        next_start = trips.loc[i + 1, "StartTime"]
        connection_time = next_start - current_end
        if connection_time <= TIGHT_THRESHOLD:
            tight_connections.append({
                "Train": train_id,
                "FromTripEnd": current_end,
                "ToTripStart": next_start,
                "ConnectionTime": connection_time,
                "FromStation": trips.loc[i, "To"],
                "ToStation": trips.loc[i + 1, "From"]
            })

df_tight = pd.DataFrame(tight_connections)

# Step 4: Apply buffer by shifting trips forward
df_buffered = df_schedule.copy()
df_buffered.sort_values(by=["Train", "StartTime"], inplace=True)

for _, row in df_tight.iterrows():
    train_id = row["Train"]
    to_start = row["ToTripStart"]
    affected = df_buffered[
        (df_buffered["Train"] == train_id) &
        (df_buffered["StartTime"] >= to_start)
    ].index
    df_buffered.loc[affected, "StartTime"] += BUFFER_TIME
    df_buffered.loc[affected, "EndTime"] += BUFFER_TIME

# Step 5: Recalculate cost
C_TU = 1000
C_Light = 0.10
traction_units = df_buffered["Train"].nunique()
traction_cost = traction_units * C_TU

light_travel_cost = 0
for _, row in df_buffered[df_buffered["Type"] == "Light Travel"].iterrows():
    key = f"{row['From']},{row['To']}"
    if key in empty_runs:
        dist = empty_runs[key]["Distance"]
        light_travel_cost += dist * C_Light

total_cost = traction_cost + light_travel_cost

# Step 6: Calculate nodes and edges
nodes = set()
edges = 0
for _, row in df_buffered.iterrows():
    u = (row["StartTime"], row["From"])
    v = (row["EndTime"], row["To"])
    nodes.update([u, v])
    edges += 1

# Step 7: Save result
buffered_schedule_path = "schedule_buffered_600s.csv"
df_buffered.to_csv(buffered_schedule_path, index=False)

# Step 8: Summary
print("\n===== ⏱️ Buffered Plan Summary (600s for tight links) =====")
print(f" Tight Connections Found   : {len(df_tight)}")
print(f" Buffer Applied per Link   : {BUFFER_TIME} seconds")
print(f" Trains (Vehicles) Used    : {traction_units}")
print(f" Light Travel Cost         : {round(light_travel_cost, 2)}")
print(f" Total Cost                : {round(total_cost, 2)}")
print(f" Total Edges               : {edges}")
print(f" Total Unique Nodes        : {len(nodes)}")
print(f" Saved to File             : {buffered_schedule_path}")
# Out:
# ===== ⏱️ Buffered Plan Summary (600s for tight links) =====
#  Tight Connections Found   : 0
#  Buffer Applied per Link   : 600 seconds
#  Trains (Vehicles) Used    : 4
#  Light Travel Cost         : 0.0
#  Total Cost                : 4000.0
#  Total Edges               : 2124
#  Total Unique Nodes        : 1064
#  Saved to File             : schedule_buffered_600s.csv

# %%
import pandas as pd

# Load the original schedule before buffering
df_schedule = pd.read_csv("full_schedule_Instance_G.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.lines as mlines
import json
import re

# Load JSON data
with open("Instance_G.json") as f:
    data = json.load(f)

# Extract empty runs
empty_runs = data["EmptyRunData"]

# === CONFIGURATION ===
TIGHT_THRESHOLD = 300  # seconds
BUFFER_TIME = 600      # buffer to add after tight connections
C_TU = 1000            # traction unit cost
C_Light = 0.10         # light travel cost per km

# === STEP 1: Detect Tight Connections ===
train_trips = df_schedule[df_schedule["Type"] == "Train Trip"].copy()
train_trips.sort_values(by=["Train", "StartTime"], inplace=True)

tight_connections = []
for train_id, group in train_trips.groupby("Train"):
    trips = group.sort_values("StartTime").reset_index(drop=True)
    for i in range(len(trips) - 1):
        current_end = trips.loc[i, "EndTime"]
        next_start = trips.loc[i + 1, "StartTime"]
        connection_time = next_start - current_end
        if connection_time <= TIGHT_THRESHOLD:
            tight_connections.append({
                "Train": train_id,
                "FromTripEnd": current_end,
                "ToTripStart": next_start,
                "ConnectionTime": connection_time,
                "FromStation": trips.loc[i, "To"],
                "ToStation": trips.loc[i + 1, "From"]
            })

df_tight = pd.DataFrame(tight_connections)

# === STEP 2: Apply Buffer ===
df_buffered = df_schedule.copy()
df_buffered.sort_values(by=["Train", "StartTime"], inplace=True)

for _, row in df_tight.iterrows():
    train_id = row["Train"]
    to_start = row["ToTripStart"]
    affected = df_buffered[
        (df_buffered["Train"] == train_id) &
        (df_buffered["StartTime"] >= to_start)
    ].index
    df_buffered.loc[affected, "StartTime"] += BUFFER_TIME
    df_buffered.loc[affected, "EndTime"] += BUFFER_TIME

# === STEP 3: Recalculate Cost ===
traction_units = df_buffered["Train"].nunique()
traction_cost = traction_units * C_TU

light_travel_cost = 0
for _, row in df_buffered[df_buffered["Type"] == "Light Travel"].iterrows():
    key = f"{row['From']},{row['To']}"
    if key in empty_runs:
        dist = empty_runs[key]["Distance"]
        light_travel_cost += dist * C_Light

total_cost = traction_cost + light_travel_cost

# === STEP 4: Plot with Buffer Annotations ===
stations = sorted(set(df_buffered["From"]).union(set(df_buffered["To"])))
station_to_y = {station: i for i, station in enumerate(stations)}

train_ids = sorted(df_buffered["Train"].unique())
cmap = cm.get_cmap('tab20', len(train_ids))
train_to_color = {train: cmap(i) for i, train in enumerate(train_ids)}

plt.figure(figsize=(20, 12))
nodes = set()

# Plot train arcs
for _, row in df_buffered.iterrows():
    from_station = row["From"]
    to_station = row["To"]
    start = row["StartTime"]
    end = row["EndTime"]
    train = row["Train"]
    typ = row["Type"]

    u = (start, station_to_y[from_station])
    v = (end, station_to_y[to_station])
    color = train_to_color[train]
    linestyle = '-' if typ == "Train Trip" else '--'

    plt.plot([u[0], v[0]], [u[1], v[1]], color=color, linestyle=linestyle, linewidth=1)
    nodes.update([u, v])

# Annotate buffer arcs in red
for _, row in df_tight.iterrows():
    train_id = row["Train"]
    station = row["ToStation"]
    y = station_to_y[station]
    from_time = row["ToTripStart"]
    to_time = from_time + BUFFER_TIME
    plt.plot([from_time, to_time], [y, y], color='red', linestyle=':', linewidth=1)
    plt.text(to_time + 10, y + 0.15, '+600s', fontsize=6, color='red')

# Plot nodes
for t, y in nodes:
    plt.scatter(t, y, color='black', s=10)

# Axis settings
plt.yticks(list(station_to_y.values()), list(station_to_y.keys()))
plt.xlabel("Time (seconds)")
plt.ylabel("Stations")
plt.title("Buffered Plan with 600s Delay Buffers on Tight Connections")
plt.grid(True, linestyle='--', linewidth=0.5)

# Legend
legend_lines = [
    mlines.Line2D([], [], color=train_to_color[train], linewidth=2, label=train)
    for train in train_ids[:12]
]
legend_lines.append(mlines.Line2D([], [], color='red', linestyle=':', linewidth=1, label='Buffer +600s'))
plt.legend(handles=legend_lines, title="Trains", loc='upper center', bbox_to_anchor=(0.5, -0.08),
           ncol=6, fontsize=8, title_fontsize=10, frameon=True)

plt.tight_layout()
plt.show()

# === STEP 5: Summary ===
print("\n===== ⏱️ Buffered Plan Summary (600s for tight links) =====")
print(f" Tight Connections Found   : {len(df_tight)}")
print(f" Buffer Applied per Link   : {BUFFER_TIME} seconds")
print(f" Trains (Vehicles) Used    : {traction_units}")
print(f" Light Travel Cost         : {round(light_travel_cost, 2)}")
print(f" Total Cost                : {round(total_cost, 2)}")
print(f" Total Edges               : {len(df_buffered)}")
print(f" Total Unique Nodes        : {len(nodes)}")
# Out:
# /tmp/ipython-input-9-2804083255.py:76: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(train_ids))
# ===== ⏱️ Buffered Plan Summary (600s for tight links) =====
#  Tight Connections Found   : 0
#  Buffer Applied per Link   : 600 seconds
#  Trains (Vehicles) Used    : 4
#  Light Travel Cost         : 0.0
#  Total Cost                : 4000.0
#  Total Edges               : 2124
#  Total Unique Nodes        : 1064

# %%
from collections import defaultdict
import pandas as pd

# Configuration
TIGHT_THRESHOLD = 300  # seconds

# Initialize counter
tight_counts = defaultdict(int)
total_counts = defaultdict(int)

# Detect tight and total connections per station
train_trips = df_schedule[df_schedule["Type"] == "Train Trip"].copy()
train_trips.sort_values(by=["Train", "StartTime"], inplace=True)

for train_id, group in train_trips.groupby("Train"):
    trips = group.reset_index(drop=True)
    for i in range(len(trips) - 1):
        end_time = trips.loc[i, "EndTime"]
        next_start = trips.loc[i + 1, "StartTime"]
        conn_time = next_start - end_time
        station = trips.loc[i + 1, "From"]

        total_counts[station] += 1
        if conn_time <= TIGHT_THRESHOLD:
            tight_counts[station] += 1

# Create summary DataFrame
df_station_tightness = pd.DataFrame({
    "TotalConnections": pd.Series(total_counts),
    "TightConnections": pd.Series(tight_counts)
})
df_station_tightness["TightRatio"] = df_station_tightness["TightConnections"] / df_station_tightness["TotalConnections"]
df_station_tightness = df_station_tightness.fillna(0).sort_values(by="TightRatio", ascending=False)

# Show top 10 stations
print("\n===== 🔍 Stations with Highest Tight Connection Ratios =====")
print(df_station_tightness.head(10).round(2))
# Out:
# ===== 🔍 Stations with Highest Tight Connection Ratios =====
#           TotalConnections  TightConnections  TightRatio
# Station1                26                 0           0
# Station0               530                 0           0
# Station2               504                 0           0
# /tmp/ipython-input-10-1435511764.py:33: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_station_tightness = df_station_tightness.fillna(0).sort_values(by="TightRatio", ascending=False)
