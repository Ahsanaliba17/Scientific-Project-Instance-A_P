# %% [markdown]
# **Scheduling Problem**

# %% [markdown]
# Random Space Time Network Instance_A

# %% [markdown]
# **Step 01 Generating a Space Time Network**

# %%
# Load required libraries
import json  # Used to read and parse JSON files
import matplotlib.pyplot as plt  # Used for plotting the space-time network
import re  # Used for natural sorting of station names like Station1, Station2, Station10
import time  # Used to measure computation time
import matplotlib.ticker as ticker  # (Optional) used for custom formatting of x-axis ticks

# Start the timer to measure total computation time
start_time = time.time()

# Open and load the JSON file containing the instance data for stations, trips, and empty runs
with open("Instance_A.json") as f:
    data = json.load(f)

# Define a helper function that creates a sorting key for natural sorting (e.g., Station2 before Station10)
def natural_key(s):
    return [int(text) if text.isdigit() else text for text in re.split('(\d+)', s)]

# Extract and sort all station names using natural sorting
stations = sorted([s["Name"] for s in data["StationList"]], key=natural_key)

# Create a dictionary mapping each station name to a corresponding y-axis index (0, 1, ..., 33)
station_to_y = {name: i for i, name in enumerate(stations)}

# Sort all trips based on their start times
trips = sorted(data["TripList"], key=lambda x: x["StartTime"])

# Extract the empty run data which contains light travel durations between station pairs
empty_runs = data["EmptyRunData"]

# Initialize lists to store different types of arcs (edges) and special nodes
train_arcs = []          # Arcs representing productive trips (trains with passengers)
light_arcs_arrival = []  # Arcs representing light vehicle travel after completing a trip
light_arcs_source = []   # Arcs representing vehicle repositioning from source to first trip
ground_arcs = []         # Arcs representing idle waiting time at a station
source_nodes = []        # Artificial source nodes (before each trip)
sink_nodes = []          # Artificial sink nodes (after each trip)
nodes_set = set()        # Set to store all unique (time, station index) pairs (i.e., nodes)

# Step 1: Create artificial source and sink nodes for each trip
for trip in trips:
    source_nodes.append((trip["StartTime"] - 1, station_to_y[trip["Origin"]]))  # source node before trip starts
    sink_nodes.append((trip["EndTime"] + 1, station_to_y[trip["Destination"]]))  # sink node after trip ends

# Step 2: Create productive train arcs
for trip in trips:
    u = (trip["StartTime"], station_to_y[trip["Origin"]])
    v = (trip["EndTime"], station_to_y[trip["Destination"]])
    train_arcs.append((u, v))
    nodes_set.update([u, v])  # store nodes

# Step 3: Create light arcs from trip end to future trip start
for trip_a in trips:
    for trip_b in trips:
        if trip_a["Id"] != trip_b["Id"] and trip_a["EndTime"] < trip_b["StartTime"]:
            key = f"{trip_a['Destination']},{trip_b['Origin']}"
            if trip_a["Destination"] != trip_b["Origin"] and key in empty_runs:
                transfer_time = empty_runs[key]["Duration"]
                if trip_a["EndTime"] + transfer_time <= trip_b["StartTime"]:
                    u = (trip_a["EndTime"], station_to_y[trip_a["Destination"]])
                    v = (trip_a["EndTime"] + transfer_time, station_to_y[trip_b["Origin"]])
                    light_arcs_arrival.append((u, v))
                    nodes_set.update([u, v])
                    break

# Step 4: Create light arcs from artificial source to feasible trip origin
for src in source_nodes:
    t0, y0 = src
    for trip in trips:
        key = f"{stations[y0]},{trip['Origin']}"
        if key in empty_runs and t0 < trip["StartTime"]:
            duration = empty_runs[key]["Duration"]
            if t0 + duration <= trip["StartTime"]:
                u = src
                v = (t0 + duration, station_to_y[trip["Origin"]])
                light_arcs_source.append((u, v))
                nodes_set.update([u, v])
                break

# Step 5: Create ground arcs between end of one trip and start of another at same station
for trip_a in trips:
    for trip_b in trips:
        if trip_a["Destination"] == trip_b["Origin"] and trip_b["StartTime"] > trip_a["EndTime"]:
            u = (trip_a["EndTime"], station_to_y[trip_a["Destination"]])
            v = (trip_b["StartTime"], station_to_y[trip_b["Origin"]])
            ground_arcs.append((u, v))
            nodes_set.update([u, v])
            break

# Start plotting the space-time network
plt.figure(figsize=(20, 12))

# Draw productive train arcs (blue)
for u, v in train_arcs:
    plt.plot([u[0], v[0]], [u[1], v[1]], color='blue', linewidth=0.9)

# Draw light arcs after trip end (dashed gray)
for u, v in light_arcs_arrival:
    plt.plot([u[0], v[0]], [u[1], v[1]], color='gray', linestyle='dashed', linewidth=0.8)

# Draw light arcs from source node (dotted dark gray)
for u, v in light_arcs_source:
    plt.plot([u[0], v[0]], [u[1], v[1]], color='darkgray', linestyle='dotted', linewidth=0.8)

# Draw ground arcs (green)
for u, v in ground_arcs:
    plt.plot([u[0], v[0]], [u[1], v[1]], color='green', linestyle='solid', linewidth=0.7)

# Scatter plot all nodes for clarity
for (u, v) in train_arcs + light_arcs_arrival + light_arcs_source + ground_arcs:
    plt.scatter([u[0], v[0]], [u[1], v[1]], s=6, color='black')

# Configure y-axis with station names in top-down order
plt.yticks(range(len(stations)), stations)

# Set labels and title
plt.xlabel("Time (seconds)")
plt.ylabel("Stations (top: Station0)")
plt.title("Space-Time Network - Instance_A")

# Add grid and tighten layout
plt.grid(True, linestyle='--', linewidth=0.3)
plt.tight_layout()

# Show the final plot
plt.show()

# Calculate total edges and computation time
total_edges = len(train_arcs) + len(light_arcs_arrival) + len(light_arcs_source) + len(ground_arcs)
end_time_calc = time.time()

# Print network statistics
print("Network Summary")
print(f"Number of nodes       : {len(nodes_set)}")
print(f"Number of edges       : {total_edges}")
print(f"Computation time (s)  : {round(end_time_calc - start_time, 3)}")
# Out:
# Network Summary
# Number of nodes       : 553
# Number of edges       : 530
# Computation time (s)  : 7.581

# %% [markdown]
# **Step 02 Costing Calculation and Vehicles Calculation Using Pulp**

# %% [markdown]
# Pulp Installation for Mixed Integer Program Optimization

# %%
# Install PuLP
# !pip install pulp

# Load libraries
import json, re
import pulp
import pandas as pd

# Load JSON file
with open("Instance_A.json") as f:
    data = json.load(f)

# Cost parameters
C_TU = 1000
C_Light = 0.10

# Parse stations and trips
stations = sorted(
    [s["Name"] for s in data["StationList"]],
    key=lambda s: [int(t) if t.isdigit() else t for t in re.split("(\d+)", s)]
)
station_index = {name: i for i, name in enumerate(stations)}

trips = sorted(data["TripList"], key=lambda x: x["StartTime"])
trip_ids = [trip["Id"] for trip in trips]
trip_map = {trip["Id"]: trip for trip in trips}
empty_runs = data["EmptyRunData"]

# Optimization model
model = pulp.LpProblem("RollingStockCirculationPlanning", pulp.LpMinimize)

x = {trip["Id"]: pulp.LpVariable(f"x_{trip['Id']}", cat="Binary") for trip in trips}
vehicles = {trip["Id"]: pulp.LpVariable(f"veh_{trip['Id']}", cat="Binary") for trip in trips}
z = {}

# Generate light travel arcs
for i, trip_a in enumerate(trips):
    for j, trip_b in enumerate(trips):
        if i != j and trip_a["EndTime"] < trip_b["StartTime"]:
            key = f"{trip_a['Destination']},{trip_b['Origin']}"
            if key in empty_runs:
                ttime = empty_runs[key]["Duration"]
                if trip_a["EndTime"] + ttime <= trip_b["StartTime"]:
                    arc = f"{trip_a['Id']}_{trip_b['Id']}"
                    z[arc] = pulp.LpVariable(f"z_{arc}", cat="Binary")

# Objective
model += (
    pulp.lpSum([vehicles[trip["Id"]] for trip in trips]) * C_TU +
    pulp.lpSum([
        z[arc] *
        empty_runs[f"{trip_map[int(arc.split('_')[0])]['Destination']},{trip_map[int(arc.split('_')[1])]['Origin']}"]["Distance"] *
        C_Light for arc in z
    ])
)

# Constraints
for trip in trips:
    model += x[trip["Id"]] == 1

for trip in trips:
    incoming = [z[arc] for arc in z if int(arc.split('_')[1]) == trip["Id"]]
    model += vehicles[trip["Id"]] + pulp.lpSum(incoming) >= x[trip["Id"]]

for trip in trips:
    outgoing = [z[arc] for arc in z if int(arc.split('_')[0]) == trip["Id"]]
    model += pulp.lpSum(outgoing) <= 1

# Solve
model.solve(pulp.PULP_CBC_CMD(msg=0))

# Result
num_vehicles = sum(v.varValue for v in vehicles.values())
light_cost = sum(
    z[arc].varValue *
    empty_runs[f"{trip_map[int(arc.split('_')[0])]['Destination']},{trip_map[int(arc.split('_')[1])]['Origin']}"]["Distance"] *
    C_Light for arc in z
)
traction_cost = num_vehicles * C_TU
total_cost = traction_cost + light_cost

# Display
results = {
    "Total Cost": round(total_cost, 2),
    "Traction Unit Cost": round(traction_cost, 2),
    "Light Travel Cost": round(light_cost, 2),
    "Deadheading Cost": 0.00,
    "Number of Vehicles Used": int(num_vehicles)
}
pd.DataFrame([results])
# Out:
# Collecting pulp
#   Downloading pulp-3.2.1-py3-none-any.whl.metadata (6.9 kB)
# Downloading pulp-3.2.1-py3-none-any.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 88.1 MB/s eta 0:00:00
# Installing collected packages: pulp
# Successfully installed pulp-3.2.1
#    Total Cost  Traction Unit Cost  Light Travel Cost  Deadheading Cost  \
# 0    12936.34             12000.0             936.34               0.0
#
#    Number of Vehicles Used
# 0                       12

# %% [markdown]
# **`Schedule Calculator`**

# %%
# STEP 1: Install pulp (for Google Colab; skip if already installed)
# !pip install pulp

# STEP 2: Import required libraries
import json           # For reading the JSON file
import re             # For sorting station names naturally
import pulp           # For defining and solving the optimization model
import pandas as pd   # For creating and displaying schedule tables
from pulp import LpStatus  # For checking the model solution status

# STEP 3: Load data from the JSON file
with open("Instance_A.json") as f:
    data = json.load(f)

# STEP 4: Define cost parameters
C_TU = 1000       # Cost for using a train unit
C_Light = 0.10    # Cost per km for light (empty) travel

# STEP 5: Prepare and sort stations
stations = sorted(
    [s["Name"] for s in data["StationList"]],
    key=lambda s: [int(t) if t.isdigit() else t for t in re.split("(\d+)", s)]
)
station_index = {name: i for i, name in enumerate(stations)}

# STEP 6: Extract trips and empty run data
trips = sorted(data["TripList"], key=lambda x: x["StartTime"])
trip_map = {trip["Id"]: trip for trip in trips}
empty_runs = data["EmptyRunData"]

# STEP 7: Define the optimization model
model = pulp.LpProblem("RollingStock", pulp.LpMinimize)

# Binary variable for each trip: 1 if performed
x = {trip["Id"]: pulp.LpVariable(f"x_{trip['Id']}", cat="Binary") for trip in trips}

# Binary variable for vehicle usage: 1 if a new train starts with this trip
vehicles = {trip["Id"]: pulp.LpVariable(f"veh_{trip['Id']}", cat="Binary") for trip in trips}

# Binary variables for light connections between trips
z = {}
for i, a in enumerate(trips):
    for j, b in enumerate(trips):
        if i != j and a["EndTime"] < b["StartTime"]:
            key = f"{a['Destination']},{b['Origin']}"
            if key in empty_runs:
                dt = empty_runs[key]["Duration"]
                if a["EndTime"] + dt <= b["StartTime"]:
                    arc = f"{a['Id']}_{b['Id']}"
                    z[arc] = pulp.LpVariable(f"z_{arc}", cat="Binary")

# STEP 8: Define objective function to minimize total cost
model += (
    pulp.lpSum([vehicles[tid] for tid in x]) * C_TU +
    pulp.lpSum([
        z[arc] * empty_runs[
            f"{trip_map[int(arc.split('_')[0])]['Destination']},{trip_map[int(arc.split('_')[1])]['Origin']}"
        ]["Distance"] * C_Light for arc in z
    ])
)

# STEP 9: Add constraints
# Ensure each trip is covered
for trip in trips:
    model += x[trip["Id"]] == 1

# A trip is covered either by a new vehicle or from a previous trip via light travel
for trip in trips:
    incoming = [z[arc] for arc in z if int(arc.split("_")[1]) == trip["Id"]]
    model += vehicles[trip["Id"]] + pulp.lpSum(incoming) >= x[trip["Id"]]

# A trip connects to at most one next trip
for trip in trips:
    outgoing = [z[arc] for arc in z if int(arc.split("_")[0]) == trip["Id"]]
    model += pulp.lpSum(outgoing) <= 1

# STEP 10: Solve the model
model.solve(pulp.PULP_CBC_CMD(msg=0))

# STEP 11: Check if solution is feasible
status = LpStatus[model.status]
print(f"\n🔍 Model Status: {status}")
if status != "Optimal":
    print(" No feasible or optimal solution found.")
else:
    print(" Feasible and optimal solution found.")

# STEP 12: Assign Train IDs
trip_to_train = {}
train_counter = 1
outgoing_map = {int(arc.split('_')[0]): int(arc.split('_')[1]) for arc in z if z[arc].varValue == 1}
visited = set()

for trip in trips:
    tid = trip["Id"]
    if tid not in visited:
        current_train = f"Train_{train_counter}"
        while tid in trip_map:
            visited.add(tid)
            trip_to_train[tid] = current_train
            tid = outgoing_map.get(tid, None)
            if tid is None or tid in visited:
                break
        train_counter += 1

# STEP 13: Build the full trip and light travel schedule
full_schedule = []

# Add train trips
for tid, var in x.items():
    if var.varValue == 1:
        trip = trip_map[tid]
        full_schedule.append({
            "Train": trip_to_train[tid],
            "Type": "Train Trip",
            "From": trip["Origin"],
            "To": trip["Destination"],
            "StartTime": trip["StartTime"],
            "EndTime": trip["EndTime"]
        })

# Add light travel trips
light_travel_cost = 0
for arc, var in z.items():
    if var.varValue == 1:
        from_id, to_id = map(int, arc.split("_"))
        trip_a = trip_map[from_id]
        trip_b = trip_map[to_id]
        key = f"{trip_a['Destination']},{trip_b['Origin']}"
        dur = empty_runs[key]["Duration"]
        dist = empty_runs[key]["Distance"]
        cost = dist * C_Light
        light_travel_cost += cost
        full_schedule.append({
            "Train": trip_to_train[from_id],
            "Type": "Light Travel",
            "From": trip_a["Destination"],
            "To": trip_b["Origin"],
            "StartTime": trip_a["EndTime"],
            "EndTime": trip_a["EndTime"] + dur
        })

# STEP 14: Display the final schedule
full_schedule = sorted(full_schedule, key=lambda x: x["StartTime"])
df_schedule = pd.DataFrame(full_schedule)
print("\n Complete Trip and Light Travel Schedule:")
print(df_schedule.to_string(index=False))

# STEP 15: Print cost breakdown
traction_units = sum([vehicles[tid].varValue for tid in vehicles])
traction_cost = traction_units * C_TU
total_cost = pulp.value(model.objective)

print("\n Cost Breakdown:")
print(f"Total Cost           : {total_cost:.2f}")
print(f"Traction Unit Cost   : {traction_cost:.2f}")
print(f"Light Travel Cost    : {light_travel_cost:.2f}")
print(f"Number of Vehicles   : {int(traction_units)}")
# Out:
# Requirement already satisfied: pulp in /usr/local/lib/python3.11/dist-packages (3.2.1)
#
# 🔍 Model Status: Optimal
#  Feasible and optimal solution found.
#
#  Complete Trip and Light Travel Schedule:
#    Train         Type      From        To  StartTime  EndTime
#  Train_1   Train Trip  Station0  Station1          0    40440
#  Train_2   Train Trip  Station2  Station3       4560    11880
#  Train_3   Train Trip  Station4  Station5       8940    14100
#  Train_4   Train Trip  Station6  Station7       9120    35760
#  Train_2 Light Travel  Station3 Station15      11880    13620
#  Train_5   Train Trip  Station2  Station8      12240    19320
#  Train_3 Light Travel  Station5 Station17      14100    18600
#  Train_6   Train Trip  Station9 Station10      18000    24540
#  Train_5 Light Travel  Station8  Station8      19320    19320
#  Train_7   Train Trip Station11 Station12      19620    40380
#  Train_8   Train Trip Station11 Station12      19620    40380
#  Train_9   Train Trip Station13 Station14      22440    26040
#  Train_6 Light Travel Station10 Station17      24540    34080
#  Train_9 Light Travel Station14 Station22      26040    32340
#  Train_2   Train Trip Station15 Station16      33120    67800
#  Train_4 Light Travel  Station7  Station7      35760    35760
#  Train_6   Train Trip Station17 Station18      36540    50520
#  Train_5   Train Trip  Station8 Station19      40080    48840
#  Train_7 Light Travel Station12 Station12      40380    40380
#  Train_8 Light Travel Station12 Station12      40380    40380
#  Train_1 Light Travel  Station1  Station1      40440    40440
#  Train_1   Train Trip  Station1 Station20      42780   104400
#  Train_3   Train Trip Station17 Station18      44760    56100
#  Train_5 Light Travel Station19 Station19      48840    48840
#  Train_5   Train Trip Station19  Station8      49080    52200
#  Train_6 Light Travel Station18  Station5      50520    53040
# Train_10   Train Trip Station21 Station22      52080    68160
#  Train_5 Light Travel  Station8  Station8      52200    52200
#  Train_3 Light Travel Station18 Station25      56100    56520
#  Train_4   Train Trip  Station7 Station23      61920    65880
# Train_11   Train Trip  Station1 Station22      62520    67260
#  Train_9   Train Trip Station22 Station23      64320    67620
#  Train_4 Light Travel Station23  Station1      65880    66840
#  Train_4   Train Trip  Station1 Station24      67200    78480
# Train_11 Light Travel Station22 Station22      67260    67260
#  Train_9 Light Travel Station23 Station23      67620    67620
#  Train_2 Light Travel Station16 Station11      67800    71520
# Train_11   Train Trip Station22 Station21      68040    79560
# Train_10 Light Travel Station22 Station23      68160    70020
#  Train_6   Train Trip  Station5  Station4      68220    75120
#  Train_9   Train Trip Station23  Station1      69180    73800
#  Train_3   Train Trip Station25 Station18      71400    77040
#  Train_5   Train Trip  Station8 Station18      72300    78960
#  Train_9 Light Travel  Station1  Station1      73800    73800
#  Train_6 Light Travel  Station4  Station4      75120    75120
#  Train_3 Light Travel Station18  Station2      77040    77100
#  Train_4 Light Travel Station24  Station9      78480    81720
#  Train_5 Light Travel Station18  Station2      78960    79020
# Train_11 Light Travel Station21 Station21      79560    79560
#  Train_5   Train Trip  Station2  Station3      90960    98280
#  Train_6   Train Trip  Station4  Station5      95340   100500
#  Train_5 Light Travel  Station3 Station17      98280   102900
#  Train_3   Train Trip  Station2  Station8      98640   105720
#  Train_6 Light Travel  Station5 Station17     100500   105000
#  Train_4   Train Trip  Station9 Station10     104400   110940
#  Train_1 Light Travel Station20 Station20     104400   104400
#  Train_3 Light Travel  Station8  Station8     105720   105720
#  Train_8   Train Trip Station12 Station11     108300   124860
#  Train_7   Train Trip Station12 Station11     108300   124860
#  Train_4 Light Travel Station10 Station26     110940   123000
#  Train_6   Train Trip Station17 Station18     122940   136920
#  Train_8 Light Travel Station11 Station23     124860   126300
#  Train_7 Light Travel Station11 Station11     124860   124860
#  Train_3   Train Trip  Station8 Station19     126480   135240
#  Train_2   Train Trip Station11 Station12     128580   150720
#  Train_7   Train Trip Station11 Station12     128580   150720
#  Train_5   Train Trip Station17 Station18     131160   142500
#  Train_8   Train Trip Station23 Station22     134460   137280
# Train_10   Train Trip Station23 Station22     134460   137280
#  Train_3 Light Travel Station19 Station19     135240   135240
#  Train_3   Train Trip Station19  Station8     135480   138600
#  Train_6 Light Travel Station18  Station5     136920   139440
#  Train_8 Light Travel Station22 Station22     137280   137280
# Train_10 Light Travel Station22  Station7     137280   139440
# Train_11   Train Trip Station21 Station22     138480   154560
#  Train_3 Light Travel  Station8  Station8     138600   138600
#  Train_5 Light Travel Station18 Station25     142500   142920
# Train_10   Train Trip  Station7 Station23     148320   152280
#  Train_4   Train Trip Station26 Station27     148740   159840
#  Train_9   Train Trip  Station1 Station22     148920   153660
#  Train_8   Train Trip Station22 Station23     150720   154020
#  Train_2 Light Travel Station12 Station12     150720   150720
#  Train_7 Light Travel Station12 Station12     150720   150720
# Train_10 Light Travel Station23  Station9     152280   162480
#  Train_9 Light Travel Station22 Station22     153660   153660
#  Train_8 Light Travel Station23 Station23     154020   154020
#  Train_9   Train Trip Station22 Station21     154440   165960
# Train_11 Light Travel Station22 Station22     154560   154560
#  Train_6   Train Trip  Station5  Station4     154620   161520
#  Train_8   Train Trip Station23  Station1     155580   160200
#  Train_5   Train Trip Station25 Station18     157800   163440
#  Train_3   Train Trip  Station8 Station18     158700   165360
#  Train_4 Light Travel Station27  Station6     159840   165780
#  Train_8 Light Travel  Station1 Station28     160200   163500
#  Train_1   Train Trip Station20  Station1     160440   213240
#  Train_6 Light Travel  Station4  Station4     161520   161520
#  Train_5 Light Travel Station18  Station2     163440   163500
#  Train_3 Light Travel Station18  Station2     165360   165420
#  Train_9 Light Travel Station21 Station21     165960   165960
#  Train_8   Train Trip Station28 Station29     174720   184260
#  Train_3   Train Trip  Station2  Station3     177360   184680
#  Train_6   Train Trip  Station4  Station5     181740   186900
#  Train_4   Train Trip  Station6  Station7     181920   208560
#  Train_8 Light Travel Station29  Station1     184260   189180
#  Train_3 Light Travel  Station3 Station17     184680   189300
#  Train_5   Train Trip  Station2  Station8     185040   192120
#  Train_6 Light Travel  Station5 Station17     186900   191400
# Train_10   Train Trip  Station9 Station10     190800   197340
#  Train_5 Light Travel  Station8  Station8     192120   192120
#  Train_7   Train Trip Station12 Station11     194700   211260
#  Train_2   Train Trip Station12 Station11     194700   211260
# Train_10 Light Travel Station10 Station26     197340   209400
#  Train_8   Train Trip  Station1 Station30     203640   252420
#  Train_4 Light Travel  Station7  Station7     208560   208560
#  Train_6   Train Trip Station17 Station18     209340   223320
#  Train_7 Light Travel Station11 Station11     211260   211260
#  Train_2 Light Travel Station11 Station11     211260   211260
#  Train_5   Train Trip  Station8 Station19     212880   221640
#  Train_1 Light Travel  Station1  Station1     213240   213240
#  Train_2   Train Trip Station11 Station12     214980   237120
#  Train_7   Train Trip Station11 Station12     214980   237120
#  Train_3   Train Trip Station17 Station18     217560   228900
#  Train_5 Light Travel Station19 Station19     221640   221640
#  Train_5   Train Trip Station19  Station8     221880   225000
#  Train_6 Light Travel Station18  Station5     223320   225840
#  Train_9   Train Trip Station21 Station22     224880   240960
#  Train_5 Light Travel  Station8  Station8     225000   225000
#  Train_3 Light Travel Station18 Station25     228900   229320
#  Train_4   Train Trip  Station7 Station23     234720   238680
# Train_10   Train Trip Station26 Station27     235140   246240
#  Train_1   Train Trip  Station1 Station22     235320   240060
# Train_11   Train Trip Station22 Station23     237120   240420
#  Train_2 Light Travel Station12 Station12     237120   237120
#  Train_7 Light Travel Station12 Station12     237120   237120
#  Train_4 Light Travel Station23 Station23     238680   238680
#  Train_1 Light Travel Station22 Station22     240060   240060
# Train_11 Light Travel Station23 Station23     240420   240420
#  Train_1   Train Trip Station22 Station21     240840   252360
#  Train_9 Light Travel Station22 Station22     240960   240960
#  Train_6   Train Trip  Station5  Station4     241020   247920
#  Train_4   Train Trip Station23  Station1     241980   246600
#  Train_3   Train Trip Station25 Station18     244200   249840
#  Train_5   Train Trip  Station8 Station18     245100   251760
# Train_10 Light Travel Station27  Station9     246240   253680
#  Train_4 Light Travel  Station1  Station1     246600   246600
# Train_12   Train Trip Station20  Station1     246840   299640
#  Train_6 Light Travel  Station4  Station4     247920   247920
#  Train_3 Light Travel Station18  Station2     249840   249900
#  Train_5 Light Travel Station18  Station2     251760   251820
#  Train_1 Light Travel Station21 Station28     252360   258300
#  Train_8 Light Travel Station30 Station32     252420   272820
#  Train_1   Train Trip Station28 Station29     261120   270660
#  Train_6   Train Trip  Station4  Station5     268140   273300
#  Train_1 Light Travel Station29 Station22     270660   278340
#  Train_5   Train Trip  Station2  Station8     271440   278520
#  Train_6 Light Travel  Station5  Station4     273300   274140
#  Train_4   Train Trip  Station1 Station24     274500   287280
# Train_10   Train Trip  Station9 Station10     277200   283740
#  Train_5 Light Travel  Station8  Station8     278520   278520
# Train_10 Light Travel Station10  Station9     283740   286920
#  Train_4 Light Travel Station24  Station1     287280   293220
#  Train_1   Train Trip Station22 Station21     289980   306480
#  Train_7   Train Trip Station12 Station11     290220   311700
#  Train_2   Train Trip Station12 Station11     290220   311700
#  Train_9   Train Trip Station22  Station1     290880   295800
#  Train_9 Light Travel  Station1 Station31     295800   297180
# Train_12 Light Travel  Station1  Station1     299640   299640
#  Train_4   Train Trip  Station1 Station20     301980   363600
#  Train_1 Light Travel Station21 Station21     306480   306480
#  Train_1   Train Trip Station21 Station22     311280   327360
#  Train_7 Light Travel Station11 Station11     311700   311700
#  Train_2 Light Travel Station11 Station11     311700   311700
#  Train_9   Train Trip Station31 Station22     313260   315720
#  Train_9 Light Travel Station22 Station23     315720   317580
#  Train_2   Train Trip Station11 Station12     317280   334200
#  Train_7   Train Trip Station11 Station12     317280   334200
# Train_12   Train Trip  Station1 Station22     321720   326460
#  Train_9   Train Trip Station23 Station12     321840   339600
# Train_11   Train Trip Station23 Station12     323340   339000
# Train_12 Light Travel Station22 Station22     326460   326460
# Train_12   Train Trip Station22 Station21     327240   338760
#  Train_1 Light Travel Station22 Station26     327360   334560
#  Train_2 Light Travel Station12 Station11     334200   342300
#  Train_7 Light Travel Station12  Station1     334200   341880
# Train_12 Light Travel Station21 Station21     338760   338760
# Train_11 Light Travel Station12  Station1     339000   346680
#  Train_9 Light Travel Station12 Station11     339600   347700
#  Train_3   Train Trip  Station2  Station3     350160   357480
#  Train_3 Light Travel  Station3  Station2     357480   359820
# Train_10   Train Trip  Station9 Station10     363600   370140
#  Train_4 Light Travel Station20 Station20     363600   363600
# Train_10 Light Travel Station10  Station9     370140   373320
#  Train_9   Train Trip Station11 Station12     387780   409920
#  Train_2   Train Trip Station11 Station12     387780   409920
# Train_11   Train Trip  Station1 Station20     388380   450000
#  Train_8   Train Trip Station32  Station1     394800   410460
# Train_12   Train Trip Station21 Station22     397680   413760
#  Train_7   Train Trip  Station1 Station22     408120   412860
#  Train_9 Light Travel Station12 Station23     409920   416640
#  Train_2 Light Travel Station12  Station7     409920   417120
#  Train_8 Light Travel  Station1  Station1     410460   410460
#  Train_7 Light Travel Station22 Station22     412860   412860
#  Train_7   Train Trip Station22 Station21     413640   425160
# Train_12 Light Travel Station22 Station22     413760   413760
#  Train_7 Light Travel Station21 Station21     425160   425160
#  Train_3   Train Trip  Station2  Station3     436560   443880
#  Train_6   Train Trip  Station4  Station5     440940   446100
#  Train_3 Light Travel  Station3 Station15     443880   445620
#  Train_6 Light Travel  Station5 Station17     446100   450600
# Train_10   Train Trip  Station9 Station10     450000   456540
# Train_11 Light Travel Station20 Station20     450000   450000
# Train_10 Light Travel Station10 Station17     456540   466080
#  Train_3   Train Trip Station15 Station16     465120   499800
# Train_10   Train Trip Station17 Station18     468540   482520
#  Train_5   Train Trip  Station8 Station19     472080   480840
# Train_12   Train Trip Station22 Station23     475140   479640
#  Train_1   Train Trip Station26 Station27     475680   487320
#  Train_6   Train Trip Station17 Station18     476760   488100
# Train_12 Light Travel Station23 Station23     479640   479640
#  Train_5 Light Travel Station19 Station19     480840   480840
#  Train_5   Train Trip Station19  Station8     481080   484200
# Train_10 Light Travel Station18  Station5     482520   485040
#  Train_7   Train Trip Station21 Station22     484080   500160
#  Train_5 Light Travel  Station8  Station8     484200   484200
#  Train_1 Light Travel Station27 Station26     487320   490980
#  Train_6 Light Travel Station18 Station25     488100   488520
#  Train_2   Train Trip  Station7 Station23     493920   497880
#  Train_1   Train Trip Station26 Station27     494340   505440
#  Train_8   Train Trip  Station1 Station22     494520   499260
#  Train_9   Train Trip Station23 Station12     494640   512400
# Train_12   Train Trip Station23 Station12     496140   511800
#  Train_2 Light Travel Station23 Station23     497880   497880
#  Train_8 Light Travel Station22 Station22     499260   499260
#  Train_3 Light Travel Station16  Station9     499800   505680
#  Train_8   Train Trip Station22 Station21     500040   511560
#  Train_7 Light Travel Station22 Station22     500160   500160
# Train_10   Train Trip  Station5  Station4     500220   507120
#  Train_2   Train Trip Station23  Station1     501180   505800
#  Train_6   Train Trip Station25 Station18     503400   509040
#  Train_5   Train Trip  Station8 Station18     504300   510960
#  Train_1 Light Travel Station27  Station6     505440   511380
#  Train_2 Light Travel  Station1 Station11     505800   506220
# Train_11   Train Trip Station20  Station1     506040   558840
#  Train_7   Train Trip Station22 Station23     506760   510240
# Train_10 Light Travel  Station4  Station4     507120   507120
#  Train_6 Light Travel Station18  Station2     509040   509100
#  Train_7 Light Travel Station23 Station11     510240   511620
#  Train_5 Light Travel Station18  Station2     510960   511020
#  Train_8 Light Travel Station21 Station21     511560   511560
# Train_12 Light Travel Station12 Station13     511800   515940
#  Train_5   Train Trip  Station2  Station3     522960   530280
# Train_10   Train Trip  Station4  Station5     527340   532500
#  Train_1   Train Trip  Station6  Station7     527520   554160
#  Train_7   Train Trip Station11 Station12     528600   552120
#  Train_2   Train Trip Station11 Station12     528600   552120
#  Train_5 Light Travel  Station3 Station17     530280   534900
#  Train_6   Train Trip  Station2  Station8     530640   537720
# Train_10 Light Travel  Station5 Station17     532500   537000
#  Train_3   Train Trip  Station9 Station10     536400   542940
#  Train_6 Light Travel  Station8  Station8     537720   537720
# Train_12   Train Trip Station13 Station14     540840   544440
#  Train_3 Light Travel Station10 Station26     542940   555000
# Train_12 Light Travel Station14 Station22     544440   550740
#  Train_1 Light Travel  Station7  Station7     554160   554160
# Train_10   Train Trip Station17 Station18     554940   568920
#  Train_6   Train Trip  Station8 Station19     558480   567240
# Train_11 Light Travel  Station1  Station1     558840   558840
#  Train_3   Train Trip Station26 Station27     562080   573720
#  Train_5   Train Trip Station17 Station18     563160   574500
#  Train_6 Light Travel Station19 Station19     567240   567240
#  Train_6   Train Trip Station19  Station8     567480   570600
# Train_10 Light Travel Station18  Station5     568920   571440
#  Train_8   Train Trip Station21 Station22     570480   586560
#  Train_6 Light Travel  Station8  Station8     570600   570600
#  Train_3 Light Travel Station27 Station26     573720   577380
#  Train_5 Light Travel Station18 Station25     574500   574920
#  Train_1   Train Trip  Station7 Station23     580320   584280
#  Train_3   Train Trip Station26 Station27     580740   591840
# Train_11   Train Trip  Station1 Station22     580920   585660
# Train_12   Train Trip Station22 Station23     582720   586020
#  Train_1 Light Travel Station23  Station1     584280   585240
#  Train_1   Train Trip  Station1 Station24     585600   596880
# Train_11 Light Travel Station22 Station22     585660   585660
# Train_12 Light Travel Station23 Station23     586020   586020
# Train_11   Train Trip Station22 Station21     586440   597960
# Train_10   Train Trip  Station5  Station4     586620   593520
# Train_12   Train Trip Station23  Station1     587580   592200
#  Train_5   Train Trip Station25 Station18     589800   595440
#  Train_6   Train Trip  Station8 Station18     590700   597360
#  Train_4   Train Trip Station20  Station0     592440   604800
#
#  Cost Breakdown:
# Total Cost           : 12936.34
# Traction Unit Cost   : 12000.00
# Light Travel Cost    : 936.34
# Number of Vehicles   : 12

# %% [markdown]
# **Convert List_A to a CSV File**

# %%
import pandas as pd

# Convert full_schedule (a list of dicts) into a DataFrame
df_schedule = pd.DataFrame(full_schedule)

# Save to CSV
df_schedule.to_csv("full_schedule_Instance_A.csv", index=False)

# For Google Colab: provide download link
from google.colab import files
files.download("full_schedule_Instance_A.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.lines as mlines
import time

# Start timer
start_time = time.time()

# Load schedule
df_schedule = pd.read_csv("full_schedule_Instance_A.csv")

# Step 1: Map stations to Y-axis positions
stations = sorted(set(df_schedule["From"]).union(set(df_schedule["To"])))
station_to_y = {station: i for i, station in enumerate(stations)}

# Step 2: Predefine 12 train IDs
train_ids = [f"Train_{i}" for i in range(1, 13)]

# Step 3: Assign each train a unique color
cmap = cm.get_cmap('tab20', len(train_ids))
train_to_color = {train: cmap(i) for i, train in enumerate(train_ids)}

# Step 4: Initialize plot and track nodes/edges
plt.figure(figsize=(20, 12))
nodes = set()
edges = []

# Step 5: Plot edges and store nodes/edges
for _, row in df_schedule.iterrows():
    from_station = row["From"]
    to_station = row["To"]
    start_time_trip = row["StartTime"]
    end_time_trip = row["EndTime"]
    train = row["Train"]
    edge_type = row["Type"]

    u = (start_time_trip, station_to_y[from_station])
    v = (end_time_trip, station_to_y[to_station])

    nodes.update([u, v])
    edges.append((u, v))

    color = train_to_color.get(train, 'black')
    linestyle = '-' if edge_type == "Train Trip" else '--'
    plt.plot([u[0], v[0]], [u[1], v[1]], color=color, linestyle=linestyle, linewidth=1)

# Step 6: Plot nodes
for t, y in nodes:
    plt.scatter(t, y, color='black', s=10)
    plt.text(t, y + 0.1, f'{t}', fontsize=5, ha='center', color='darkred')

# Step 7: Axis formatting
plt.yticks(list(station_to_y.values()), list(station_to_y.keys()))
plt.xlabel("Time (seconds)")
plt.ylabel("Stations")
plt.title("Space-Time Network_Instance_A")
plt.grid(True, linestyle='--', linewidth=0.5)

# Step 8: Legend
legend_lines = [
    mlines.Line2D([], [], color=train_to_color[train], linewidth=2, label=train)
    for train in train_ids
]
plt.legend(handles=legend_lines, title="Trains", loc='upper center', bbox_to_anchor=(0.5, -0.08),
           ncol=6, fontsize=8, title_fontsize=10, frameon=True)

plt.tight_layout()
plt.show()

# End timer
end_time = time.time()

# Step 9: Print summary
print("\n===== Network Summary =====")
print(f"Total Nodes      : {len(nodes)}")
print(f"Total Edges      : {len(edges)}")
print(f"Execution Time   : {round(end_time - start_time, 3)} seconds")
# Out:
# /tmp/ipython-input-5-1490137331.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(train_ids))
# ===== Network Summary =====
# Total Nodes      : 353
# Total Edges      : 290
# Execution Time   : 12.812 seconds

# %% [markdown]
# **Robustness Calculation**

# %%
# STEP 01: Identify tight connections
# Define threshold (e.g., 300 seconds = 5 minutes)
TIGHT_THRESHOLD = 300  # seconds

# Extract only productive train trips for each train
train_trips = df_schedule[df_schedule["Type"] == "Train Trip"].copy()
train_trips.sort_values(by=["Train", "StartTime"], inplace=True)

# Find consecutive trips by the same train
tight_connections = []
for train_id, group in train_trips.groupby("Train"):
    trips = group.sort_values("StartTime").reset_index(drop=True)
    for i in range(len(trips) - 1):
        current_end = trips.loc[i, "EndTime"]
        next_start = trips.loc[i + 1, "StartTime"]
        connection_time = next_start - current_end
        if connection_time <= TIGHT_THRESHOLD:
            tight_connections.append({
                "Train": train_id,
                "FromTripEnd": current_end,
                "ToTripStart": next_start,
                "ConnectionTime": connection_time,
                "FromStation": trips.loc[i, "To"],
                "ToStation": trips.loc[i + 1, "From"]
            })

# Display the tight connections
df_tight = pd.DataFrame(tight_connections)
print(f"\n Tight Connections (<= {TIGHT_THRESHOLD} seconds): {len(df_tight)} found")
if not df_tight.empty:
    print(df_tight.to_string(index=False))
else:
    print(" No tight connections found.")
# Out:
#  Tight Connections (<= 300 seconds): 5 found
#   Train  FromTripEnd  ToTripStart  ConnectionTime FromStation ToStation
# Train_3       135240       135480             240   Station19 Station19
# Train_5        48840        49080             240   Station19 Station19
# Train_5       221640       221880             240   Station19 Station19
# Train_5       480840       481080             240   Station19 Station19
# Train_6       567240       567480             240   Station19 Station19

# %%
import pandas as pd

# Step 2: Set threshold for tight connections
TIGHT_THRESHOLD = 300  # seconds
BUFFER_TIME = 600      # seconds

# Step 3: Detect tight connections
train_trips = df_schedule[df_schedule["Type"] == "Train Trip"].copy()
train_trips.sort_values(by=["Train", "StartTime"], inplace=True)

tight_connections = []
for train_id, group in train_trips.groupby("Train"):
    trips = group.sort_values("StartTime").reset_index(drop=True)
    for i in range(len(trips) - 1):
        current_end = trips.loc[i, "EndTime"]
        next_start = trips.loc[i + 1, "StartTime"]
        connection_time = next_start - current_end
        if connection_time <= TIGHT_THRESHOLD:
            tight_connections.append({
                "Train": train_id,
                "FromTripEnd": current_end,
                "ToTripStart": next_start,
                "ConnectionTime": connection_time,
                "FromStation": trips.loc[i, "To"],
                "ToStation": trips.loc[i + 1, "From"]
            })

df_tight = pd.DataFrame(tight_connections)

# Step 4: Apply buffer by shifting trips forward
df_buffered = df_schedule.copy()
df_buffered.sort_values(by=["Train", "StartTime"], inplace=True)

for _, row in df_tight.iterrows():
    train_id = row["Train"]
    to_start = row["ToTripStart"]
    affected = df_buffered[
        (df_buffered["Train"] == train_id) &
        (df_buffered["StartTime"] >= to_start)
    ].index
    df_buffered.loc[affected, "StartTime"] += BUFFER_TIME
    df_buffered.loc[affected, "EndTime"] += BUFFER_TIME

# Step 5: Recalculate cost
C_TU = 1000
C_Light = 0.10
traction_units = df_buffered["Train"].nunique()
traction_cost = traction_units * C_TU

light_travel_cost = 0
for _, row in df_buffered[df_buffered["Type"] == "Light Travel"].iterrows():
    key = f"{row['From']},{row['To']}"
    if key in empty_runs:
        dist = empty_runs[key]["Distance"]
        light_travel_cost += dist * C_Light

total_cost = traction_cost + light_travel_cost

# Step 6: Calculate nodes and edges
nodes = set()
edges = 0
for _, row in df_buffered.iterrows():
    u = (row["StartTime"], row["From"])
    v = (row["EndTime"], row["To"])
    nodes.update([u, v])
    edges += 1

# Step 7: Save result
buffered_schedule_path = "schedule_buffered_600s.csv"
df_buffered.to_csv(buffered_schedule_path, index=False)

# Step 8: Summary
print("\n===== ⏱️ Buffered Plan Summary (600s for tight links) =====")
print(f" Tight Connections Found   : {len(df_tight)}")
print(f" Buffer Applied per Link   : {BUFFER_TIME} seconds")
print(f" Trains (Vehicles) Used    : {traction_units}")
print(f" Light Travel Cost         : {round(light_travel_cost, 2)}")
print(f" Total Cost                : {round(total_cost, 2)}")
print(f" Total Edges               : {edges}")
print(f" Total Unique Nodes        : {len(nodes)}")
print(f" Saved to File             : {buffered_schedule_path}")
# Out:
# ===== ⏱️ Buffered Plan Summary (600s for tight links) =====
#  Tight Connections Found   : 5
#  Buffer Applied per Link   : 600 seconds
#  Trains (Vehicles) Used    : 12
#  Light Travel Cost         : 936.34
#  Total Cost                : 12936.34
#  Total Edges               : 290
#  Total Unique Nodes        : 355
#  Saved to File             : schedule_buffered_600s.csv

# %%
import pandas as pd

# Load the original schedule before buffering
df_schedule = pd.read_csv("full_schedule_Instance_A.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.lines as mlines
import json
import re

# Load JSON data
with open("Instance_A.json") as f:
    data = json.load(f)

# Extract empty runs
empty_runs = data["EmptyRunData"]

# === CONFIGURATION ===
TIGHT_THRESHOLD = 300  # seconds
BUFFER_TIME = 600      # buffer to add after tight connections
C_TU = 1000            # traction unit cost
C_Light = 0.10         # light travel cost per km

# === STEP 1: Detect Tight Connections ===
train_trips = df_schedule[df_schedule["Type"] == "Train Trip"].copy()
train_trips.sort_values(by=["Train", "StartTime"], inplace=True)

tight_connections = []
for train_id, group in train_trips.groupby("Train"):
    trips = group.sort_values("StartTime").reset_index(drop=True)
    for i in range(len(trips) - 1):
        current_end = trips.loc[i, "EndTime"]
        next_start = trips.loc[i + 1, "StartTime"]
        connection_time = next_start - current_end
        if connection_time <= TIGHT_THRESHOLD:
            tight_connections.append({
                "Train": train_id,
                "FromTripEnd": current_end,
                "ToTripStart": next_start,
                "ConnectionTime": connection_time,
                "FromStation": trips.loc[i, "To"],
                "ToStation": trips.loc[i + 1, "From"]
            })

df_tight = pd.DataFrame(tight_connections)

# === STEP 2: Apply Buffer ===
df_buffered = df_schedule.copy()
df_buffered.sort_values(by=["Train", "StartTime"], inplace=True)

for _, row in df_tight.iterrows():
    train_id = row["Train"]
    to_start = row["ToTripStart"]
    affected = df_buffered[
        (df_buffered["Train"] == train_id) &
        (df_buffered["StartTime"] >= to_start)
    ].index
    df_buffered.loc[affected, "StartTime"] += BUFFER_TIME
    df_buffered.loc[affected, "EndTime"] += BUFFER_TIME

# === STEP 3: Recalculate Cost ===
traction_units = df_buffered["Train"].nunique()
traction_cost = traction_units * C_TU

light_travel_cost = 0
for _, row in df_buffered[df_buffered["Type"] == "Light Travel"].iterrows():
    key = f"{row['From']},{row['To']}"
    if key in empty_runs:
        dist = empty_runs[key]["Distance"]
        light_travel_cost += dist * C_Light

total_cost = traction_cost + light_travel_cost

# === STEP 4: Plot with Buffer Annotations ===
stations = sorted(set(df_buffered["From"]).union(set(df_buffered["To"])))
station_to_y = {station: i for i, station in enumerate(stations)}

train_ids = sorted(df_buffered["Train"].unique())
cmap = cm.get_cmap('tab20', len(train_ids))
train_to_color = {train: cmap(i) for i, train in enumerate(train_ids)}

plt.figure(figsize=(20, 12))
nodes = set()

# Plot train arcs
for _, row in df_buffered.iterrows():
    from_station = row["From"]
    to_station = row["To"]
    start = row["StartTime"]
    end = row["EndTime"]
    train = row["Train"]
    typ = row["Type"]

    u = (start, station_to_y[from_station])
    v = (end, station_to_y[to_station])
    color = train_to_color[train]
    linestyle = '-' if typ == "Train Trip" else '--'

    plt.plot([u[0], v[0]], [u[1], v[1]], color=color, linestyle=linestyle, linewidth=1)
    nodes.update([u, v])

# Annotate buffer arcs in red
for _, row in df_tight.iterrows():
    train_id = row["Train"]
    station = row["ToStation"]
    y = station_to_y[station]
    from_time = row["ToTripStart"]
    to_time = from_time + BUFFER_TIME
    plt.plot([from_time, to_time], [y, y], color='red', linestyle=':', linewidth=1)
    plt.text(to_time + 10, y + 0.15, '+600s', fontsize=6, color='red')

# Plot nodes
for t, y in nodes:
    plt.scatter(t, y, color='black', s=10)

# Axis settings
plt.yticks(list(station_to_y.values()), list(station_to_y.keys()))
plt.xlabel("Time (seconds)")
plt.ylabel("Stations")
plt.title("Buffered Plan with 600s Delay Buffers on Tight Connections")
plt.grid(True, linestyle='--', linewidth=0.5)

# Legend
legend_lines = [
    mlines.Line2D([], [], color=train_to_color[train], linewidth=2, label=train)
    for train in train_ids[:12]
]
legend_lines.append(mlines.Line2D([], [], color='red', linestyle=':', linewidth=1, label='Buffer +600s'))
plt.legend(handles=legend_lines, title="Trains", loc='upper center', bbox_to_anchor=(0.5, -0.08),
           ncol=6, fontsize=8, title_fontsize=10, frameon=True)

plt.tight_layout()
plt.show()

# === STEP 5: Summary ===
print("\n===== ⏱️ Buffered Plan Summary (600s for tight links) =====")
print(f" Tight Connections Found   : {len(df_tight)}")
print(f" Buffer Applied per Link   : {BUFFER_TIME} seconds")
print(f" Trains (Vehicles) Used    : {traction_units}")
print(f" Light Travel Cost         : {round(light_travel_cost, 2)}")
print(f" Total Cost                : {round(total_cost, 2)}")
print(f" Total Edges               : {len(df_buffered)}")
print(f" Total Unique Nodes        : {len(nodes)}")
# Out:
# /tmp/ipython-input-9-2111523906.py:76: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(train_ids))
# ===== ⏱️ Buffered Plan Summary (600s for tight links) =====
#  Tight Connections Found   : 5
#  Buffer Applied per Link   : 600 seconds
#  Trains (Vehicles) Used    : 12
#  Light Travel Cost         : 936.34
#  Total Cost                : 12936.34
#  Total Edges               : 290
#  Total Unique Nodes        : 355

# %%
from collections import defaultdict
import pandas as pd

# Configuration
TIGHT_THRESHOLD = 300  # seconds

# Initialize counter
tight_counts = defaultdict(int)
total_counts = defaultdict(int)

# Detect tight and total connections per station
train_trips = df_schedule[df_schedule["Type"] == "Train Trip"].copy()
train_trips.sort_values(by=["Train", "StartTime"], inplace=True)

for train_id, group in train_trips.groupby("Train"):
    trips = group.reset_index(drop=True)
    for i in range(len(trips) - 1):
        end_time = trips.loc[i, "EndTime"]
        next_start = trips.loc[i + 1, "StartTime"]
        conn_time = next_start - end_time
        station = trips.loc[i + 1, "From"]

        total_counts[station] += 1
        if conn_time <= TIGHT_THRESHOLD:
            tight_counts[station] += 1

# Create summary DataFrame
df_station_tightness = pd.DataFrame({
    "TotalConnections": pd.Series(total_counts),
    "TightConnections": pd.Series(tight_counts)
})
df_station_tightness["TightRatio"] = df_station_tightness["TightConnections"] / df_station_tightness["TotalConnections"]
df_station_tightness = df_station_tightness.fillna(0).sort_values(by="TightRatio", ascending=False)

# Show top 10 stations
print("\n===== 🔍 Stations with Highest Tight Connection Ratios =====")
print(df_station_tightness.head(10).round(2))
# Out:
# ===== 🔍 Stations with Highest Tight Connection Ratios =====
#            TotalConnections  TightConnections  TightRatio
# Station19                 5               5.0         1.0
# Station11                10               0.0         0.0
# Station1                 13               0.0         0.0
# Station12                 6               0.0         0.0
# Station13                 1               0.0         0.0
# Station15                 2               0.0         0.0
# Station17                10               0.0         0.0
# Station2                  9               0.0         0.0
# Station20                 3               0.0         0.0
# Station21                 6               0.0         0.0
