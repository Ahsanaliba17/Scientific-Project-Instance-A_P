# %% [markdown]
# **Scheduling Problem**

# %% [markdown]
# Random Space Time Network Instance_C

# %% [markdown]
# **Step 01 Generating a Space Time Network**

# %%
# Load required libraries
import json  # Used to read and parse JSON files
import matplotlib.pyplot as plt  # Used for plotting the space-time network
import re  # Used for natural sorting of station names like Station1, Station2, Station10
import time  # Used to measure computation time
import matplotlib.ticker as ticker  # (Optional) used for custom formatting of x-axis ticks

# Start the timer to measure total computation time
start_time = time.time()

# Open and load the JSON file containing the instance data for stations, trips, and empty runs
with open("Instance_C.json") as f:
    data = json.load(f)

# Define a helper function that creates a sorting key for natural sorting (e.g., Station2 before Station10)
def natural_key(s):
    return [int(text) if text.isdigit() else text for text in re.split('(\d+)', s)]

# Extract and sort all station names using natural sorting
stations = sorted([s["Name"] for s in data["StationList"]], key=natural_key)

# Create a dictionary mapping each station name to a corresponding y-axis index (0, 1, ..., 33)
station_to_y = {name: i for i, name in enumerate(stations)}

# Sort all trips based on their start times
trips = sorted(data["TripList"], key=lambda x: x["StartTime"])

# Extract the empty run data which contains light travel durations between station pairs
empty_runs = data["EmptyRunData"]

# Initialize lists to store different types of arcs (edges) and special nodes
train_arcs = []          # Arcs representing productive trips (trains with passengers)
light_arcs_arrival = []  # Arcs representing light vehicle travel after completing a trip
light_arcs_source = []   # Arcs representing vehicle repositioning from source to first trip
ground_arcs = []         # Arcs representing idle waiting time at a station
source_nodes = []        # Artificial source nodes (before each trip)
sink_nodes = []          # Artificial sink nodes (after each trip)
nodes_set = set()        # Set to store all unique (time, station index) pairs (i.e., nodes)

# Step 1: Create artificial source and sink nodes for each trip
for trip in trips:
    source_nodes.append((trip["StartTime"] - 1, station_to_y[trip["Origin"]]))  # source node before trip starts
    sink_nodes.append((trip["EndTime"] + 1, station_to_y[trip["Destination"]]))  # sink node after trip ends

# Step 2: Create productive train arcs
for trip in trips:
    u = (trip["StartTime"], station_to_y[trip["Origin"]])
    v = (trip["EndTime"], station_to_y[trip["Destination"]])
    train_arcs.append((u, v))
    nodes_set.update([u, v])  # store nodes

# Step 3: Create light arcs from trip end to future trip start
for trip_a in trips:
    for trip_b in trips:
        if trip_a["Id"] != trip_b["Id"] and trip_a["EndTime"] < trip_b["StartTime"]:
            key = f"{trip_a['Destination']},{trip_b['Origin']}"
            if trip_a["Destination"] != trip_b["Origin"] and key in empty_runs:
                transfer_time = empty_runs[key]["Duration"]
                if trip_a["EndTime"] + transfer_time <= trip_b["StartTime"]:
                    u = (trip_a["EndTime"], station_to_y[trip_a["Destination"]])
                    v = (trip_a["EndTime"] + transfer_time, station_to_y[trip_b["Origin"]])
                    light_arcs_arrival.append((u, v))
                    nodes_set.update([u, v])
                    break

# Step 4: Create light arcs from artificial source to feasible trip origin
for src in source_nodes:
    t0, y0 = src
    for trip in trips:
        key = f"{stations[y0]},{trip['Origin']}"
        if key in empty_runs and t0 < trip["StartTime"]:
            duration = empty_runs[key]["Duration"]
            if t0 + duration <= trip["StartTime"]:
                u = src
                v = (t0 + duration, station_to_y[trip["Origin"]])
                light_arcs_source.append((u, v))
                nodes_set.update([u, v])
                break

# Step 5: Create ground arcs between end of one trip and start of another at same station
for trip_a in trips:
    for trip_b in trips:
        if trip_a["Destination"] == trip_b["Origin"] and trip_b["StartTime"] > trip_a["EndTime"]:
            u = (trip_a["EndTime"], station_to_y[trip_a["Destination"]])
            v = (trip_b["StartTime"], station_to_y[trip_b["Origin"]])
            ground_arcs.append((u, v))
            nodes_set.update([u, v])
            break

# Start plotting the space-time network
plt.figure(figsize=(20, 12))

# Draw productive train arcs (blue)
for u, v in train_arcs:
    plt.plot([u[0], v[0]], [u[1], v[1]], color='blue', linewidth=0.9)

# Draw light arcs after trip end (dashed gray)
for u, v in light_arcs_arrival:
    plt.plot([u[0], v[0]], [u[1], v[1]], color='gray', linestyle='dashed', linewidth=0.8)

# Draw light arcs from source node (dotted dark gray)
for u, v in light_arcs_source:
    plt.plot([u[0], v[0]], [u[1], v[1]], color='darkgray', linestyle='dotted', linewidth=0.8)

# Draw ground arcs (green)
for u, v in ground_arcs:
    plt.plot([u[0], v[0]], [u[1], v[1]], color='green', linestyle='solid', linewidth=0.7)

# Scatter plot all nodes for clarity
for (u, v) in train_arcs + light_arcs_arrival + light_arcs_source + ground_arcs:
    plt.scatter([u[0], v[0]], [u[1], v[1]], s=6, color='black')

# Configure y-axis with station names in top-down order
plt.yticks(range(len(stations)), stations)

# Set labels and title
plt.xlabel("Time (seconds)")
plt.ylabel("Stations (top: Station0)")
plt.title("Space-Time Network - Instance_C")

# Add grid and tighten layout
plt.grid(True, linestyle='--', linewidth=0.3)
plt.tight_layout()

# Show the final plot
plt.show()

# Calculate total edges and computation time
total_edges = len(train_arcs) + len(light_arcs_arrival) + len(light_arcs_source) + len(ground_arcs)
end_time_calc = time.time()

# Print network statistics
print("Network Summary")
print(f"Number of nodes       : {len(nodes_set)}")
print(f"Number of edges       : {total_edges}")
print(f"Computation time (s)  : {round(end_time_calc - start_time, 3)}")
# Out:
# Network Summary
# Number of nodes       : 1512
# Number of edges       : 1510
# Computation time (s)  : 25.254

# %% [markdown]
# **Step 02 Costing Calculation and Vehicles Calculation Using Pulp**

# %% [markdown]
# Pulp Installation for Mixed Integer Program Optimization

# %%
# Install PuLP
# !pip install pulp

# Load libraries
import json, re
import pulp
import pandas as pd

# Load JSON file
with open("Instance_C.json") as f:
    data = json.load(f)

# Cost parameters
C_TU = 1000
C_Light = 0.10

# Parse stations and trips
stations = sorted(
    [s["Name"] for s in data["StationList"]],
    key=lambda s: [int(t) if t.isdigit() else t for t in re.split("(\d+)", s)]
)
station_index = {name: i for i, name in enumerate(stations)}

trips = sorted(data["TripList"], key=lambda x: x["StartTime"])
trip_ids = [trip["Id"] for trip in trips]
trip_map = {trip["Id"]: trip for trip in trips}
empty_runs = data["EmptyRunData"]

# Optimization model
model = pulp.LpProblem("RollingStockCirculationPlanning", pulp.LpMinimize)

x = {trip["Id"]: pulp.LpVariable(f"x_{trip['Id']}", cat="Binary") for trip in trips}
vehicles = {trip["Id"]: pulp.LpVariable(f"veh_{trip['Id']}", cat="Binary") for trip in trips}
z = {}

# Generate light travel arcs
for i, trip_a in enumerate(trips):
    for j, trip_b in enumerate(trips):
        if i != j and trip_a["EndTime"] < trip_b["StartTime"]:
            key = f"{trip_a['Destination']},{trip_b['Origin']}"
            if key in empty_runs:
                ttime = empty_runs[key]["Duration"]
                if trip_a["EndTime"] + ttime <= trip_b["StartTime"]:
                    arc = f"{trip_a['Id']}_{trip_b['Id']}"
                    z[arc] = pulp.LpVariable(f"z_{arc}", cat="Binary")

# Objective
model += (
    pulp.lpSum([vehicles[trip["Id"]] for trip in trips]) * C_TU +
    pulp.lpSum([
        z[arc] *
        empty_runs[f"{trip_map[int(arc.split('_')[0])]['Destination']},{trip_map[int(arc.split('_')[1])]['Origin']}"]["Distance"] *
        C_Light for arc in z
    ])
)

# Constraints
for trip in trips:
    model += x[trip["Id"]] == 1

for trip in trips:
    incoming = [z[arc] for arc in z if int(arc.split('_')[1]) == trip["Id"]]
    model += vehicles[trip["Id"]] + pulp.lpSum(incoming) >= x[trip["Id"]]

for trip in trips:
    outgoing = [z[arc] for arc in z if int(arc.split('_')[0]) == trip["Id"]]
    model += pulp.lpSum(outgoing) <= 1

# Solve
model.solve(pulp.PULP_CBC_CMD(msg=0))

# Result
num_vehicles = sum(v.varValue for v in vehicles.values())
light_cost = sum(
    z[arc].varValue *
    empty_runs[f"{trip_map[int(arc.split('_')[0])]['Destination']},{trip_map[int(arc.split('_')[1])]['Origin']}"]["Distance"] *
    C_Light for arc in z
)
traction_cost = num_vehicles * C_TU
total_cost = traction_cost + light_cost

# Display
results = {
    "Total Cost": round(total_cost, 2),
    "Traction Unit Cost": round(traction_cost, 2),
    "Light Travel Cost": round(light_cost, 2),
    "Deadheading Cost": 0.00,
    "Number of Vehicles Used": int(num_vehicles)
}
pd.DataFrame([results])
# Out:
# Collecting pulp
#   Downloading pulp-3.2.1-py3-none-any.whl.metadata (6.9 kB)
# Downloading pulp-3.2.1-py3-none-any.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 99.6 MB/s eta 0:00:00
# Installing collected packages: pulp
# Successfully installed pulp-3.2.1
#    Total Cost  Traction Unit Cost  Light Travel Cost  Deadheading Cost  \
# 0      2000.0              2000.0                0.0               0.0
#
#    Number of Vehicles Used
# 0                        2

# %% [markdown]
# **`Schedule Calculator`**

# %%
# STEP 1: Install pulp (for Google Colab; skip if already installed)
# !pip install pulp

# STEP 2: Import required libraries
import json           # For reading the JSON file
import re             # For sorting station names naturally
import pulp           # For defining and solving the optimization model
import pandas as pd   # For creating and displaying schedule tables
from pulp import LpStatus  # For checking the model solution status

# STEP 3: Load data from the JSON file
with open("Instance_C.json") as f:
    data = json.load(f)

# STEP 4: Define cost parameters
C_TU = 1000       # Cost for using a train unit
C_Light = 0.10    # Cost per km for light (empty) travel

# STEP 5: Prepare and sort stations
stations = sorted(
    [s["Name"] for s in data["StationList"]],
    key=lambda s: [int(t) if t.isdigit() else t for t in re.split("(\d+)", s)]
)
station_index = {name: i for i, name in enumerate(stations)}

# STEP 6: Extract trips and empty run data
trips = sorted(data["TripList"], key=lambda x: x["StartTime"])
trip_map = {trip["Id"]: trip for trip in trips}
empty_runs = data["EmptyRunData"]

# STEP 7: Define the optimization model
model = pulp.LpProblem("RollingStock", pulp.LpMinimize)

# Binary variable for each trip: 1 if performed
x = {trip["Id"]: pulp.LpVariable(f"x_{trip['Id']}", cat="Binary") for trip in trips}

# Binary variable for vehicle usage: 1 if a new train starts with this trip
vehicles = {trip["Id"]: pulp.LpVariable(f"veh_{trip['Id']}", cat="Binary") for trip in trips}

# Binary variables for light connections between trips
z = {}
for i, a in enumerate(trips):
    for j, b in enumerate(trips):
        if i != j and a["EndTime"] < b["StartTime"]:
            key = f"{a['Destination']},{b['Origin']}"
            if key in empty_runs:
                dt = empty_runs[key]["Duration"]
                if a["EndTime"] + dt <= b["StartTime"]:
                    arc = f"{a['Id']}_{b['Id']}"
                    z[arc] = pulp.LpVariable(f"z_{arc}", cat="Binary")

# STEP 8: Define objective function to minimize total cost
model += (
    pulp.lpSum([vehicles[tid] for tid in x]) * C_TU +
    pulp.lpSum([
        z[arc] * empty_runs[
            f"{trip_map[int(arc.split('_')[0])]['Destination']},{trip_map[int(arc.split('_')[1])]['Origin']}"
        ]["Distance"] * C_Light for arc in z
    ])
)

# STEP 9: Add constraints
# Ensure each trip is covered
for trip in trips:
    model += x[trip["Id"]] == 1

# A trip is covered either by a new vehicle or from a previous trip via light travel
for trip in trips:
    incoming = [z[arc] for arc in z if int(arc.split("_")[1]) == trip["Id"]]
    model += vehicles[trip["Id"]] + pulp.lpSum(incoming) >= x[trip["Id"]]

# A trip connects to at most one next trip
for trip in trips:
    outgoing = [z[arc] for arc in z if int(arc.split("_")[0]) == trip["Id"]]
    model += pulp.lpSum(outgoing) <= 1

# STEP 10: Solve the model
model.solve(pulp.PULP_CBC_CMD(msg=0))

# STEP 11: Check if solution is feasible
status = LpStatus[model.status]
print(f"\n🔍 Model Status: {status}")
if status != "Optimal":
    print(" No feasible or optimal solution found.")
else:
    print(" Feasible and optimal solution found.")

# STEP 12: Assign Train IDs
trip_to_train = {}
train_counter = 1
outgoing_map = {int(arc.split('_')[0]): int(arc.split('_')[1]) for arc in z if z[arc].varValue == 1}
visited = set()

for trip in trips:
    tid = trip["Id"]
    if tid not in visited:
        current_train = f"Train_{train_counter}"
        while tid in trip_map:
            visited.add(tid)
            trip_to_train[tid] = current_train
            tid = outgoing_map.get(tid, None)
            if tid is None or tid in visited:
                break
        train_counter += 1

# STEP 13: Build the full trip and light travel schedule
full_schedule = []

# Add train trips
for tid, var in x.items():
    if var.varValue == 1:
        trip = trip_map[tid]
        full_schedule.append({
            "Train": trip_to_train[tid],
            "Type": "Train Trip",
            "From": trip["Origin"],
            "To": trip["Destination"],
            "StartTime": trip["StartTime"],
            "EndTime": trip["EndTime"]
        })

# Add light travel trips
light_travel_cost = 0
for arc, var in z.items():
    if var.varValue == 1:
        from_id, to_id = map(int, arc.split("_"))
        trip_a = trip_map[from_id]
        trip_b = trip_map[to_id]
        key = f"{trip_a['Destination']},{trip_b['Origin']}"
        dur = empty_runs[key]["Duration"]
        dist = empty_runs[key]["Distance"]
        cost = dist * C_Light
        light_travel_cost += cost
        full_schedule.append({
            "Train": trip_to_train[from_id],
            "Type": "Light Travel",
            "From": trip_a["Destination"],
            "To": trip_b["Origin"],
            "StartTime": trip_a["EndTime"],
            "EndTime": trip_a["EndTime"] + dur
        })

# STEP 14: Display the final schedule
full_schedule = sorted(full_schedule, key=lambda x: x["StartTime"])
df_schedule = pd.DataFrame(full_schedule)
print("\n Complete Trip and Light Travel Schedule:")
print(df_schedule.to_string(index=False))

# STEP 15: Print cost breakdown
traction_units = sum([vehicles[tid].varValue for tid in vehicles])
traction_cost = traction_units * C_TU
total_cost = pulp.value(model.objective)

print("\n Cost Breakdown:")
print(f"Total Cost           : {total_cost:.2f}")
print(f"Traction Unit Cost   : {traction_cost:.2f}")
print(f"Light Travel Cost    : {light_travel_cost:.2f}")
print(f"Number of Vehicles   : {int(traction_units)}")
# Out:
# Requirement already satisfied: pulp in /usr/local/lib/python3.11/dist-packages (3.2.1)
#
# 🔍 Model Status: Optimal
#  Feasible and optimal solution found.
#
#  Complete Trip and Light Travel Schedule:
#   Train         Type     From       To  StartTime  EndTime
# Train_1   Train Trip Station0 Station1      20190    21150
# Train_1 Light Travel Station1 Station1      21150    21150
# Train_2   Train Trip Station0 Station1      21990    22950
# Train_1   Train Trip Station1 Station0      22140    23130
# Train_2 Light Travel Station1 Station1      22950    22950
# Train_1 Light Travel Station0 Station0      23130    23130
# Train_1   Train Trip Station0 Station1      23790    24750
# Train_2   Train Trip Station1 Station0      23940    24930
# Train_1 Light Travel Station1 Station1      24750    24750
# Train_2 Light Travel Station0 Station0      24930    24930
# Train_2   Train Trip Station0 Station1      25590    26550
# Train_1   Train Trip Station1 Station0      25740    26730
# Train_2 Light Travel Station1 Station1      26550    26550
# Train_1 Light Travel Station0 Station0      26730    26730
# Train_1   Train Trip Station0 Station1      27390    28350
# Train_2   Train Trip Station1 Station0      27540    28530
# Train_1 Light Travel Station1 Station1      28350    28350
# Train_2 Light Travel Station0 Station0      28530    28530
# Train_2   Train Trip Station0 Station1      29190    30150
# Train_1   Train Trip Station1 Station0      29340    30330
# Train_2 Light Travel Station1 Station1      30150    30150
# Train_1 Light Travel Station0 Station0      30330    30330
# Train_1   Train Trip Station0 Station1      30990    31950
# Train_2   Train Trip Station1 Station0      31140    32130
# Train_1 Light Travel Station1 Station1      31950    31950
# Train_2 Light Travel Station0 Station0      32130    32130
# Train_2   Train Trip Station0 Station1      32790    33750
# Train_1   Train Trip Station1 Station0      32940    33930
# Train_2 Light Travel Station1 Station1      33750    33750
# Train_1 Light Travel Station0 Station0      33930    33930
# Train_1   Train Trip Station0 Station1      34590    35550
# Train_2   Train Trip Station1 Station0      34740    35730
# Train_1 Light Travel Station1 Station1      35550    35550
# Train_2 Light Travel Station0 Station0      35730    35730
# Train_2   Train Trip Station0 Station1      36390    37350
# Train_1   Train Trip Station1 Station0      36540    37530
# Train_2 Light Travel Station1 Station1      37350    37350
# Train_1 Light Travel Station0 Station0      37530    37530
# Train_1   Train Trip Station0 Station1      38190    39150
# Train_2   Train Trip Station1 Station0      38340    39330
# Train_1 Light Travel Station1 Station1      39150    39150
# Train_2 Light Travel Station0 Station0      39330    39330
# Train_2   Train Trip Station0 Station1      39990    40950
# Train_1   Train Trip Station1 Station0      40140    41130
# Train_2 Light Travel Station1 Station1      40950    40950
# Train_1 Light Travel Station0 Station0      41130    41130
# Train_1   Train Trip Station0 Station1      41790    42750
# Train_2   Train Trip Station1 Station0      41940    42930
# Train_1 Light Travel Station1 Station1      42750    42750
# Train_2 Light Travel Station0 Station0      42930    42930
# Train_2   Train Trip Station0 Station1      43590    44550
# Train_1   Train Trip Station1 Station0      43740    44730
# Train_2 Light Travel Station1 Station1      44550    44550
# Train_1 Light Travel Station0 Station0      44730    44730
# Train_1   Train Trip Station0 Station1      45390    46350
# Train_2   Train Trip Station1 Station0      45540    46530
# Train_1 Light Travel Station1 Station1      46350    46350
# Train_2 Light Travel Station0 Station0      46530    46530
# Train_2   Train Trip Station0 Station1      47190    48150
# Train_1   Train Trip Station1 Station0      47340    48330
# Train_2 Light Travel Station1 Station1      48150    48150
# Train_1 Light Travel Station0 Station0      48330    48330
# Train_1   Train Trip Station0 Station1      48990    49950
# Train_2   Train Trip Station1 Station0      49140    50130
# Train_1 Light Travel Station1 Station1      49950    49950
# Train_2 Light Travel Station0 Station0      50130    50130
# Train_2   Train Trip Station0 Station1      50790    51750
# Train_1   Train Trip Station1 Station0      50940    51930
# Train_2 Light Travel Station1 Station1      51750    51750
# Train_1 Light Travel Station0 Station0      51930    51930
# Train_1   Train Trip Station0 Station1      52590    53550
# Train_2   Train Trip Station1 Station0      52740    53730
# Train_1 Light Travel Station1 Station1      53550    53550
# Train_2 Light Travel Station0 Station0      53730    53730
# Train_2   Train Trip Station0 Station1      54390    55350
# Train_1   Train Trip Station1 Station0      54540    55530
# Train_2 Light Travel Station1 Station1      55350    55350
# Train_1 Light Travel Station0 Station0      55530    55530
# Train_1   Train Trip Station0 Station1      56190    57150
# Train_2   Train Trip Station1 Station0      56340    57330
# Train_1 Light Travel Station1 Station1      57150    57150
# Train_2 Light Travel Station0 Station0      57330    57330
# Train_2   Train Trip Station0 Station1      57990    58950
# Train_1   Train Trip Station1 Station0      58140    59130
# Train_2 Light Travel Station1 Station1      58950    58950
# Train_1 Light Travel Station0 Station0      59130    59130
# Train_1   Train Trip Station0 Station1      59790    60750
# Train_2   Train Trip Station1 Station0      59940    60930
# Train_1 Light Travel Station1 Station1      60750    60750
# Train_2 Light Travel Station0 Station0      60930    60930
# Train_2   Train Trip Station0 Station1      61590    62550
# Train_1   Train Trip Station1 Station0      61740    62730
# Train_2 Light Travel Station1 Station1      62550    62550
# Train_1 Light Travel Station0 Station0      62730    62730
# Train_1   Train Trip Station0 Station1      63390    64350
# Train_2   Train Trip Station1 Station0      63540    64530
# Train_1 Light Travel Station1 Station1      64350    64350
# Train_2 Light Travel Station0 Station0      64530    64530
# Train_2   Train Trip Station0 Station1      65190    66150
# Train_1   Train Trip Station1 Station0      65340    66330
# Train_2 Light Travel Station1 Station1      66150    66150
# Train_1 Light Travel Station0 Station0      66330    66330
# Train_1   Train Trip Station0 Station1      66990    67950
# Train_2   Train Trip Station1 Station0      67140    68130
# Train_1 Light Travel Station1 Station1      67950    67950
# Train_2 Light Travel Station0 Station0      68130    68130
# Train_2   Train Trip Station0 Station1      68790    69750
# Train_1   Train Trip Station1 Station0      68940    69930
# Train_2 Light Travel Station1 Station1      69750    69750
# Train_1 Light Travel Station0 Station0      69930    69930
# Train_1   Train Trip Station0 Station1      70590    71550
# Train_2   Train Trip Station1 Station0      70740    71730
# Train_1 Light Travel Station1 Station1      71550    71550
# Train_2 Light Travel Station0 Station0      71730    71730
# Train_2   Train Trip Station0 Station1      72390    73350
# Train_1   Train Trip Station1 Station0      72540    73530
# Train_2 Light Travel Station1 Station1      73350    73350
# Train_1 Light Travel Station0 Station0      73530    73530
# Train_1   Train Trip Station0 Station1      74190    75150
# Train_2   Train Trip Station1 Station0      74340    75330
# Train_1 Light Travel Station1 Station1      75150    75150
# Train_2 Light Travel Station0 Station0      75330    75330
# Train_2   Train Trip Station0 Station1      75990    76950
# Train_1   Train Trip Station1 Station0      76140    77130
# Train_2 Light Travel Station1 Station1      76950    76950
# Train_1 Light Travel Station0 Station0      77130    77130
# Train_1   Train Trip Station0 Station1      77790    78750
# Train_2   Train Trip Station1 Station0      77940    78930
# Train_1 Light Travel Station1 Station1      78750    78750
# Train_2 Light Travel Station0 Station0      78930    78930
# Train_2   Train Trip Station0 Station1      79590    80550
# Train_1   Train Trip Station1 Station0      79740    80730
# Train_2 Light Travel Station1 Station1      80550    80550
# Train_1 Light Travel Station0 Station0      80730    80730
# Train_1   Train Trip Station0 Station1      81390    82350
# Train_2   Train Trip Station1 Station0      81540    82530
# Train_1 Light Travel Station1 Station1      82350    82350
# Train_2 Light Travel Station0 Station0      82530    82530
# Train_2   Train Trip Station0 Station1      83190    84150
# Train_1   Train Trip Station1 Station0      83340    84330
# Train_2 Light Travel Station1 Station1      84150    84150
# Train_1 Light Travel Station0 Station0      84330    84330
# Train_2   Train Trip Station1 Station0      85140    86130
# Train_2 Light Travel Station0 Station0      86130    86130
# Train_2   Train Trip Station0 Station1     106590   107550
# Train_2 Light Travel Station1 Station1     107550   107550
# Train_1   Train Trip Station0 Station1     108390   109350
# Train_2   Train Trip Station1 Station0     108540   109530
# Train_1 Light Travel Station1 Station1     109350   109350
# Train_2 Light Travel Station0 Station0     109530   109530
# Train_2   Train Trip Station0 Station1     110190   111150
# Train_1   Train Trip Station1 Station0     110340   111330
# Train_2 Light Travel Station1 Station1     111150   111150
# Train_1 Light Travel Station0 Station0     111330   111330
# Train_1   Train Trip Station0 Station1     111990   112950
# Train_2   Train Trip Station1 Station0     112140   113130
# Train_1 Light Travel Station1 Station1     112950   112950
# Train_2 Light Travel Station0 Station0     113130   113130
# Train_2   Train Trip Station0 Station1     113790   114750
# Train_1   Train Trip Station1 Station0     113940   114930
# Train_2 Light Travel Station1 Station1     114750   114750
# Train_1 Light Travel Station0 Station0     114930   114930
# Train_1   Train Trip Station0 Station1     115590   116550
# Train_2   Train Trip Station1 Station0     115740   116730
# Train_1 Light Travel Station1 Station1     116550   116550
# Train_2 Light Travel Station0 Station0     116730   116730
# Train_2   Train Trip Station0 Station1     117390   118350
# Train_1   Train Trip Station1 Station0     117540   118530
# Train_2 Light Travel Station1 Station1     118350   118350
# Train_1 Light Travel Station0 Station0     118530   118530
# Train_1   Train Trip Station0 Station1     119190   120150
# Train_2   Train Trip Station1 Station0     119340   120330
# Train_1 Light Travel Station1 Station1     120150   120150
# Train_2 Light Travel Station0 Station0     120330   120330
# Train_2   Train Trip Station0 Station1     120990   121950
# Train_1   Train Trip Station1 Station0     121140   122130
# Train_2 Light Travel Station1 Station1     121950   121950
# Train_1 Light Travel Station0 Station0     122130   122130
# Train_1   Train Trip Station0 Station1     122790   123750
# Train_2   Train Trip Station1 Station0     122940   123930
# Train_1 Light Travel Station1 Station1     123750   123750
# Train_2 Light Travel Station0 Station0     123930   123930
# Train_2   Train Trip Station0 Station1     124590   125550
# Train_1   Train Trip Station1 Station0     124740   125730
# Train_2 Light Travel Station1 Station1     125550   125550
# Train_1 Light Travel Station0 Station0     125730   125730
# Train_1   Train Trip Station0 Station1     126390   127350
# Train_2   Train Trip Station1 Station0     126540   127530
# Train_1 Light Travel Station1 Station1     127350   127350
# Train_2 Light Travel Station0 Station0     127530   127530
# Train_2   Train Trip Station0 Station1     128190   129150
# Train_1   Train Trip Station1 Station0     128340   129330
# Train_2 Light Travel Station1 Station1     129150   129150
# Train_1 Light Travel Station0 Station0     129330   129330
# Train_1   Train Trip Station0 Station1     129990   130950
# Train_2   Train Trip Station1 Station0     130140   131130
# Train_1 Light Travel Station1 Station1     130950   130950
# Train_2 Light Travel Station0 Station0     131130   131130
# Train_2   Train Trip Station0 Station1     131790   132750
# Train_1   Train Trip Station1 Station0     131940   132930
# Train_2 Light Travel Station1 Station1     132750   132750
# Train_1 Light Travel Station0 Station0     132930   132930
# Train_1   Train Trip Station0 Station1     133590   134550
# Train_2   Train Trip Station1 Station0     133740   134730
# Train_1 Light Travel Station1 Station1     134550   134550
# Train_2 Light Travel Station0 Station0     134730   134730
# Train_2   Train Trip Station0 Station1     135390   136350
# Train_1   Train Trip Station1 Station0     135540   136530
# Train_2 Light Travel Station1 Station1     136350   136350
# Train_1 Light Travel Station0 Station0     136530   136530
# Train_1   Train Trip Station0 Station1     137190   138150
# Train_2   Train Trip Station1 Station0     137340   138330
# Train_1 Light Travel Station1 Station1     138150   138150
# Train_2 Light Travel Station0 Station0     138330   138330
# Train_2   Train Trip Station0 Station1     138990   139950
# Train_1   Train Trip Station1 Station0     139140   140130
# Train_2 Light Travel Station1 Station1     139950   139950
# Train_1 Light Travel Station0 Station0     140130   140130
# Train_1   Train Trip Station0 Station1     140790   141750
# Train_2   Train Trip Station1 Station0     140940   141930
# Train_1 Light Travel Station1 Station1     141750   141750
# Train_2 Light Travel Station0 Station0     141930   141930
# Train_2   Train Trip Station0 Station1     142590   143550
# Train_1   Train Trip Station1 Station0     142740   143730
# Train_2 Light Travel Station1 Station1     143550   143550
# Train_1 Light Travel Station0 Station0     143730   143730
# Train_1   Train Trip Station0 Station1     144390   145350
# Train_2   Train Trip Station1 Station0     144540   145530
# Train_1 Light Travel Station1 Station1     145350   145350
# Train_2 Light Travel Station0 Station0     145530   145530
# Train_2   Train Trip Station0 Station1     146190   147150
# Train_1   Train Trip Station1 Station0     146340   147330
# Train_2 Light Travel Station1 Station1     147150   147150
# Train_1 Light Travel Station0 Station0     147330   147330
# Train_1   Train Trip Station0 Station1     147990   148950
# Train_2   Train Trip Station1 Station0     148140   149130
# Train_1 Light Travel Station1 Station1     148950   148950
# Train_2 Light Travel Station0 Station0     149130   149130
# Train_2   Train Trip Station0 Station1     149790   150750
# Train_1   Train Trip Station1 Station0     149940   150930
# Train_2 Light Travel Station1 Station1     150750   150750
# Train_1 Light Travel Station0 Station0     150930   150930
# Train_1   Train Trip Station0 Station1     151590   152550
# Train_2   Train Trip Station1 Station0     151740   152730
# Train_1 Light Travel Station1 Station1     152550   152550
# Train_2 Light Travel Station0 Station0     152730   152730
# Train_2   Train Trip Station0 Station1     153390   154350
# Train_1   Train Trip Station1 Station0     153540   154530
# Train_2 Light Travel Station1 Station1     154350   154350
# Train_1 Light Travel Station0 Station0     154530   154530
# Train_1   Train Trip Station0 Station1     155190   156150
# Train_2   Train Trip Station1 Station0     155340   156330
# Train_1 Light Travel Station1 Station1     156150   156150
# Train_2 Light Travel Station0 Station0     156330   156330
# Train_2   Train Trip Station0 Station1     156990   157950
# Train_1   Train Trip Station1 Station0     157140   158130
# Train_2 Light Travel Station1 Station1     157950   157950
# Train_1 Light Travel Station0 Station0     158130   158130
# Train_1   Train Trip Station0 Station1     158790   159750
# Train_2   Train Trip Station1 Station0     158940   159930
# Train_1 Light Travel Station1 Station1     159750   159750
# Train_2 Light Travel Station0 Station0     159930   159930
# Train_2   Train Trip Station0 Station1     160590   161550
# Train_1   Train Trip Station1 Station0     160740   161730
# Train_2 Light Travel Station1 Station1     161550   161550
# Train_1 Light Travel Station0 Station0     161730   161730
# Train_1   Train Trip Station0 Station1     162390   163350
# Train_2   Train Trip Station1 Station0     162540   163530
# Train_1 Light Travel Station1 Station1     163350   163350
# Train_2 Light Travel Station0 Station0     163530   163530
# Train_2   Train Trip Station0 Station1     164190   165150
# Train_1   Train Trip Station1 Station0     164340   165330
# Train_2 Light Travel Station1 Station1     165150   165150
# Train_1 Light Travel Station0 Station0     165330   165330
# Train_1   Train Trip Station0 Station1     165990   166950
# Train_2   Train Trip Station1 Station0     166140   167130
# Train_1 Light Travel Station1 Station1     166950   166950
# Train_2 Light Travel Station0 Station0     167130   167130
# Train_2   Train Trip Station0 Station1     167790   168750
# Train_1   Train Trip Station1 Station0     167940   168930
# Train_2 Light Travel Station1 Station1     168750   168750
# Train_1 Light Travel Station0 Station0     168930   168930
# Train_1   Train Trip Station0 Station1     169590   170550
# Train_2   Train Trip Station1 Station0     169740   170730
# Train_1 Light Travel Station1 Station1     170550   170550
# Train_2 Light Travel Station0 Station0     170730   170730
# Train_1   Train Trip Station1 Station0     171540   172530
# Train_1 Light Travel Station0 Station0     172530   172530
# Train_2   Train Trip Station0 Station1     192990   193950
# Train_2 Light Travel Station1 Station1     193950   193950
# Train_1   Train Trip Station0 Station1     194790   195750
# Train_2   Train Trip Station1 Station0     194940   195930
# Train_1 Light Travel Station1 Station1     195750   195750
# Train_2 Light Travel Station0 Station0     195930   195930
# Train_2   Train Trip Station0 Station1     196590   197550
# Train_1   Train Trip Station1 Station0     196740   197730
# Train_2 Light Travel Station1 Station1     197550   197550
# Train_1 Light Travel Station0 Station0     197730   197730
# Train_1   Train Trip Station0 Station1     198390   199350
# Train_2   Train Trip Station1 Station0     198540   199530
# Train_1 Light Travel Station1 Station1     199350   199350
# Train_2 Light Travel Station0 Station0     199530   199530
# Train_2   Train Trip Station0 Station1     200190   201150
# Train_1   Train Trip Station1 Station0     200340   201330
# Train_2 Light Travel Station1 Station1     201150   201150
# Train_1 Light Travel Station0 Station0     201330   201330
# Train_1   Train Trip Station0 Station1     201990   202950
# Train_2   Train Trip Station1 Station0     202140   203130
# Train_1 Light Travel Station1 Station1     202950   202950
# Train_2 Light Travel Station0 Station0     203130   203130
# Train_2   Train Trip Station0 Station1     203790   204750
# Train_1   Train Trip Station1 Station0     203940   204930
# Train_2 Light Travel Station1 Station1     204750   204750
# Train_1 Light Travel Station0 Station0     204930   204930
# Train_1   Train Trip Station0 Station1     205590   206550
# Train_2   Train Trip Station1 Station0     205740   206730
# Train_1 Light Travel Station1 Station1     206550   206550
# Train_2 Light Travel Station0 Station0     206730   206730
# Train_2   Train Trip Station0 Station1     207390   208350
# Train_1   Train Trip Station1 Station0     207540   208530
# Train_2 Light Travel Station1 Station1     208350   208350
# Train_1 Light Travel Station0 Station0     208530   208530
# Train_1   Train Trip Station0 Station1     209190   210150
# Train_2   Train Trip Station1 Station0     209340   210330
# Train_1 Light Travel Station1 Station1     210150   210150
# Train_2 Light Travel Station0 Station0     210330   210330
# Train_2   Train Trip Station0 Station1     210990   211950
# Train_1   Train Trip Station1 Station0     211140   212130
# Train_2 Light Travel Station1 Station1     211950   211950
# Train_1 Light Travel Station0 Station0     212130   212130
# Train_1   Train Trip Station0 Station1     212790   213750
# Train_2   Train Trip Station1 Station0     212940   213930
# Train_1 Light Travel Station1 Station1     213750   213750
# Train_2 Light Travel Station0 Station0     213930   213930
# Train_2   Train Trip Station0 Station1     214590   215550
# Train_1   Train Trip Station1 Station0     214740   215730
# Train_2 Light Travel Station1 Station1     215550   215550
# Train_1 Light Travel Station0 Station0     215730   215730
# Train_1   Train Trip Station0 Station1     216390   217350
# Train_2   Train Trip Station1 Station0     216540   217530
# Train_1 Light Travel Station1 Station1     217350   217350
# Train_2 Light Travel Station0 Station0     217530   217530
# Train_2   Train Trip Station0 Station1     218190   219150
# Train_1   Train Trip Station1 Station0     218340   219330
# Train_2 Light Travel Station1 Station1     219150   219150
# Train_1 Light Travel Station0 Station0     219330   219330
# Train_1   Train Trip Station0 Station1     219990   220950
# Train_2   Train Trip Station1 Station0     220140   221130
# Train_1 Light Travel Station1 Station1     220950   220950
# Train_2 Light Travel Station0 Station0     221130   221130
# Train_2   Train Trip Station0 Station1     221790   222750
# Train_1   Train Trip Station1 Station0     221940   222930
# Train_2 Light Travel Station1 Station1     222750   222750
# Train_1 Light Travel Station0 Station0     222930   222930
# Train_1   Train Trip Station0 Station1     223590   224550
# Train_2   Train Trip Station1 Station0     223740   224730
# Train_1 Light Travel Station1 Station1     224550   224550
# Train_2 Light Travel Station0 Station0     224730   224730
# Train_2   Train Trip Station0 Station1     225390   226350
# Train_1   Train Trip Station1 Station0     225540   226530
# Train_2 Light Travel Station1 Station1     226350   226350
# Train_1 Light Travel Station0 Station0     226530   226530
# Train_1   Train Trip Station0 Station1     227190   228150
# Train_2   Train Trip Station1 Station0     227340   228330
# Train_1 Light Travel Station1 Station1     228150   228150
# Train_2 Light Travel Station0 Station0     228330   228330
# Train_2   Train Trip Station0 Station1     228990   229950
# Train_1   Train Trip Station1 Station0     229140   230130
# Train_2 Light Travel Station1 Station1     229950   229950
# Train_1 Light Travel Station0 Station0     230130   230130
# Train_1   Train Trip Station0 Station1     230790   231750
# Train_2   Train Trip Station1 Station0     230940   231930
# Train_1 Light Travel Station1 Station1     231750   231750
# Train_2 Light Travel Station0 Station0     231930   231930
# Train_2   Train Trip Station0 Station1     232590   233550
# Train_1   Train Trip Station1 Station0     232740   233730
# Train_2 Light Travel Station1 Station1     233550   233550
# Train_1 Light Travel Station0 Station0     233730   233730
# Train_1   Train Trip Station0 Station1     234390   235350
# Train_2   Train Trip Station1 Station0     234540   235530
# Train_1 Light Travel Station1 Station1     235350   235350
# Train_2 Light Travel Station0 Station0     235530   235530
# Train_2   Train Trip Station0 Station1     236190   237150
# Train_1   Train Trip Station1 Station0     236340   237330
# Train_2 Light Travel Station1 Station1     237150   237150
# Train_1 Light Travel Station0 Station0     237330   237330
# Train_1   Train Trip Station0 Station1     237990   238950
# Train_2   Train Trip Station1 Station0     238140   239130
# Train_1 Light Travel Station1 Station1     238950   238950
# Train_2 Light Travel Station0 Station0     239130   239130
# Train_2   Train Trip Station0 Station1     239790   240750
# Train_1   Train Trip Station1 Station0     239940   240930
# Train_2 Light Travel Station1 Station1     240750   240750
# Train_1 Light Travel Station0 Station0     240930   240930
# Train_1   Train Trip Station0 Station1     241590   242550
# Train_2   Train Trip Station1 Station0     241740   242730
# Train_1 Light Travel Station1 Station1     242550   242550
# Train_2 Light Travel Station0 Station0     242730   242730
# Train_2   Train Trip Station0 Station1     243390   244350
# Train_1   Train Trip Station1 Station0     243540   244530
# Train_2 Light Travel Station1 Station1     244350   244350
# Train_1 Light Travel Station0 Station0     244530   244530
# Train_1   Train Trip Station0 Station1     245190   246150
# Train_2   Train Trip Station1 Station0     245340   246330
# Train_1 Light Travel Station1 Station1     246150   246150
# Train_2 Light Travel Station0 Station0     246330   246330
# Train_2   Train Trip Station0 Station1     246990   247950
# Train_1   Train Trip Station1 Station0     247140   248130
# Train_2 Light Travel Station1 Station1     247950   247950
# Train_1 Light Travel Station0 Station0     248130   248130
# Train_1   Train Trip Station0 Station1     248790   249750
# Train_2   Train Trip Station1 Station0     248940   249930
# Train_1 Light Travel Station1 Station1     249750   249750
# Train_2 Light Travel Station0 Station0     249930   249930
# Train_2   Train Trip Station0 Station1     250590   251550
# Train_1   Train Trip Station1 Station0     250740   251730
# Train_2 Light Travel Station1 Station1     251550   251550
# Train_1 Light Travel Station0 Station0     251730   251730
# Train_1   Train Trip Station0 Station1     252390   253350
# Train_2   Train Trip Station1 Station0     252540   253530
# Train_1 Light Travel Station1 Station1     253350   253350
# Train_2 Light Travel Station0 Station0     253530   253530
# Train_2   Train Trip Station0 Station1     254190   255150
# Train_1   Train Trip Station1 Station0     254340   255330
# Train_2 Light Travel Station1 Station1     255150   255150
# Train_1 Light Travel Station0 Station0     255330   255330
# Train_1   Train Trip Station0 Station1     255990   256950
# Train_2   Train Trip Station1 Station0     256140   257130
# Train_1 Light Travel Station1 Station1     256950   256950
# Train_2 Light Travel Station0 Station0     257130   257130
# Train_1   Train Trip Station1 Station0     257940   258930
# Train_1 Light Travel Station0 Station0     258930   258930
# Train_2   Train Trip Station0 Station1     279390   280350
# Train_2 Light Travel Station1 Station1     280350   280350
# Train_1   Train Trip Station0 Station1     281190   282150
# Train_2   Train Trip Station1 Station0     281340   282330
# Train_1 Light Travel Station1 Station1     282150   282150
# Train_2 Light Travel Station0 Station0     282330   282330
# Train_2   Train Trip Station0 Station1     282990   283950
# Train_1   Train Trip Station1 Station0     283140   284130
# Train_2 Light Travel Station1 Station1     283950   283950
# Train_1 Light Travel Station0 Station0     284130   284130
# Train_1   Train Trip Station0 Station1     284790   285750
# Train_2   Train Trip Station1 Station0     284940   285930
# Train_1 Light Travel Station1 Station1     285750   285750
# Train_2 Light Travel Station0 Station0     285930   285930
# Train_2   Train Trip Station0 Station1     286590   287550
# Train_1   Train Trip Station1 Station0     286740   287730
# Train_2 Light Travel Station1 Station1     287550   287550
# Train_1 Light Travel Station0 Station0     287730   287730
# Train_1   Train Trip Station0 Station1     288390   289350
# Train_2   Train Trip Station1 Station0     288540   289530
# Train_1 Light Travel Station1 Station1     289350   289350
# Train_2 Light Travel Station0 Station0     289530   289530
# Train_2   Train Trip Station0 Station1     290190   291150
# Train_1   Train Trip Station1 Station0     290340   291330
# Train_2 Light Travel Station1 Station1     291150   291150
# Train_1 Light Travel Station0 Station0     291330   291330
# Train_1   Train Trip Station0 Station1     291990   292950
# Train_2   Train Trip Station1 Station0     292140   293130
# Train_1 Light Travel Station1 Station1     292950   292950
# Train_2 Light Travel Station0 Station0     293130   293130
# Train_2   Train Trip Station0 Station1     293790   294750
# Train_1   Train Trip Station1 Station0     293940   294930
# Train_2 Light Travel Station1 Station1     294750   294750
# Train_1 Light Travel Station0 Station0     294930   294930
# Train_1   Train Trip Station0 Station1     295590   296550
# Train_2   Train Trip Station1 Station0     295740   296730
# Train_1 Light Travel Station1 Station1     296550   296550
# Train_2 Light Travel Station0 Station0     296730   296730
# Train_2   Train Trip Station0 Station1     297390   298350
# Train_1   Train Trip Station1 Station0     297540   298530
# Train_2 Light Travel Station1 Station1     298350   298350
# Train_1 Light Travel Station0 Station0     298530   298530
# Train_1   Train Trip Station0 Station1     299190   300150
# Train_2   Train Trip Station1 Station0     299340   300330
# Train_1 Light Travel Station1 Station1     300150   300150
# Train_2 Light Travel Station0 Station0     300330   300330
# Train_2   Train Trip Station0 Station1     300990   301950
# Train_1   Train Trip Station1 Station0     301140   302130
# Train_2 Light Travel Station1 Station1     301950   301950
# Train_1 Light Travel Station0 Station0     302130   302130
# Train_1   Train Trip Station0 Station1     302790   303750
# Train_2   Train Trip Station1 Station0     302940   303930
# Train_1 Light Travel Station1 Station1     303750   303750
# Train_2 Light Travel Station0 Station0     303930   303930
# Train_2   Train Trip Station0 Station1     304590   305550
# Train_1   Train Trip Station1 Station0     304740   305730
# Train_2 Light Travel Station1 Station1     305550   305550
# Train_1 Light Travel Station0 Station0     305730   305730
# Train_1   Train Trip Station0 Station1     306390   307350
# Train_2   Train Trip Station1 Station0     306540   307530
# Train_1 Light Travel Station1 Station1     307350   307350
# Train_2 Light Travel Station0 Station0     307530   307530
# Train_2   Train Trip Station0 Station1     308190   309150
# Train_1   Train Trip Station1 Station0     308340   309330
# Train_2 Light Travel Station1 Station1     309150   309150
# Train_1 Light Travel Station0 Station0     309330   309330
# Train_1   Train Trip Station0 Station1     309990   310950
# Train_2   Train Trip Station1 Station0     310140   311130
# Train_1 Light Travel Station1 Station1     310950   310950
# Train_2 Light Travel Station0 Station0     311130   311130
# Train_2   Train Trip Station0 Station1     311790   312750
# Train_1   Train Trip Station1 Station0     311940   312930
# Train_2 Light Travel Station1 Station1     312750   312750
# Train_1 Light Travel Station0 Station0     312930   312930
# Train_1   Train Trip Station0 Station1     313590   314550
# Train_2   Train Trip Station1 Station0     313740   314730
# Train_1 Light Travel Station1 Station1     314550   314550
# Train_2 Light Travel Station0 Station0     314730   314730
# Train_2   Train Trip Station0 Station1     315390   316350
# Train_1   Train Trip Station1 Station0     315540   316530
# Train_2 Light Travel Station1 Station1     316350   316350
# Train_1 Light Travel Station0 Station0     316530   316530
# Train_1   Train Trip Station0 Station1     317190   318150
# Train_2   Train Trip Station1 Station0     317340   318330
# Train_1 Light Travel Station1 Station1     318150   318150
# Train_2 Light Travel Station0 Station0     318330   318330
# Train_2   Train Trip Station0 Station1     318990   319950
# Train_1   Train Trip Station1 Station0     319140   320130
# Train_2 Light Travel Station1 Station1     319950   319950
# Train_1 Light Travel Station0 Station0     320130   320130
# Train_1   Train Trip Station0 Station1     320790   321750
# Train_2   Train Trip Station1 Station0     320940   321930
# Train_1 Light Travel Station1 Station1     321750   321750
# Train_2 Light Travel Station0 Station0     321930   321930
# Train_2   Train Trip Station0 Station1     322590   323550
# Train_1   Train Trip Station1 Station0     322740   323730
# Train_2 Light Travel Station1 Station1     323550   323550
# Train_1 Light Travel Station0 Station0     323730   323730
# Train_1   Train Trip Station0 Station1     324390   325350
# Train_2   Train Trip Station1 Station0     324540   325530
# Train_1 Light Travel Station1 Station1     325350   325350
# Train_2 Light Travel Station0 Station0     325530   325530
# Train_2   Train Trip Station0 Station1     326190   327150
# Train_1   Train Trip Station1 Station0     326340   327330
# Train_2 Light Travel Station1 Station1     327150   327150
# Train_1 Light Travel Station0 Station0     327330   327330
# Train_1   Train Trip Station0 Station1     327990   328950
# Train_2   Train Trip Station1 Station0     328140   329130
# Train_1 Light Travel Station1 Station1     328950   328950
# Train_2 Light Travel Station0 Station0     329130   329130
# Train_2   Train Trip Station0 Station1     329790   330750
# Train_1   Train Trip Station1 Station0     329940   330930
# Train_2 Light Travel Station1 Station1     330750   330750
# Train_1 Light Travel Station0 Station0     330930   330930
# Train_1   Train Trip Station0 Station1     331590   332550
# Train_2   Train Trip Station1 Station0     331740   332730
# Train_1 Light Travel Station1 Station1     332550   332550
# Train_2 Light Travel Station0 Station0     332730   332730
# Train_2   Train Trip Station0 Station1     333390   334350
# Train_1   Train Trip Station1 Station0     333540   334530
# Train_2 Light Travel Station1 Station1     334350   334350
# Train_1 Light Travel Station0 Station0     334530   334530
# Train_1   Train Trip Station0 Station1     335190   336150
# Train_2   Train Trip Station1 Station0     335340   336330
# Train_1 Light Travel Station1 Station1     336150   336150
# Train_2 Light Travel Station0 Station0     336330   336330
# Train_2   Train Trip Station0 Station1     336990   337950
# Train_1   Train Trip Station1 Station0     337140   338130
# Train_2 Light Travel Station1 Station1     337950   337950
# Train_1 Light Travel Station0 Station0     338130   338130
# Train_1   Train Trip Station0 Station1     338790   339750
# Train_2   Train Trip Station1 Station0     338940   339930
# Train_1 Light Travel Station1 Station1     339750   339750
# Train_2 Light Travel Station0 Station0     339930   339930
# Train_2   Train Trip Station0 Station1     340590   341550
# Train_1   Train Trip Station1 Station0     340740   341730
# Train_2 Light Travel Station1 Station1     341550   341550
# Train_1 Light Travel Station0 Station0     341730   341730
# Train_1   Train Trip Station0 Station1     342390   343350
# Train_2   Train Trip Station1 Station0     342540   343530
# Train_1 Light Travel Station1 Station1     343350   343350
# Train_2 Light Travel Station0 Station0     343530   343530
# Train_1   Train Trip Station1 Station0     344340   345330
# Train_1 Light Travel Station0 Station0     345330   345330
# Train_1   Train Trip Station0 Station1     365790   366750
# Train_1 Light Travel Station1 Station1     366750   366750
# Train_2   Train Trip Station0 Station1     367590   368550
# Train_1   Train Trip Station1 Station0     367740   368730
# Train_2 Light Travel Station1 Station1     368550   368550
# Train_1 Light Travel Station0 Station0     368730   368730
# Train_1   Train Trip Station0 Station1     369390   370350
# Train_2   Train Trip Station1 Station0     369540   370530
# Train_1 Light Travel Station1 Station1     370350   370350
# Train_2 Light Travel Station0 Station0     370530   370530
# Train_2   Train Trip Station0 Station1     371190   372150
# Train_1   Train Trip Station1 Station0     371340   372330
# Train_2 Light Travel Station1 Station1     372150   372150
# Train_1 Light Travel Station0 Station0     372330   372330
# Train_1   Train Trip Station0 Station1     372990   373950
# Train_2   Train Trip Station1 Station0     373140   374130
# Train_1 Light Travel Station1 Station1     373950   373950
# Train_2 Light Travel Station0 Station0     374130   374130
# Train_2   Train Trip Station0 Station1     374790   375750
# Train_1   Train Trip Station1 Station0     374940   375930
# Train_2 Light Travel Station1 Station1     375750   375750
# Train_1 Light Travel Station0 Station0     375930   375930
# Train_1   Train Trip Station0 Station1     376590   377550
# Train_2   Train Trip Station1 Station0     376740   377730
# Train_1 Light Travel Station1 Station1     377550   377550
# Train_2 Light Travel Station0 Station0     377730   377730
# Train_2   Train Trip Station0 Station1     378390   379350
# Train_1   Train Trip Station1 Station0     378540   379530
# Train_2 Light Travel Station1 Station1     379350   379350
# Train_1 Light Travel Station0 Station0     379530   379530
# Train_1   Train Trip Station0 Station1     380190   381150
# Train_2   Train Trip Station1 Station0     380340   381330
# Train_1 Light Travel Station1 Station1     381150   381150
# Train_2 Light Travel Station0 Station0     381330   381330
# Train_2   Train Trip Station0 Station1     381990   382950
# Train_1   Train Trip Station1 Station0     382140   383130
# Train_2 Light Travel Station1 Station1     382950   382950
# Train_1 Light Travel Station0 Station0     383130   383130
# Train_1   Train Trip Station0 Station1     383790   384750
# Train_2   Train Trip Station1 Station0     383940   384930
# Train_1 Light Travel Station1 Station1     384750   384750
# Train_2 Light Travel Station0 Station0     384930   384930
# Train_2   Train Trip Station0 Station1     385590   386550
# Train_1   Train Trip Station1 Station0     385740   386730
# Train_2 Light Travel Station1 Station1     386550   386550
# Train_1 Light Travel Station0 Station0     386730   386730
# Train_1   Train Trip Station0 Station1     387390   388350
# Train_2   Train Trip Station1 Station0     387540   388530
# Train_1 Light Travel Station1 Station1     388350   388350
# Train_2 Light Travel Station0 Station0     388530   388530
# Train_2   Train Trip Station0 Station1     389190   390150
# Train_1   Train Trip Station1 Station0     389340   390330
# Train_2 Light Travel Station1 Station1     390150   390150
# Train_1 Light Travel Station0 Station0     390330   390330
# Train_1   Train Trip Station0 Station1     390990   391950
# Train_2   Train Trip Station1 Station0     391140   392130
# Train_1 Light Travel Station1 Station1     391950   391950
# Train_2 Light Travel Station0 Station0     392130   392130
# Train_2   Train Trip Station0 Station1     392790   393750
# Train_1   Train Trip Station1 Station0     392940   393930
# Train_2 Light Travel Station1 Station1     393750   393750
# Train_1 Light Travel Station0 Station0     393930   393930
# Train_1   Train Trip Station0 Station1     394590   395550
# Train_2   Train Trip Station1 Station0     394740   395730
# Train_1 Light Travel Station1 Station1     395550   395550
# Train_2 Light Travel Station0 Station0     395730   395730
# Train_2   Train Trip Station0 Station1     396390   397350
# Train_1   Train Trip Station1 Station0     396540   397530
# Train_2 Light Travel Station1 Station1     397350   397350
# Train_1 Light Travel Station0 Station0     397530   397530
# Train_1   Train Trip Station0 Station1     398190   399150
# Train_2   Train Trip Station1 Station0     398340   399330
# Train_1 Light Travel Station1 Station1     399150   399150
# Train_2 Light Travel Station0 Station0     399330   399330
# Train_2   Train Trip Station0 Station1     399990   400950
# Train_1   Train Trip Station1 Station0     400140   401130
# Train_2 Light Travel Station1 Station1     400950   400950
# Train_1 Light Travel Station0 Station0     401130   401130
# Train_1   Train Trip Station0 Station1     401790   402750
# Train_2   Train Trip Station1 Station0     401940   402930
# Train_1 Light Travel Station1 Station1     402750   402750
# Train_2 Light Travel Station0 Station0     402930   402930
# Train_2   Train Trip Station0 Station1     403590   404550
# Train_1   Train Trip Station1 Station0     403740   404730
# Train_2 Light Travel Station1 Station1     404550   404550
# Train_1 Light Travel Station0 Station0     404730   404730
# Train_1   Train Trip Station0 Station1     405390   406350
# Train_2   Train Trip Station1 Station0     405540   406530
# Train_1 Light Travel Station1 Station1     406350   406350
# Train_2 Light Travel Station0 Station0     406530   406530
# Train_2   Train Trip Station0 Station1     407190   408150
# Train_1   Train Trip Station1 Station0     407340   408330
# Train_2 Light Travel Station1 Station1     408150   408150
# Train_1 Light Travel Station0 Station0     408330   408330
# Train_1   Train Trip Station0 Station1     408990   409950
# Train_2   Train Trip Station1 Station0     409140   410130
# Train_1 Light Travel Station1 Station1     409950   409950
# Train_2 Light Travel Station0 Station0     410130   410130
# Train_2   Train Trip Station0 Station1     410790   411750
# Train_1   Train Trip Station1 Station0     410940   411930
# Train_2 Light Travel Station1 Station1     411750   411750
# Train_1 Light Travel Station0 Station0     411930   411930
# Train_1   Train Trip Station0 Station1     412590   413550
# Train_2   Train Trip Station1 Station0     412740   413730
# Train_1 Light Travel Station1 Station1     413550   413550
# Train_2 Light Travel Station0 Station0     413730   413730
# Train_2   Train Trip Station0 Station1     414390   415350
# Train_1   Train Trip Station1 Station0     414540   415530
# Train_2 Light Travel Station1 Station1     415350   415350
# Train_1 Light Travel Station0 Station0     415530   415530
# Train_1   Train Trip Station0 Station1     416190   417150
# Train_2   Train Trip Station1 Station0     416340   417330
# Train_1 Light Travel Station1 Station1     417150   417150
# Train_2 Light Travel Station0 Station0     417330   417330
# Train_2   Train Trip Station0 Station1     417990   418950
# Train_1   Train Trip Station1 Station0     418140   419130
# Train_2 Light Travel Station1 Station1     418950   418950
# Train_1 Light Travel Station0 Station0     419130   419130
# Train_1   Train Trip Station0 Station1     419790   420750
# Train_2   Train Trip Station1 Station0     419940   420930
# Train_1 Light Travel Station1 Station1     420750   420750
# Train_2 Light Travel Station0 Station0     420930   420930
# Train_2   Train Trip Station0 Station1     421590   422550
# Train_1   Train Trip Station1 Station0     421740   422730
# Train_2 Light Travel Station1 Station1     422550   422550
# Train_1 Light Travel Station0 Station0     422730   422730
# Train_1   Train Trip Station0 Station1     423390   424350
# Train_2   Train Trip Station1 Station0     423540   424530
# Train_1 Light Travel Station1 Station1     424350   424350
# Train_2 Light Travel Station0 Station0     424530   424530
# Train_2   Train Trip Station0 Station1     425190   426150
# Train_1   Train Trip Station1 Station0     425340   426330
# Train_2 Light Travel Station1 Station1     426150   426150
# Train_1 Light Travel Station0 Station0     426330   426330
# Train_1   Train Trip Station0 Station1     426990   427950
# Train_2   Train Trip Station1 Station0     427140   428130
# Train_1 Light Travel Station1 Station1     427950   427950
# Train_2 Light Travel Station0 Station0     428130   428130
# Train_2   Train Trip Station0 Station1     428790   429750
# Train_1   Train Trip Station1 Station0     428940   429930
# Train_2 Light Travel Station1 Station1     429750   429750
# Train_1 Light Travel Station0 Station0     429930   429930
# Train_2   Train Trip Station1 Station0     430740   431730
# Train_2 Light Travel Station0 Station0     431730   431730
# Train_2   Train Trip Station0 Station1     452190   453150
# Train_2 Light Travel Station1 Station1     453150   453150
# Train_1   Train Trip Station0 Station1     453990   454950
# Train_2   Train Trip Station1 Station0     454140   455130
# Train_1 Light Travel Station1 Station1     454950   454950
# Train_2 Light Travel Station0 Station0     455130   455130
# Train_2   Train Trip Station0 Station1     455790   456750
# Train_1   Train Trip Station1 Station0     455940   456930
# Train_2 Light Travel Station1 Station1     456750   456750
# Train_1 Light Travel Station0 Station0     456930   456930
# Train_1   Train Trip Station0 Station1     457590   458550
# Train_2   Train Trip Station1 Station0     457740   458730
# Train_1 Light Travel Station1 Station1     458550   458550
# Train_2 Light Travel Station0 Station0     458730   458730
# Train_2   Train Trip Station0 Station1     459390   460350
# Train_1   Train Trip Station1 Station0     459540   460530
# Train_2 Light Travel Station1 Station1     460350   460350
# Train_1 Light Travel Station0 Station0     460530   460530
# Train_1   Train Trip Station0 Station1     461190   462150
# Train_2   Train Trip Station1 Station0     461340   462330
# Train_1 Light Travel Station1 Station1     462150   462150
# Train_2 Light Travel Station0 Station0     462330   462330
# Train_2   Train Trip Station0 Station1     462990   463950
# Train_1   Train Trip Station1 Station0     463140   464130
# Train_2 Light Travel Station1 Station1     463950   463950
# Train_1 Light Travel Station0 Station0     464130   464130
# Train_1   Train Trip Station0 Station1     464790   465750
# Train_2   Train Trip Station1 Station0     464940   465930
# Train_1 Light Travel Station1 Station1     465750   465750
# Train_2 Light Travel Station0 Station0     465930   465930
# Train_2   Train Trip Station0 Station1     466590   467550
# Train_1   Train Trip Station1 Station0     466740   467730
# Train_2 Light Travel Station1 Station1     467550   467550
# Train_1 Light Travel Station0 Station0     467730   467730
# Train_1   Train Trip Station0 Station1     468390   469350
# Train_2   Train Trip Station1 Station0     468540   469530
# Train_1 Light Travel Station1 Station1     469350   469350
# Train_2 Light Travel Station0 Station0     469530   469530
# Train_2   Train Trip Station0 Station1     470190   471150
# Train_1   Train Trip Station1 Station0     470340   471330
# Train_2 Light Travel Station1 Station1     471150   471150
# Train_1 Light Travel Station0 Station0     471330   471330
# Train_1   Train Trip Station0 Station1     471990   472950
# Train_2   Train Trip Station1 Station0     472140   473130
# Train_1 Light Travel Station1 Station1     472950   472950
# Train_2 Light Travel Station0 Station0     473130   473130
# Train_2   Train Trip Station0 Station1     473790   474750
# Train_1   Train Trip Station1 Station0     473940   474930
# Train_2 Light Travel Station1 Station1     474750   474750
# Train_1 Light Travel Station0 Station0     474930   474930
# Train_1   Train Trip Station0 Station1     475590   476550
# Train_2   Train Trip Station1 Station0     475740   476730
# Train_1 Light Travel Station1 Station1     476550   476550
# Train_2 Light Travel Station0 Station0     476730   476730
# Train_2   Train Trip Station0 Station1     477390   478350
# Train_1   Train Trip Station1 Station0     477540   478530
# Train_2 Light Travel Station1 Station1     478350   478350
# Train_1 Light Travel Station0 Station0     478530   478530
# Train_1   Train Trip Station0 Station1     479190   480150
# Train_2   Train Trip Station1 Station0     479340   480330
# Train_1 Light Travel Station1 Station1     480150   480150
# Train_2 Light Travel Station0 Station0     480330   480330
# Train_2   Train Trip Station0 Station1     480990   481950
# Train_1   Train Trip Station1 Station0     481140   482130
# Train_2 Light Travel Station1 Station1     481950   481950
# Train_1 Light Travel Station0 Station0     482130   482130
# Train_1   Train Trip Station0 Station1     482790   483750
# Train_2   Train Trip Station1 Station0     482940   483930
# Train_1 Light Travel Station1 Station1     483750   483750
# Train_2 Light Travel Station0 Station0     483930   483930
# Train_2   Train Trip Station0 Station1     484590   485550
# Train_1   Train Trip Station1 Station0     484740   485730
# Train_2 Light Travel Station1 Station1     485550   485550
# Train_1 Light Travel Station0 Station0     485730   485730
# Train_1   Train Trip Station0 Station1     486390   487350
# Train_2   Train Trip Station1 Station0     486540   487530
# Train_1 Light Travel Station1 Station1     487350   487350
# Train_2 Light Travel Station0 Station0     487530   487530
# Train_2   Train Trip Station0 Station1     488190   489150
# Train_1   Train Trip Station1 Station0     488340   489330
# Train_2 Light Travel Station1 Station1     489150   489150
# Train_1 Light Travel Station0 Station0     489330   489330
# Train_1   Train Trip Station0 Station1     489990   490950
# Train_2   Train Trip Station1 Station0     490140   491130
# Train_1 Light Travel Station1 Station1     490950   490950
# Train_2 Light Travel Station0 Station0     491130   491130
# Train_2   Train Trip Station0 Station1     491790   492750
# Train_1   Train Trip Station1 Station0     491940   492930
# Train_2 Light Travel Station1 Station1     492750   492750
# Train_1 Light Travel Station0 Station0     492930   492930
# Train_1   Train Trip Station0 Station1     493590   494550
# Train_2   Train Trip Station1 Station0     493740   494730
# Train_1 Light Travel Station1 Station1     494550   494550
# Train_2 Light Travel Station0 Station0     494730   494730
# Train_2   Train Trip Station0 Station1     495390   496350
# Train_1   Train Trip Station1 Station0     495540   496530
# Train_2 Light Travel Station1 Station1     496350   496350
# Train_1 Light Travel Station0 Station0     496530   496530
# Train_1   Train Trip Station0 Station1     497190   498150
# Train_2   Train Trip Station1 Station0     497340   498330
# Train_1 Light Travel Station1 Station1     498150   498150
# Train_2 Light Travel Station0 Station0     498330   498330
# Train_2   Train Trip Station0 Station1     498990   499950
# Train_1   Train Trip Station1 Station0     499140   500130
# Train_2 Light Travel Station1 Station1     499950   499950
# Train_1 Light Travel Station0 Station0     500130   500130
# Train_1   Train Trip Station0 Station1     500790   501750
# Train_2   Train Trip Station1 Station0     500940   501930
# Train_1 Light Travel Station1 Station1     501750   501750
# Train_2 Light Travel Station0 Station0     501930   501930
# Train_2   Train Trip Station0 Station1     502590   503550
# Train_1   Train Trip Station1 Station0     502740   503730
# Train_2 Light Travel Station1 Station1     503550   503550
# Train_1 Light Travel Station0 Station0     503730   503730
# Train_1   Train Trip Station0 Station1     504390   505350
# Train_2   Train Trip Station1 Station0     504540   505530
# Train_1 Light Travel Station1 Station1     505350   505350
# Train_2 Light Travel Station0 Station0     505530   505530
# Train_2   Train Trip Station0 Station1     506190   507150
# Train_1   Train Trip Station1 Station0     506340   507330
# Train_2 Light Travel Station1 Station1     507150   507150
# Train_1 Light Travel Station0 Station0     507330   507330
# Train_1   Train Trip Station0 Station1     507990   508950
# Train_2   Train Trip Station1 Station0     508140   509130
# Train_1 Light Travel Station1 Station1     508950   508950
# Train_2 Light Travel Station0 Station0     509130   509130
# Train_2   Train Trip Station0 Station1     509790   510750
# Train_1   Train Trip Station1 Station0     509940   510930
# Train_2 Light Travel Station1 Station1     510750   510750
# Train_1 Light Travel Station0 Station0     510930   510930
# Train_1   Train Trip Station0 Station1     511590   512550
# Train_2   Train Trip Station1 Station0     511740   512730
# Train_1 Light Travel Station1 Station1     512550   512550
# Train_2 Light Travel Station0 Station0     512730   512730
# Train_2   Train Trip Station0 Station1     513390   514350
# Train_1   Train Trip Station1 Station0     513540   514530
# Train_2 Light Travel Station1 Station1     514350   514350
# Train_1 Light Travel Station0 Station0     514530   514530
# Train_1   Train Trip Station0 Station1     515190   516150
# Train_2   Train Trip Station1 Station0     515340   516330
# Train_1 Light Travel Station1 Station1     516150   516150
# Train_2 Light Travel Station0 Station0     516330   516330
# Train_1   Train Trip Station1 Station0     517140   518130
# Train_1 Light Travel Station0 Station0     518130   518130
# Train_1   Train Trip Station0 Station1     538590   539550
# Train_1 Light Travel Station1 Station1     539550   539550
# Train_2   Train Trip Station0 Station1     540390   541350
# Train_1   Train Trip Station1 Station0     540540   541530
# Train_2 Light Travel Station1 Station1     541350   541350
# Train_1 Light Travel Station0 Station0     541530   541530
# Train_1   Train Trip Station0 Station1     542190   543150
# Train_2   Train Trip Station1 Station0     542340   543330
# Train_1 Light Travel Station1 Station1     543150   543150
# Train_2 Light Travel Station0 Station0     543330   543330
# Train_2   Train Trip Station0 Station1     543990   544950
# Train_1   Train Trip Station1 Station0     544140   545130
# Train_2 Light Travel Station1 Station1     544950   544950
# Train_1 Light Travel Station0 Station0     545130   545130
# Train_1   Train Trip Station0 Station1     545790   546750
# Train_2   Train Trip Station1 Station0     545940   546930
# Train_1 Light Travel Station1 Station1     546750   546750
# Train_2 Light Travel Station0 Station0     546930   546930
# Train_2   Train Trip Station0 Station1     547590   548550
# Train_1   Train Trip Station1 Station0     547740   548730
# Train_2 Light Travel Station1 Station1     548550   548550
# Train_1 Light Travel Station0 Station0     548730   548730
# Train_1   Train Trip Station0 Station1     549390   550350
# Train_2   Train Trip Station1 Station0     549540   550530
# Train_1 Light Travel Station1 Station1     550350   550350
# Train_2 Light Travel Station0 Station0     550530   550530
# Train_2   Train Trip Station0 Station1     551190   552150
# Train_1   Train Trip Station1 Station0     551340   552330
# Train_2 Light Travel Station1 Station1     552150   552150
# Train_1 Light Travel Station0 Station0     552330   552330
# Train_1   Train Trip Station0 Station1     552990   553950
# Train_2   Train Trip Station1 Station0     553140   554130
# Train_1 Light Travel Station1 Station1     553950   553950
# Train_2 Light Travel Station0 Station0     554130   554130
# Train_2   Train Trip Station0 Station1     554790   555750
# Train_1   Train Trip Station1 Station0     554940   555930
# Train_2 Light Travel Station1 Station1     555750   555750
# Train_1 Light Travel Station0 Station0     555930   555930
# Train_1   Train Trip Station0 Station1     556590   557550
# Train_2   Train Trip Station1 Station0     556740   557730
# Train_1 Light Travel Station1 Station1     557550   557550
# Train_2 Light Travel Station0 Station0     557730   557730
# Train_2   Train Trip Station0 Station1     558390   559350
# Train_1   Train Trip Station1 Station0     558540   559530
# Train_2 Light Travel Station1 Station1     559350   559350
# Train_1 Light Travel Station0 Station0     559530   559530
# Train_1   Train Trip Station0 Station1     560190   561150
# Train_2   Train Trip Station1 Station0     560340   561330
# Train_1 Light Travel Station1 Station1     561150   561150
# Train_2 Light Travel Station0 Station0     561330   561330
# Train_2   Train Trip Station0 Station1     561990   562950
# Train_1   Train Trip Station1 Station0     562140   563130
# Train_2 Light Travel Station1 Station1     562950   562950
# Train_1 Light Travel Station0 Station0     563130   563130
# Train_1   Train Trip Station0 Station1     563790   564750
# Train_2   Train Trip Station1 Station0     563940   564930
# Train_1 Light Travel Station1 Station1     564750   564750
# Train_2 Light Travel Station0 Station0     564930   564930
# Train_2   Train Trip Station0 Station1     565590   566550
# Train_1   Train Trip Station1 Station0     565740   566730
# Train_2 Light Travel Station1 Station1     566550   566550
# Train_1 Light Travel Station0 Station0     566730   566730
# Train_1   Train Trip Station0 Station1     567390   568350
# Train_2   Train Trip Station1 Station0     567540   568530
# Train_1 Light Travel Station1 Station1     568350   568350
# Train_2 Light Travel Station0 Station0     568530   568530
# Train_2   Train Trip Station0 Station1     569190   570150
# Train_1   Train Trip Station1 Station0     569340   570330
# Train_2 Light Travel Station1 Station1     570150   570150
# Train_1 Light Travel Station0 Station0     570330   570330
# Train_1   Train Trip Station0 Station1     570990   571950
# Train_2   Train Trip Station1 Station0     571140   572130
# Train_1 Light Travel Station1 Station1     571950   571950
# Train_2 Light Travel Station0 Station0     572130   572130
# Train_2   Train Trip Station0 Station1     572790   573750
# Train_1   Train Trip Station1 Station0     572940   573930
# Train_2 Light Travel Station1 Station1     573750   573750
# Train_1 Light Travel Station0 Station0     573930   573930
# Train_1   Train Trip Station0 Station1     574590   575550
# Train_2   Train Trip Station1 Station0     574740   575730
# Train_1 Light Travel Station1 Station1     575550   575550
# Train_2 Light Travel Station0 Station0     575730   575730
# Train_2   Train Trip Station0 Station1     576390   577350
# Train_1   Train Trip Station1 Station0     576540   577530
# Train_2 Light Travel Station1 Station1     577350   577350
# Train_1 Light Travel Station0 Station0     577530   577530
# Train_1   Train Trip Station0 Station1     578190   579150
# Train_2   Train Trip Station1 Station0     578340   579330
# Train_1 Light Travel Station1 Station1     579150   579150
# Train_2 Light Travel Station0 Station0     579330   579330
# Train_2   Train Trip Station0 Station1     579990   580950
# Train_1   Train Trip Station1 Station0     580140   581130
# Train_2 Light Travel Station1 Station1     580950   580950
# Train_1 Light Travel Station0 Station0     581130   581130
# Train_1   Train Trip Station0 Station1     581790   582750
# Train_2   Train Trip Station1 Station0     581940   582930
# Train_1 Light Travel Station1 Station1     582750   582750
# Train_2 Light Travel Station0 Station0     582930   582930
# Train_2   Train Trip Station0 Station1     583590   584550
# Train_1   Train Trip Station1 Station0     583740   584730
# Train_2 Light Travel Station1 Station1     584550   584550
# Train_1 Light Travel Station0 Station0     584730   584730
# Train_1   Train Trip Station0 Station1     585390   586350
# Train_2   Train Trip Station1 Station0     585540   586530
# Train_1 Light Travel Station1 Station1     586350   586350
# Train_2 Light Travel Station0 Station0     586530   586530
# Train_2   Train Trip Station0 Station1     587190   588150
# Train_1   Train Trip Station1 Station0     587340   588330
# Train_2 Light Travel Station1 Station1     588150   588150
# Train_1 Light Travel Station0 Station0     588330   588330
# Train_1   Train Trip Station0 Station1     588990   589950
# Train_2   Train Trip Station1 Station0     589140   590130
# Train_1 Light Travel Station1 Station1     589950   589950
# Train_2 Light Travel Station0 Station0     590130   590130
# Train_2   Train Trip Station0 Station1     590790   591750
# Train_1   Train Trip Station1 Station0     590940   591930
# Train_2 Light Travel Station1 Station1     591750   591750
# Train_1 Light Travel Station0 Station0     591930   591930
# Train_1   Train Trip Station0 Station1     592590   593550
# Train_2   Train Trip Station1 Station0     592740   593730
# Train_1 Light Travel Station1 Station1     593550   593550
# Train_2 Light Travel Station0 Station0     593730   593730
# Train_2   Train Trip Station0 Station1     594390   595350
# Train_1   Train Trip Station1 Station0     594540   595530
# Train_2 Light Travel Station1 Station1     595350   595350
# Train_1 Light Travel Station0 Station0     595530   595530
# Train_1   Train Trip Station0 Station1     596190   597150
# Train_2   Train Trip Station1 Station0     596340   597330
# Train_1 Light Travel Station1 Station1     597150   597150
# Train_2 Light Travel Station0 Station0     597330   597330
# Train_2   Train Trip Station0 Station1     597990   598950
# Train_1   Train Trip Station1 Station0     598140   599130
# Train_2 Light Travel Station1 Station1     598950   598950
# Train_1 Light Travel Station0 Station0     599130   599130
# Train_1   Train Trip Station0 Station1     599790   600750
# Train_2   Train Trip Station1 Station0     599940   600930
# Train_1 Light Travel Station1 Station1     600750   600750
# Train_2 Light Travel Station0 Station0     600930   600930
# Train_2   Train Trip Station0 Station1     601590   602550
# Train_1   Train Trip Station1 Station0     601740   602730
# Train_2 Light Travel Station1 Station1     602550   602550
# Train_2   Train Trip Station1 Station0     603540   604530
#
#  Cost Breakdown:
# Total Cost           : 2000.00
# Traction Unit Cost   : 2000.00
# Light Travel Cost    : 0.00
# Number of Vehicles   : 2

# %% [markdown]
# **Convert List_A to a CSV File**

# %%
import pandas as pd

# Convert full_schedule (a list of dicts) into a DataFrame
df_schedule = pd.DataFrame(full_schedule)

# Save to CSV
df_schedule.to_csv("full_schedule_Instance_C.csv", index=False)

# For Google Colab: provide download link
from google.colab import files
files.download("full_schedule_Instance_C.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.lines as mlines
import time

# Start timer
start_time = time.time()

# Load schedule
df_schedule = pd.read_csv("full_schedule_Instance_C.csv")

# Step 1: Map stations to Y-axis positions
stations = sorted(set(df_schedule["From"]).union(set(df_schedule["To"])))
station_to_y = {station: i for i, station in enumerate(stations)}

# Step 2: Predefine 3 train IDs
train_ids = [f"Train_{i}" for i in range(1, 3)]

# Step 3: Assign each train a unique color
cmap = cm.get_cmap('tab20', len(train_ids))
train_to_color = {train: cmap(i) for i, train in enumerate(train_ids)}

# Step 4: Initialize plot and track nodes/edges
plt.figure(figsize=(20, 12))
nodes = set()
edges = []

# Step 5: Plot edges and store nodes/edges
for _, row in df_schedule.iterrows():
    from_station = row["From"]
    to_station = row["To"]
    start_time_trip = row["StartTime"]
    end_time_trip = row["EndTime"]
    train = row["Train"]
    edge_type = row["Type"]

    u = (start_time_trip, station_to_y[from_station])
    v = (end_time_trip, station_to_y[to_station])

    nodes.update([u, v])
    edges.append((u, v))

    color = train_to_color.get(train, 'black')
    linestyle = '-' if edge_type == "Train Trip" else '--'
    plt.plot([u[0], v[0]], [u[1], v[1]], color=color, linestyle=linestyle, linewidth=1)

# Step 6: Plot nodes
for t, y in nodes:
    plt.scatter(t, y, color='black', s=10)
    plt.text(t, y + 0.1, f'{t}', fontsize=5, ha='center', color='darkred')

# Step 7: Axis formatting
plt.yticks(list(station_to_y.values()), list(station_to_y.keys()))
plt.xlabel("Time (seconds)")
plt.ylabel("Stations")
plt.title("Space-Time Network_Instance_C")
plt.grid(True, linestyle='--', linewidth=0.5)

# Step 8: Legend
legend_lines = [
    mlines.Line2D([], [], color=train_to_color[train], linewidth=2, label=train)
    for train in train_ids
]
plt.legend(handles=legend_lines, title="Trains", loc='upper center', bbox_to_anchor=(0.5, -0.08),
           ncol=6, fontsize=8, title_fontsize=10, frameon=True)

plt.tight_layout()
plt.show()

# End timer
end_time = time.time()

# Step 9: Print summary
print("\n===== Network Summary =====")
print(f"Total Nodes      : {len(nodes)}")
print(f"Total Edges      : {len(edges)}")
print(f"Execution Time   : {round(end_time - start_time, 3)} seconds")
# Out:
# /tmp/ipython-input-11-2273373265.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(train_ids))
# ===== Network Summary =====
# Total Nodes      : 1008
# Total Edges      : 1006
# Execution Time   : 20.05 seconds

# %% [markdown]
# **Robustness Calculation**

# %%
# STEP 01: Identify tight connections
# Define threshold (e.g., 300 seconds = 5 minutes)
TIGHT_THRESHOLD = 300  # seconds

# Extract only productive train trips for each train
train_trips = df_schedule[df_schedule["Type"] == "Train Trip"].copy()
train_trips.sort_values(by=["Train", "StartTime"], inplace=True)

# Find consecutive trips by the same train
tight_connections = []
for train_id, group in train_trips.groupby("Train"):
    trips = group.sort_values("StartTime").reset_index(drop=True)
    for i in range(len(trips) - 1):
        current_end = trips.loc[i, "EndTime"]
        next_start = trips.loc[i + 1, "StartTime"]
        connection_time = next_start - current_end
        if connection_time <= TIGHT_THRESHOLD:
            tight_connections.append({
                "Train": train_id,
                "FromTripEnd": current_end,
                "ToTripStart": next_start,
                "ConnectionTime": connection_time,
                "FromStation": trips.loc[i, "To"],
                "ToStation": trips.loc[i + 1, "From"]
            })

# Display the tight connections
df_tight = pd.DataFrame(tight_connections)
print(f"\n Tight Connections (<= {TIGHT_THRESHOLD} seconds): {len(df_tight)} found")
if not df_tight.empty:
    print(df_tight.to_string(index=False))
else:
    print(" No tight connections found.")
# Out:
#  Tight Connections (<= 300 seconds): 0 found
#  No tight connections found.

# %%
import pandas as pd

# Step 2: Set threshold for tight connections
TIGHT_THRESHOLD = 300  # seconds
BUFFER_TIME = 600      # seconds

# Step 3: Detect tight connections
train_trips = df_schedule[df_schedule["Type"] == "Train Trip"].copy()
train_trips.sort_values(by=["Train", "StartTime"], inplace=True)

tight_connections = []
for train_id, group in train_trips.groupby("Train"):
    trips = group.sort_values("StartTime").reset_index(drop=True)
    for i in range(len(trips) - 1):
        current_end = trips.loc[i, "EndTime"]
        next_start = trips.loc[i + 1, "StartTime"]
        connection_time = next_start - current_end
        if connection_time <= TIGHT_THRESHOLD:
            tight_connections.append({
                "Train": train_id,
                "FromTripEnd": current_end,
                "ToTripStart": next_start,
                "ConnectionTime": connection_time,
                "FromStation": trips.loc[i, "To"],
                "ToStation": trips.loc[i + 1, "From"]
            })

df_tight = pd.DataFrame(tight_connections)

# Step 4: Apply buffer by shifting trips forward
df_buffered = df_schedule.copy()
df_buffered.sort_values(by=["Train", "StartTime"], inplace=True)

for _, row in df_tight.iterrows():
    train_id = row["Train"]
    to_start = row["ToTripStart"]
    affected = df_buffered[
        (df_buffered["Train"] == train_id) &
        (df_buffered["StartTime"] >= to_start)
    ].index
    df_buffered.loc[affected, "StartTime"] += BUFFER_TIME
    df_buffered.loc[affected, "EndTime"] += BUFFER_TIME

# Step 5: Recalculate cost
C_TU = 1000
C_Light = 0.10
traction_units = df_buffered["Train"].nunique()
traction_cost = traction_units * C_TU

light_travel_cost = 0
for _, row in df_buffered[df_buffered["Type"] == "Light Travel"].iterrows():
    key = f"{row['From']},{row['To']}"
    if key in empty_runs:
        dist = empty_runs[key]["Distance"]
        light_travel_cost += dist * C_Light

total_cost = traction_cost + light_travel_cost

# Step 6: Calculate nodes and edges
nodes = set()
edges = 0
for _, row in df_buffered.iterrows():
    u = (row["StartTime"], row["From"])
    v = (row["EndTime"], row["To"])
    nodes.update([u, v])
    edges += 1

# Step 7: Save result
buffered_schedule_path = "schedule_buffered_600s.csv"
df_buffered.to_csv(buffered_schedule_path, index=False)

# Step 8: Summary
print("\n===== ⏱️ Buffered Plan Summary (600s for tight links) =====")
print(f" Tight Connections Found   : {len(df_tight)}")
print(f" Buffer Applied per Link   : {BUFFER_TIME} seconds")
print(f" Trains (Vehicles) Used    : {traction_units}")
print(f" Light Travel Cost         : {round(light_travel_cost, 2)}")
print(f" Total Cost                : {round(total_cost, 2)}")
print(f" Total Edges               : {edges}")
print(f" Total Unique Nodes        : {len(nodes)}")
print(f" Saved to File             : {buffered_schedule_path}")
# Out:
# ===== ⏱️ Buffered Plan Summary (600s for tight links) =====
#  Tight Connections Found   : 0
#  Buffer Applied per Link   : 600 seconds
#  Trains (Vehicles) Used    : 2
#  Light Travel Cost         : 0.0
#  Total Cost                : 2000.0
#  Total Edges               : 1006
#  Total Unique Nodes        : 1008
#  Saved to File             : schedule_buffered_600s.csv

# %%
import pandas as pd

# Load the original schedule before buffering
df_schedule = pd.read_csv("full_schedule_Instance_C.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.lines as mlines
import json
import re

# Load JSON data
with open("Instance_C.json") as f:
    data = json.load(f)

# Extract empty runs
empty_runs = data["EmptyRunData"]

# === CONFIGURATION ===
TIGHT_THRESHOLD = 300  # seconds
BUFFER_TIME = 600      # buffer to add after tight connections
C_TU = 1000            # traction unit cost
C_Light = 0.10         # light travel cost per km

# === STEP 1: Detect Tight Connections ===
train_trips = df_schedule[df_schedule["Type"] == "Train Trip"].copy()
train_trips.sort_values(by=["Train", "StartTime"], inplace=True)

tight_connections = []
for train_id, group in train_trips.groupby("Train"):
    trips = group.sort_values("StartTime").reset_index(drop=True)
    for i in range(len(trips) - 1):
        current_end = trips.loc[i, "EndTime"]
        next_start = trips.loc[i + 1, "StartTime"]
        connection_time = next_start - current_end
        if connection_time <= TIGHT_THRESHOLD:
            tight_connections.append({
                "Train": train_id,
                "FromTripEnd": current_end,
                "ToTripStart": next_start,
                "ConnectionTime": connection_time,
                "FromStation": trips.loc[i, "To"],
                "ToStation": trips.loc[i + 1, "From"]
            })

df_tight = pd.DataFrame(tight_connections)

# === STEP 2: Apply Buffer ===
df_buffered = df_schedule.copy()
df_buffered.sort_values(by=["Train", "StartTime"], inplace=True)

for _, row in df_tight.iterrows():
    train_id = row["Train"]
    to_start = row["ToTripStart"]
    affected = df_buffered[
        (df_buffered["Train"] == train_id) &
        (df_buffered["StartTime"] >= to_start)
    ].index
    df_buffered.loc[affected, "StartTime"] += BUFFER_TIME
    df_buffered.loc[affected, "EndTime"] += BUFFER_TIME

# === STEP 3: Recalculate Cost ===
traction_units = df_buffered["Train"].nunique()
traction_cost = traction_units * C_TU

light_travel_cost = 0
for _, row in df_buffered[df_buffered["Type"] == "Light Travel"].iterrows():
    key = f"{row['From']},{row['To']}"
    if key in empty_runs:
        dist = empty_runs[key]["Distance"]
        light_travel_cost += dist * C_Light

total_cost = traction_cost + light_travel_cost

# === STEP 4: Plot with Buffer Annotations ===
stations = sorted(set(df_buffered["From"]).union(set(df_buffered["To"])))
station_to_y = {station: i for i, station in enumerate(stations)}

train_ids = sorted(df_buffered["Train"].unique())
cmap = cm.get_cmap('tab20', len(train_ids))
train_to_color = {train: cmap(i) for i, train in enumerate(train_ids)}

plt.figure(figsize=(20, 12))
nodes = set()

# Plot train arcs
for _, row in df_buffered.iterrows():
    from_station = row["From"]
    to_station = row["To"]
    start = row["StartTime"]
    end = row["EndTime"]
    train = row["Train"]
    typ = row["Type"]

    u = (start, station_to_y[from_station])
    v = (end, station_to_y[to_station])
    color = train_to_color[train]
    linestyle = '-' if typ == "Train Trip" else '--'

    plt.plot([u[0], v[0]], [u[1], v[1]], color=color, linestyle=linestyle, linewidth=1)
    nodes.update([u, v])

# Annotate buffer arcs in red
for _, row in df_tight.iterrows():
    train_id = row["Train"]
    station = row["ToStation"]
    y = station_to_y[station]
    from_time = row["ToTripStart"]
    to_time = from_time + BUFFER_TIME
    plt.plot([from_time, to_time], [y, y], color='red', linestyle=':', linewidth=1)
    plt.text(to_time + 10, y + 0.15, '+600s', fontsize=6, color='red')

# Plot nodes
for t, y in nodes:
    plt.scatter(t, y, color='black', s=10)

# Axis settings
plt.yticks(list(station_to_y.values()), list(station_to_y.keys()))
plt.xlabel("Time (seconds)")
plt.ylabel("Stations")
plt.title("Buffered Plan with 600s Delay Buffers on Tight Connections")
plt.grid(True, linestyle='--', linewidth=0.5)

# Legend
legend_lines = [
    mlines.Line2D([], [], color=train_to_color[train], linewidth=2, label=train)
    for train in train_ids[:12]
]
legend_lines.append(mlines.Line2D([], [], color='red', linestyle=':', linewidth=1, label='Buffer +600s'))
plt.legend(handles=legend_lines, title="Trains", loc='upper center', bbox_to_anchor=(0.5, -0.08),
           ncol=6, fontsize=8, title_fontsize=10, frameon=True)

plt.tight_layout()
plt.show()

# === STEP 5: Summary ===
print("\n===== ⏱️ Buffered Plan Summary (600s for tight links) =====")
print(f" Tight Connections Found   : {len(df_tight)}")
print(f" Buffer Applied per Link   : {BUFFER_TIME} seconds")
print(f" Trains (Vehicles) Used    : {traction_units}")
print(f" Light Travel Cost         : {round(light_travel_cost, 2)}")
print(f" Total Cost                : {round(total_cost, 2)}")
print(f" Total Edges               : {len(df_buffered)}")
print(f" Total Unique Nodes        : {len(nodes)}")
# Out:
# /tmp/ipython-input-9-1934405000.py:76: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(train_ids))
# ===== ⏱️ Buffered Plan Summary (600s for tight links) =====
#  Tight Connections Found   : 0
#  Buffer Applied per Link   : 600 seconds
#  Trains (Vehicles) Used    : 2
#  Light Travel Cost         : 0.0
#  Total Cost                : 2000.0
#  Total Edges               : 1006
#  Total Unique Nodes        : 1008

# %%
from collections import defaultdict
import pandas as pd

# Configuration
TIGHT_THRESHOLD = 300  # seconds

# Initialize counter
tight_counts = defaultdict(int)
total_counts = defaultdict(int)

# Detect tight and total connections per station
train_trips = df_schedule[df_schedule["Type"] == "Train Trip"].copy()
train_trips.sort_values(by=["Train", "StartTime"], inplace=True)

for train_id, group in train_trips.groupby("Train"):
    trips = group.reset_index(drop=True)
    for i in range(len(trips) - 1):
        end_time = trips.loc[i, "EndTime"]
        next_start = trips.loc[i + 1, "StartTime"]
        conn_time = next_start - end_time
        station = trips.loc[i + 1, "From"]

        total_counts[station] += 1
        if conn_time <= TIGHT_THRESHOLD:
            tight_counts[station] += 1

# Create summary DataFrame
df_station_tightness = pd.DataFrame({
    "TotalConnections": pd.Series(total_counts),
    "TightConnections": pd.Series(tight_counts)
})
df_station_tightness["TightRatio"] = df_station_tightness["TightConnections"] / df_station_tightness["TotalConnections"]
df_station_tightness = df_station_tightness.fillna(0).sort_values(by="TightRatio", ascending=False)

# Show top 10 stations
print("\n===== 🔍 Stations with Highest Tight Connection Ratios =====")
print(df_station_tightness.head(10).round(2))
# Out:
# ===== 🔍 Stations with Highest Tight Connection Ratios =====
#           TotalConnections  TightConnections  TightRatio
# Station1               252                 0           0
# Station0               250                 0           0
# /tmp/ipython-input-10-1435511764.py:33: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_station_tightness = df_station_tightness.fillna(0).sort_values(by="TightRatio", ascending=False)
