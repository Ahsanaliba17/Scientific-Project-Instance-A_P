# %% [markdown]
# **Scheduling Problem**

# %% [markdown]
# Random Space Time Network Instance_D

# %% [markdown]
# **Step 01 Generating a Space Time Network**

# %%
# Load required libraries
import json  # Used to read and parse JSON files
import matplotlib.pyplot as plt  # Used for plotting the space-time network
import re  # Used for natural sorting of station names like Station1, Station2, Station10
import time  # Used to measure computation time
import matplotlib.ticker as ticker  # (Optional) used for custom formatting of x-axis ticks

# Start the timer to measure total computation time
start_time = time.time()

# Open and load the JSON file containing the instance data for stations, trips, and empty runs
with open("Instance_D.json") as f:
    data = json.load(f)

# Define a helper function that creates a sorting key for natural sorting (e.g., Station2 before Station10)
def natural_key(s):
    return [int(text) if text.isdigit() else text for text in re.split('(\d+)', s)]

# Extract and sort all station names using natural sorting
stations = sorted([s["Name"] for s in data["StationList"]], key=natural_key)

# Create a dictionary mapping each station name to a corresponding y-axis index (0, 1, ..., 33)
station_to_y = {name: i for i, name in enumerate(stations)}

# Sort all trips based on their start times
trips = sorted(data["TripList"], key=lambda x: x["StartTime"])

# Extract the empty run data which contains light travel durations between station pairs
empty_runs = data["EmptyRunData"]

# Initialize lists to store different types of arcs (edges) and special nodes
train_arcs = []          # Arcs representing productive trips (trains with passengers)
light_arcs_arrival = []  # Arcs representing light vehicle travel after completing a trip
light_arcs_source = []   # Arcs representing vehicle repositioning from source to first trip
ground_arcs = []         # Arcs representing idle waiting time at a station
source_nodes = []        # Artificial source nodes (before each trip)
sink_nodes = []          # Artificial sink nodes (after each trip)
nodes_set = set()        # Set to store all unique (time, station index) pairs (i.e., nodes)

# Step 1: Create artificial source and sink nodes for each trip
for trip in trips:
    source_nodes.append((trip["StartTime"] - 1, station_to_y[trip["Origin"]]))  # source node before trip starts
    sink_nodes.append((trip["EndTime"] + 1, station_to_y[trip["Destination"]]))  # sink node after trip ends

# Step 2: Create productive train arcs
for trip in trips:
    u = (trip["StartTime"], station_to_y[trip["Origin"]])
    v = (trip["EndTime"], station_to_y[trip["Destination"]])
    train_arcs.append((u, v))
    nodes_set.update([u, v])  # store nodes

# Step 3: Create light arcs from trip end to future trip start
for trip_a in trips:
    for trip_b in trips:
        if trip_a["Id"] != trip_b["Id"] and trip_a["EndTime"] < trip_b["StartTime"]:
            key = f"{trip_a['Destination']},{trip_b['Origin']}"
            if trip_a["Destination"] != trip_b["Origin"] and key in empty_runs:
                transfer_time = empty_runs[key]["Duration"]
                if trip_a["EndTime"] + transfer_time <= trip_b["StartTime"]:
                    u = (trip_a["EndTime"], station_to_y[trip_a["Destination"]])
                    v = (trip_a["EndTime"] + transfer_time, station_to_y[trip_b["Origin"]])
                    light_arcs_arrival.append((u, v))
                    nodes_set.update([u, v])
                    break

# Step 4: Create light arcs from artificial source to feasible trip origin
for src in source_nodes:
    t0, y0 = src
    for trip in trips:
        key = f"{stations[y0]},{trip['Origin']}"
        if key in empty_runs and t0 < trip["StartTime"]:
            duration = empty_runs[key]["Duration"]
            if t0 + duration <= trip["StartTime"]:
                u = src
                v = (t0 + duration, station_to_y[trip["Origin"]])
                light_arcs_source.append((u, v))
                nodes_set.update([u, v])
                break

# Step 5: Create ground arcs between end of one trip and start of another at same station
for trip_a in trips:
    for trip_b in trips:
        if trip_a["Destination"] == trip_b["Origin"] and trip_b["StartTime"] > trip_a["EndTime"]:
            u = (trip_a["EndTime"], station_to_y[trip_a["Destination"]])
            v = (trip_b["StartTime"], station_to_y[trip_b["Origin"]])
            ground_arcs.append((u, v))
            nodes_set.update([u, v])
            break

# Start plotting the space-time network
plt.figure(figsize=(20, 12))

# Draw productive train arcs (blue)
for u, v in train_arcs:
    plt.plot([u[0], v[0]], [u[1], v[1]], color='blue', linewidth=0.9)

# Draw light arcs after trip end (dashed gray)
for u, v in light_arcs_arrival:
    plt.plot([u[0], v[0]], [u[1], v[1]], color='gray', linestyle='dashed', linewidth=0.8)

# Draw light arcs from source node (dotted dark gray)
for u, v in light_arcs_source:
    plt.plot([u[0], v[0]], [u[1], v[1]], color='darkgray', linestyle='dotted', linewidth=0.8)

# Draw ground arcs (green)
for u, v in ground_arcs:
    plt.plot([u[0], v[0]], [u[1], v[1]], color='green', linestyle='solid', linewidth=0.7)

# Scatter plot all nodes for clarity
for (u, v) in train_arcs + light_arcs_arrival + light_arcs_source + ground_arcs:
    plt.scatter([u[0], v[0]], [u[1], v[1]], s=6, color='black')

# Configure y-axis with station names in top-down order
plt.yticks(range(len(stations)), stations)

# Set labels and title
plt.xlabel("Time (seconds)")
plt.ylabel("Stations (top: Station0)")
plt.title("Space-Time Network - Instance_D")

# Add grid and tighten layout
plt.grid(True, linestyle='--', linewidth=0.3)
plt.tight_layout()

# Show the final plot
plt.show()

# Calculate total edges and computation time
total_edges = len(train_arcs) + len(light_arcs_arrival) + len(light_arcs_source) + len(ground_arcs)
end_time_calc = time.time()

# Print network statistics
print("Network Summary")
print(f"Number of nodes       : {len(nodes_set)}")
print(f"Number of edges       : {total_edges}")
print(f"Computation time (s)  : {round(end_time_calc - start_time, 3)}")
# Out:
# Network Summary
# Number of nodes       : 1445
# Number of edges       : 1501
# Computation time (s)  : 25.131

# %% [markdown]
# **Step 02 Costing Calculation and Vehicles Calculation Using Pulp**

# %% [markdown]
# Pulp Installation for Mixed Integer Program Optimization

# %%
# Install PuLP
# !pip install pulp

# Load libraries
import json, re
import pulp
import pandas as pd

# Load JSON file
with open("Instance_D.json") as f:
    data = json.load(f)

# Cost parameters
C_TU = 1000
C_Light = 0.10

# Parse stations and trips
stations = sorted(
    [s["Name"] for s in data["StationList"]],
    key=lambda s: [int(t) if t.isdigit() else t for t in re.split("(\d+)", s)]
)
station_index = {name: i for i, name in enumerate(stations)}

trips = sorted(data["TripList"], key=lambda x: x["StartTime"])
trip_ids = [trip["Id"] for trip in trips]
trip_map = {trip["Id"]: trip for trip in trips}
empty_runs = data["EmptyRunData"]

# Optimization model
model = pulp.LpProblem("RollingStockCirculationPlanning", pulp.LpMinimize)

x = {trip["Id"]: pulp.LpVariable(f"x_{trip['Id']}", cat="Binary") for trip in trips}
vehicles = {trip["Id"]: pulp.LpVariable(f"veh_{trip['Id']}", cat="Binary") for trip in trips}
z = {}

# Generate light travel arcs
for i, trip_a in enumerate(trips):
    for j, trip_b in enumerate(trips):
        if i != j and trip_a["EndTime"] < trip_b["StartTime"]:
            key = f"{trip_a['Destination']},{trip_b['Origin']}"
            if key in empty_runs:
                ttime = empty_runs[key]["Duration"]
                if trip_a["EndTime"] + ttime <= trip_b["StartTime"]:
                    arc = f"{trip_a['Id']}_{trip_b['Id']}"
                    z[arc] = pulp.LpVariable(f"z_{arc}", cat="Binary")

# Objective
model += (
    pulp.lpSum([vehicles[trip["Id"]] for trip in trips]) * C_TU +
    pulp.lpSum([
        z[arc] *
        empty_runs[f"{trip_map[int(arc.split('_')[0])]['Destination']},{trip_map[int(arc.split('_')[1])]['Origin']}"]["Distance"] *
        C_Light for arc in z
    ])
)

# Constraints
for trip in trips:
    model += x[trip["Id"]] == 1

for trip in trips:
    incoming = [z[arc] for arc in z if int(arc.split('_')[1]) == trip["Id"]]
    model += vehicles[trip["Id"]] + pulp.lpSum(incoming) >= x[trip["Id"]]

for trip in trips:
    outgoing = [z[arc] for arc in z if int(arc.split('_')[0]) == trip["Id"]]
    model += pulp.lpSum(outgoing) <= 1

# Solve
model.solve(pulp.PULP_CBC_CMD(msg=0))

# Result
num_vehicles = sum(v.varValue for v in vehicles.values())
light_cost = sum(
    z[arc].varValue *
    empty_runs[f"{trip_map[int(arc.split('_')[0])]['Destination']},{trip_map[int(arc.split('_')[1])]['Origin']}"]["Distance"] *
    C_Light for arc in z
)
traction_cost = num_vehicles * C_TU
total_cost = traction_cost + light_cost

# Display
results = {
    "Total Cost": round(total_cost, 2),
    "Traction Unit Cost": round(traction_cost, 2),
    "Light Travel Cost": round(light_cost, 2),
    "Deadheading Cost": 0.00,
    "Number of Vehicles Used": int(num_vehicles)
}
pd.DataFrame([results])
# Out:
# Collecting pulp
#   Downloading pulp-3.2.1-py3-none-any.whl.metadata (6.9 kB)
# Downloading pulp-3.2.1-py3-none-any.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 63.4 MB/s eta 0:00:00
# Installing collected packages: pulp
# Successfully installed pulp-3.2.1
#    Total Cost  Traction Unit Cost  Light Travel Cost  Deadheading Cost  \
# 0    11093.73             11000.0              93.73               0.0
#
#    Number of Vehicles Used
# 0                       11

# %% [markdown]
# **`Schedule Calculator`**

# %%
# STEP 1: Install pulp (for Google Colab; skip if already installed)
# !pip install pulp

# STEP 2: Import required libraries
import json           # For reading the JSON file
import re             # For sorting station names naturally
import pulp           # For defining and solving the optimization model
import pandas as pd   # For creating and displaying schedule tables
from pulp import LpStatus  # For checking the model solution status

# STEP 3: Load data from the JSON file
with open("Instance_D.json") as f:
    data = json.load(f)

# STEP 4: Define cost parameters
C_TU = 1000       # Cost for using a train unit
C_Light = 0.10    # Cost per km for light (empty) travel

# STEP 5: Prepare and sort stations
stations = sorted(
    [s["Name"] for s in data["StationList"]],
    key=lambda s: [int(t) if t.isdigit() else t for t in re.split("(\d+)", s)]
)
station_index = {name: i for i, name in enumerate(stations)}

# STEP 6: Extract trips and empty run data
trips = sorted(data["TripList"], key=lambda x: x["StartTime"])
trip_map = {trip["Id"]: trip for trip in trips}
empty_runs = data["EmptyRunData"]

# STEP 7: Define the optimization model
model = pulp.LpProblem("RollingStock", pulp.LpMinimize)

# Binary variable for each trip: 1 if performed
x = {trip["Id"]: pulp.LpVariable(f"x_{trip['Id']}", cat="Binary") for trip in trips}

# Binary variable for vehicle usage: 1 if a new train starts with this trip
vehicles = {trip["Id"]: pulp.LpVariable(f"veh_{trip['Id']}", cat="Binary") for trip in trips}

# Binary variables for light connections between trips
z = {}
for i, a in enumerate(trips):
    for j, b in enumerate(trips):
        if i != j and a["EndTime"] < b["StartTime"]:
            key = f"{a['Destination']},{b['Origin']}"
            if key in empty_runs:
                dt = empty_runs[key]["Duration"]
                if a["EndTime"] + dt <= b["StartTime"]:
                    arc = f"{a['Id']}_{b['Id']}"
                    z[arc] = pulp.LpVariable(f"z_{arc}", cat="Binary")

# STEP 8: Define objective function to minimize total cost
model += (
    pulp.lpSum([vehicles[tid] for tid in x]) * C_TU +
    pulp.lpSum([
        z[arc] * empty_runs[
            f"{trip_map[int(arc.split('_')[0])]['Destination']},{trip_map[int(arc.split('_')[1])]['Origin']}"
        ]["Distance"] * C_Light for arc in z
    ])
)

# STEP 9: Add constraints
# Ensure each trip is covered
for trip in trips:
    model += x[trip["Id"]] == 1

# A trip is covered either by a new vehicle or from a previous trip via light travel
for trip in trips:
    incoming = [z[arc] for arc in z if int(arc.split("_")[1]) == trip["Id"]]
    model += vehicles[trip["Id"]] + pulp.lpSum(incoming) >= x[trip["Id"]]

# A trip connects to at most one next trip
for trip in trips:
    outgoing = [z[arc] for arc in z if int(arc.split("_")[0]) == trip["Id"]]
    model += pulp.lpSum(outgoing) <= 1

# STEP 10: Solve the model
model.solve(pulp.PULP_CBC_CMD(msg=0))

# STEP 11: Check if solution is feasible
status = LpStatus[model.status]
print(f"\n🔍 Model Status: {status}")
if status != "Optimal":
    print(" No feasible or optimal solution found.")
else:
    print(" Feasible and optimal solution found.")

# STEP 12: Assign Train IDs
trip_to_train = {}
train_counter = 1
outgoing_map = {int(arc.split('_')[0]): int(arc.split('_')[1]) for arc in z if z[arc].varValue == 1}
visited = set()

for trip in trips:
    tid = trip["Id"]
    if tid not in visited:
        current_train = f"Train_{train_counter}"
        while tid in trip_map:
            visited.add(tid)
            trip_to_train[tid] = current_train
            tid = outgoing_map.get(tid, None)
            if tid is None or tid in visited:
                break
        train_counter += 1

# STEP 13: Build the full trip and light travel schedule
full_schedule = []

# Add train trips
for tid, var in x.items():
    if var.varValue == 1:
        trip = trip_map[tid]
        full_schedule.append({
            "Train": trip_to_train[tid],
            "Type": "Train Trip",
            "From": trip["Origin"],
            "To": trip["Destination"],
            "StartTime": trip["StartTime"],
            "EndTime": trip["EndTime"]
        })

# Add light travel trips
light_travel_cost = 0
for arc, var in z.items():
    if var.varValue == 1:
        from_id, to_id = map(int, arc.split("_"))
        trip_a = trip_map[from_id]
        trip_b = trip_map[to_id]
        key = f"{trip_a['Destination']},{trip_b['Origin']}"
        dur = empty_runs[key]["Duration"]
        dist = empty_runs[key]["Distance"]
        cost = dist * C_Light
        light_travel_cost += cost
        full_schedule.append({
            "Train": trip_to_train[from_id],
            "Type": "Light Travel",
            "From": trip_a["Destination"],
            "To": trip_b["Origin"],
            "StartTime": trip_a["EndTime"],
            "EndTime": trip_a["EndTime"] + dur
        })

# STEP 14: Display the final schedule
full_schedule = sorted(full_schedule, key=lambda x: x["StartTime"])
df_schedule = pd.DataFrame(full_schedule)
print("\n Complete Trip and Light Travel Schedule:")
print(df_schedule.to_string(index=False))

# STEP 15: Print cost breakdown
traction_units = sum([vehicles[tid].varValue for tid in vehicles])
traction_cost = traction_units * C_TU
total_cost = pulp.value(model.objective)

print("\n Cost Breakdown:")
print(f"Total Cost           : {total_cost:.2f}")
print(f"Traction Unit Cost   : {traction_cost:.2f}")
print(f"Light Travel Cost    : {light_travel_cost:.2f}")
print(f"Number of Vehicles   : {int(traction_units)}")
# Out:
# Requirement already satisfied: pulp in /usr/local/lib/python3.11/dist-packages (3.2.1)
#
# 🔍 Model Status: Optimal
#  Feasible and optimal solution found.
#
#  Complete Trip and Light Travel Schedule:
#    Train         Type      From        To  StartTime  EndTime
#  Train_1   Train Trip  Station0  Station1          0   522840
#  Train_2   Train Trip  Station2  Station3         60     3600
#  Train_3   Train Trip  Station4  Station5        480     4260
#  Train_4   Train Trip  Station6  Station7       3480     6900
#  Train_5   Train Trip  Station6  Station1       3600     4440
#  Train_2 Light Travel  Station3  Station3       3600     3600
#  Train_3 Light Travel  Station5  Station5       4260     4260
#  Train_5 Light Travel  Station1  Station1       4440     4440
#  Train_4 Light Travel  Station7  Station7       6900     6900
#  Train_2   Train Trip  Station3  Station2       7200    10680
#  Train_6   Train Trip  Station6  Station8       8100     8520
#  Train_5   Train Trip  Station1  Station6       8400     9360
#  Train_3   Train Trip  Station5  Station4       8400    10860
#  Train_6 Light Travel  Station8 Station13       8520     9000
#  Train_5 Light Travel  Station6  Station1       9360    10380
#  Train_2 Light Travel  Station2  Station2      10680    10680
#  Train_3 Light Travel  Station4  Station9      10860    11580
#  Train_3   Train Trip  Station9  Station6      13500    14640
#  Train_4   Train Trip  Station7  Station6      13500    15720
#  Train_3 Light Travel  Station6  Station6      14640    14640
#  Train_5   Train Trip  Station1  Station6      15600    16440
#  Train_4 Light Travel  Station6  Station6      15720    15720
#  Train_5 Light Travel  Station6  Station6      16440    16440
#  Train_3   Train Trip  Station6  Station1      17340    18060
#  Train_3 Light Travel  Station1  Station1      18060    18060
#  Train_3   Train Trip  Station1  Station6      20400    21240
#  Train_3 Light Travel  Station6  Station6      21240    21240
#  Train_5   Train Trip  Station6  Station1      22200    22920
#  Train_5 Light Travel  Station1  Station1      22920    22920
#  Train_3   Train Trip  Station6  Station1      22980    23820
#  Train_4   Train Trip  Station6 Station10      23220    23820
#  Train_7   Train Trip Station11 Station12      23340    24240
#  Train_6   Train Trip Station13 Station14      23700    27000
#  Train_3 Light Travel  Station1 Station29      23820    25080
#  Train_4 Light Travel Station10 Station10      23820    23820
#  Train_7 Light Travel Station12 Station12      24240    24240
#  Train_7   Train Trip Station12 Station12      25800    30060
#  Train_8   Train Trip Station15 Station16      26520    27420
#  Train_9   Train Trip Station17 Station18      26640    29820
#  Train_6 Light Travel Station14 Station14      27000    27000
#  Train_8 Light Travel Station16 Station16      27420    27420
#  Train_4   Train Trip Station10 Station10      28980    30900
#  Train_8   Train Trip Station16 Station19      29160    30540
#  Train_2   Train Trip  Station2 Station20      29400    33420
#  Train_9 Light Travel Station18 Station18      29820    29820
#  Train_7 Light Travel Station12 Station12      30060    30060
# Train_10   Train Trip Station21 Station22      30360    32580
#  Train_8 Light Travel Station19 Station15      30540    32040
# Train_11   Train Trip Station23 Station24      30720    32580
#  Train_4 Light Travel Station10 Station31      30900    31740
#  Train_7   Train Trip Station12 Station11      31020    31920
#  Train_7 Light Travel Station11 Station11      31920    31920
#  Train_9   Train Trip Station18 Station17      32580    34440
# Train_10 Light Travel Station22 Station22      32580    32580
# Train_11 Light Travel Station24 Station24      32580    32580
#  Train_6   Train Trip Station14 Station14      33180    34920
#  Train_2 Light Travel Station20 Station20      33420    33420
#  Train_8   Train Trip Station15 Station25      34020    34920
#  Train_5   Train Trip  Station1  Station6      34320    35280
#  Train_9 Light Travel Station17 Station17      34440    34440
#  Train_7   Train Trip Station11 Station26      34800    37980
#  Train_6 Light Travel Station14 Station14      34920    34920
#  Train_8 Light Travel Station25 Station25      34920    34920
#  Train_5 Light Travel  Station6  Station6      35280    35280
#  Train_9   Train Trip Station17 Station27      35580    36240
#  Train_9 Light Travel Station27 Station27      36240    36240
#  Train_6   Train Trip Station14 Station14      36780    38520
# Train_11   Train Trip Station24 Station23      36780    41640
# Train_10   Train Trip Station22 Station21      36900    39180
#  Train_2   Train Trip Station20  Station2      37200    41940
#  Train_5   Train Trip  Station6 Station28      37320    38040
#  Train_8   Train Trip Station25 Station15      37860    38460
#  Train_7 Light Travel Station26 Station26      37980    37980
#  Train_5 Light Travel Station28  Station6      38040    38340
#  Train_3   Train Trip Station29 Station30      38100    38880
#  Train_8 Light Travel Station15 Station19      38460    39960
#  Train_4   Train Trip Station31 Station32      38520    40380
#  Train_6 Light Travel Station14 Station14      38520    38520
#  Train_3 Light Travel Station30  Station9      38880    38940
# Train_10 Light Travel Station21 Station21      39180    39180
#  Train_5   Train Trip  Station6 Station10      39960    40560
#  Train_7   Train Trip Station26 Station11      40200    43020
#  Train_6   Train Trip Station14 Station33      40260    47160
#  Train_4 Light Travel Station32 Station32      40380    40380
#  Train_5 Light Travel Station10 Station28      40560    41160
# Train_10   Train Trip Station21 Station34      40860    43380
#  Train_9   Train Trip Station27 Station17      41040    41940
#  Train_3   Train Trip  Station9 Station29      41100    42060
#  Train_5   Train Trip Station28  Station6      41160    41760
# Train_11 Light Travel Station23 Station23      41640    41640
#  Train_5 Light Travel  Station6 Station10      41760    42060
#  Train_2 Light Travel  Station2  Station2      41940    41940
#  Train_9 Light Travel Station17 Station17      41940    41940
#  Train_3 Light Travel Station29 Station29      42060    42060
#  Train_7 Light Travel Station11 Station11      43020    43020
# Train_10 Light Travel Station34 Station34      43380    43380
#  Train_5   Train Trip Station10  Station6      43500    44100
#  Train_5 Light Travel  Station6  Station6      44100    44100
#  Train_7   Train Trip Station11 Station12      45360    46260
#  Train_5   Train Trip  Station6  Station1      45600    46440
#  Train_4   Train Trip Station32 Station31      46200    49860
#  Train_7 Light Travel Station12 Station12      46260    46260
#  Train_5 Light Travel  Station1  Station1      46440    46440
#  Train_7   Train Trip Station12 Station12      46980    50640
#  Train_6 Light Travel Station33  Station4      47160    48420
#  Train_3   Train Trip Station29 Station35      48000    50220
# Train_11   Train Trip Station23 Station36      48960    50640
#  Train_4 Light Travel Station31 Station10      49860    50700
#  Train_3 Light Travel Station35 Station35      50220    50220
#  Train_3   Train Trip Station35 Station29      50400    52860
# Train_10   Train Trip Station34 Station21      50580    52980
#  Train_7 Light Travel Station12 Station12      50640    50640
# Train_11 Light Travel Station36 Station36      50640    50640
#  Train_2   Train Trip  Station2 Station37      51720    52560
#  Train_7   Train Trip Station12 Station11      51780    52680
#  Train_4   Train Trip Station10 Station10      52020    56040
#  Train_2 Light Travel Station37 Station37      52560    52560
#  Train_7 Light Travel Station11 Station11      52680    52680
#  Train_3 Light Travel Station29 Station29      52860    52860
# Train_10 Light Travel Station21 Station21      52980    52980
# Train_10   Train Trip Station21 Station22      53400    55620
#  Train_2   Train Trip Station37  Station2      53520    54180
#  Train_2 Light Travel  Station2  Station2      54180    54180
#  Train_8   Train Trip Station19 Station16      55320    56160
# Train_11   Train Trip Station36 Station23      55380    60180
# Train_10 Light Travel Station22 Station22      55620    55620
#  Train_4 Light Travel Station10 Station10      56040    56040
#  Train_8 Light Travel Station16 Station16      56160    56160
#  Train_7   Train Trip Station11 Station12      57000    57900
#  Train_7 Light Travel Station12 Station12      57900    57900
#  Train_5   Train Trip  Station1  Station6      58500    59460
#  Train_7   Train Trip Station12 Station12      58800    62160
#  Train_5 Light Travel  Station6  Station6      59460    59460
# Train_11 Light Travel Station23 Station23      60180    60180
#  Train_4   Train Trip Station10  Station6      60420    61140
#  Train_4 Light Travel  Station6  Station6      61140    61140
# Train_10   Train Trip Station22 Station21      61560    63840
#  Train_7 Light Travel Station12 Station12      62160    62160
#  Train_8   Train Trip Station16 Station15      62340    63240
#  Train_7   Train Trip Station12 Station11      62580    63480
#  Train_4   Train Trip  Station6  Station1      62700    63540
#  Train_8 Light Travel Station15 Station15      63240    63240
#  Train_7 Light Travel Station11 Station11      63480    63480
#  Train_4 Light Travel  Station1  Station1      63540    63540
# Train_10 Light Travel Station21 Station21      63840    63840
#  Train_4   Train Trip  Station1  Station6      71100    72060
#  Train_4 Light Travel  Station6  Station6      72060    72060
#  Train_2   Train Trip  Station2  Station3      86460    90000
#  Train_6   Train Trip  Station4  Station5      86880    90660
#  Train_4   Train Trip  Station6  Station7      89880    93300
#  Train_5   Train Trip  Station6  Station1      90000    90840
#  Train_2 Light Travel  Station3  Station3      90000    90000
#  Train_6 Light Travel  Station5  Station5      90660    90660
#  Train_5 Light Travel  Station1  Station1      90840    90840
#  Train_4 Light Travel  Station7  Station7      93300    93300
#  Train_2   Train Trip  Station3  Station2      93600    97080
#  Train_5   Train Trip  Station1  Station6      94800    95760
#  Train_6   Train Trip  Station5  Station4      94800    97260
#  Train_5 Light Travel  Station6  Station6      95760    95760
#  Train_2 Light Travel  Station2  Station2      97080    97080
#  Train_6 Light Travel  Station4 Station13      97260    98760
#  Train_4   Train Trip  Station7  Station6      99900   102120
#  Train_4 Light Travel  Station6  Station6     102120   102120
#  Train_5   Train Trip  Station6  Station1     109380   110220
#  Train_4   Train Trip  Station6 Station10     109620   110220
#  Train_7   Train Trip Station11 Station12     109740   110640
#  Train_6   Train Trip Station13 Station14     110100   113400
#  Train_5 Light Travel  Station1  Station1     110220   110220
#  Train_4 Light Travel Station10 Station10     110220   110220
#  Train_7 Light Travel Station12 Station12     110640   110640
#  Train_7   Train Trip Station12 Station12     112200   116460
#  Train_8   Train Trip Station15 Station16     112920   113820
#  Train_9   Train Trip Station17 Station18     113040   116220
#  Train_6 Light Travel Station14 Station14     113400   113400
#  Train_8 Light Travel Station16 Station16     113820   113820
#  Train_4   Train Trip Station10 Station10     115380   117300
#  Train_8   Train Trip Station16 Station19     115560   116940
#  Train_2   Train Trip  Station2 Station20     115800   119820
#  Train_9 Light Travel Station18 Station18     116220   116220
#  Train_7 Light Travel Station12 Station12     116460   116460
# Train_10   Train Trip Station21 Station22     116760   118980
#  Train_8 Light Travel Station19 Station15     116940   118440
# Train_11   Train Trip Station23 Station24     117120   118980
#  Train_4 Light Travel Station10 Station31     117300   118140
#  Train_7   Train Trip Station12 Station11     117420   118320
#  Train_7 Light Travel Station11 Station11     118320   118320
#  Train_9   Train Trip Station18 Station17     118980   120840
# Train_10 Light Travel Station22 Station22     118980   118980
# Train_11 Light Travel Station24 Station24     118980   118980
#  Train_6   Train Trip Station14 Station14     119580   121320
#  Train_2 Light Travel Station20 Station20     119820   119820
#  Train_8   Train Trip Station15 Station25     120420   121320
#  Train_5   Train Trip  Station1  Station6     120720   121680
#  Train_9 Light Travel Station17 Station17     120840   120840
#  Train_7   Train Trip Station11 Station26     121200   124380
#  Train_6 Light Travel Station14 Station14     121320   121320
#  Train_8 Light Travel Station25 Station25     121320   121320
#  Train_5 Light Travel  Station6  Station6     121680   121680
#  Train_9   Train Trip Station17 Station27     121980   122640
#  Train_9 Light Travel Station27 Station27     122640   122640
#  Train_3   Train Trip Station29 Station38     122700   125400
#  Train_6   Train Trip Station14 Station14     123180   124920
# Train_11   Train Trip Station24 Station23     123180   128040
# Train_10   Train Trip Station22 Station21     123300   125580
#  Train_2   Train Trip Station20  Station2     123600   128340
#  Train_5   Train Trip  Station6 Station28     123720   124440
#  Train_8   Train Trip Station25 Station15     124260   124860
#  Train_7 Light Travel Station26 Station26     124380   124380
#  Train_5 Light Travel Station28  Station6     124440   124740
#  Train_8 Light Travel Station15 Station19     124860   126360
#  Train_4   Train Trip Station31 Station32     124920   126780
#  Train_6 Light Travel Station14 Station14     124920   124920
#  Train_3 Light Travel Station38 Station38     125400   125400
# Train_10 Light Travel Station21 Station21     125580   125580
#  Train_5   Train Trip  Station6 Station10     126360   126960
#  Train_7   Train Trip Station26 Station11     126600   129420
#  Train_6   Train Trip Station14 Station33     126660   133560
#  Train_4 Light Travel Station32 Station32     126780   126780
#  Train_3   Train Trip Station38 Station29     126960   129720
#  Train_5 Light Travel Station10 Station28     126960   127560
#  Train_9   Train Trip Station27 Station17     127440   128340
#  Train_5   Train Trip Station28  Station6     127560   128160
# Train_11 Light Travel Station23 Station23     128040   128040
#  Train_5 Light Travel  Station6 Station10     128160   128460
#  Train_2 Light Travel  Station2  Station2     128340   128340
#  Train_9 Light Travel Station17 Station10     128340   132180
#  Train_7 Light Travel Station11 Station11     129420   129420
#  Train_3 Light Travel Station29 Station29     129720   129720
#  Train_5   Train Trip Station10  Station6     129900   130500
#  Train_5 Light Travel  Station6  Station6     130500   130500
#  Train_7   Train Trip Station11 Station12     131760   132660
#  Train_5   Train Trip  Station6  Station1     132000   132840
#  Train_4   Train Trip Station32 Station31     132600   136260
#  Train_7 Light Travel Station12 Station12     132660   132660
#  Train_5 Light Travel  Station1  Station1     132840   132840
#  Train_7   Train Trip Station12 Station12     133380   137040
#  Train_6 Light Travel Station33 Station13     133560   133800
#  Train_3   Train Trip Station29 Station39     135000   135540
# Train_10   Train Trip Station21 Station40     135300   135780
# Train_11   Train Trip Station23 Station36     135360   137040
#  Train_3 Light Travel Station39 Station39     135540   135540
# Train_10 Light Travel Station40 Station40     135780   135780
#  Train_4 Light Travel Station31 Station31     136260   136260
#  Train_7 Light Travel Station12 Station12     137040   137040
# Train_11 Light Travel Station36 Station36     137040   137040
# Train_10   Train Trip Station40 Station21     138000   139140
#  Train_2   Train Trip  Station2 Station37     138120   138960
#  Train_7   Train Trip Station12 Station11     138180   139080
#  Train_9   Train Trip Station10 Station10     138420   142440
#  Train_3   Train Trip Station39 Station29     138720   139260
#  Train_2 Light Travel Station37 Station37     138960   138960
#  Train_7 Light Travel Station11 Station11     139080   139080
# Train_10 Light Travel Station21 Station21     139140   139140
#  Train_3 Light Travel Station29  Station4     139260   140880
# Train_10   Train Trip Station21 Station22     139800   142020
#  Train_2   Train Trip Station37  Station2     139920   140580
#  Train_2 Light Travel  Station2  Station2     140580   140580
#  Train_8   Train Trip Station19 Station16     141720   142560
# Train_11   Train Trip Station36 Station23     141780   146580
# Train_10 Light Travel Station22 Station22     142020   142020
#  Train_9 Light Travel Station10 Station10     142440   142440
#  Train_8 Light Travel Station16 Station16     142560   142560
#  Train_7   Train Trip Station11 Station12     143400   144300
#  Train_7 Light Travel Station12 Station12     144300   144300
#  Train_5   Train Trip  Station1  Station6     144900   145860
#  Train_7   Train Trip Station12 Station12     145200   148560
#  Train_5 Light Travel  Station6  Station6     145860   145860
# Train_11 Light Travel Station23 Station23     146580   146580
#  Train_9   Train Trip Station10  Station6     146820   147540
#  Train_9 Light Travel  Station6  Station6     147540   147540
# Train_10   Train Trip Station22 Station21     147960   150240
#  Train_7 Light Travel Station12 Station12     148560   148560
#  Train_8   Train Trip Station16 Station15     148740   149640
#  Train_7   Train Trip Station12 Station11     148980   149880
#  Train_9   Train Trip  Station6  Station1     149100   149940
#  Train_8 Light Travel Station15 Station15     149640   149640
#  Train_7 Light Travel Station11 Station11     149880   149880
#  Train_9 Light Travel  Station1  Station1     149940   149940
# Train_10 Light Travel Station21 Station21     150240   150240
#  Train_9   Train Trip  Station1  Station6     157500   158460
#  Train_9 Light Travel  Station6  Station6     158460   158460
#  Train_2   Train Trip  Station2  Station3     172860   176400
#  Train_3   Train Trip  Station4  Station5     173280   177060
#  Train_9   Train Trip  Station6  Station7     176280   179700
#  Train_5   Train Trip  Station6  Station1     176400   177240
#  Train_2 Light Travel  Station3  Station3     176400   176400
#  Train_3 Light Travel  Station5  Station5     177060   177060
#  Train_5 Light Travel  Station1  Station1     177240   177240
#  Train_6   Train Trip Station13 Station17     177780   183360
#  Train_9 Light Travel  Station7  Station7     179700   179700
#  Train_2   Train Trip  Station3  Station2     180000   183480
#  Train_5   Train Trip  Station1  Station6     181200   182160
#  Train_3   Train Trip  Station5  Station4     181200   183660
#  Train_5 Light Travel  Station6  Station6     182160   182160
#  Train_6 Light Travel Station17 Station17     183360   183360
#  Train_2 Light Travel  Station2  Station2     183480   183480
#  Train_3 Light Travel  Station4 Station13     183660   185160
#  Train_9   Train Trip  Station7  Station6     186300   188520
#  Train_9 Light Travel  Station6  Station6     188520   188520
#  Train_9   Train Trip  Station6  Station1     195780   196620
#  Train_5   Train Trip  Station6 Station10     196020   196620
#  Train_7   Train Trip Station11 Station12     196140   197040
#  Train_3   Train Trip Station13 Station14     196500   199800
#  Train_9 Light Travel  Station1  Station1     196620   196620
#  Train_5 Light Travel Station10 Station10     196620   196620
#  Train_7 Light Travel Station12 Station12     197040   197040
#  Train_7   Train Trip Station12 Station12     198600   202860
#  Train_8   Train Trip Station15 Station16     199320   200220
#  Train_6   Train Trip Station17 Station18     199440   202620
#  Train_3 Light Travel Station14 Station14     199800   199800
#  Train_8 Light Travel Station16 Station16     200220   200220
#  Train_5   Train Trip Station10 Station10     201780   203700
#  Train_8   Train Trip Station16 Station19     201960   203340
#  Train_2   Train Trip  Station2 Station20     202200   206220
#  Train_6 Light Travel Station18 Station18     202620   202620
#  Train_7 Light Travel Station12 Station12     202860   202860
# Train_10   Train Trip Station21 Station22     203160   205380
#  Train_8 Light Travel Station19 Station15     203340   204840
# Train_11   Train Trip Station23 Station24     203520   205380
#  Train_5 Light Travel Station10 Station29     203700   204600
#  Train_7   Train Trip Station12 Station11     203820   204720
#  Train_7 Light Travel Station11 Station11     204720   204720
#  Train_6   Train Trip Station18 Station17     205380   207240
# Train_10 Light Travel Station22 Station22     205380   205380
# Train_11 Light Travel Station24 Station24     205380   205380
#  Train_3   Train Trip Station14 Station14     205980   207720
#  Train_2 Light Travel Station20 Station20     206220   206220
#  Train_8   Train Trip Station15 Station25     206820   207720
#  Train_9   Train Trip  Station1  Station6     207120   208080
#  Train_6 Light Travel Station17 Station17     207240   207240
#  Train_7   Train Trip Station11 Station26     207600   210780
#  Train_3 Light Travel Station14 Station14     207720   207720
#  Train_8 Light Travel Station25 Station25     207720   207720
#  Train_9 Light Travel  Station6  Station6     208080   208080
#  Train_6   Train Trip Station17 Station27     208380   209040
#  Train_6 Light Travel Station27 Station27     209040   209040
#  Train_5   Train Trip Station29 Station39     209100   209640
#  Train_3   Train Trip Station14 Station14     209580   211320
# Train_11   Train Trip Station24 Station23     209580   214440
#  Train_5 Light Travel Station39 Station39     209640   209640
# Train_10   Train Trip Station22 Station21     209700   211980
#  Train_2   Train Trip Station20  Station2     210000   214740
#  Train_9   Train Trip  Station6 Station28     210120   210840
#  Train_8   Train Trip Station25 Station15     210660   211260
#  Train_7 Light Travel Station26 Station26     210780   210780
#  Train_9 Light Travel Station28  Station6     210840   211140
#  Train_8 Light Travel Station15 Station15     211260   211260
#  Train_4   Train Trip Station31 Station32     211320   213180
#  Train_3 Light Travel Station14 Station14     211320   211320
# Train_10 Light Travel Station21 Station21     211980   211980
#  Train_9   Train Trip  Station6 Station10     212760   213360
#  Train_7   Train Trip Station26 Station11     213000   215820
#  Train_3   Train Trip Station14 Station33     213060   219960
#  Train_4 Light Travel Station32 Station32     213180   213180
#  Train_9 Light Travel Station10 Station28     213360   213960
# Train_10   Train Trip Station21 Station34     213660   216180
#  Train_6   Train Trip Station27 Station17     213840   214740
#  Train_9   Train Trip Station28  Station6     213960   214560
# Train_11 Light Travel Station23 Station23     214440   214440
#  Train_9 Light Travel  Station6 Station10     214560   214860
#  Train_2 Light Travel  Station2  Station2     214740   214740
#  Train_6 Light Travel Station17 Station17     214740   214740
#  Train_5   Train Trip Station39 Station29     215100   215580
#  Train_5 Light Travel Station29 Station29     215580   215580
#  Train_7 Light Travel Station11 Station11     215820   215820
# Train_10 Light Travel Station34 Station34     216180   216180
#  Train_9   Train Trip Station10  Station6     216300   216900
#  Train_9 Light Travel  Station6  Station6     216900   216900
#  Train_7   Train Trip Station11 Station12     218160   219060
#  Train_9   Train Trip  Station6  Station1     218400   219240
#  Train_4   Train Trip Station32 Station31     219000   222660
#  Train_7 Light Travel Station12 Station12     219060   219060
#  Train_9 Light Travel  Station1 Station10     219240   220560
#  Train_7   Train Trip Station12 Station12     219780   223440
#  Train_3 Light Travel Station33 Station19     219960   222240
#  Train_5   Train Trip Station29 Station35     220800   223020
# Train_11   Train Trip Station23 Station36     221760   223440
#  Train_4 Light Travel Station31 Station31     222660   222660
#  Train_5 Light Travel Station35 Station35     223020   223020
#  Train_5   Train Trip Station35 Station29     223200   225660
# Train_10   Train Trip Station34 Station21     223380   225780
#  Train_7 Light Travel Station12 Station12     223440   223440
# Train_11 Light Travel Station36 Station36     223440   223440
#  Train_2   Train Trip  Station2 Station37     224520   225360
#  Train_7   Train Trip Station12 Station11     224580   225480
#  Train_9   Train Trip Station10 Station10     224820   228840
#  Train_2 Light Travel Station37 Station37     225360   225360
#  Train_7 Light Travel Station11 Station11     225480   225480
#  Train_5 Light Travel Station29  Station1     225660   226920
# Train_10 Light Travel Station21 Station21     225780   225780
# Train_10   Train Trip Station21 Station22     226200   228420
#  Train_2   Train Trip Station37  Station2     226320   226980
#  Train_2 Light Travel  Station2  Station2     226980   226980
#  Train_3   Train Trip Station19 Station16     228120   228960
# Train_11   Train Trip Station36 Station23     228180   232980
# Train_10 Light Travel Station22 Station22     228420   228420
#  Train_9 Light Travel Station10 Station10     228840   228840
#  Train_3 Light Travel Station16 Station16     228960   228960
#  Train_7   Train Trip Station11 Station12     229800   230700
#  Train_7 Light Travel Station12 Station12     230700   230700
#  Train_5   Train Trip  Station1  Station6     231300   232260
#  Train_7   Train Trip Station12 Station12     231600   234960
#  Train_5 Light Travel  Station6 Station41     232260   232980
# Train_11 Light Travel Station23 Station23     232980   232980
#  Train_9   Train Trip Station10  Station6     233220   233940
#  Train_9 Light Travel  Station6  Station6     233940   233940
#  Train_5   Train Trip Station41 Station42     234180   234420
# Train_10   Train Trip Station22 Station21     234360   236640
#  Train_5 Light Travel Station42 Station42     234420   234420
#  Train_7 Light Travel Station12 Station12     234960   234960
#  Train_3   Train Trip Station16 Station15     235140   236040
#  Train_7   Train Trip Station12 Station11     235380   236280
#  Train_9   Train Trip  Station6  Station1     235500   236340
#  Train_3 Light Travel Station15 Station15     236040   236040
#  Train_7 Light Travel Station11 Station11     236280   236280
#  Train_9 Light Travel  Station1  Station1     236340   236340
# Train_10 Light Travel Station21 Station21     236640   236640
#  Train_7   Train Trip Station11 Station33     238680   242160
# Train_10   Train Trip Station21 Station33     239640   246300
# Train_11   Train Trip Station23 Station33     240780   251580
#  Train_7 Light Travel Station33 Station33     242160   242160
#  Train_9   Train Trip  Station1  Station6     243900   244860
#  Train_6   Train Trip Station17 Station33     244500   251340
#  Train_9 Light Travel  Station6  Station6     244860   244860
# Train_10 Light Travel Station33  Station4     246300   247560
#  Train_6 Light Travel Station33 Station33     251340   251340
# Train_11 Light Travel Station33 Station33     251580   251580
#  Train_6   Train Trip Station33 Station30     257340   257820
# Train_11   Train Trip Station33 Station30     257340   257820
#  Train_7   Train Trip Station33 Station30     257340   257820
#  Train_6 Light Travel Station30  Station9     257820   257880
# Train_11 Light Travel Station30  Station9     257820   257880
#  Train_7 Light Travel Station30  Station9     257820   257880
#  Train_2   Train Trip  Station2  Station3     259260   262800
#  Train_7   Train Trip  Station9 Station43     259620   260100
#  Train_6   Train Trip  Station9 Station43     259620   260100
# Train_11   Train Trip  Station9 Station43     259620   260100
# Train_10   Train Trip  Station4  Station5     259680   263460
#  Train_7 Light Travel Station43  Station6     260100   260700
#  Train_6 Light Travel Station43 Station43     260100   260100
# Train_11 Light Travel Station43  Station1     260100   261360
#  Train_7   Train Trip  Station6  Station7     262680   266100
#  Train_2 Light Travel  Station3  Station3     262800   262800
# Train_10 Light Travel  Station5  Station5     263460   263460
#  Train_7 Light Travel  Station7  Station7     266100   266100
#  Train_2   Train Trip  Station3  Station2     266400   269880
#  Train_9   Train Trip  Station6  Station8     267300   267720
# Train_11   Train Trip  Station1  Station6     267600   268560
# Train_10   Train Trip  Station5  Station4     267600   270060
#  Train_9 Light Travel  Station8 Station13     267720   268200
#  Train_9   Train Trip Station13 Station23     268260   280320
# Train_11 Light Travel  Station6 Station13     268560   269340
#  Train_2 Light Travel  Station2  Station2     269880   269880
# Train_10 Light Travel  Station4  Station9     270060   270780
# Train_10   Train Trip  Station9  Station6     272700   273840
#  Train_7   Train Trip  Station7  Station6     272700   274920
# Train_10 Light Travel  Station6  Station6     273840   273840
#  Train_7 Light Travel  Station6 Station33     274920   275460
# Train_11   Train Trip Station13 Station21     276060   281760
#  Train_9 Light Travel Station23 Station23     280320   280320
# Train_11 Light Travel Station21 Station21     281760   281760
# Train_11   Train Trip Station21 Station22     286920   289140
#  Train_6   Train Trip Station43 Station30     287400   287760
#  Train_6 Light Travel Station30 Station30     287760   287760
#  Train_8   Train Trip Station15 Station30     288240   290700
#  Train_3   Train Trip Station15 Station30     288240   290700
# Train_11 Light Travel Station22 Station22     289140   289140
# Train_11   Train Trip Station22 Station21     290700   292980
#  Train_8 Light Travel Station30 Station30     290700   290700
#  Train_3 Light Travel Station30  Station9     290700   290760
#  Train_3   Train Trip  Station9 Station43     291000   291480
#  Train_3 Light Travel Station43 Station44     291480   292200
# Train_11 Light Travel Station21 Station21     292980   292980
#  Train_6   Train Trip Station30 Station15     295680   297840
#  Train_8   Train Trip Station30 Station15     295680   297840
#  Train_6 Light Travel Station15 Station44     297840   299340
#  Train_8 Light Travel Station15 Station15     297840   297840
#  Train_7   Train Trip Station33 Station30     324420   324900
#  Train_7 Light Travel Station30  Station9     324900   324960
#  Train_7   Train Trip  Station9 Station43     328260   328740
#  Train_7 Light Travel Station43 Station44     328740   329460
#  Train_2   Train Trip  Station2  Station6     332760   336780
#  Train_4   Train Trip Station31  Station6     335640   336780
#  Train_2 Light Travel  Station6  Station6     336780   336780
#  Train_4 Light Travel  Station6  Station6     336780   336780
#  Train_4   Train Trip  Station6 Station31     339000   340140
#  Train_2   Train Trip  Station6  Station2     339000   343200
#  Train_4 Light Travel Station31 Station31     340140   340140
#  Train_2 Light Travel  Station2  Station2     343200   343200
# Train_10   Train Trip  Station6  Station8     353700   354120
# Train_10 Light Travel  Station8  Station9     354120   354420
# Train_10   Train Trip  Station9  Station6     359100   360240
# Train_10 Light Travel  Station6  Station6     360240   360240
#  Train_6   Train Trip Station44 Station45     415500   416820
#  Train_7   Train Trip Station44 Station45     415500   416820
#  Train_3   Train Trip Station44 Station45     415500   416820
#  Train_6 Light Travel Station45 Station45     416820   416820
#  Train_7 Light Travel Station45 Station45     416820   416820
#  Train_3 Light Travel Station45 Station45     416820   416820
#  Train_3   Train Trip Station45 Station44     418380   419160
#  Train_6   Train Trip Station45 Station44     418380   419160
#  Train_7   Train Trip Station45 Station44     418380   419160
#  Train_3 Light Travel Station44 Station13     419160   419520
#  Train_6 Light Travel Station44 Station13     419160   419520
#  Train_7 Light Travel Station44  Station6     419160   420300
#  Train_7   Train Trip  Station6  Station1     435600   436440
#  Train_7 Light Travel  Station1  Station6     436440   437460
#  Train_6   Train Trip Station13 Station11     445560   448560
#  Train_6 Light Travel Station11 Station17     448560   451200
#  Train_5   Train Trip Station42 Station41     449520   449760
#  Train_5 Light Travel Station41 Station11     449760   450540
#  Train_7   Train Trip  Station6  Station1     454980   455820
# Train_10   Train Trip  Station6 Station10     455220   455820
#  Train_5   Train Trip Station11 Station12     455340   456240
#  Train_3   Train Trip Station13 Station14     455700   459000
#  Train_7 Light Travel  Station1  Station1     455820   455820
# Train_10 Light Travel Station10 Station10     455820   455820
#  Train_5 Light Travel Station12 Station12     456240   456240
#  Train_5   Train Trip Station12 Station12     457800   462060
#  Train_8   Train Trip Station15 Station16     458520   459420
#  Train_6   Train Trip Station17 Station18     458640   461820
#  Train_3 Light Travel Station14 Station14     459000   459000
#  Train_8 Light Travel Station16 Station16     459420   459420
# Train_10   Train Trip Station10 Station10     460980   462900
#  Train_8   Train Trip Station16 Station19     461160   462540
#  Train_2   Train Trip  Station2 Station20     461400   465420
#  Train_6 Light Travel Station18 Station18     461820   461820
#  Train_5 Light Travel Station12 Station12     462060   462060
# Train_11   Train Trip Station21 Station22     462360   464580
#  Train_8 Light Travel Station19 Station15     462540   464040
#  Train_9   Train Trip Station23 Station24     462720   464580
# Train_10 Light Travel Station10 Station29     462900   463800
#  Train_5   Train Trip Station12 Station11     463020   463920
#  Train_5 Light Travel Station11 Station11     463920   463920
#  Train_6   Train Trip Station18 Station17     464580   466440
# Train_11 Light Travel Station22 Station22     464580   464580
#  Train_9 Light Travel Station24 Station24     464580   464580
#  Train_3   Train Trip Station14 Station14     465180   466920
#  Train_2 Light Travel Station20 Station20     465420   465420
#  Train_8   Train Trip Station15 Station25     466020   466920
#  Train_7   Train Trip  Station1  Station6     466320   467280
#  Train_6 Light Travel Station17 Station17     466440   466440
#  Train_5   Train Trip Station11 Station26     466800   469980
#  Train_3 Light Travel Station14 Station14     466920   466920
#  Train_8 Light Travel Station25 Station25     466920   466920
#  Train_7 Light Travel  Station6  Station6     467280   467280
#  Train_6   Train Trip Station17 Station27     467580   468240
#  Train_6 Light Travel Station27 Station27     468240   468240
# Train_10   Train Trip Station29 Station39     468300   468840
#  Train_3   Train Trip Station14 Station14     468780   470520
#  Train_9   Train Trip Station24 Station23     468780   473640
# Train_10 Light Travel Station39 Station39     468840   468840
# Train_11   Train Trip Station22 Station21     468900   471180
#  Train_2   Train Trip Station20  Station2     469200   473940
#  Train_7   Train Trip  Station6 Station28     469320   470040
#  Train_8   Train Trip Station25 Station15     469860   470460
#  Train_5 Light Travel Station26 Station26     469980   469980
#  Train_7 Light Travel Station28  Station6     470040   470340
#  Train_8 Light Travel Station15 Station19     470460   471960
#  Train_4   Train Trip Station31 Station32     470520   472380
#  Train_3 Light Travel Station14 Station14     470520   470520
# Train_11 Light Travel Station21 Station21     471180   471180
#  Train_7   Train Trip  Station6 Station10     471960   472560
#  Train_5   Train Trip Station26 Station11     472200   475020
#  Train_3   Train Trip Station14 Station33     472260   479160
#  Train_4 Light Travel Station32 Station32     472380   472380
#  Train_7 Light Travel Station10 Station28     472560   473160
#  Train_6   Train Trip Station27 Station17     473040   473940
#  Train_7   Train Trip Station28  Station6     473160   473760
#  Train_9 Light Travel Station23 Station23     473640   473640
#  Train_7 Light Travel  Station6 Station10     473760   474060
#  Train_2 Light Travel  Station2  Station2     473940   473940
#  Train_6 Light Travel Station17 Station17     473940   473940
# Train_10   Train Trip Station39 Station29     474300   474780
# Train_10 Light Travel Station29 Station29     474780   474780
#  Train_5 Light Travel Station11 Station11     475020   475020
#  Train_7   Train Trip Station10  Station6     475500   476100
#  Train_7 Light Travel  Station6  Station6     476100   476100
#  Train_5   Train Trip Station11 Station12     477360   478260
#  Train_7   Train Trip  Station6  Station1     477600   478440
#  Train_4   Train Trip Station32 Station31     478200   481860
#  Train_5 Light Travel Station12 Station12     478260   478260
#  Train_7 Light Travel  Station1  Station1     478440   478440
#  Train_5   Train Trip Station12 Station12     478980   482640
#  Train_3 Light Travel Station33  Station4     479160   480420
# Train_10   Train Trip Station29 Station35     480000   482220
# Train_11   Train Trip Station21 Station40     480900   481380
#  Train_9   Train Trip Station23 Station36     480960   482640
# Train_11 Light Travel Station40 Station40     481380   481380
#  Train_4 Light Travel Station31 Station10     481860   482700
# Train_10 Light Travel Station35 Station35     482220   482220
# Train_10   Train Trip Station35 Station29     482400   484860
#  Train_5 Light Travel Station12 Station12     482640   482640
#  Train_9 Light Travel Station36 Station36     482640   482640
# Train_11   Train Trip Station40 Station21     483600   484740
#  Train_2   Train Trip  Station2 Station37     483720   484560
#  Train_5   Train Trip Station12 Station11     483780   484680
#  Train_4   Train Trip Station10 Station10     484020   488040
#  Train_2 Light Travel Station37 Station37     484560   484560
#  Train_5 Light Travel Station11 Station11     484680   484680
# Train_11 Light Travel Station21 Station21     484740   484740
# Train_10 Light Travel Station29 Station29     484860   484860
# Train_11   Train Trip Station21 Station22     485400   487620
#  Train_2   Train Trip Station37  Station2     485520   486180
#  Train_2 Light Travel  Station2  Station2     486180   486180
#  Train_8   Train Trip Station19 Station16     487320   488160
#  Train_9   Train Trip Station36 Station23     487380   492180
# Train_11 Light Travel Station22 Station22     487620   487620
#  Train_4 Light Travel Station10 Station10     488040   488040
#  Train_8 Light Travel Station16 Station16     488160   488160
#  Train_5   Train Trip Station11 Station12     489000   489900
#  Train_5 Light Travel Station12 Station12     489900   489900
#  Train_7   Train Trip  Station1  Station6     490500   491460
#  Train_5   Train Trip Station12 Station12     490800   494160
#  Train_7 Light Travel  Station6  Station1     491460   492480
#  Train_9 Light Travel Station23 Station23     492180   492180
#  Train_4   Train Trip Station10  Station6     492420   493140
#  Train_4 Light Travel  Station6  Station6     493140   493140
# Train_11   Train Trip Station22 Station21     493560   495840
#  Train_5 Light Travel Station12 Station12     494160   494160
#  Train_8   Train Trip Station16 Station15     494340   495240
#  Train_5   Train Trip Station12 Station11     494580   495480
#  Train_4   Train Trip  Station6  Station1     494700   495540
#  Train_8 Light Travel Station15 Station15     495240   495240
#  Train_5 Light Travel Station11 Station11     495480   495480
#  Train_4 Light Travel  Station1  Station1     495540   495540
# Train_11 Light Travel Station21 Station21     495840   495840
#  Train_4   Train Trip  Station1  Station6     503100   504060
#  Train_4 Light Travel  Station6  Station6     504060   504060
#  Train_2   Train Trip  Station2  Station3     518460   522000
#  Train_3   Train Trip  Station4  Station5     518880   522660
#  Train_4   Train Trip  Station6  Station7     521880   525300
#  Train_2 Light Travel  Station3  Station3     522000   522000
#  Train_3 Light Travel  Station5  Station5     522660   522660
#  Train_7   Train Trip  Station1  Station0     522840   604800
#  Train_1 Light Travel  Station1  Station1     522840   522840
#  Train_4 Light Travel  Station7  Station7     525300   525300
#  Train_2   Train Trip  Station3  Station2     525600   529080
#  Train_1   Train Trip  Station1  Station6     526800   527760
#  Train_3   Train Trip  Station5  Station4     526800   529260
#  Train_1 Light Travel  Station6  Station6     527760   527760
#  Train_2 Light Travel  Station2  Station2     529080   529080
#  Train_3 Light Travel  Station4 Station13     529260   530760
#  Train_4   Train Trip  Station7  Station6     531900   534120
#  Train_4 Light Travel  Station6  Station6     534120   534120
#  Train_1   Train Trip  Station6  Station1     541380   542220
#  Train_4   Train Trip  Station6 Station10     541620   542220
#  Train_5   Train Trip Station11 Station12     541740   542640
#  Train_3   Train Trip Station13 Station14     542100   545400
#  Train_1 Light Travel  Station1  Station1     542220   542220
#  Train_4 Light Travel Station10 Station10     542220   542220
#  Train_5 Light Travel Station12 Station12     542640   542640
#  Train_5   Train Trip Station12 Station12     544200   548460
#  Train_8   Train Trip Station15 Station16     544920   545820
#  Train_6   Train Trip Station17 Station18     545040   548220
#  Train_3 Light Travel Station14 Station14     545400   545400
#  Train_8 Light Travel Station16 Station16     545820   545820
#  Train_4   Train Trip Station10 Station10     547380   549300
#  Train_8   Train Trip Station16 Station19     547560   548940
#  Train_2   Train Trip  Station2 Station20     547800   551820
#  Train_6 Light Travel Station18 Station18     548220   548220
#  Train_5 Light Travel Station12 Station12     548460   548460
# Train_11   Train Trip Station21 Station22     548760   550980
#  Train_8 Light Travel Station19 Station15     548940   550440
#  Train_9   Train Trip Station23 Station24     549120   550980
#  Train_4 Light Travel Station10 Station31     549300   550140
#  Train_5   Train Trip Station12 Station11     549420   550320
#  Train_5 Light Travel Station11 Station11     550320   550320
#  Train_6   Train Trip Station18 Station17     550980   552840
# Train_11 Light Travel Station22 Station22     550980   550980
#  Train_9 Light Travel Station24 Station24     550980   550980
#  Train_3   Train Trip Station14 Station14     551580   553320
#  Train_2 Light Travel Station20 Station20     551820   551820
#  Train_8   Train Trip Station15 Station25     552420   553320
#  Train_1   Train Trip  Station1  Station6     552720   553680
#  Train_6 Light Travel Station17 Station17     552840   552840
#  Train_5   Train Trip Station11 Station26     553200   556380
#  Train_3 Light Travel Station14 Station14     553320   553320
#  Train_8 Light Travel Station25 Station25     553320   553320
#  Train_1 Light Travel  Station6  Station6     553680   553680
#  Train_6   Train Trip Station17 Station27     553980   554640
#  Train_6 Light Travel Station27 Station27     554640   554640
# Train_10   Train Trip Station29 Station38     554700   557400
#  Train_3   Train Trip Station14 Station14     555180   556920
#  Train_9   Train Trip Station24 Station23     555180   560040
# Train_11   Train Trip Station22 Station21     555300   557580
#  Train_2   Train Trip Station20  Station2     555600   560340
#  Train_1   Train Trip  Station6 Station28     555720   556440
#  Train_8   Train Trip Station25 Station15     556260   556860
#  Train_5 Light Travel Station26 Station26     556380   556380
#  Train_1 Light Travel Station28  Station6     556440   556740
#  Train_8 Light Travel Station15 Station19     556860   558360
#  Train_4   Train Trip Station31 Station32     556920   558780
#  Train_3 Light Travel Station14 Station14     556920   556920
# Train_10 Light Travel Station38 Station38     557400   557400
# Train_11 Light Travel Station21 Station21     557580   557580
#  Train_1   Train Trip  Station6 Station10     558360   558960
#  Train_5   Train Trip Station26 Station11     558600   561420
#  Train_3   Train Trip Station14 Station33     558660   565560
#  Train_4 Light Travel Station32 Station32     558780   558780
# Train_10   Train Trip Station38 Station29     558960   561720
#  Train_1 Light Travel Station10 Station28     558960   559560
#  Train_6   Train Trip Station27 Station17     559440   560340
#  Train_1   Train Trip Station28  Station6     559560   560160
#  Train_9 Light Travel Station23 Station23     560040   560040
#  Train_1 Light Travel  Station6 Station10     560160   560460
#  Train_2 Light Travel  Station2  Station2     560340   560340
#  Train_5 Light Travel Station11 Station11     561420   561420
# Train_10 Light Travel Station29 Station29     561720   561720
#  Train_1   Train Trip Station10  Station6     561900   562500
#  Train_1 Light Travel  Station6  Station6     562500   562500
#  Train_5   Train Trip Station11 Station12     563760   564660
#  Train_1   Train Trip  Station6  Station1     564000   564840
#  Train_4   Train Trip Station32 Station31     564600   568260
#  Train_5 Light Travel Station12 Station12     564660   564660
#  Train_1 Light Travel  Station1  Station1     564840   564840
#  Train_5   Train Trip Station12 Station12     565380   569040
# Train_10   Train Trip Station29 Station39     567000   567540
# Train_11   Train Trip Station21 Station40     567300   567780
#  Train_9   Train Trip Station23 Station36     567360   569040
# Train_10 Light Travel Station39 Station39     567540   567540
# Train_11 Light Travel Station40 Station40     567780   567780
#  Train_4 Light Travel Station31 Station10     568260   569100
#  Train_5 Light Travel Station12 Station12     569040   569040
#  Train_9 Light Travel Station36 Station36     569040   569040
# Train_11   Train Trip Station40 Station21     570000   571140
#  Train_2   Train Trip  Station2 Station37     570120   570960
#  Train_5   Train Trip Station12 Station11     570180   571080
#  Train_4   Train Trip Station10 Station10     570420   574440
# Train_10   Train Trip Station39 Station29     570720   571260
#  Train_2 Light Travel Station37 Station37     570960   570960
#  Train_5 Light Travel Station11 Station11     571080   571080
# Train_11 Light Travel Station21 Station21     571140   571140
# Train_11   Train Trip Station21 Station22     571800   574020
#  Train_2   Train Trip Station37  Station2     571920   572580
#  Train_8   Train Trip Station19 Station16     573720   574560
#  Train_9   Train Trip Station36 Station23     573780   578580
# Train_11 Light Travel Station22 Station22     574020   574020
#  Train_4 Light Travel Station10 Station10     574440   574440
#  Train_8 Light Travel Station16 Station16     574560   574560
#  Train_5   Train Trip Station11 Station12     575400   576300
#  Train_5 Light Travel Station12 Station12     576300   576300
#  Train_1   Train Trip  Station1  Station6     576900   577860
#  Train_5   Train Trip Station12 Station12     577200   580560
#  Train_1 Light Travel  Station6  Station6     577860   577860
#  Train_4   Train Trip Station10  Station6     578820   579540
#  Train_4 Light Travel  Station6  Station6     579540   579540
# Train_11   Train Trip Station22 Station21     579960   582240
#  Train_5 Light Travel Station12 Station12     580560   580560
#  Train_8   Train Trip Station16 Station15     580740   581640
#  Train_5   Train Trip Station12 Station11     580980   581880
#  Train_1   Train Trip  Station6  Station1     581100   581940
#  Train_1 Light Travel  Station1  Station1     581940   581940
#  Train_1   Train Trip  Station1  Station6     589500   590460
#
#  Cost Breakdown:
# Total Cost           : 11093.73
# Traction Unit Cost   : 11000.00
# Light Travel Cost    : 93.73
# Number of Vehicles   : 11

# %% [markdown]
# **Convert List_A to a CSV File**

# %%
import pandas as pd

# Convert full_schedule (a list of dicts) into a DataFrame
df_schedule = pd.DataFrame(full_schedule)

# Save to CSV
df_schedule.to_csv("full_schedule_Instance_D.csv", index=False)

# For Google Colab: provide download link
from google.colab import files
files.download("full_schedule_Instance_D.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.lines as mlines
import time

# Start timer
start_time = time.time()

# Load schedule
df_schedule = pd.read_csv("full_schedule_Instance_D.csv")

# Step 1: Map stations to Y-axis positions
stations = sorted(set(df_schedule["From"]).union(set(df_schedule["To"])))
station_to_y = {station: i for i, station in enumerate(stations)}

# Step 2: Predefine train IDs
train_ids = [f"Train_{i}" for i in range(1, 12)]

# Step 3: Assign each train a unique color
cmap = cm.get_cmap('tab20', len(train_ids))
train_to_color = {train: cmap(i) for i, train in enumerate(train_ids)}

# Step 4: Initialize plot and track nodes/edges
plt.figure(figsize=(20, 12))
nodes = set()
edges = []

# Step 5: Plot edges and store nodes/edges
for _, row in df_schedule.iterrows():
    from_station = row["From"]
    to_station = row["To"]
    start_time_trip = row["StartTime"]
    end_time_trip = row["EndTime"]
    train = row["Train"]
    edge_type = row["Type"]

    u = (start_time_trip, station_to_y[from_station])
    v = (end_time_trip, station_to_y[to_station])

    nodes.update([u, v])
    edges.append((u, v))

    color = train_to_color.get(train, 'black')
    linestyle = '-' if edge_type == "Train Trip" else '--'
    plt.plot([u[0], v[0]], [u[1], v[1]], color=color, linestyle=linestyle, linewidth=1)

# Step 6: Plot nodes
for t, y in nodes:
    plt.scatter(t, y, color='black', s=10)
    plt.text(t, y + 0.1, f'{t}', fontsize=5, ha='center', color='darkred')

# Step 7: Axis formatting
plt.yticks(list(station_to_y.values()), list(station_to_y.keys()))
plt.xlabel("Time (seconds)")
plt.ylabel("Stations")
plt.title("Space-Time Network_Instance_D")
plt.grid(True, linestyle='--', linewidth=0.5)

# Step 8: Legend
legend_lines = [
    mlines.Line2D([], [], color=train_to_color[train], linewidth=2, label=train)
    for train in train_ids
]
plt.legend(handles=legend_lines, title="Trains", loc='upper center', bbox_to_anchor=(0.5, -0.08),
           ncol=6, fontsize=8, title_fontsize=10, frameon=True)

plt.tight_layout()
plt.show()

# End timer
end_time = time.time()

# Step 9: Print summary
print("\n===== Network Summary =====")
print(f"Total Nodes      : {len(nodes)}")
print(f"Total Edges      : {len(edges)}")
print(f"Execution Time   : {round(end_time - start_time, 3)} seconds")
# Out:
# /tmp/ipython-input-11-405131375.py:21: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(train_ids))
# ===== Network Summary =====
# Total Nodes      : 805
# Total Edges      : 754
# Execution Time   : 16.585 seconds

# %% [markdown]
# **Robustness Calculation**

# %%
# STEP 01: Identify tight connections
# Define threshold (e.g., 300 seconds = 5 minutes)
TIGHT_THRESHOLD = 300  # seconds

# Extract only productive train trips for each train
train_trips = df_schedule[df_schedule["Type"] == "Train Trip"].copy()
train_trips.sort_values(by=["Train", "StartTime"], inplace=True)

# Find consecutive trips by the same train
tight_connections = []
for train_id, group in train_trips.groupby("Train"):
    trips = group.sort_values("StartTime").reset_index(drop=True)
    for i in range(len(trips) - 1):
        current_end = trips.loc[i, "EndTime"]
        next_start = trips.loc[i + 1, "StartTime"]
        connection_time = next_start - current_end
        if connection_time <= TIGHT_THRESHOLD:
            tight_connections.append({
                "Train": train_id,
                "FromTripEnd": current_end,
                "ToTripStart": next_start,
                "ConnectionTime": connection_time,
                "FromStation": trips.loc[i, "To"],
                "ToStation": trips.loc[i + 1, "From"]
            })

# Display the tight connections
df_tight = pd.DataFrame(tight_connections)
print(f"\n Tight Connections (<= {TIGHT_THRESHOLD} seconds): {len(df_tight)} found")
if not df_tight.empty:
    print(df_tight.to_string(index=False))
else:
    print(" No tight connections found.")
# Out:
#  Tight Connections (<= 300 seconds): 4 found
#    Train  FromTripEnd  ToTripStart  ConnectionTime FromStation ToStation
# Train_10       482220       482400             180   Station35 Station35
#  Train_3        50220        50400             180   Station35 Station35
#  Train_3       290700       291000             300   Station30  Station9
#  Train_5       223020       223200             180   Station35 Station35

# %%
import pandas as pd

# Step 2: Set threshold for tight connections
TIGHT_THRESHOLD = 300  # seconds
BUFFER_TIME = 600      # seconds

# Step 3: Detect tight connections
train_trips = df_schedule[df_schedule["Type"] == "Train Trip"].copy()
train_trips.sort_values(by=["Train", "StartTime"], inplace=True)

tight_connections = []
for train_id, group in train_trips.groupby("Train"):
    trips = group.sort_values("StartTime").reset_index(drop=True)
    for i in range(len(trips) - 1):
        current_end = trips.loc[i, "EndTime"]
        next_start = trips.loc[i + 1, "StartTime"]
        connection_time = next_start - current_end
        if connection_time <= TIGHT_THRESHOLD:
            tight_connections.append({
                "Train": train_id,
                "FromTripEnd": current_end,
                "ToTripStart": next_start,
                "ConnectionTime": connection_time,
                "FromStation": trips.loc[i, "To"],
                "ToStation": trips.loc[i + 1, "From"]
            })

df_tight = pd.DataFrame(tight_connections)

# Step 4: Apply buffer by shifting trips forward
df_buffered = df_schedule.copy()
df_buffered.sort_values(by=["Train", "StartTime"], inplace=True)

for _, row in df_tight.iterrows():
    train_id = row["Train"]
    to_start = row["ToTripStart"]
    affected = df_buffered[
        (df_buffered["Train"] == train_id) &
        (df_buffered["StartTime"] >= to_start)
    ].index
    df_buffered.loc[affected, "StartTime"] += BUFFER_TIME
    df_buffered.loc[affected, "EndTime"] += BUFFER_TIME

# Step 5: Recalculate cost
C_TU = 1000
C_Light = 0.10
traction_units = df_buffered["Train"].nunique()
traction_cost = traction_units * C_TU

light_travel_cost = 0
for _, row in df_buffered[df_buffered["Type"] == "Light Travel"].iterrows():
    key = f"{row['From']},{row['To']}"
    if key in empty_runs:
        dist = empty_runs[key]["Distance"]
        light_travel_cost += dist * C_Light

total_cost = traction_cost + light_travel_cost

# Step 6: Calculate nodes and edges
nodes = set()
edges = 0
for _, row in df_buffered.iterrows():
    u = (row["StartTime"], row["From"])
    v = (row["EndTime"], row["To"])
    nodes.update([u, v])
    edges += 1

# Step 7: Save result
buffered_schedule_path = "schedule_buffered_600s.csv"
df_buffered.to_csv(buffered_schedule_path, index=False)

# Step 8: Summary
print("\n===== ⏱️ Buffered Plan Summary (600s for tight links) =====")
print(f" Tight Connections Found   : {len(df_tight)}")
print(f" Buffer Applied per Link   : {BUFFER_TIME} seconds")
print(f" Trains (Vehicles) Used    : {traction_units}")
print(f" Light Travel Cost         : {round(light_travel_cost, 2)}")
print(f" Total Cost                : {round(total_cost, 2)}")
print(f" Total Edges               : {edges}")
print(f" Total Unique Nodes        : {len(nodes)}")
print(f" Saved to File             : {buffered_schedule_path}")
# Out:
# ===== ⏱️ Buffered Plan Summary (600s for tight links) =====
#  Tight Connections Found   : 4
#  Buffer Applied per Link   : 600 seconds
#  Trains (Vehicles) Used    : 11
#  Light Travel Cost         : 93.73
#  Total Cost                : 11093.73
#  Total Edges               : 754
#  Total Unique Nodes        : 813
#  Saved to File             : schedule_buffered_600s.csv

# %%
import pandas as pd

# Load the original schedule before buffering
df_schedule = pd.read_csv("full_schedule_Instance_D.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.lines as mlines
import json
import re

# Load JSON data
with open("Instance_D.json") as f:
    data = json.load(f)

# Extract empty runs
empty_runs = data["EmptyRunData"]

# === CONFIGURATION ===
TIGHT_THRESHOLD = 300  # seconds
BUFFER_TIME = 600      # buffer to add after tight connections
C_TU = 1000            # traction unit cost
C_Light = 0.10         # light travel cost per km

# === STEP 1: Detect Tight Connections ===
train_trips = df_schedule[df_schedule["Type"] == "Train Trip"].copy()
train_trips.sort_values(by=["Train", "StartTime"], inplace=True)

tight_connections = []
for train_id, group in train_trips.groupby("Train"):
    trips = group.sort_values("StartTime").reset_index(drop=True)
    for i in range(len(trips) - 1):
        current_end = trips.loc[i, "EndTime"]
        next_start = trips.loc[i + 1, "StartTime"]
        connection_time = next_start - current_end
        if connection_time <= TIGHT_THRESHOLD:
            tight_connections.append({
                "Train": train_id,
                "FromTripEnd": current_end,
                "ToTripStart": next_start,
                "ConnectionTime": connection_time,
                "FromStation": trips.loc[i, "To"],
                "ToStation": trips.loc[i + 1, "From"]
            })

df_tight = pd.DataFrame(tight_connections)

# === STEP 2: Apply Buffer ===
df_buffered = df_schedule.copy()
df_buffered.sort_values(by=["Train", "StartTime"], inplace=True)

for _, row in df_tight.iterrows():
    train_id = row["Train"]
    to_start = row["ToTripStart"]
    affected = df_buffered[
        (df_buffered["Train"] == train_id) &
        (df_buffered["StartTime"] >= to_start)
    ].index
    df_buffered.loc[affected, "StartTime"] += BUFFER_TIME
    df_buffered.loc[affected, "EndTime"] += BUFFER_TIME

# === STEP 3: Recalculate Cost ===
traction_units = df_buffered["Train"].nunique()
traction_cost = traction_units * C_TU

light_travel_cost = 0
for _, row in df_buffered[df_buffered["Type"] == "Light Travel"].iterrows():
    key = f"{row['From']},{row['To']}"
    if key in empty_runs:
        dist = empty_runs[key]["Distance"]
        light_travel_cost += dist * C_Light

total_cost = traction_cost + light_travel_cost

# === STEP 4: Plot with Buffer Annotations ===
stations = sorted(set(df_buffered["From"]).union(set(df_buffered["To"])))
station_to_y = {station: i for i, station in enumerate(stations)}

train_ids = sorted(df_buffered["Train"].unique())
cmap = cm.get_cmap('tab20', len(train_ids))
train_to_color = {train: cmap(i) for i, train in enumerate(train_ids)}

plt.figure(figsize=(20, 12))
nodes = set()

# Plot train arcs
for _, row in df_buffered.iterrows():
    from_station = row["From"]
    to_station = row["To"]
    start = row["StartTime"]
    end = row["EndTime"]
    train = row["Train"]
    typ = row["Type"]

    u = (start, station_to_y[from_station])
    v = (end, station_to_y[to_station])
    color = train_to_color[train]
    linestyle = '-' if typ == "Train Trip" else '--'

    plt.plot([u[0], v[0]], [u[1], v[1]], color=color, linestyle=linestyle, linewidth=1)
    nodes.update([u, v])

# Annotate buffer arcs in red
for _, row in df_tight.iterrows():
    train_id = row["Train"]
    station = row["ToStation"]
    y = station_to_y[station]
    from_time = row["ToTripStart"]
    to_time = from_time + BUFFER_TIME
    plt.plot([from_time, to_time], [y, y], color='red', linestyle=':', linewidth=1)
    plt.text(to_time + 10, y + 0.15, '+600s', fontsize=6, color='red')

# Plot nodes
for t, y in nodes:
    plt.scatter(t, y, color='black', s=10)

# Axis settings
plt.yticks(list(station_to_y.values()), list(station_to_y.keys()))
plt.xlabel("Time (seconds)")
plt.ylabel("Stations")
plt.title("Buffered Plan with 600s Delay Buffers on Tight Connections")
plt.grid(True, linestyle='--', linewidth=0.5)

# Legend
legend_lines = [
    mlines.Line2D([], [], color=train_to_color[train], linewidth=2, label=train)
    for train in train_ids[:12]
]
legend_lines.append(mlines.Line2D([], [], color='red', linestyle=':', linewidth=1, label='Buffer +600s'))
plt.legend(handles=legend_lines, title="Trains", loc='upper center', bbox_to_anchor=(0.5, -0.08),
           ncol=6, fontsize=8, title_fontsize=10, frameon=True)

plt.tight_layout()
plt.show()

# === STEP 5: Summary ===
print("\n===== ⏱️ Buffered Plan Summary (600s for tight links) =====")
print(f" Tight Connections Found   : {len(df_tight)}")
print(f" Buffer Applied per Link   : {BUFFER_TIME} seconds")
print(f" Trains (Vehicles) Used    : {traction_units}")
print(f" Light Travel Cost         : {round(light_travel_cost, 2)}")
print(f" Total Cost                : {round(total_cost, 2)}")
print(f" Total Edges               : {len(df_buffered)}")
print(f" Total Unique Nodes        : {len(nodes)}")
# Out:
# /tmp/ipython-input-9-1901469668.py:76: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', len(train_ids))
# ===== ⏱️ Buffered Plan Summary (600s for tight links) =====
#  Tight Connections Found   : 4
#  Buffer Applied per Link   : 600 seconds
#  Trains (Vehicles) Used    : 11
#  Light Travel Cost         : 93.73
#  Total Cost                : 11093.73
#  Total Edges               : 754
#  Total Unique Nodes        : 813

# %%
from collections import defaultdict
import pandas as pd

# Configuration
TIGHT_THRESHOLD = 300  # seconds

# Initialize counter
tight_counts = defaultdict(int)
total_counts = defaultdict(int)

# Detect tight and total connections per station
train_trips = df_schedule[df_schedule["Type"] == "Train Trip"].copy()
train_trips.sort_values(by=["Train", "StartTime"], inplace=True)

for train_id, group in train_trips.groupby("Train"):
    trips = group.reset_index(drop=True)
    for i in range(len(trips) - 1):
        end_time = trips.loc[i, "EndTime"]
        next_start = trips.loc[i + 1, "StartTime"]
        conn_time = next_start - end_time
        station = trips.loc[i + 1, "From"]

        total_counts[station] += 1
        if conn_time <= TIGHT_THRESHOLD:
            tight_counts[station] += 1

# Create summary DataFrame
df_station_tightness = pd.DataFrame({
    "TotalConnections": pd.Series(total_counts),
    "TightConnections": pd.Series(tight_counts)
})
df_station_tightness["TightRatio"] = df_station_tightness["TightConnections"] / df_station_tightness["TotalConnections"]
df_station_tightness = df_station_tightness.fillna(0).sort_values(by="TightRatio", ascending=False)

# Show top 10 stations
print("\n===== 🔍 Stations with Highest Tight Connection Ratios =====")
print(df_station_tightness.head(10).round(2))
# Out:
# ===== 🔍 Stations with Highest Tight Connection Ratios =====
#            TotalConnections  TightConnections  TightRatio
# Station35                 3               3.0        1.00
# Station9                  9               1.0        0.11
# Station1                 23               0.0        0.00
# Station10                20               0.0        0.00
# Station13                 9               0.0        0.00
# Station14                15               0.0        0.00
# Station15                11               0.0        0.00
# Station16                10               0.0        0.00
# Station17                10               0.0        0.00
# Station18                 5               0.0        0.00
